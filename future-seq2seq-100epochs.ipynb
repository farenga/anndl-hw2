# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Pre-processing

X_max = X.max(axis=0)
X_min = X.min(axis=0)

X_mean = X.mean(axis=0)
X_std = X.std(axis=0)

X_scaled = (X-X_min)/(X_max-X_min)

# %%
for i in range(X.shape[-1]):
    plt.figure(figsize=(15,3))
    plt.plot(X[:,i],color='steelblue')
    plt.plot(X_scaled[:,i],color='limegreen',alpha=.5)
    plt.axhline(y=X_mean[i],color='darkorange',linewidth=2)
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
sequence_length = 400
stride = 1
X_train, y_train = extract_sequences(X_scaled,sequence_length,stride)
input_shape = X_train.shape[1:]

# %%
input_shape = X_train.shape[1:]
epochs = 100
batch_size = 256

# %%
def build_lstm_seq2seq(input_shape,n_units):

    input_layer = tfkl.Input(shape=input_shape, name='Input')
    
    x,h,c = tfkl.LSTM(units=n_units, return_sequences=False,return_state=True)(input_layer)
    x = tfkl.RepeatVector(1)(x)
    x = tfkl.LSTM(units=n_units, return_sequences=True,return_state=False)(x,initial_state=[h,c])
    x = tfkl.Flatten()(x)
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
lstm_units = 512
model = build_lstm_seq2seq(input_shape,lstm_units)
model.summary()
# Out:
# 2022-01-13 13:53:18.577877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:18.733232: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:18.734373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:18.736101: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-13 13:53:18.737441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:18.738526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:18.739599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:21.219020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:21.220215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:21.221266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 13:53:21.222288: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 400, 7)]     0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 512), (None, 1064960     Input[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 1, 512)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 1, 512)       2099200     repeat_vector[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            3591        flatten[0][0]
# ==================================================================================================
# Total params: 3,167,751
# Trainable params: 3,167,751
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

history = model.fit(
    X_train,
    y_train,
    validation_split=.1,
    epochs = epochs,
    batch_size = batch_size,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# 2022-01-13 13:53:24.161999: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-01-13 13:53:28.544498: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 240/240 [==============================] - 46s 169ms/step - loss: 0.0052 - mae: 0.0384 - val_loss: 0.0012 - val_mae: 0.0231
# Epoch 2/100
# 240/240 [==============================] - 39s 165ms/step - loss: 0.0011 - mae: 0.0218 - val_loss: 0.0011 - val_mae: 0.0226
# Epoch 3/100
# 240/240 [==============================] - 40s 165ms/step - loss: 9.6471e-04 - mae: 0.0203 - val_loss: 9.4026e-04 - val_mae: 0.0198
# Epoch 4/100
# 240/240 [==============================] - 40s 165ms/step - loss: 9.1102e-04 - mae: 0.0195 - val_loss: 8.8527e-04 - val_mae: 0.0190
# Epoch 5/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.8794e-04 - mae: 0.0192 - val_loss: 8.7925e-04 - val_mae: 0.0189
# Epoch 6/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.6286e-04 - mae: 0.0188 - val_loss: 8.8529e-04 - val_mae: 0.0193
# Epoch 7/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.5729e-04 - mae: 0.0187 - val_loss: 8.4106e-04 - val_mae: 0.0183
# Epoch 8/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.4126e-04 - mae: 0.0183 - val_loss: 8.3566e-04 - val_mae: 0.0181
# Epoch 9/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.3977e-04 - mae: 0.0183 - val_loss: 8.5836e-04 - val_mae: 0.0185
# Epoch 10/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.4968e-04 - mae: 0.0185 - val_loss: 8.4587e-04 - val_mae: 0.0185
# Epoch 11/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.3915e-04 - mae: 0.0183 - val_loss: 9.1457e-04 - val_mae: 0.0198
# Epoch 12/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.3629e-04 - mae: 0.0183 - val_loss: 8.2440e-04 - val_mae: 0.0181
# Epoch 13/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.2673e-04 - mae: 0.0181 - val_loss: 8.0944e-04 - val_mae: 0.0177
# Epoch 14/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.2642e-04 - mae: 0.0181 - val_loss: 8.3186e-04 - val_mae: 0.0183
# Epoch 15/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.2236e-04 - mae: 0.0180 - val_loss: 8.3810e-04 - val_mae: 0.0184
# Epoch 16/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.2484e-04 - mae: 0.0182 - val_loss: 8.0833e-04 - val_mae: 0.0178
# Epoch 17/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.1972e-04 - mae: 0.0181 - val_loss: 8.1893e-04 - val_mae: 0.0179
# Epoch 18/100
# 240/240 [==============================] - 40s 165ms/step - loss: 8.1252e-04 - mae: 0.0179 - val_loss: 8.0110e-04 - val_mae: 0.0177
# Epoch 19/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.8732e-04 - mae: 0.0173 - val_loss: 7.9545e-04 - val_mae: 0.0177
# Epoch 20/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.9366e-04 - mae: 0.0175 - val_loss: 8.1043e-04 - val_mae: 0.0179
# Epoch 21/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.9201e-04 - mae: 0.0175 - val_loss: 8.0242e-04 - val_mae: 0.0177
# Epoch 22/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.9485e-04 - mae: 0.0176 - val_loss: 8.1354e-04 - val_mae: 0.0181
# Epoch 23/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.8721e-04 - mae: 0.0174 - val_loss: 7.9159e-04 - val_mae: 0.0176
# Epoch 24/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.9504e-04 - mae: 0.0176 - val_loss: 7.8988e-04 - val_mae: 0.0176
# Epoch 25/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.9041e-04 - mae: 0.0175 - val_loss: 7.8227e-04 - val_mae: 0.0174
# Epoch 26/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.8851e-04 - mae: 0.0174 - val_loss: 8.0597e-04 - val_mae: 0.0180
# Epoch 27/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.9148e-04 - mae: 0.0175 - val_loss: 8.0280e-04 - val_mae: 0.0178
# Epoch 28/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.8702e-04 - mae: 0.0174 - val_loss: 7.9525e-04 - val_mae: 0.0178
# Epoch 29/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.7197e-04 - mae: 0.0171 - val_loss: 7.6959e-04 - val_mae: 0.0170
# Epoch 30/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.6736e-04 - mae: 0.0170 - val_loss: 7.6963e-04 - val_mae: 0.0171
# Epoch 31/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.6910e-04 - mae: 0.0171 - val_loss: 7.6990e-04 - val_mae: 0.0172
# Epoch 32/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.6941e-04 - mae: 0.0171 - val_loss: 7.8759e-04 - val_mae: 0.0176
# Epoch 33/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.6803e-04 - mae: 0.0171 - val_loss: 7.7670e-04 - val_mae: 0.0174
# Epoch 34/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.6622e-04 - mae: 0.0170 - val_loss: 7.7033e-04 - val_mae: 0.0171
# Epoch 35/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.6533e-04 - mae: 0.0171 - val_loss: 7.6056e-04 - val_mae: 0.0169
# Epoch 36/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.6235e-04 - mae: 0.0170 - val_loss: 7.6878e-04 - val_mae: 0.0171
# Epoch 37/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.6202e-04 - mae: 0.0170 - val_loss: 7.9896e-04 - val_mae: 0.0181
# Epoch 38/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.6341e-04 - mae: 0.0171 - val_loss: 7.6433e-04 - val_mae: 0.0172
# Epoch 39/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.4874e-04 - mae: 0.0167 - val_loss: 7.4867e-04 - val_mae: 0.0169
# Epoch 40/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.4627e-04 - mae: 0.0167 - val_loss: 7.4926e-04 - val_mae: 0.0168
# Epoch 41/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.4660e-04 - mae: 0.0167 - val_loss: 7.6191e-04 - val_mae: 0.0171
# Epoch 42/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.4733e-04 - mae: 0.0168 - val_loss: 7.5570e-04 - val_mae: 0.0170
# Epoch 43/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.4482e-04 - mae: 0.0167 - val_loss: 7.4827e-04 - val_mae: 0.0168
# Epoch 44/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.4317e-04 - mae: 0.0167 - val_loss: 7.4845e-04 - val_mae: 0.0169
# Epoch 45/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.4385e-04 - mae: 0.0167 - val_loss: 7.6183e-04 - val_mae: 0.0171
# Epoch 46/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.4388e-04 - mae: 0.0167 - val_loss: 7.5661e-04 - val_mae: 0.0169
# Epoch 47/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.4426e-04 - mae: 0.0167 - val_loss: 7.5305e-04 - val_mae: 0.0170
# Epoch 48/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.4304e-04 - mae: 0.0167 - val_loss: 7.5127e-04 - val_mae: 0.0171
# Epoch 49/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3274e-04 - mae: 0.0165 - val_loss: 7.4294e-04 - val_mae: 0.0166
# Epoch 50/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3387e-04 - mae: 0.0165 - val_loss: 7.3895e-04 - val_mae: 0.0167
# Epoch 51/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3158e-04 - mae: 0.0165 - val_loss: 7.4642e-04 - val_mae: 0.0169
# Epoch 52/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3120e-04 - mae: 0.0165 - val_loss: 7.4230e-04 - val_mae: 0.0167
# Epoch 53/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3087e-04 - mae: 0.0165 - val_loss: 7.4195e-04 - val_mae: 0.0168
# Epoch 54/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3086e-04 - mae: 0.0165 - val_loss: 7.3360e-04 - val_mae: 0.0166
# Epoch 55/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.3036e-04 - mae: 0.0165 - val_loss: 7.4945e-04 - val_mae: 0.0168
# Epoch 56/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.3028e-04 - mae: 0.0165 - val_loss: 7.3659e-04 - val_mae: 0.0168
# Epoch 57/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2982e-04 - mae: 0.0165 - val_loss: 7.4082e-04 - val_mae: 0.0167
# Epoch 58/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2956e-04 - mae: 0.0165 - val_loss: 7.4268e-04 - val_mae: 0.0167
# Epoch 59/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2794e-04 - mae: 0.0164 - val_loss: 7.3523e-04 - val_mae: 0.0167
# Epoch 60/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2928e-04 - mae: 0.0165 - val_loss: 7.3477e-04 - val_mae: 0.0166
# Epoch 61/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.2707e-04 - mae: 0.0164 - val_loss: 7.3452e-04 - val_mae: 0.0168
# Epoch 62/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.2834e-04 - mae: 0.0165 - val_loss: 7.3725e-04 - val_mae: 0.0166
# Epoch 63/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2749e-04 - mae: 0.0164 - val_loss: 7.3266e-04 - val_mae: 0.0166
# Epoch 64/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2591e-04 - mae: 0.0164 - val_loss: 7.3798e-04 - val_mae: 0.0166
# Epoch 65/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.2066e-04 - mae: 0.0163 - val_loss: 7.3327e-04 - val_mae: 0.0167
# Epoch 66/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.2003e-04 - mae: 0.0163 - val_loss: 7.2873e-04 - val_mae: 0.0165
# Epoch 67/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1982e-04 - mae: 0.0163 - val_loss: 7.2947e-04 - val_mae: 0.0165
# Epoch 68/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.2101e-04 - mae: 0.0163 - val_loss: 7.2804e-04 - val_mae: 0.0165
# Epoch 69/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1981e-04 - mae: 0.0163 - val_loss: 7.2697e-04 - val_mae: 0.0165
# Epoch 70/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1920e-04 - mae: 0.0163 - val_loss: 7.2837e-04 - val_mae: 0.0165
# Epoch 71/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1957e-04 - mae: 0.0163 - val_loss: 7.2756e-04 - val_mae: 0.0165
# Epoch 72/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1930e-04 - mae: 0.0163 - val_loss: 7.2671e-04 - val_mae: 0.0165
# Epoch 73/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1926e-04 - mae: 0.0163 - val_loss: 7.2841e-04 - val_mae: 0.0166
# Epoch 74/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1881e-04 - mae: 0.0163 - val_loss: 7.2948e-04 - val_mae: 0.0165
# Epoch 75/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1571e-04 - mae: 0.0162 - val_loss: 7.2376e-04 - val_mae: 0.0165
# Epoch 76/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1490e-04 - mae: 0.0162 - val_loss: 7.2416e-04 - val_mae: 0.0164
# Epoch 77/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1495e-04 - mae: 0.0162 - val_loss: 7.2538e-04 - val_mae: 0.0165
# Epoch 78/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1452e-04 - mae: 0.0162 - val_loss: 7.2417e-04 - val_mae: 0.0165
# Epoch 79/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1473e-04 - mae: 0.0162 - val_loss: 7.2455e-04 - val_mae: 0.0165
# Epoch 80/100
# 240/240 [==============================] - 41s 169ms/step - loss: 7.1411e-04 - mae: 0.0162 - val_loss: 7.2412e-04 - val_mae: 0.0164
# Epoch 81/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1444e-04 - mae: 0.0162 - val_loss: 7.2248e-04 - val_mae: 0.0164
# Epoch 82/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1377e-04 - mae: 0.0162 - val_loss: 7.2381e-04 - val_mae: 0.0165
# Epoch 83/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1403e-04 - mae: 0.0162 - val_loss: 7.2268e-04 - val_mae: 0.0164
# Epoch 84/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1344e-04 - mae: 0.0162 - val_loss: 7.2352e-04 - val_mae: 0.0165
# Epoch 85/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1237e-04 - mae: 0.0162 - val_loss: 7.2276e-04 - val_mae: 0.0164
# Epoch 86/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1252e-04 - mae: 0.0162 - val_loss: 7.2326e-04 - val_mae: 0.0164
# Epoch 87/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1251e-04 - mae: 0.0162 - val_loss: 7.2377e-04 - val_mae: 0.0165
# Epoch 88/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1239e-04 - mae: 0.0162 - val_loss: 7.2248e-04 - val_mae: 0.0165
# Epoch 89/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1191e-04 - mae: 0.0162 - val_loss: 7.2173e-04 - val_mae: 0.0164
# Epoch 90/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1197e-04 - mae: 0.0162 - val_loss: 7.2013e-04 - val_mae: 0.0164
# Epoch 91/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1206e-04 - mae: 0.0162 - val_loss: 7.2119e-04 - val_mae: 0.0164
# Epoch 92/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1128e-04 - mae: 0.0161 - val_loss: 7.2127e-04 - val_mae: 0.0164
# Epoch 93/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1159e-04 - mae: 0.0161 - val_loss: 7.2116e-04 - val_mae: 0.0164
# Epoch 94/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1155e-04 - mae: 0.0161 - val_loss: 7.2172e-04 - val_mae: 0.0164
# Epoch 95/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1128e-04 - mae: 0.0161 - val_loss: 7.2135e-04 - val_mae: 0.0164
# Epoch 96/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1147e-04 - mae: 0.0162 - val_loss: 7.2406e-04 - val_mae: 0.0164
# Epoch 97/100
# 240/240 [==============================] - 40s 166ms/step - loss: 7.1144e-04 - mae: 0.0162 - val_loss: 7.2049e-04 - val_mae: 0.0164
# Epoch 98/100
# 240/240 [==============================] - 39s 165ms/step - loss: 7.1106e-04 - mae: 0.0161 - val_loss: 7.1967e-04 - val_mae: 0.0163
# Epoch 99/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1079e-04 - mae: 0.0161 - val_loss: 7.2010e-04 - val_mae: 0.0164
# Epoch 100/100
# 240/240 [==============================] - 40s 165ms/step - loss: 7.1064e-04 - mae: 0.0161 - val_loss: 7.2137e-04 - val_mae: 0.0164

# %%
window = sequence_length
last_window = X_scaled[-window:]
last_window = np.expand_dims(last_window, axis=0)
pred = model.predict(last_window)
last_window.shape, pred.shape
# Out:
# ((1, 400, 7), (1, 7))

# %%
future_window = 1152

pred = np.array([])
X_temp = last_window
for t in range(future_window):
    pred_temp = model.predict(X_temp)
    pred_temp = np.expand_dims(pred_temp, axis=0)
    if(len(pred)==0):
        pred = pred_temp
    else:
        pred = np.concatenate((pred,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)

# %%
pred_scaled = pred[0]*(X_max-X_min)+X_min

# %%
window = 400
future_window = 1152
for i in range(pred.shape[-1]):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),X[-window:,i],color='steelblue',label='window')
    plt.plot(range(window,window+future_window),pred_scaled[:,i],color='red',label='prediction')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i))
    plt.legend()
    plt.savefig('bigplot'+str(i))

# %%
#PAPER PLOTS
window = 100
future_window = 400
for i in range(pred.shape[-1]):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),X[-window:,i],color='steelblue',label='window')
    plt.plot(range(window,window+future_window),pred_scaled[:future_window,i],color='red',label='prediction')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i))
    plt.legend()
    plt.savefig('tinyplot'+str(i))

# %%
#for i in range(pred_scaled.shape[-1]):
#    plt.figure(figsize=(20,5))
#    plt.plot(range(window),train_scaled[-window:,i])
#    plt.plot(range(window,window+future_window),val_scaled[:future_window,i])
#    plt.plot(range(window,window+future_window),pred[0,:,i])

# %%
best_epoch = np.argmin(history['val_loss'])
fig_size = (15,5)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#PAPER PLOTS
best_epoch = np.argmin(history['val_loss'])
fig_size = (7,3)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()
plt.savefig("mse.png")

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()
plt.savefig("mae.png")

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()
plt.savefig("lr.png")

# %%
model.save('model')
#model = tfk.models.load_model('model')
# !zip -r model.zip model
# Out:
# 2022-01-13 15:03:41.010912: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
#   adding: model/ (stored 0%)
#   adding: model/keras_metadata.pb (deflated 89%)
#   adding: model/saved_model.pb (deflated 90%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.index (deflated 65%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 6%)
#   adding: model/assets/ (stored 0%)
