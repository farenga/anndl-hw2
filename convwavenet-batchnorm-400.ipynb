# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2data/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2data/Training.csv',delimiter=',',skip_header=True)

# %%
# Pre-processing

X_max = X.max(axis=0)
X_min = X.min(axis=0)

X_mean = X.mean(axis=0)
X_std = X.std(axis=0)

X_scaled = (X-X_min)/(X_max-X_min)

# %%
#for i in range(X.shape[-1]):
i=0
plt.figure(figsize=(20,3))
plt.plot(X[:,i],color='steelblue')
plt.plot(X_scaled[:,i],color='limegreen',alpha=.5)
plt.axhline(y=X_mean[i],color='darkorange',linewidth=2)
plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)
plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,future=1,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length+future < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length:i+sequence_length+future])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
stride = 1
sequence_length = 400
future = 4
X_train, y_train = extract_sequences(X_scaled,sequence_length, future, stride)
X_train.shape,y_train.shape
# Out:
# ((68124, 400, 7), (68124, 4, 7))

# %%
def build_conv(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPool1D()(x)
    
    x = tfkl.Flatten()(x1)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    x = tfkl.Dense(256,activation='relu')(x)
    x = tfkl.Dropout(.2)(x)
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
input_shape = X_train.shape[1:]

model = build_conv(input_shape)
model.summary()
# Out:
# 2022-01-18 23:40:17.181550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:17.301128: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:17.301834: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:17.302943: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-18 23:40:17.304000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:17.304669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:17.305296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:19.056409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:19.057226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:19.057990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-18 23:40:19.058571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 400, 7)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 400, 16)      352         Input[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 400, 32)      1568        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 400, 64)      6208        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 400, 128)     24704       conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 400, 256)     98560       conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 400, 256)     1024        conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 200, 256)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 200, 16)      12304       max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 200, 32)      1568        conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 200, 64)      6208        conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 200, 128)     24704       conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 200, 256)     98560       conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 256)     1024        conv1d_9[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 256)     0           max_pooling1d[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 100, 256)     0           add[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 100, 16)      12304       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 100, 32)      1568        conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 100, 64)      6208        conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 100, 128)     24704       conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 100, 256)     98560       conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 256)     1024        conv1d_14[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 256)     0           max_pooling1d_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 50, 256)      0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 50, 16)       12304       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 50, 32)       1568        conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 50, 64)       6208        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 50, 128)      24704       conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 50, 256)      98560       conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 256)      1024        conv1d_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 50, 256)      0           max_pooling1d_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 25, 256)      0           add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 25, 16)       12304       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 25, 32)       1568        conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 25, 64)       6208        conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 25, 128)      24704       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 25, 256)      98560       conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 25, 256)      1024        conv1d_24[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 25, 256)      0           max_pooling1d_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 12, 256)      0           add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 12, 16)       12304       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 12, 32)       1568        conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 12, 64)       6208        conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 12, 128)      24704       conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 12, 256)      98560       conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 12, 256)      1024        conv1d_29[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 256)      0           max_pooling1d_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 6, 256)       0           add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 6, 16)        12304       max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 6, 32)        1568        conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 6, 64)        6208        conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 6, 128)       24704       conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 6, 256)       98560       conv1d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 6, 256)       1024        conv1d_34[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 6, 256)       0           max_pooling1d_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 3, 256)       0           add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 3, 16)        12304       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 3, 32)        1568        conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 3, 64)        6208        conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 3, 128)       24704       conv1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 3, 256)       98560       conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 3, 256)       1024        conv1d_39[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 3, 256)       0           max_pooling1d_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 1, 256)       0           add_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          65792       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 28)           7196        dropout[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 4, 7)         0           dense_1[0][0]
# ==================================================================================================
# Total params: 1,215,980
# Trainable params: 1,211,884
# Non-trainable params: 4,096
# __________________________________________________________________________________________________

# %%
tfk.utils.plot_model(model, expand_nested=False)

# %%
epochs = 300
batch_size = 256

model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.7, min_lr=1e-5)
        ]
    ).history
# Out:
# 2022-01-18 23:40:23.109271: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/300
# 2022-01-18 23:40:29.002085: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 240/240 [==============================] - 51s 160ms/step - loss: 0.1128 - mae: 0.1577 - val_loss: 0.2231 - val_mae: 0.3898
# Epoch 2/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0148 - mae: 0.0942 - val_loss: 0.3182 - val_mae: 0.4833
# Epoch 3/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0127 - mae: 0.0870 - val_loss: 0.0587 - val_mae: 0.2016
# Epoch 4/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0115 - mae: 0.0824 - val_loss: 0.0089 - val_mae: 0.0723
# Epoch 5/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0105 - mae: 0.0789 - val_loss: 0.0081 - val_mae: 0.0691
# Epoch 6/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0095 - mae: 0.0752 - val_loss: 0.0073 - val_mae: 0.0640
# Epoch 7/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0087 - mae: 0.0717 - val_loss: 0.0077 - val_mae: 0.0629
# Epoch 8/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0079 - mae: 0.0685 - val_loss: 0.0063 - val_mae: 0.0585
# Epoch 9/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0073 - mae: 0.0657 - val_loss: 0.0055 - val_mae: 0.0556
# Epoch 10/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0064 - mae: 0.0618 - val_loss: 0.0067 - val_mae: 0.0620
# Epoch 11/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0059 - mae: 0.0593 - val_loss: 0.0044 - val_mae: 0.0502
# Epoch 12/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0054 - mae: 0.0566 - val_loss: 0.0057 - val_mae: 0.0569
# Epoch 13/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0050 - mae: 0.0545 - val_loss: 0.0039 - val_mae: 0.0464
# Epoch 14/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0046 - mae: 0.0519 - val_loss: 0.0047 - val_mae: 0.0512
# Epoch 15/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0043 - mae: 0.0502 - val_loss: 0.0035 - val_mae: 0.0444
# Epoch 16/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0040 - mae: 0.0484 - val_loss: 0.0032 - val_mae: 0.0426
# Epoch 17/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0038 - mae: 0.0467 - val_loss: 0.0034 - val_mae: 0.0443
# Epoch 18/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0036 - mae: 0.0453 - val_loss: 0.0032 - val_mae: 0.0429
# Epoch 19/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0034 - val_mae: 0.0429
# Epoch 20/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0032 - mae: 0.0431 - val_loss: 0.0036 - val_mae: 0.0456
# Epoch 21/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0032 - mae: 0.0426 - val_loss: 0.0030 - val_mae: 0.0412
# Epoch 22/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0030 - mae: 0.0416 - val_loss: 0.0031 - val_mae: 0.0414
# Epoch 23/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0029 - mae: 0.0408 - val_loss: 0.0030 - val_mae: 0.0412
# Epoch 24/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0028 - mae: 0.0401 - val_loss: 0.0025 - val_mae: 0.0380
# Epoch 25/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0027 - mae: 0.0391 - val_loss: 0.0026 - val_mae: 0.0379
# Epoch 26/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0027 - mae: 0.0390 - val_loss: 0.0024 - val_mae: 0.0360
# Epoch 27/300
# 240/240 [==============================] - 36s 150ms/step - loss: 0.0026 - mae: 0.0381 - val_loss: 0.0028 - val_mae: 0.0402
# Epoch 28/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0026 - mae: 0.0381 - val_loss: 0.0026 - val_mae: 0.0378
# Epoch 29/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0025 - mae: 0.0375 - val_loss: 0.0025 - val_mae: 0.0377
# Epoch 30/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0029 - val_mae: 0.0387
# Epoch 31/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0024 - mae: 0.0367 - val_loss: 0.0031 - val_mae: 0.0418
# Epoch 32/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0024 - mae: 0.0363 - val_loss: 0.0031 - val_mae: 0.0413
# Epoch 33/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0024 - mae: 0.0363 - val_loss: 0.0033 - val_mae: 0.0422
# Epoch 34/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0023 - mae: 0.0360 - val_loss: 0.0025 - val_mae: 0.0381
# Epoch 35/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0023 - mae: 0.0354 - val_loss: 0.0024 - val_mae: 0.0359
# Epoch 36/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0022 - mae: 0.0352 - val_loss: 0.0022 - val_mae: 0.0344
# Epoch 37/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0022 - mae: 0.0350 - val_loss: 0.0021 - val_mae: 0.0338
# Epoch 38/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0023 - mae: 0.0354 - val_loss: 0.0028 - val_mae: 0.0382
# Epoch 39/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0022 - mae: 0.0346 - val_loss: 0.0025 - val_mae: 0.0366
# Epoch 40/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0021 - mae: 0.0342 - val_loss: 0.0023 - val_mae: 0.0358
# Epoch 41/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0021 - mae: 0.0336 - val_loss: 0.0023 - val_mae: 0.0355
# Epoch 42/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0021 - mae: 0.0336 - val_loss: 0.0027 - val_mae: 0.0382
# Epoch 43/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0021 - mae: 0.0339 - val_loss: 0.0021 - val_mae: 0.0339
# Epoch 44/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0020 - mae: 0.0335 - val_loss: 0.0021 - val_mae: 0.0339
# Epoch 45/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0021 - mae: 0.0336 - val_loss: 0.0018 - val_mae: 0.0308
# Epoch 46/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0020 - mae: 0.0331 - val_loss: 0.0020 - val_mae: 0.0329
# Epoch 47/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0020 - mae: 0.0335 - val_loss: 0.0017 - val_mae: 0.0309
# Epoch 48/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0020 - mae: 0.0330 - val_loss: 0.0018 - val_mae: 0.0323
# Epoch 49/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0020 - mae: 0.0332 - val_loss: 0.0020 - val_mae: 0.0333
# Epoch 50/300
# 240/240 [==============================] - 36s 150ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0019 - val_mae: 0.0323
# Epoch 51/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 0.0016 - val_mae: 0.0291
# Epoch 52/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0325 - val_loss: 0.0023 - val_mae: 0.0360
# Epoch 53/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 0.0027 - val_mae: 0.0387
# Epoch 54/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0322 - val_loss: 0.0017 - val_mae: 0.0312
# Epoch 55/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0319 - val_loss: 0.0020 - val_mae: 0.0333
# Epoch 56/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0020 - mae: 0.0331 - val_loss: 0.0014 - val_mae: 0.0275
# Epoch 57/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 0.0026 - val_mae: 0.0367
# Epoch 58/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0018 - mae: 0.0315 - val_loss: 0.0018 - val_mae: 0.0315
# Epoch 59/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0018 - mae: 0.0315 - val_loss: 0.0017 - val_mae: 0.0302
# Epoch 60/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0318 - val_loss: 0.0016 - val_mae: 0.0294
# Epoch 61/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0317 - val_loss: 0.0023 - val_mae: 0.0357
# Epoch 62/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0019 - mae: 0.0319 - val_loss: 0.0014 - val_mae: 0.0273
# Epoch 63/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0018 - mae: 0.0312 - val_loss: 0.0014 - val_mae: 0.0280
# Epoch 64/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0018 - mae: 0.0308 - val_loss: 0.0015 - val_mae: 0.0282
# Epoch 65/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0018 - mae: 0.0312 - val_loss: 0.0018 - val_mae: 0.0314
# Epoch 66/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0018 - mae: 0.0312 - val_loss: 0.0016 - val_mae: 0.0296
# Epoch 67/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0016 - mae: 0.0295 - val_loss: 0.0012 - val_mae: 0.0250
# Epoch 68/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0016 - mae: 0.0289 - val_loss: 9.9368e-04 - val_mae: 0.0226
# Epoch 69/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0012 - val_mae: 0.0252
# Epoch 70/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0011 - val_mae: 0.0242
# Epoch 71/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0016 - mae: 0.0287 - val_loss: 0.0012 - val_mae: 0.0251
# Epoch 72/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0011 - val_mae: 0.0239
# Epoch 73/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0015 - mae: 0.0287 - val_loss: 0.0012 - val_mae: 0.0248
# Epoch 74/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0016 - mae: 0.0289 - val_loss: 0.0013 - val_mae: 0.0269
# Epoch 75/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0010 - val_mae: 0.0230
# Epoch 76/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 77/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0016 - mae: 0.0287 - val_loss: 0.0011 - val_mae: 0.0241
# Epoch 78/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0015 - mae: 0.0285 - val_loss: 0.0010 - val_mae: 0.0231
# Epoch 79/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0014 - mae: 0.0276 - val_loss: 9.0238e-04 - val_mae: 0.0218
# Epoch 80/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 8.4911e-04 - val_mae: 0.0209
# Epoch 81/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 8.7984e-04 - val_mae: 0.0216
# Epoch 82/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 9.3320e-04 - val_mae: 0.0223
# Epoch 83/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 9.3097e-04 - val_mae: 0.0219
# Epoch 84/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 9.6854e-04 - val_mae: 0.0223
# Epoch 85/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 8.3349e-04 - val_mae: 0.0206
# Epoch 86/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 9.0740e-04 - val_mae: 0.0215
# Epoch 87/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0014 - mae: 0.0271 - val_loss: 9.2305e-04 - val_mae: 0.0219
# Epoch 88/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0271 - val_loss: 9.3055e-04 - val_mae: 0.0223
# Epoch 89/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0014 - mae: 0.0271 - val_loss: 9.0983e-04 - val_mae: 0.0217
# Epoch 90/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0014 - mae: 0.0269 - val_loss: 8.0386e-04 - val_mae: 0.0203
# Epoch 91/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0264 - val_loss: 8.2162e-04 - val_mae: 0.0206
# Epoch 92/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 7.6630e-04 - val_mae: 0.0197
# Epoch 93/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 7.8856e-04 - val_mae: 0.0200
# Epoch 94/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 7.7793e-04 - val_mae: 0.0199
# Epoch 95/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 7.3897e-04 - val_mae: 0.0193
# Epoch 96/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 7.1571e-04 - val_mae: 0.0188
# Epoch 97/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 7.4685e-04 - val_mae: 0.0196
# Epoch 98/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 7.3875e-04 - val_mae: 0.0193
# Epoch 99/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 7.2502e-04 - val_mae: 0.0190
# Epoch 100/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 8.0307e-04 - val_mae: 0.0205
# Epoch 101/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 7.4002e-04 - val_mae: 0.0194
# Epoch 102/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 8.0081e-04 - val_mae: 0.0202
# Epoch 103/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 7.6462e-04 - val_mae: 0.0198
# Epoch 104/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 7.8014e-04 - val_mae: 0.0200
# Epoch 105/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 7.1279e-04 - val_mae: 0.0189
# Epoch 106/300
# 240/240 [==============================] - 36s 150ms/step - loss: 0.0013 - mae: 0.0255 - val_loss: 6.9147e-04 - val_mae: 0.0185
# Epoch 107/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 6.8399e-04 - val_mae: 0.0182
# Epoch 108/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 6.7747e-04 - val_mae: 0.0182
# Epoch 109/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 6.7009e-04 - val_mae: 0.0182
# Epoch 110/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 6.8573e-04 - val_mae: 0.0183
# Epoch 111/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 6.6996e-04 - val_mae: 0.0180
# Epoch 112/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 6.8552e-04 - val_mae: 0.0184
# Epoch 113/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 6.5986e-04 - val_mae: 0.0178
# Epoch 114/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0252 - val_loss: 6.7850e-04 - val_mae: 0.0182
# Epoch 115/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 6.7066e-04 - val_mae: 0.0181
# Epoch 116/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 6.2947e-04 - val_mae: 0.0174
# Epoch 117/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 6.4186e-04 - val_mae: 0.0176
# Epoch 118/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 6.3673e-04 - val_mae: 0.0176
# Epoch 119/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.3962e-04 - val_mae: 0.0178
# Epoch 120/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.2615e-04 - val_mae: 0.0173
# Epoch 121/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.4803e-04 - val_mae: 0.0179
# Epoch 122/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.8560e-04 - val_mae: 0.0184
# Epoch 123/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 6.6860e-04 - val_mae: 0.0183
# Epoch 124/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.3541e-04 - val_mae: 0.0176
# Epoch 125/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 6.2569e-04 - val_mae: 0.0174
# Epoch 126/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0247 - val_loss: 6.1451e-04 - val_mae: 0.0172
# Epoch 127/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 6.0194e-04 - val_mae: 0.0169
# Epoch 128/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 6.1866e-04 - val_mae: 0.0172
# Epoch 129/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 6.0560e-04 - val_mae: 0.0170
# Epoch 130/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 5.9095e-04 - val_mae: 0.0168
# Epoch 131/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 5.9998e-04 - val_mae: 0.0170
# Epoch 132/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 5.8531e-04 - val_mae: 0.0166
# Epoch 133/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 6.0829e-04 - val_mae: 0.0170
# Epoch 134/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 6.1201e-04 - val_mae: 0.0173
# Epoch 135/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 6.0230e-04 - val_mae: 0.0169
# Epoch 136/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 5.8483e-04 - val_mae: 0.0166
# Epoch 137/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 5.7919e-04 - val_mae: 0.0165
# Epoch 138/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 5.7922e-04 - val_mae: 0.0165
# Epoch 139/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 5.7511e-04 - val_mae: 0.0164
# Epoch 140/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 5.8146e-04 - val_mae: 0.0165
# Epoch 141/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 5.8460e-04 - val_mae: 0.0166
# Epoch 142/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 5.8610e-04 - val_mae: 0.0167
# Epoch 143/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 5.8022e-04 - val_mae: 0.0165
# Epoch 144/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0012 - mae: 0.0242 - val_loss: 5.7838e-04 - val_mae: 0.0165
# Epoch 145/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 5.8050e-04 - val_mae: 0.0166
# Epoch 146/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 5.7450e-04 - val_mae: 0.0165
# Epoch 147/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 5.6731e-04 - val_mae: 0.0163
# Epoch 148/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 5.9331e-04 - val_mae: 0.0168
# Epoch 149/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.7031e-04 - val_mae: 0.0164
# Epoch 150/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.6632e-04 - val_mae: 0.0163
# Epoch 151/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.6631e-04 - val_mae: 0.0162
# Epoch 152/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.6852e-04 - val_mae: 0.0163
# Epoch 153/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.6793e-04 - val_mae: 0.0163
# Epoch 154/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.7464e-04 - val_mae: 0.0165
# Epoch 155/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 5.7562e-04 - val_mae: 0.0165
# Epoch 156/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 5.7233e-04 - val_mae: 0.0165
# Epoch 157/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 5.6026e-04 - val_mae: 0.0162
# Epoch 158/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 5.6310e-04 - val_mae: 0.0162
# Epoch 159/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 5.6076e-04 - val_mae: 0.0162
# Epoch 160/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.7007e-04 - val_mae: 0.0164
# Epoch 161/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.6087e-04 - val_mae: 0.0162
# Epoch 162/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.6769e-04 - val_mae: 0.0164
# Epoch 163/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.6885e-04 - val_mae: 0.0164
# Epoch 164/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 5.5960e-04 - val_mae: 0.0162
# Epoch 165/300
# 240/240 [==============================] - 36s 150ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5768e-04 - val_mae: 0.0161
# Epoch 166/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5786e-04 - val_mae: 0.0161
# Epoch 167/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5830e-04 - val_mae: 0.0162
# Epoch 168/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5024e-04 - val_mae: 0.0160
# Epoch 169/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.5102e-04 - val_mae: 0.0160
# Epoch 170/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5547e-04 - val_mae: 0.0161
# Epoch 171/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5428e-04 - val_mae: 0.0161
# Epoch 172/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.5863e-04 - val_mae: 0.0161
# Epoch 173/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4808e-04 - val_mae: 0.0160
# Epoch 174/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.4971e-04 - val_mae: 0.0160
# Epoch 175/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.4657e-04 - val_mae: 0.0159
# Epoch 176/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.5283e-04 - val_mae: 0.0160
# Epoch 177/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 5.4878e-04 - val_mae: 0.0160
# Epoch 178/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4930e-04 - val_mae: 0.0160
# Epoch 179/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4871e-04 - val_mae: 0.0160
# Epoch 180/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4792e-04 - val_mae: 0.0159
# Epoch 181/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.5203e-04 - val_mae: 0.0160
# Epoch 182/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4759e-04 - val_mae: 0.0159
# Epoch 183/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.5254e-04 - val_mae: 0.0160
# Epoch 184/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4768e-04 - val_mae: 0.0159
# Epoch 185/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.5179e-04 - val_mae: 0.0160
# Epoch 186/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4674e-04 - val_mae: 0.0159
# Epoch 187/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.5050e-04 - val_mae: 0.0160
# Epoch 188/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4458e-04 - val_mae: 0.0159
# Epoch 189/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.5318e-04 - val_mae: 0.0161
# Epoch 190/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4695e-04 - val_mae: 0.0159
# Epoch 191/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4751e-04 - val_mae: 0.0159
# Epoch 192/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4675e-04 - val_mae: 0.0159
# Epoch 193/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4832e-04 - val_mae: 0.0160
# Epoch 194/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4965e-04 - val_mae: 0.0160
# Epoch 195/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.5027e-04 - val_mae: 0.0160
# Epoch 196/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4780e-04 - val_mae: 0.0160
# Epoch 197/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4612e-04 - val_mae: 0.0159
# Epoch 198/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4510e-04 - val_mae: 0.0159
# Epoch 199/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4486e-04 - val_mae: 0.0159
# Epoch 200/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4525e-04 - val_mae: 0.0159
# Epoch 201/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4550e-04 - val_mae: 0.0159
# Epoch 202/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4677e-04 - val_mae: 0.0159
# Epoch 203/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4207e-04 - val_mae: 0.0158
# Epoch 204/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4321e-04 - val_mae: 0.0159
# Epoch 205/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4615e-04 - val_mae: 0.0159
# Epoch 206/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4567e-04 - val_mae: 0.0159
# Epoch 207/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4601e-04 - val_mae: 0.0159
# Epoch 208/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4500e-04 - val_mae: 0.0159
# Epoch 209/300
# 240/240 [==============================] - 36s 150ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4491e-04 - val_mae: 0.0159
# Epoch 210/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4730e-04 - val_mae: 0.0159
# Epoch 211/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 5.4557e-04 - val_mae: 0.0159
# Epoch 212/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4100e-04 - val_mae: 0.0158
# Epoch 213/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4623e-04 - val_mae: 0.0159
# Epoch 214/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4721e-04 - val_mae: 0.0159
# Epoch 215/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4389e-04 - val_mae: 0.0159
# Epoch 216/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4331e-04 - val_mae: 0.0158
# Epoch 217/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4651e-04 - val_mae: 0.0159
# Epoch 218/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4393e-04 - val_mae: 0.0159
# Epoch 219/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4667e-04 - val_mae: 0.0159
# Epoch 220/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4356e-04 - val_mae: 0.0158
# Epoch 221/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4651e-04 - val_mae: 0.0159
# Epoch 222/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4331e-04 - val_mae: 0.0159
# Epoch 223/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4540e-04 - val_mae: 0.0159
# Epoch 224/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4834e-04 - val_mae: 0.0160
# Epoch 225/300
# 240/240 [==============================] - 36s 150ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4533e-04 - val_mae: 0.0159
# Epoch 226/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4814e-04 - val_mae: 0.0159
# Epoch 227/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4308e-04 - val_mae: 0.0158
# Epoch 228/300
# 240/240 [==============================] - 36s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4651e-04 - val_mae: 0.0159
# Epoch 229/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4412e-04 - val_mae: 0.0159
# Epoch 230/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4566e-04 - val_mae: 0.0159
# Epoch 231/300
# 240/240 [==============================] - 36s 149ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4772e-04 - val_mae: 0.0160
# Epoch 232/300
# 240/240 [==============================] - 35s 148ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 5.4516e-04 - val_mae: 0.0159

# %%
future_window = 864

# %%
def autoregression_pred_multiout(model,window,future,future_window):
    last_window = X_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape
    pred = np.array([])
    X_temp = last_window
    for t in range(0,future_window,future):
        pred_temp = model.predict(X_temp)
        #pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,future:,:],pred_temp), axis=1)

    pred_scaled = pred[0]*(X_max-X_min)+X_min
    return pred_scaled

# %%
pred = autoregression_pred_multiout(model,sequence_length,future,future_window)

# %%
window = sequence_length
for i in range(pred.shape[-1]):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),X[-window:,i],color='steelblue')
    plt.plot(range(window,window+future_window),pred[:,i],color='lightblue')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)

# %%
#for i in range(pred_scaled.shape[-1]):
#    plt.figure(figsize=(20,5))
#    plt.plot(range(window),train_scaled[-window:,i])
#    plt.plot(range(window,window+future_window),val_scaled[:future_window,i])
#    plt.plot(range(window,window+future_window),pred[0,:,i])

# %%
best_epoch = np.argmin(history['val_loss'])
fig_size = (15,5)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# SCORE 4.0981531143, same with no state and no layer norm

# %%
model.save('model')
#model = tfk.models.load_model('model')
# !zip -r model.zip model
# Out:
# 2022-01-19 02:03:39.083332: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
#   adding: model/ (stored 0%)
#   adding: model/assets/ (stored 0%)
#   adding: model/keras_metadata.pb (deflated 95%)
#   adding: model/saved_model.pb (deflated 91%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.index (deflated 79%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 25%)
