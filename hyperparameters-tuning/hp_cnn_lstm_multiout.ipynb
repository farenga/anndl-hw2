# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,future=1,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length+future < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length:i+sequence_length+future])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_convlstm(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    #x1 = tfkl.Conv1D(filters=16,kernel_size=3,padding="causal",activation='relu')(input_layer)
    #x1 = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x1)
    x1 = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(input_layer)
    x1 = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x1)

    #x1 = tfkl.MaxPool1D()(x1)
    
    x = tfkl.LSTM(units=512, return_sequences=False,return_state=False)(x1)
    #x = tfkl.Flatten()(x)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x1),tfkl.Flatten()(x2)])
    x = tfkl.Dense(7*future)(x)
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
stride = 1
sequence_length = 200
future = 2
X_train, y_train = extract_sequences(train_scaled,sequence_length, future, stride)
X_train.shape,y_train.shape
# Out:
# ((67174, 200, 7), (67174, 2, 7))

# %%
models_array = []
history_array = []

epochs = 200
batch_size = 256

    
input_shape = X_train.shape[1:]
print(input_shape)
models = [build_convlstm]
models_lables = ['conv lstm']

for m in models:

    model = m(input_shape)
    model.summary()
    
    tfk.utils.plot_model(model)

    print("******************")
    
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            #tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.7, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# (200, 7)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 200, 7)]          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 200, 64)           1408
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 200, 128)          24704
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 512)               1312768
# _________________________________________________________________
# dense_4 (Dense)              (None, 14)                7182
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 2, 7)              0
# =================================================================
# Total params: 1,346,062
# Trainable params: 1,346,062
# Non-trainable params: 0
# _________________________________________________________________
# ******************
# Epoch 1/200
# 237/237 [==============================] - 24s 96ms/step - loss: 0.0062 - mae: 0.0469 - val_loss: 0.0018 - val_mae: 0.0305
# Epoch 2/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0014 - mae: 0.0262 - val_loss: 0.0012 - val_mae: 0.0240
# Epoch 3/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0012 - mae: 0.0240 - val_loss: 0.0012 - val_mae: 0.0232
# Epoch 4/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0012 - mae: 0.0231 - val_loss: 0.0012 - val_mae: 0.0231
# Epoch 5/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0011 - mae: 0.0220 - val_loss: 0.0013 - val_mae: 0.0242
# Epoch 6/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0011 - mae: 0.0224 - val_loss: 0.0011 - val_mae: 0.0222
# Epoch 7/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0011 - mae: 0.0217 - val_loss: 0.0011 - val_mae: 0.0234
# Epoch 8/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0011 - mae: 0.0214 - val_loss: 0.0010 - val_mae: 0.0205
# Epoch 9/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0011 - mae: 0.0214 - val_loss: 0.0011 - val_mae: 0.0219
# Epoch 10/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0011 - mae: 0.0215 - val_loss: 0.0010 - val_mae: 0.0211
# Epoch 11/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0010 - mae: 0.0210 - val_loss: 0.0012 - val_mae: 0.0238
# Epoch 12/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0010 - mae: 0.0209 - val_loss: 0.0010 - val_mae: 0.0209
# Epoch 13/200
# 237/237 [==============================] - 22s 94ms/step - loss: 0.0010 - mae: 0.0207 - val_loss: 9.7844e-04 - val_mae: 0.0201
# Epoch 14/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.9495e-04 - mae: 0.0206 - val_loss: 0.0011 - val_mae: 0.0230
# Epoch 15/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.9589e-04 - mae: 0.0206 - val_loss: 9.6156e-04 - val_mae: 0.0199
# Epoch 16/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.7720e-04 - mae: 0.0204 - val_loss: 0.0010 - val_mae: 0.0209
# Epoch 17/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.7163e-04 - mae: 0.0203 - val_loss: 0.0010 - val_mae: 0.0210
# Epoch 18/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.7698e-04 - mae: 0.0204 - val_loss: 0.0010 - val_mae: 0.0213
# Epoch 19/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.5983e-04 - mae: 0.0201 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 20/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.5610e-04 - mae: 0.0201 - val_loss: 9.3837e-04 - val_mae: 0.0198
# Epoch 21/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.4990e-04 - mae: 0.0200 - val_loss: 9.2132e-04 - val_mae: 0.0197
# Epoch 22/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.3169e-04 - mae: 0.0197 - val_loss: 0.0011 - val_mae: 0.0228
# Epoch 23/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.4004e-04 - mae: 0.0199 - val_loss: 9.7570e-04 - val_mae: 0.0208
# Epoch 24/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.9763e-04 - mae: 0.0191 - val_loss: 9.5755e-04 - val_mae: 0.0203
# Epoch 25/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.0137e-04 - mae: 0.0192 - val_loss: 9.4770e-04 - val_mae: 0.0206
# Epoch 26/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.9852e-04 - mae: 0.0192 - val_loss: 9.1350e-04 - val_mae: 0.0194
# Epoch 27/200
# 237/237 [==============================] - 22s 94ms/step - loss: 9.0924e-04 - mae: 0.0194 - val_loss: 9.4725e-04 - val_mae: 0.0202
# Epoch 28/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.9213e-04 - mae: 0.0191 - val_loss: 9.9354e-04 - val_mae: 0.0210
# Epoch 29/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.9793e-04 - mae: 0.0193 - val_loss: 9.9080e-04 - val_mae: 0.0210
# Epoch 30/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.9299e-04 - mae: 0.0192 - val_loss: 9.1187e-04 - val_mae: 0.0194
# Epoch 31/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.9424e-04 - mae: 0.0193 - val_loss: 8.9653e-04 - val_mae: 0.0191
# Epoch 32/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.8511e-04 - mae: 0.0191 - val_loss: 8.9477e-04 - val_mae: 0.0195
# Epoch 33/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.7414e-04 - mae: 0.0188 - val_loss: 8.7146e-04 - val_mae: 0.0187
# Epoch 34/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.8248e-04 - mae: 0.0190 - val_loss: 9.5641e-04 - val_mae: 0.0203
# Epoch 35/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.8243e-04 - mae: 0.0191 - val_loss: 8.8207e-04 - val_mae: 0.0190
# Epoch 36/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.7379e-04 - mae: 0.0190 - val_loss: 9.2051e-04 - val_mae: 0.0195
# Epoch 37/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.7670e-04 - mae: 0.0190 - val_loss: 9.1290e-04 - val_mae: 0.0198
# Epoch 38/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.6459e-04 - mae: 0.0187 - val_loss: 8.8259e-04 - val_mae: 0.0191
# Epoch 39/200
# 237/237 [==============================] - 23s 95ms/step - loss: 8.6037e-04 - mae: 0.0187 - val_loss: 8.7365e-04 - val_mae: 0.0190
# Epoch 40/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.6569e-04 - mae: 0.0189 - val_loss: 8.5646e-04 - val_mae: 0.0185
# Epoch 41/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.5887e-04 - mae: 0.0187 - val_loss: 9.2547e-04 - val_mae: 0.0194
# Epoch 42/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.5756e-04 - mae: 0.0187 - val_loss: 8.6706e-04 - val_mae: 0.0187
# Epoch 43/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.6219e-04 - mae: 0.0189 - val_loss: 8.6513e-04 - val_mae: 0.0189
# Epoch 44/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.3454e-04 - mae: 0.0183 - val_loss: 8.4830e-04 - val_mae: 0.0185
# Epoch 45/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.3805e-04 - mae: 0.0184 - val_loss: 8.5922e-04 - val_mae: 0.0186
# Epoch 46/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.2961e-04 - mae: 0.0182 - val_loss: 8.3427e-04 - val_mae: 0.0183
# Epoch 47/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.3035e-04 - mae: 0.0183 - val_loss: 9.0709e-04 - val_mae: 0.0197
# Epoch 48/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.3128e-04 - mae: 0.0184 - val_loss: 8.3268e-04 - val_mae: 0.0183
# Epoch 49/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.2760e-04 - mae: 0.0183 - val_loss: 8.4018e-04 - val_mae: 0.0183
# Epoch 50/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.2407e-04 - mae: 0.0182 - val_loss: 8.7163e-04 - val_mae: 0.0190
# Epoch 51/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.2900e-04 - mae: 0.0183 - val_loss: 9.0410e-04 - val_mae: 0.0198
# Epoch 52/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.3011e-04 - mae: 0.0184 - val_loss: 8.6102e-04 - val_mae: 0.0189
# Epoch 53/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.2046e-04 - mae: 0.0182 - val_loss: 8.2870e-04 - val_mae: 0.0182
# Epoch 54/200
# 237/237 [==============================] - 22s 95ms/step - loss: 8.0723e-04 - mae: 0.0180 - val_loss: 8.3750e-04 - val_mae: 0.0184
# Epoch 55/200
# 237/237 [==============================] - 23s 95ms/step - loss: 8.0801e-04 - mae: 0.0180 - val_loss: 8.2132e-04 - val_mae: 0.0180
# Epoch 56/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.0404e-04 - mae: 0.0180 - val_loss: 8.3947e-04 - val_mae: 0.0186
# Epoch 57/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.0046e-04 - mae: 0.0179 - val_loss: 8.2411e-04 - val_mae: 0.0180
# Epoch 58/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.9898e-04 - mae: 0.0179 - val_loss: 8.2929e-04 - val_mae: 0.0183
# Epoch 59/200
# 237/237 [==============================] - 22s 94ms/step - loss: 8.0235e-04 - mae: 0.0181 - val_loss: 8.1406e-04 - val_mae: 0.0180
# Epoch 60/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.9543e-04 - mae: 0.0179 - val_loss: 8.1038e-04 - val_mae: 0.0179
# Epoch 61/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.9457e-04 - mae: 0.0179 - val_loss: 8.5033e-04 - val_mae: 0.0189
# Epoch 62/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.9936e-04 - mae: 0.0180 - val_loss: 8.2356e-04 - val_mae: 0.0184
# Epoch 63/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.9152e-04 - mae: 0.0179 - val_loss: 8.4377e-04 - val_mae: 0.0186
# Epoch 64/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.7910e-04 - mae: 0.0177 - val_loss: 8.1107e-04 - val_mae: 0.0179
# Epoch 65/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.7780e-04 - mae: 0.0177 - val_loss: 8.1337e-04 - val_mae: 0.0182
# Epoch 66/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.7475e-04 - mae: 0.0176 - val_loss: 7.9529e-04 - val_mae: 0.0177
# Epoch 67/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.7762e-04 - mae: 0.0177 - val_loss: 8.1715e-04 - val_mae: 0.0183
# Epoch 68/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.7422e-04 - mae: 0.0177 - val_loss: 7.9692e-04 - val_mae: 0.0177
# Epoch 69/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.7115e-04 - mae: 0.0176 - val_loss: 8.2148e-04 - val_mae: 0.0184
# Epoch 70/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.7281e-04 - mae: 0.0177 - val_loss: 8.0615e-04 - val_mae: 0.0180
# Epoch 71/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.6921e-04 - mae: 0.0176 - val_loss: 8.2466e-04 - val_mae: 0.0180
# Epoch 72/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.6999e-04 - mae: 0.0176 - val_loss: 8.0335e-04 - val_mae: 0.0179
# Epoch 73/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.6735e-04 - mae: 0.0176 - val_loss: 7.9871e-04 - val_mae: 0.0177
# Epoch 74/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.5546e-04 - mae: 0.0174 - val_loss: 7.9566e-04 - val_mae: 0.0176
# Epoch 75/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.5442e-04 - mae: 0.0174 - val_loss: 7.9722e-04 - val_mae: 0.0177
# Epoch 76/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.5128e-04 - mae: 0.0174 - val_loss: 7.9971e-04 - val_mae: 0.0177
# Epoch 77/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.5312e-04 - mae: 0.0175 - val_loss: 7.8732e-04 - val_mae: 0.0176
# Epoch 78/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.4891e-04 - mae: 0.0174 - val_loss: 7.9202e-04 - val_mae: 0.0177
# Epoch 79/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.5044e-04 - mae: 0.0174 - val_loss: 7.8483e-04 - val_mae: 0.0177
# Epoch 80/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.4582e-04 - mae: 0.0173 - val_loss: 7.8898e-04 - val_mae: 0.0176
# Epoch 81/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.4479e-04 - mae: 0.0174 - val_loss: 7.8067e-04 - val_mae: 0.0175
# Epoch 82/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.4658e-04 - mae: 0.0174 - val_loss: 8.1309e-04 - val_mae: 0.0182
# Epoch 83/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.4479e-04 - mae: 0.0174 - val_loss: 7.8918e-04 - val_mae: 0.0176
# Epoch 84/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.3305e-04 - mae: 0.0172 - val_loss: 7.9503e-04 - val_mae: 0.0179
# Epoch 85/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.3171e-04 - mae: 0.0172 - val_loss: 7.7826e-04 - val_mae: 0.0175
# Epoch 86/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.2884e-04 - mae: 0.0172 - val_loss: 7.7846e-04 - val_mae: 0.0176
# Epoch 87/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.3002e-04 - mae: 0.0172 - val_loss: 7.8194e-04 - val_mae: 0.0176
# Epoch 88/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.2752e-04 - mae: 0.0172 - val_loss: 7.7679e-04 - val_mae: 0.0176
# Epoch 89/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.2809e-04 - mae: 0.0172 - val_loss: 7.8274e-04 - val_mae: 0.0176
# Epoch 90/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.2607e-04 - mae: 0.0172 - val_loss: 7.8824e-04 - val_mae: 0.0177
# Epoch 91/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.2727e-04 - mae: 0.0172 - val_loss: 7.8189e-04 - val_mae: 0.0178
# Epoch 92/200
# 237/237 [==============================] - 22s 94ms/step - loss: 7.2372e-04 - mae: 0.0171 - val_loss: 7.8370e-04 - val_mae: 0.0177
# Epoch 93/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.2313e-04 - mae: 0.0172 - val_loss: 7.7237e-04 - val_mae: 0.0176
# Epoch 94/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.1463e-04 - mae: 0.0171 - val_loss: 7.7127e-04 - val_mae: 0.0176
# Epoch 95/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.1406e-04 - mae: 0.0171 - val_loss: 7.7062e-04 - val_mae: 0.0176
# Epoch 96/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.1148e-04 - mae: 0.0170 - val_loss: 7.7239e-04 - val_mae: 0.0176
# Epoch 97/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.1190e-04 - mae: 0.0170 - val_loss: 7.7051e-04 - val_mae: 0.0176
# Epoch 98/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0978e-04 - mae: 0.0170 - val_loss: 7.6973e-04 - val_mae: 0.0175
# Epoch 99/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0876e-04 - mae: 0.0170 - val_loss: 7.7082e-04 - val_mae: 0.0175
# Epoch 100/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0817e-04 - mae: 0.0170 - val_loss: 7.6192e-04 - val_mae: 0.0174
# Epoch 101/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0592e-04 - mae: 0.0170 - val_loss: 7.6947e-04 - val_mae: 0.0175
# Epoch 102/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0837e-04 - mae: 0.0170 - val_loss: 7.7284e-04 - val_mae: 0.0177
# Epoch 103/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0551e-04 - mae: 0.0170 - val_loss: 7.6775e-04 - val_mae: 0.0176
# Epoch 104/200
# 237/237 [==============================] - 22s 93ms/step - loss: 7.0615e-04 - mae: 0.0170 - val_loss: 7.6267e-04 - val_mae: 0.0174
# Epoch 105/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9772e-04 - mae: 0.0169 - val_loss: 7.5872e-04 - val_mae: 0.0174
# Epoch 106/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9625e-04 - mae: 0.0169 - val_loss: 7.6535e-04 - val_mae: 0.0175
# Epoch 107/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9626e-04 - mae: 0.0169 - val_loss: 7.5967e-04 - val_mae: 0.0174
# Epoch 108/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9455e-04 - mae: 0.0169 - val_loss: 7.6088e-04 - val_mae: 0.0174
# Epoch 109/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9334e-04 - mae: 0.0169 - val_loss: 7.6778e-04 - val_mae: 0.0175
# Epoch 110/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9362e-04 - mae: 0.0169 - val_loss: 7.5438e-04 - val_mae: 0.0174
# Epoch 111/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9261e-04 - mae: 0.0169 - val_loss: 7.5720e-04 - val_mae: 0.0175
# Epoch 112/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9102e-04 - mae: 0.0169 - val_loss: 7.6144e-04 - val_mae: 0.0175
# Epoch 113/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.9032e-04 - mae: 0.0169 - val_loss: 7.6298e-04 - val_mae: 0.0175
# Epoch 114/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.8941e-04 - mae: 0.0169 - val_loss: 7.5488e-04 - val_mae: 0.0174
# Epoch 115/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.8396e-04 - mae: 0.0168 - val_loss: 7.5809e-04 - val_mae: 0.0175
# Epoch 116/200
# 237/237 [==============================] - 22s 91ms/step - loss: 6.8251e-04 - mae: 0.0168 - val_loss: 7.5168e-04 - val_mae: 0.0174
# Epoch 117/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.8293e-04 - mae: 0.0168 - val_loss: 7.5172e-04 - val_mae: 0.0174
# Epoch 118/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.8153e-04 - mae: 0.0168 - val_loss: 7.5316e-04 - val_mae: 0.0174
# Epoch 119/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.8099e-04 - mae: 0.0168 - val_loss: 7.5644e-04 - val_mae: 0.0175
# Epoch 120/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.8022e-04 - mae: 0.0168 - val_loss: 7.5201e-04 - val_mae: 0.0174
# Epoch 121/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.7940e-04 - mae: 0.0168 - val_loss: 7.5145e-04 - val_mae: 0.0174
# Epoch 122/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.7887e-04 - mae: 0.0168 - val_loss: 7.4956e-04 - val_mae: 0.0173
# Epoch 123/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.7798e-04 - mae: 0.0168 - val_loss: 7.5162e-04 - val_mae: 0.0174
# Epoch 124/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.7696e-04 - mae: 0.0168 - val_loss: 7.5554e-04 - val_mae: 0.0175
# Epoch 125/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.7325e-04 - mae: 0.0167 - val_loss: 7.4930e-04 - val_mae: 0.0174
# Epoch 126/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.7198e-04 - mae: 0.0167 - val_loss: 7.4926e-04 - val_mae: 0.0174
# Epoch 127/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.7221e-04 - mae: 0.0167 - val_loss: 7.4573e-04 - val_mae: 0.0174
# Epoch 128/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.7108e-04 - mae: 0.0167 - val_loss: 7.4713e-04 - val_mae: 0.0174
# Epoch 129/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.7059e-04 - mae: 0.0167 - val_loss: 7.4771e-04 - val_mae: 0.0174
# Epoch 130/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.6984e-04 - mae: 0.0167 - val_loss: 7.4634e-04 - val_mae: 0.0174
# Epoch 131/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.6908e-04 - mae: 0.0167 - val_loss: 7.4713e-04 - val_mae: 0.0174
# Epoch 132/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.6861e-04 - mae: 0.0167 - val_loss: 7.4742e-04 - val_mae: 0.0174
# Epoch 133/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6875e-04 - mae: 0.0167 - val_loss: 7.4524e-04 - val_mae: 0.0174
# Epoch 134/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6718e-04 - mae: 0.0167 - val_loss: 7.4723e-04 - val_mae: 0.0174
# Epoch 135/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6419e-04 - mae: 0.0166 - val_loss: 7.4225e-04 - val_mae: 0.0173
# Epoch 136/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6384e-04 - mae: 0.0166 - val_loss: 7.4367e-04 - val_mae: 0.0174
# Epoch 137/200
# 237/237 [==============================] - 22s 91ms/step - loss: 6.6336e-04 - mae: 0.0166 - val_loss: 7.4212e-04 - val_mae: 0.0173
# Epoch 138/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6281e-04 - mae: 0.0166 - val_loss: 7.4267e-04 - val_mae: 0.0174
# Epoch 139/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6209e-04 - mae: 0.0166 - val_loss: 7.4372e-04 - val_mae: 0.0174
# Epoch 140/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6169e-04 - mae: 0.0166 - val_loss: 7.4429e-04 - val_mae: 0.0174
# Epoch 141/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6170e-04 - mae: 0.0166 - val_loss: 7.4061e-04 - val_mae: 0.0173
# Epoch 142/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6012e-04 - mae: 0.0166 - val_loss: 7.4100e-04 - val_mae: 0.0174
# Epoch 143/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.6040e-04 - mae: 0.0166 - val_loss: 7.4330e-04 - val_mae: 0.0174
# Epoch 144/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.5995e-04 - mae: 0.0166 - val_loss: 7.3919e-04 - val_mae: 0.0173
# Epoch 145/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.5744e-04 - mae: 0.0166 - val_loss: 7.3912e-04 - val_mae: 0.0173
# Epoch 146/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.5723e-04 - mae: 0.0166 - val_loss: 7.4001e-04 - val_mae: 0.0173
# Epoch 147/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5670e-04 - mae: 0.0166 - val_loss: 7.4024e-04 - val_mae: 0.0174
# Epoch 148/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5654e-04 - mae: 0.0166 - val_loss: 7.3880e-04 - val_mae: 0.0173
# Epoch 149/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5606e-04 - mae: 0.0166 - val_loss: 7.3895e-04 - val_mae: 0.0173
# Epoch 150/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5571e-04 - mae: 0.0166 - val_loss: 7.3905e-04 - val_mae: 0.0173
# Epoch 151/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5556e-04 - mae: 0.0166 - val_loss: 7.3824e-04 - val_mae: 0.0173
# Epoch 152/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5467e-04 - mae: 0.0166 - val_loss: 7.4007e-04 - val_mae: 0.0174
# Epoch 153/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5457e-04 - mae: 0.0166 - val_loss: 7.4042e-04 - val_mae: 0.0174
# Epoch 154/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5446e-04 - mae: 0.0166 - val_loss: 7.3964e-04 - val_mae: 0.0174
# Epoch 155/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5263e-04 - mae: 0.0166 - val_loss: 7.3696e-04 - val_mae: 0.0173
# Epoch 156/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5234e-04 - mae: 0.0165 - val_loss: 7.3662e-04 - val_mae: 0.0173
# Epoch 157/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5197e-04 - mae: 0.0165 - val_loss: 7.3583e-04 - val_mae: 0.0173
# Epoch 158/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5194e-04 - mae: 0.0165 - val_loss: 7.3607e-04 - val_mae: 0.0173
# Epoch 159/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5197e-04 - mae: 0.0165 - val_loss: 7.3799e-04 - val_mae: 0.0173
# Epoch 160/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.5122e-04 - mae: 0.0165 - val_loss: 7.3833e-04 - val_mae: 0.0174
# Epoch 161/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5112e-04 - mae: 0.0165 - val_loss: 7.3734e-04 - val_mae: 0.0173
# Epoch 162/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5117e-04 - mae: 0.0165 - val_loss: 7.3569e-04 - val_mae: 0.0173
# Epoch 163/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.5044e-04 - mae: 0.0165 - val_loss: 7.3614e-04 - val_mae: 0.0173
# Epoch 164/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.5044e-04 - mae: 0.0165 - val_loss: 7.3722e-04 - val_mae: 0.0173
# Epoch 165/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4976e-04 - mae: 0.0165 - val_loss: 7.3893e-04 - val_mae: 0.0173
# Epoch 166/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4989e-04 - mae: 0.0165 - val_loss: 7.3443e-04 - val_mae: 0.0173
# Epoch 167/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4963e-04 - mae: 0.0165 - val_loss: 7.3733e-04 - val_mae: 0.0173
# Epoch 168/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4948e-04 - mae: 0.0165 - val_loss: 7.3588e-04 - val_mae: 0.0173
# Epoch 169/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4912e-04 - mae: 0.0165 - val_loss: 7.3576e-04 - val_mae: 0.0173
# Epoch 170/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4878e-04 - mae: 0.0165 - val_loss: 7.3477e-04 - val_mae: 0.0173
# Epoch 171/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4851e-04 - mae: 0.0165 - val_loss: 7.3337e-04 - val_mae: 0.0173
# Epoch 172/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4821e-04 - mae: 0.0165 - val_loss: 7.3621e-04 - val_mae: 0.0173
# Epoch 173/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4829e-04 - mae: 0.0165 - val_loss: 7.3438e-04 - val_mae: 0.0173
# Epoch 174/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4787e-04 - mae: 0.0165 - val_loss: 7.3590e-04 - val_mae: 0.0173
# Epoch 175/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4754e-04 - mae: 0.0165 - val_loss: 7.3391e-04 - val_mae: 0.0173
# Epoch 176/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4742e-04 - mae: 0.0165 - val_loss: 7.3546e-04 - val_mae: 0.0173
# Epoch 177/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4721e-04 - mae: 0.0165 - val_loss: 7.3298e-04 - val_mae: 0.0173
# Epoch 178/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4672e-04 - mae: 0.0165 - val_loss: 7.3507e-04 - val_mae: 0.0173
# Epoch 179/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4707e-04 - mae: 0.0165 - val_loss: 7.3320e-04 - val_mae: 0.0173
# Epoch 180/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4613e-04 - mae: 0.0165 - val_loss: 7.3514e-04 - val_mae: 0.0173
# Epoch 181/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4605e-04 - mae: 0.0165 - val_loss: 7.3236e-04 - val_mae: 0.0173
# Epoch 182/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4620e-04 - mae: 0.0165 - val_loss: 7.3274e-04 - val_mae: 0.0173
# Epoch 183/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4563e-04 - mae: 0.0165 - val_loss: 7.3224e-04 - val_mae: 0.0173
# Epoch 184/200
# 237/237 [==============================] - 22s 92ms/step - loss: 6.4548e-04 - mae: 0.0165 - val_loss: 7.3342e-04 - val_mae: 0.0173
# Epoch 185/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4514e-04 - mae: 0.0165 - val_loss: 7.3302e-04 - val_mae: 0.0173
# Epoch 186/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4477e-04 - mae: 0.0165 - val_loss: 7.3227e-04 - val_mae: 0.0173
# Epoch 187/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4482e-04 - mae: 0.0165 - val_loss: 7.3388e-04 - val_mae: 0.0173
# Epoch 188/200
# 237/237 [==============================] - 22s 93ms/step - loss: 6.4436e-04 - mae: 0.0165 - val_loss: 7.3110e-04 - val_mae: 0.0173
# Epoch 189/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4422e-04 - mae: 0.0165 - val_loss: 7.3165e-04 - val_mae: 0.0173
# Epoch 190/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4401e-04 - mae: 0.0165 - val_loss: 7.3263e-04 - val_mae: 0.0173
# Epoch 191/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4354e-04 - mae: 0.0165 - val_loss: 7.3135e-04 - val_mae: 0.0173
# Epoch 192/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4343e-04 - mae: 0.0165 - val_loss: 7.3104e-04 - val_mae: 0.0173
# Epoch 193/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4296e-04 - mae: 0.0165 - val_loss: 7.3115e-04 - val_mae: 0.0173
# Epoch 194/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4297e-04 - mae: 0.0165 - val_loss: 7.3116e-04 - val_mae: 0.0173
# Epoch 195/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4282e-04 - mae: 0.0165 - val_loss: 7.3284e-04 - val_mae: 0.0173
# Epoch 196/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4253e-04 - mae: 0.0165 - val_loss: 7.3077e-04 - val_mae: 0.0173
# Epoch 197/200
# 237/237 [==============================] - 22s 95ms/step - loss: 6.4186e-04 - mae: 0.0165 - val_loss: 7.3169e-04 - val_mae: 0.0173
# Epoch 198/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4218e-04 - mae: 0.0165 - val_loss: 7.3094e-04 - val_mae: 0.0173
# Epoch 199/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4137e-04 - mae: 0.0165 - val_loss: 7.3058e-04 - val_mae: 0.0173
# Epoch 200/200
# 237/237 [==============================] - 22s 94ms/step - loss: 6.4139e-04 - mae: 0.0165 - val_loss: 7.2983e-04 - val_mae: 0.0173

# %%
tfk.utils.plot_model(model, expand_nested=True)

# %%
future_window = 864

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled    


def autoregression_pred_multiout(model,window,future):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape
    pred = np.array([])
    X_temp = last_window
    for t in range(0,future_window,future):
        pred_temp = model.predict(X_temp)
        #pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,future:,:],pred_temp), axis=1)

    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred_multiout(model,sequence_length,future))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 8.482335896565589  MAE: 4.712347844931892
#
# Best model is conv lstm

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
for i,model in enumerate(models_array):
    save_model(model,models_lables[i])
#save_model(model_2,'model_2')

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
