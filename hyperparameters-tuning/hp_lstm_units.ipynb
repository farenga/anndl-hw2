# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_lstm(input_shape,n_units):

    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
        
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
models_array = []
history_array = []
epochs = 50
batch_size = 256

sequence_length = 400
stride = 1

X_train, y_train = extract_sequences(train_scaled,sequence_length,stride)
X_train.shape,y_train.shape

input_shape = X_train.shape[1:]

lstm_units = [352,400,450,500]

for units in lstm_units:
    
    model = build_lstm(input_shape,units)
    model.summary()

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 352)               506880
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 2471
# =================================================================
# Total params: 509,351
# Trainable params: 509,351
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 236/236 [==============================] - 24s 94ms/step - loss: 0.0057 - mae: 0.0425 - val_loss: 0.0016 - val_mae: 0.0277
# Epoch 2/50
# 236/236 [==============================] - 22s 92ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 0.0012 - val_mae: 0.0233
# Epoch 3/50
# 236/236 [==============================] - 22s 92ms/step - loss: 0.0011 - mae: 0.0226 - val_loss: 0.0012 - val_mae: 0.0234
# Epoch 4/50
# 236/236 [==============================] - 22s 92ms/step - loss: 0.0010 - mae: 0.0211 - val_loss: 9.9192e-04 - val_mae: 0.0204
# Epoch 5/50
# 236/236 [==============================] - 22s 91ms/step - loss: 9.4325e-04 - mae: 0.0201 - val_loss: 9.4029e-04 - val_mae: 0.0198
# Epoch 6/50
# 236/236 [==============================] - 22s 91ms/step - loss: 8.9778e-04 - mae: 0.0195 - val_loss: 8.9801e-04 - val_mae: 0.0191
# Epoch 7/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.7416e-04 - mae: 0.0192 - val_loss: 9.3435e-04 - val_mae: 0.0202
# Epoch 8/50
# 236/236 [==============================] - 22s 91ms/step - loss: 8.5414e-04 - mae: 0.0188 - val_loss: 8.9642e-04 - val_mae: 0.0194
# Epoch 9/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.3961e-04 - mae: 0.0186 - val_loss: 9.2811e-04 - val_mae: 0.0206
# Epoch 10/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.3167e-04 - mae: 0.0184 - val_loss: 8.5202e-04 - val_mae: 0.0185
# Epoch 11/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.1954e-04 - mae: 0.0182 - val_loss: 8.4474e-04 - val_mae: 0.0184
# Epoch 12/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.1481e-04 - mae: 0.0181 - val_loss: 8.5658e-04 - val_mae: 0.0185
# Epoch 13/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.0661e-04 - mae: 0.0180 - val_loss: 8.2224e-04 - val_mae: 0.0179
# Epoch 14/50
# 236/236 [==============================] - 22s 93ms/step - loss: 7.9898e-04 - mae: 0.0178 - val_loss: 8.6972e-04 - val_mae: 0.0186
# Epoch 15/50
# 236/236 [==============================] - 22s 92ms/step - loss: 8.0322e-04 - mae: 0.0179 - val_loss: 8.6100e-04 - val_mae: 0.0189
# Epoch 16/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.9559e-04 - mae: 0.0178 - val_loss: 8.4371e-04 - val_mae: 0.0185
# Epoch 17/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.9574e-04 - mae: 0.0178 - val_loss: 8.3348e-04 - val_mae: 0.0183
# Epoch 18/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.9404e-04 - mae: 0.0178 - val_loss: 8.2783e-04 - val_mae: 0.0181
# Epoch 19/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.8627e-04 - mae: 0.0176 - val_loss: 8.3616e-04 - val_mae: 0.0183
# Epoch 20/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.8238e-04 - mae: 0.0176 - val_loss: 8.4760e-04 - val_mae: 0.0187
# Epoch 21/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.6294e-04 - mae: 0.0171 - val_loss: 7.8528e-04 - val_mae: 0.0173
# Epoch 22/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5966e-04 - mae: 0.0171 - val_loss: 7.8099e-04 - val_mae: 0.0172
# Epoch 23/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5583e-04 - mae: 0.0170 - val_loss: 8.0590e-04 - val_mae: 0.0179
# Epoch 24/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5971e-04 - mae: 0.0171 - val_loss: 8.1148e-04 - val_mae: 0.0182
# Epoch 25/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5451e-04 - mae: 0.0170 - val_loss: 7.8700e-04 - val_mae: 0.0176
# Epoch 26/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5752e-04 - mae: 0.0171 - val_loss: 7.9020e-04 - val_mae: 0.0173
# Epoch 27/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5514e-04 - mae: 0.0171 - val_loss: 7.7442e-04 - val_mae: 0.0171
# Epoch 28/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.6183e-04 - mae: 0.0172 - val_loss: 7.8272e-04 - val_mae: 0.0174
# Epoch 29/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5469e-04 - mae: 0.0171 - val_loss: 7.7251e-04 - val_mae: 0.0172
# Epoch 30/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.5016e-04 - mae: 0.0170 - val_loss: 7.8772e-04 - val_mae: 0.0174
# Epoch 31/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3539e-04 - mae: 0.0167 - val_loss: 7.7045e-04 - val_mae: 0.0172
# Epoch 32/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3536e-04 - mae: 0.0167 - val_loss: 7.6716e-04 - val_mae: 0.0171
# Epoch 33/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3340e-04 - mae: 0.0166 - val_loss: 7.7084e-04 - val_mae: 0.0170
# Epoch 34/50
# 236/236 [==============================] - 22s 91ms/step - loss: 7.3533e-04 - mae: 0.0167 - val_loss: 7.6520e-04 - val_mae: 0.0171
# Epoch 35/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3263e-04 - mae: 0.0166 - val_loss: 7.6572e-04 - val_mae: 0.0171
# Epoch 36/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3253e-04 - mae: 0.0167 - val_loss: 7.6229e-04 - val_mae: 0.0169
# Epoch 37/50
# 236/236 [==============================] - 22s 91ms/step - loss: 7.3397e-04 - mae: 0.0167 - val_loss: 7.7138e-04 - val_mae: 0.0171
# Epoch 38/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3559e-04 - mae: 0.0167 - val_loss: 7.7562e-04 - val_mae: 0.0171
# Epoch 39/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.3127e-04 - mae: 0.0166 - val_loss: 7.8025e-04 - val_mae: 0.0172
# Epoch 40/50
# 236/236 [==============================] - 22s 91ms/step - loss: 7.3235e-04 - mae: 0.0167 - val_loss: 7.6007e-04 - val_mae: 0.0168
# Epoch 41/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.2106e-04 - mae: 0.0164 - val_loss: 7.5390e-04 - val_mae: 0.0167
# Epoch 42/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1992e-04 - mae: 0.0164 - val_loss: 7.6258e-04 - val_mae: 0.0171
# Epoch 43/50
# 236/236 [==============================] - 22s 91ms/step - loss: 7.1903e-04 - mae: 0.0164 - val_loss: 7.5432e-04 - val_mae: 0.0168
# Epoch 44/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1828e-04 - mae: 0.0164 - val_loss: 7.5225e-04 - val_mae: 0.0168
# Epoch 45/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1874e-04 - mae: 0.0164 - val_loss: 7.5185e-04 - val_mae: 0.0168
# Epoch 46/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1895e-04 - mae: 0.0164 - val_loss: 7.5663e-04 - val_mae: 0.0170
# Epoch 47/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.2014e-04 - mae: 0.0164 - val_loss: 7.4886e-04 - val_mae: 0.0167
# Epoch 48/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1707e-04 - mae: 0.0164 - val_loss: 7.5111e-04 - val_mae: 0.0167
# Epoch 49/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1780e-04 - mae: 0.0164 - val_loss: 7.5598e-04 - val_mae: 0.0167
# Epoch 50/50
# 236/236 [==============================] - 22s 92ms/step - loss: 7.1635e-04 - mae: 0.0164 - val_loss: 7.5048e-04 - val_mae: 0.0168
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 400)               652800
# _________________________________________________________________
# dense_7 (Dense)              (None, 7)                 2807
# =================================================================
# Total params: 655,607
# Trainable params: 655,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 236/236 [==============================] - 28s 113ms/step - loss: 0.0059 - mae: 0.0444 - val_loss: 0.0016 - val_mae: 0.0285
# Epoch 2/50
# 236/236 [==============================] - 26s 111ms/step - loss: 0.0014 - mae: 0.0251 - val_loss: 0.0013 - val_mae: 0.0237
# Epoch 3/50
# 236/236 [==============================] - 26s 110ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0012 - val_mae: 0.0248
# Epoch 4/50
# 236/236 [==============================] - 26s 111ms/step - loss: 0.0010 - mae: 0.0213 - val_loss: 0.0011 - val_mae: 0.0213
# Epoch 5/50
# 236/236 [==============================] - 26s 111ms/step - loss: 9.6056e-04 - mae: 0.0203 - val_loss: 9.9107e-04 - val_mae: 0.0205
# Epoch 6/50
# 236/236 [==============================] - 26s 111ms/step - loss: 9.0820e-04 - mae: 0.0196 - val_loss: 9.0243e-04 - val_mae: 0.0191
# Epoch 7/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.7820e-04 - mae: 0.0192 - val_loss: 9.2924e-04 - val_mae: 0.0200
# Epoch 8/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.5975e-04 - mae: 0.0189 - val_loss: 8.9101e-04 - val_mae: 0.0194
# Epoch 9/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.3982e-04 - mae: 0.0186 - val_loss: 8.7959e-04 - val_mae: 0.0193
# Epoch 10/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.3015e-04 - mae: 0.0184 - val_loss: 8.4949e-04 - val_mae: 0.0185
# Epoch 11/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.2153e-04 - mae: 0.0183 - val_loss: 8.4311e-04 - val_mae: 0.0184
# Epoch 12/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.1208e-04 - mae: 0.0180 - val_loss: 8.4431e-04 - val_mae: 0.0183
# Epoch 13/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.0666e-04 - mae: 0.0180 - val_loss: 8.2667e-04 - val_mae: 0.0180
# Epoch 14/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.9832e-04 - mae: 0.0178 - val_loss: 8.7240e-04 - val_mae: 0.0185
# Epoch 15/50
# 236/236 [==============================] - 26s 111ms/step - loss: 8.0100e-04 - mae: 0.0179 - val_loss: 8.4437e-04 - val_mae: 0.0185
# Epoch 16/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.9160e-04 - mae: 0.0177 - val_loss: 8.3105e-04 - val_mae: 0.0182
# Epoch 17/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.7245e-04 - mae: 0.0173 - val_loss: 8.0247e-04 - val_mae: 0.0175
# Epoch 18/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.7209e-04 - mae: 0.0173 - val_loss: 8.0315e-04 - val_mae: 0.0178
# Epoch 19/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6958e-04 - mae: 0.0173 - val_loss: 8.0104e-04 - val_mae: 0.0176
# Epoch 20/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.6770e-04 - mae: 0.0172 - val_loss: 7.9281e-04 - val_mae: 0.0174
# Epoch 21/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.7191e-04 - mae: 0.0173 - val_loss: 7.9822e-04 - val_mae: 0.0175
# Epoch 22/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.7093e-04 - mae: 0.0173 - val_loss: 7.9054e-04 - val_mae: 0.0175
# Epoch 23/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6558e-04 - mae: 0.0172 - val_loss: 8.0740e-04 - val_mae: 0.0176
# Epoch 24/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6898e-04 - mae: 0.0172 - val_loss: 8.2850e-04 - val_mae: 0.0185
# Epoch 25/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6624e-04 - mae: 0.0172 - val_loss: 8.1307e-04 - val_mae: 0.0179
# Epoch 26/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6742e-04 - mae: 0.0172 - val_loss: 8.0446e-04 - val_mae: 0.0175
# Epoch 27/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6359e-04 - mae: 0.0172 - val_loss: 7.7834e-04 - val_mae: 0.0171
# Epoch 28/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.6975e-04 - mae: 0.0173 - val_loss: 7.8607e-04 - val_mae: 0.0174
# Epoch 29/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.6291e-04 - mae: 0.0171 - val_loss: 7.8637e-04 - val_mae: 0.0175
# Epoch 30/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.4093e-04 - mae: 0.0167 - val_loss: 7.9332e-04 - val_mae: 0.0176
# Epoch 31/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.4204e-04 - mae: 0.0168 - val_loss: 7.7151e-04 - val_mae: 0.0171
# Epoch 32/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.4214e-04 - mae: 0.0168 - val_loss: 7.7109e-04 - val_mae: 0.0171
# Epoch 33/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.4145e-04 - mae: 0.0167 - val_loss: 7.8153e-04 - val_mae: 0.0172
# Epoch 34/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.4278e-04 - mae: 0.0168 - val_loss: 7.6814e-04 - val_mae: 0.0171
# Epoch 35/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.3979e-04 - mae: 0.0167 - val_loss: 7.7053e-04 - val_mae: 0.0172
# Epoch 36/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.3846e-04 - mae: 0.0167 - val_loss: 7.6964e-04 - val_mae: 0.0170
# Epoch 37/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.4083e-04 - mae: 0.0168 - val_loss: 7.8430e-04 - val_mae: 0.0173
# Epoch 38/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.4304e-04 - mae: 0.0168 - val_loss: 7.8499e-04 - val_mae: 0.0171
# Epoch 39/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.3823e-04 - mae: 0.0167 - val_loss: 7.8807e-04 - val_mae: 0.0173
# Epoch 40/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.2665e-04 - mae: 0.0165 - val_loss: 7.5925e-04 - val_mae: 0.0169
# Epoch 41/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.2601e-04 - mae: 0.0165 - val_loss: 7.6235e-04 - val_mae: 0.0168
# Epoch 42/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.2473e-04 - mae: 0.0164 - val_loss: 7.6764e-04 - val_mae: 0.0172
# Epoch 43/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.2399e-04 - mae: 0.0164 - val_loss: 7.5695e-04 - val_mae: 0.0169
# Epoch 44/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.2266e-04 - mae: 0.0164 - val_loss: 7.5574e-04 - val_mae: 0.0169
# Epoch 45/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.2297e-04 - mae: 0.0164 - val_loss: 7.5603e-04 - val_mae: 0.0168
# Epoch 46/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.2320e-04 - mae: 0.0164 - val_loss: 7.5800e-04 - val_mae: 0.0169
# Epoch 47/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.2460e-04 - mae: 0.0165 - val_loss: 7.5582e-04 - val_mae: 0.0168
# Epoch 48/50
# 236/236 [==============================] - 26s 110ms/step - loss: 7.2136e-04 - mae: 0.0164 - val_loss: 7.5757e-04 - val_mae: 0.0168
# Epoch 49/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.2158e-04 - mae: 0.0164 - val_loss: 7.6285e-04 - val_mae: 0.0168
# Epoch 50/50
# 236/236 [==============================] - 26s 111ms/step - loss: 7.1399e-04 - mae: 0.0163 - val_loss: 7.5338e-04 - val_mae: 0.0168
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 450)               824400
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 3157
# =================================================================
# Total params: 827,557
# Trainable params: 827,557
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 236/236 [==============================] - 38s 154ms/step - loss: 0.0076 - mae: 0.0490 - val_loss: 0.0016 - val_mae: 0.0282
# Epoch 2/50
# 236/236 [==============================] - 36s 152ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 0.0013 - val_mae: 0.0245
# Epoch 3/50
# 236/236 [==============================] - 36s 152ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0012 - val_mae: 0.0242
# Epoch 4/50
# 236/236 [==============================] - 36s 152ms/step - loss: 0.0011 - mae: 0.0220 - val_loss: 0.0011 - val_mae: 0.0216
# Epoch 5/50
# 236/236 [==============================] - 36s 152ms/step - loss: 0.0010 - mae: 0.0209 - val_loss: 0.0010 - val_mae: 0.0207
# Epoch 6/50
# 236/236 [==============================] - 36s 152ms/step - loss: 9.4492e-04 - mae: 0.0202 - val_loss: 9.4326e-04 - val_mae: 0.0198
# Epoch 7/50
# 236/236 [==============================] - 36s 152ms/step - loss: 9.1185e-04 - mae: 0.0197 - val_loss: 9.5886e-04 - val_mae: 0.0207
# Epoch 8/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.9185e-04 - mae: 0.0194 - val_loss: 9.2437e-04 - val_mae: 0.0202
# Epoch 9/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.6203e-04 - mae: 0.0189 - val_loss: 8.9865e-04 - val_mae: 0.0196
# Epoch 10/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.4611e-04 - mae: 0.0187 - val_loss: 8.9097e-04 - val_mae: 0.0192
# Epoch 11/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.3434e-04 - mae: 0.0185 - val_loss: 8.6436e-04 - val_mae: 0.0185
# Epoch 12/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.2307e-04 - mae: 0.0183 - val_loss: 8.6140e-04 - val_mae: 0.0187
# Epoch 13/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.1529e-04 - mae: 0.0181 - val_loss: 8.4976e-04 - val_mae: 0.0185
# Epoch 14/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.1008e-04 - mae: 0.0181 - val_loss: 8.7574e-04 - val_mae: 0.0187
# Epoch 15/50
# 236/236 [==============================] - 36s 152ms/step - loss: 8.0828e-04 - mae: 0.0180 - val_loss: 8.5973e-04 - val_mae: 0.0187
# Epoch 16/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.9722e-04 - mae: 0.0178 - val_loss: 8.7591e-04 - val_mae: 0.0192
# Epoch 17/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7871e-04 - mae: 0.0174 - val_loss: 8.0646e-04 - val_mae: 0.0177
# Epoch 18/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7521e-04 - mae: 0.0174 - val_loss: 8.1135e-04 - val_mae: 0.0180
# Epoch 19/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7314e-04 - mae: 0.0174 - val_loss: 8.0980e-04 - val_mae: 0.0178
# Epoch 20/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.6951e-04 - mae: 0.0173 - val_loss: 8.0171e-04 - val_mae: 0.0177
# Epoch 21/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7590e-04 - mae: 0.0174 - val_loss: 8.1189e-04 - val_mae: 0.0179
# Epoch 22/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7781e-04 - mae: 0.0174 - val_loss: 7.9890e-04 - val_mae: 0.0177
# Epoch 23/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.6886e-04 - mae: 0.0173 - val_loss: 8.1501e-04 - val_mae: 0.0178
# Epoch 24/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7303e-04 - mae: 0.0173 - val_loss: 8.3352e-04 - val_mae: 0.0184
# Epoch 25/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7033e-04 - mae: 0.0173 - val_loss: 8.2015e-04 - val_mae: 0.0181
# Epoch 26/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.7114e-04 - mae: 0.0173 - val_loss: 8.1606e-04 - val_mae: 0.0179
# Epoch 27/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.6775e-04 - mae: 0.0173 - val_loss: 7.8047e-04 - val_mae: 0.0171
# Epoch 28/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.5106e-04 - mae: 0.0169 - val_loss: 8.0575e-04 - val_mae: 0.0178
# Epoch 29/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4930e-04 - mae: 0.0169 - val_loss: 7.7127e-04 - val_mae: 0.0171
# Epoch 30/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4580e-04 - mae: 0.0168 - val_loss: 8.0204e-04 - val_mae: 0.0177
# Epoch 31/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4753e-04 - mae: 0.0169 - val_loss: 7.7902e-04 - val_mae: 0.0174
# Epoch 32/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4665e-04 - mae: 0.0169 - val_loss: 7.7631e-04 - val_mae: 0.0171
# Epoch 33/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4775e-04 - mae: 0.0169 - val_loss: 7.9046e-04 - val_mae: 0.0174
# Epoch 34/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4885e-04 - mae: 0.0169 - val_loss: 7.7301e-04 - val_mae: 0.0172
# Epoch 35/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4351e-04 - mae: 0.0168 - val_loss: 7.7532e-04 - val_mae: 0.0173
# Epoch 36/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4413e-04 - mae: 0.0168 - val_loss: 7.7885e-04 - val_mae: 0.0173
# Epoch 37/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.4510e-04 - mae: 0.0169 - val_loss: 7.9126e-04 - val_mae: 0.0175
# Epoch 38/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.3178e-04 - mae: 0.0166 - val_loss: 7.6121e-04 - val_mae: 0.0168
# Epoch 39/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.3025e-04 - mae: 0.0166 - val_loss: 7.6775e-04 - val_mae: 0.0170
# Epoch 40/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2989e-04 - mae: 0.0166 - val_loss: 7.6227e-04 - val_mae: 0.0169
# Epoch 41/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.3023e-04 - mae: 0.0166 - val_loss: 7.5756e-04 - val_mae: 0.0167
# Epoch 42/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2911e-04 - mae: 0.0165 - val_loss: 7.8276e-04 - val_mae: 0.0176
# Epoch 43/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2789e-04 - mae: 0.0165 - val_loss: 7.6286e-04 - val_mae: 0.0171
# Epoch 44/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2704e-04 - mae: 0.0165 - val_loss: 7.5896e-04 - val_mae: 0.0170
# Epoch 45/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2778e-04 - mae: 0.0166 - val_loss: 7.7384e-04 - val_mae: 0.0171
# Epoch 46/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2752e-04 - mae: 0.0165 - val_loss: 7.6099e-04 - val_mae: 0.0170
# Epoch 47/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.2921e-04 - mae: 0.0166 - val_loss: 7.5963e-04 - val_mae: 0.0169
# Epoch 48/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.1863e-04 - mae: 0.0164 - val_loss: 7.5222e-04 - val_mae: 0.0167
# Epoch 49/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.1820e-04 - mae: 0.0163 - val_loss: 7.5957e-04 - val_mae: 0.0168
# Epoch 50/50
# 236/236 [==============================] - 36s 152ms/step - loss: 7.1773e-04 - mae: 0.0163 - val_loss: 7.5598e-04 - val_mae: 0.0168
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 500)               1016000
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 3507
# =================================================================
# Total params: 1,019,507
# Trainable params: 1,019,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 236/236 [==============================] - 38s 157ms/step - loss: 0.0052 - mae: 0.0416 - val_loss: 0.0016 - val_mae: 0.0276
# Epoch 2/50
# 236/236 [==============================] - 37s 155ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 0.0012 - val_mae: 0.0234
# Epoch 3/50
# 236/236 [==============================] - 37s 155ms/step - loss: 0.0011 - mae: 0.0226 - val_loss: 0.0012 - val_mae: 0.0241
# Epoch 4/50
# 236/236 [==============================] - 37s 155ms/step - loss: 0.0010 - mae: 0.0211 - val_loss: 0.0010 - val_mae: 0.0210
# Epoch 5/50
# 236/236 [==============================] - 37s 155ms/step - loss: 9.5657e-04 - mae: 0.0202 - val_loss: 9.8853e-04 - val_mae: 0.0204
# Epoch 6/50
# 236/236 [==============================] - 37s 155ms/step - loss: 9.0950e-04 - mae: 0.0196 - val_loss: 9.3072e-04 - val_mae: 0.0196
# Epoch 7/50
# 236/236 [==============================] - 36s 155ms/step - loss: 8.8517e-04 - mae: 0.0193 - val_loss: 9.4709e-04 - val_mae: 0.0205
# Epoch 8/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.6168e-04 - mae: 0.0189 - val_loss: 8.9594e-04 - val_mae: 0.0193
# Epoch 9/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.4821e-04 - mae: 0.0187 - val_loss: 8.8709e-04 - val_mae: 0.0194
# Epoch 10/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.3797e-04 - mae: 0.0185 - val_loss: 8.7776e-04 - val_mae: 0.0191
# Epoch 11/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.2543e-04 - mae: 0.0183 - val_loss: 8.7071e-04 - val_mae: 0.0189
# Epoch 12/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.1507e-04 - mae: 0.0181 - val_loss: 8.7968e-04 - val_mae: 0.0190
# Epoch 13/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.0957e-04 - mae: 0.0180 - val_loss: 8.4266e-04 - val_mae: 0.0184
# Epoch 14/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.0317e-04 - mae: 0.0179 - val_loss: 8.5830e-04 - val_mae: 0.0183
# Epoch 15/50
# 236/236 [==============================] - 37s 155ms/step - loss: 8.0257e-04 - mae: 0.0179 - val_loss: 8.5796e-04 - val_mae: 0.0189
# Epoch 16/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.9787e-04 - mae: 0.0178 - val_loss: 8.4552e-04 - val_mae: 0.0185
# Epoch 17/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7575e-04 - mae: 0.0173 - val_loss: 8.0883e-04 - val_mae: 0.0177
# Epoch 18/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7441e-04 - mae: 0.0173 - val_loss: 8.0914e-04 - val_mae: 0.0180
# Epoch 19/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7336e-04 - mae: 0.0173 - val_loss: 8.0875e-04 - val_mae: 0.0177
# Epoch 20/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7439e-04 - mae: 0.0173 - val_loss: 8.0091e-04 - val_mae: 0.0176
# Epoch 21/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7695e-04 - mae: 0.0174 - val_loss: 7.9773e-04 - val_mae: 0.0175
# Epoch 22/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7412e-04 - mae: 0.0173 - val_loss: 7.8650e-04 - val_mae: 0.0174
# Epoch 23/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.6801e-04 - mae: 0.0172 - val_loss: 8.1003e-04 - val_mae: 0.0177
# Epoch 24/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7512e-04 - mae: 0.0173 - val_loss: 8.1138e-04 - val_mae: 0.0179
# Epoch 25/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.7164e-04 - mae: 0.0173 - val_loss: 8.2908e-04 - val_mae: 0.0184
# Epoch 26/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.6919e-04 - mae: 0.0173 - val_loss: 8.0170e-04 - val_mae: 0.0175
# Epoch 27/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.6653e-04 - mae: 0.0172 - val_loss: 7.7814e-04 - val_mae: 0.0171
# Epoch 28/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4815e-04 - mae: 0.0168 - val_loss: 7.9541e-04 - val_mae: 0.0175
# Epoch 29/50
# 236/236 [==============================] - 36s 155ms/step - loss: 7.4591e-04 - mae: 0.0168 - val_loss: 7.6655e-04 - val_mae: 0.0170
# Epoch 30/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4257e-04 - mae: 0.0168 - val_loss: 7.8990e-04 - val_mae: 0.0175
# Epoch 31/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4358e-04 - mae: 0.0168 - val_loss: 7.7487e-04 - val_mae: 0.0173
# Epoch 32/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4259e-04 - mae: 0.0168 - val_loss: 7.7166e-04 - val_mae: 0.0171
# Epoch 33/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4388e-04 - mae: 0.0168 - val_loss: 7.8678e-04 - val_mae: 0.0174
# Epoch 34/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4511e-04 - mae: 0.0169 - val_loss: 7.6514e-04 - val_mae: 0.0170
# Epoch 35/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.3979e-04 - mae: 0.0167 - val_loss: 7.7415e-04 - val_mae: 0.0173
# Epoch 36/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4065e-04 - mae: 0.0168 - val_loss: 7.7922e-04 - val_mae: 0.0172
# Epoch 37/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.4238e-04 - mae: 0.0168 - val_loss: 7.8375e-04 - val_mae: 0.0173
# Epoch 38/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2783e-04 - mae: 0.0165 - val_loss: 7.5557e-04 - val_mae: 0.0168
# Epoch 39/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2593e-04 - mae: 0.0165 - val_loss: 7.6390e-04 - val_mae: 0.0170
# Epoch 40/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2641e-04 - mae: 0.0165 - val_loss: 7.5715e-04 - val_mae: 0.0169
# Epoch 41/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2654e-04 - mae: 0.0165 - val_loss: 7.5813e-04 - val_mae: 0.0167
# Epoch 42/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2494e-04 - mae: 0.0165 - val_loss: 7.7335e-04 - val_mae: 0.0174
# Epoch 43/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2411e-04 - mae: 0.0165 - val_loss: 7.5632e-04 - val_mae: 0.0169
# Epoch 44/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2314e-04 - mae: 0.0165 - val_loss: 7.5505e-04 - val_mae: 0.0169
# Epoch 45/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2291e-04 - mae: 0.0165 - val_loss: 7.7064e-04 - val_mae: 0.0170
# Epoch 46/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2371e-04 - mae: 0.0165 - val_loss: 7.5768e-04 - val_mae: 0.0170
# Epoch 47/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.2516e-04 - mae: 0.0165 - val_loss: 7.5633e-04 - val_mae: 0.0168
# Epoch 48/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.1455e-04 - mae: 0.0163 - val_loss: 7.4847e-04 - val_mae: 0.0166
# Epoch 49/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.1395e-04 - mae: 0.0163 - val_loss: 7.5733e-04 - val_mae: 0.0167
# Epoch 50/50
# 236/236 [==============================] - 37s 155ms/step - loss: 7.1357e-04 - mae: 0.0163 - val_loss: 7.5137e-04 - val_mae: 0.0168

# %%
models_array
# Out:
# [<keras.engine.functional.Functional at 0x7f22eadb5d90>,
#  <keras.engine.functional.Functional at 0x7f2351d81f90>,
#  <keras.engine.functional.Functional at 0x7f2351d4f390>,
#  <keras.engine.functional.Functional at 0x7f22e7c5cdd0>]

# %%
future_window = 1152

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred(model,sequence_length))

# %%
best_rmse = 100000
best_model = 0
for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is #" + str(best_model) + " w/ number of units: " + str(lstm_units[best_model]))
# Out:
# RMSE: 5.942057310292981  MAE: 3.690254490396443
# RMSE: 10.325654371494986  MAE: 5.6229162080352815
# RMSE: 8.937253582477886  MAE: 5.041231551025703
# RMSE: 12.233135493351146  MAE: 6.536558559279682
#
# Best model is #0 w/ number of units: 352

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=str(lstm_units[j]) + ' units' ,alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
# PLOT FOR THE PAPER

colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = 100
future_window = 400
for i in range(7):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:future_window,i],label=str(lstm_units[j]) + ' units' ,alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

    plt.savefig('plt_feature'+str(i))

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)

model_lables = ['- '+str(j)+' units' for j in lstm_units];

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ model_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ model_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + model_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ model_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ model_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ model_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ model_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ model_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
save_model(models_array[best_model],'model')
#save_model(model_2,'model_2')
# Out:
# 2022-01-12 11:25:31.613345: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# model saved!

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
