# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2data/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2data/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,future=1,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length+future < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length:i+sequence_length+future])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_conv_0(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x1 = tfkl.MaxPooling1D()(x)

    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = False,return_state=True)(x1,initial_state=[h1,c1])
       
    x = tfkl.Flatten()(x1)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_conv_1(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x1 = tfkl.AveragePooling1D()(x)

    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.AveragePooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.AveragePooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.AveragePooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = False,return_state=True)(x1,initial_state=[h1,c1])
       
    x = tfkl.Flatten()(x1)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    x = tfkl.Dense(256,activation='relu')(x)
    x = tfkl.Dropout(.2)(x)
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
stride = 1
sequence_length = 400
future = 4
X_train, y_train = extract_sequences(train_scaled,sequence_length, future, stride)
X_train.shape,y_train.shape
# Out:
# ((66972, 400, 7), (66972, 4, 7))

# %%
models_array = []
history_array = []

epochs = 200
batch_size = 256

    
input_shape = X_train.shape[1:]
print(input_shape)
models = [build_conv_0, build_conv_1]
models_lables = ['CNN LSTM 2','CNN LSTM 3']

for m in models:

    model = m(input_shape)
    model.summary()
    
    tfk.utils.plot_model(model)

    print("******************")
    
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.7, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# (400, 7)
# 2022-01-19 23:26:55.142606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:55.277823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:55.278988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:55.281467: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-19 23:26:55.283287: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:55.284434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:55.285456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:57.702052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:57.703218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:57.704236: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 23:26:57.705210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 400, 7)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 400, 16)      352         Input[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 400, 32)      1568        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 400, 64)      6208        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 400, 128)     24704       conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 400, 256)     98560       conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 400, 256)     1024        conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 200, 256)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 200, 256), ( 525312      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 200, 16)      12304       lstm[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 200, 32)      1568        conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 200, 64)      6208        conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 200, 128)     24704       conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 200, 256)     98560       conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 256)     1024        conv1d_9[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 256)     0           lstm[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 100, 256)     0           add[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 100, 256), ( 525312      max_pooling1d_1[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 100, 16)      12304       lstm_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 100, 32)      1568        conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 100, 64)      6208        conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 100, 128)     24704       conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 100, 256)     98560       conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 256)     1024        conv1d_14[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 256)     0           lstm_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 50, 256)      0           add_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      max_pooling1d_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 50, 16)       12304       lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 50, 32)       1568        conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 50, 64)       6208        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 50, 128)      24704       conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 50, 256)      98560       conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 256)      1024        conv1d_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 50, 256)      0           lstm_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 25, 256)      0           add_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, 256), (None, 525312      max_pooling1d_3[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 28)           7196        flatten[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 4, 7)         0           dense[0][0]
# ==================================================================================================
# Total params: 2,673,964
# Trainable params: 2,671,916
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# ******************
# 2022-01-19 23:27:02.796466: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-01-19 23:27:13.658627: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 236/236 [==============================] - 72s 227ms/step - loss: 0.0098 - mae: 0.0651 - val_loss: 0.2770 - val_mae: 0.4797
# Epoch 2/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0027 - mae: 0.0381 - val_loss: 0.0105 - val_mae: 0.0808
# Epoch 3/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0030 - val_mae: 0.0419
# Epoch 4/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0017 - mae: 0.0295 - val_loss: 0.0024 - val_mae: 0.0359
# Epoch 5/200
# 236/236 [==============================] - 50s 213ms/step - loss: 0.0015 - mae: 0.0282 - val_loss: 0.0023 - val_mae: 0.0360
# Epoch 6/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0019 - val_mae: 0.0326
# Epoch 7/200
# 236/236 [==============================] - 50s 213ms/step - loss: 0.0013 - mae: 0.0258 - val_loss: 0.0015 - val_mae: 0.0287
# Epoch 8/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 0.0017 - val_mae: 0.0309
# Epoch 9/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0012 - mae: 0.0247 - val_loss: 0.0017 - val_mae: 0.0303
# Epoch 10/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 0.0018 - val_mae: 0.0318
# Epoch 11/200
# 236/236 [==============================] - 50s 212ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0013 - val_mae: 0.0264
# Epoch 12/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0017 - val_mae: 0.0302
# Epoch 13/200
# 236/236 [==============================] - 51s 216ms/step - loss: 9.7225e-04 - mae: 0.0221 - val_loss: 0.0014 - val_mae: 0.0270
# Epoch 14/200
# 236/236 [==============================] - 50s 212ms/step - loss: 9.5340e-04 - mae: 0.0220 - val_loss: 0.0014 - val_mae: 0.0286
# Epoch 15/200
# 236/236 [==============================] - 50s 212ms/step - loss: 8.9660e-04 - mae: 0.0213 - val_loss: 0.0015 - val_mae: 0.0289
# Epoch 16/200
# 236/236 [==============================] - 50s 212ms/step - loss: 8.9433e-04 - mae: 0.0213 - val_loss: 0.0015 - val_mae: 0.0284
# Epoch 17/200
# 236/236 [==============================] - 50s 211ms/step - loss: 8.4635e-04 - mae: 0.0206 - val_loss: 0.0014 - val_mae: 0.0287
# Epoch 18/200
# 236/236 [==============================] - 50s 212ms/step - loss: 8.3070e-04 - mae: 0.0205 - val_loss: 0.0015 - val_mae: 0.0282
# Epoch 19/200
# 236/236 [==============================] - 50s 212ms/step - loss: 8.1111e-04 - mae: 0.0202 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 20/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.8313e-04 - mae: 0.0198 - val_loss: 0.0011 - val_mae: 0.0234
# Epoch 21/200
# 236/236 [==============================] - 50s 212ms/step - loss: 7.5946e-04 - mae: 0.0195 - val_loss: 0.0015 - val_mae: 0.0284
# Epoch 22/200
# 236/236 [==============================] - 50s 212ms/step - loss: 7.5408e-04 - mae: 0.0194 - val_loss: 0.0011 - val_mae: 0.0244
# Epoch 23/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.5161e-04 - mae: 0.0195 - val_loss: 0.0013 - val_mae: 0.0264
# Epoch 24/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.1172e-04 - mae: 0.0188 - val_loss: 0.0010 - val_mae: 0.0231
# Epoch 25/200
# 236/236 [==============================] - 50s 212ms/step - loss: 7.1022e-04 - mae: 0.0189 - val_loss: 0.0010 - val_mae: 0.0230
# Epoch 26/200
# 236/236 [==============================] - 50s 212ms/step - loss: 6.9602e-04 - mae: 0.0186 - val_loss: 9.6941e-04 - val_mae: 0.0222
# Epoch 27/200
# 236/236 [==============================] - 50s 211ms/step - loss: 6.6434e-04 - mae: 0.0182 - val_loss: 8.5024e-04 - val_mae: 0.0203
# Epoch 28/200
# 236/236 [==============================] - 50s 212ms/step - loss: 6.5929e-04 - mae: 0.0180 - val_loss: 9.1697e-04 - val_mae: 0.0215
# Epoch 29/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.1394e-04 - mae: 0.0188 - val_loss: 0.0011 - val_mae: 0.0243
# Epoch 30/200
# 236/236 [==============================] - 50s 211ms/step - loss: 6.7361e-04 - mae: 0.0183 - val_loss: 0.0010 - val_mae: 0.0231
# Epoch 31/200
# 236/236 [==============================] - 50s 212ms/step - loss: 6.4121e-04 - mae: 0.0178 - val_loss: 7.5732e-04 - val_mae: 0.0192
# Epoch 32/200
# 236/236 [==============================] - 50s 212ms/step - loss: 6.0613e-04 - mae: 0.0172 - val_loss: 8.1668e-04 - val_mae: 0.0198
# Epoch 33/200
# 236/236 [==============================] - 50s 212ms/step - loss: 5.9340e-04 - mae: 0.0170 - val_loss: 7.8188e-04 - val_mae: 0.0199
# Epoch 34/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.6824e-04 - mae: 0.0165 - val_loss: 0.0010 - val_mae: 0.0235
# Epoch 35/200
# 236/236 [==============================] - 50s 213ms/step - loss: 5.6800e-04 - mae: 0.0166 - val_loss: 8.4210e-04 - val_mae: 0.0206
# Epoch 36/200
# 236/236 [==============================] - 50s 212ms/step - loss: 5.7695e-04 - mae: 0.0168 - val_loss: 8.9989e-04 - val_mae: 0.0211
# Epoch 37/200
# 236/236 [==============================] - 50s 212ms/step - loss: 5.7214e-04 - mae: 0.0167 - val_loss: 7.7017e-04 - val_mae: 0.0196
# Epoch 38/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.9304e-04 - mae: 0.0153 - val_loss: 6.0886e-04 - val_mae: 0.0168
# Epoch 39/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.6773e-04 - mae: 0.0148 - val_loss: 6.0996e-04 - val_mae: 0.0171
# Epoch 40/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.6110e-04 - mae: 0.0147 - val_loss: 6.1122e-04 - val_mae: 0.0168
# Epoch 41/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.6736e-04 - mae: 0.0148 - val_loss: 7.6597e-04 - val_mae: 0.0197
# Epoch 42/200
# 236/236 [==============================] - 50s 213ms/step - loss: 4.6815e-04 - mae: 0.0149 - val_loss: 7.9988e-04 - val_mae: 0.0196
# Epoch 43/200
# 236/236 [==============================] - 50s 213ms/step - loss: 4.6718e-04 - mae: 0.0148 - val_loss: 6.2110e-04 - val_mae: 0.0170
# Epoch 44/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.7667e-04 - mae: 0.0151 - val_loss: 6.4559e-04 - val_mae: 0.0178
# Epoch 45/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.5350e-04 - mae: 0.0146 - val_loss: 0.0014 - val_mae: 0.0266
# Epoch 46/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.6633e-04 - mae: 0.0149 - val_loss: 6.3974e-04 - val_mae: 0.0176
# Epoch 47/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.6015e-04 - mae: 0.0147 - val_loss: 6.2206e-04 - val_mae: 0.0171
# Epoch 48/200
# 236/236 [==============================] - 50s 212ms/step - loss: 4.4737e-04 - mae: 0.0145 - val_loss: 6.3178e-04 - val_mae: 0.0173
# Epoch 49/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.9809e-04 - mae: 0.0135 - val_loss: 5.2702e-04 - val_mae: 0.0153
# Epoch 50/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.8345e-04 - mae: 0.0133 - val_loss: 6.0519e-04 - val_mae: 0.0166
# Epoch 51/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.7869e-04 - mae: 0.0131 - val_loss: 5.7315e-04 - val_mae: 0.0163
# Epoch 52/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.8061e-04 - mae: 0.0132 - val_loss: 5.4104e-04 - val_mae: 0.0156
# Epoch 53/200
# 236/236 [==============================] - 50s 211ms/step - loss: 3.8109e-04 - mae: 0.0132 - val_loss: 5.4843e-04 - val_mae: 0.0158
# Epoch 54/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.7943e-04 - mae: 0.0133 - val_loss: 5.7649e-04 - val_mae: 0.0165
# Epoch 55/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.7958e-04 - mae: 0.0133 - val_loss: 5.2514e-04 - val_mae: 0.0153
# Epoch 56/200
# 236/236 [==============================] - 50s 211ms/step - loss: 3.7718e-04 - mae: 0.0132 - val_loss: 5.1953e-04 - val_mae: 0.0154
# Epoch 57/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.6500e-04 - mae: 0.0130 - val_loss: 4.9104e-04 - val_mae: 0.0146
# Epoch 58/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.7049e-04 - mae: 0.0131 - val_loss: 4.9595e-04 - val_mae: 0.0148
# Epoch 59/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.6806e-04 - mae: 0.0131 - val_loss: 5.6136e-04 - val_mae: 0.0161
# Epoch 60/200
# 236/236 [==============================] - 50s 211ms/step - loss: 3.6042e-04 - mae: 0.0129 - val_loss: 5.4823e-04 - val_mae: 0.0160
# Epoch 61/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.6015e-04 - mae: 0.0129 - val_loss: 5.0363e-04 - val_mae: 0.0148
# Epoch 62/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.5474e-04 - mae: 0.0128 - val_loss: 4.9241e-04 - val_mae: 0.0146
# Epoch 63/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.4947e-04 - mae: 0.0127 - val_loss: 5.1593e-04 - val_mae: 0.0151
# Epoch 64/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.4578e-04 - mae: 0.0127 - val_loss: 5.0786e-04 - val_mae: 0.0151
# Epoch 65/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.5031e-04 - mae: 0.0128 - val_loss: 4.9066e-04 - val_mae: 0.0146
# Epoch 66/200
# 236/236 [==============================] - 50s 211ms/step - loss: 3.4836e-04 - mae: 0.0127 - val_loss: 4.8802e-04 - val_mae: 0.0147
# Epoch 67/200
# 236/236 [==============================] - 50s 211ms/step - loss: 3.3862e-04 - mae: 0.0125 - val_loss: 4.9923e-04 - val_mae: 0.0149
# Epoch 68/200
# 236/236 [==============================] - 50s 212ms/step - loss: 3.1222e-04 - mae: 0.0120 - val_loss: 4.6442e-04 - val_mae: 0.0143
# Epoch 69/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.9622e-04 - mae: 0.0117 - val_loss: 4.4455e-04 - val_mae: 0.0138
# Epoch 70/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.9268e-04 - mae: 0.0116 - val_loss: 4.6250e-04 - val_mae: 0.0142
# Epoch 71/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.9059e-04 - mae: 0.0116 - val_loss: 4.4646e-04 - val_mae: 0.0138
# Epoch 72/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.9741e-04 - mae: 0.0117 - val_loss: 4.5559e-04 - val_mae: 0.0140
# Epoch 73/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.9075e-04 - mae: 0.0116 - val_loss: 4.5285e-04 - val_mae: 0.0140
# Epoch 74/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.8605e-04 - mae: 0.0115 - val_loss: 4.5214e-04 - val_mae: 0.0140
# Epoch 75/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.8676e-04 - mae: 0.0115 - val_loss: 4.7806e-04 - val_mae: 0.0144
# Epoch 76/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.8640e-04 - mae: 0.0115 - val_loss: 4.6895e-04 - val_mae: 0.0143
# Epoch 77/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.8195e-04 - mae: 0.0114 - val_loss: 4.5831e-04 - val_mae: 0.0140
# Epoch 78/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.6198e-04 - mae: 0.0110 - val_loss: 4.3224e-04 - val_mae: 0.0133
# Epoch 79/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.5330e-04 - mae: 0.0109 - val_loss: 4.3697e-04 - val_mae: 0.0135
# Epoch 80/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.5286e-04 - mae: 0.0109 - val_loss: 4.4601e-04 - val_mae: 0.0139
# Epoch 81/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.5055e-04 - mae: 0.0108 - val_loss: 4.3983e-04 - val_mae: 0.0137
# Epoch 82/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.5111e-04 - mae: 0.0108 - val_loss: 4.3925e-04 - val_mae: 0.0135
# Epoch 83/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.4689e-04 - mae: 0.0107 - val_loss: 4.3295e-04 - val_mae: 0.0133
# Epoch 84/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.4338e-04 - mae: 0.0107 - val_loss: 4.3240e-04 - val_mae: 0.0134
# Epoch 85/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.4322e-04 - mae: 0.0107 - val_loss: 4.4764e-04 - val_mae: 0.0136
# Epoch 86/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.4463e-04 - mae: 0.0108 - val_loss: 4.4001e-04 - val_mae: 0.0135
# Epoch 87/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.4097e-04 - mae: 0.0106 - val_loss: 4.4409e-04 - val_mae: 0.0136
# Epoch 88/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.2863e-04 - mae: 0.0103 - val_loss: 4.2688e-04 - val_mae: 0.0132
# Epoch 89/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.2133e-04 - mae: 0.0102 - val_loss: 4.3574e-04 - val_mae: 0.0133
# Epoch 90/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.1982e-04 - mae: 0.0102 - val_loss: 4.3269e-04 - val_mae: 0.0132
# Epoch 91/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.1571e-04 - mae: 0.0101 - val_loss: 4.3561e-04 - val_mae: 0.0132
# Epoch 92/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.1354e-04 - mae: 0.0101 - val_loss: 4.4000e-04 - val_mae: 0.0133
# Epoch 93/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.1198e-04 - mae: 0.0101 - val_loss: 4.3237e-04 - val_mae: 0.0132
# Epoch 94/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.1231e-04 - mae: 0.0101 - val_loss: 4.3923e-04 - val_mae: 0.0133
# Epoch 95/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.1235e-04 - mae: 0.0101 - val_loss: 4.4130e-04 - val_mae: 0.0134
# Epoch 96/200
# 236/236 [==============================] - 50s 211ms/step - loss: 2.0931e-04 - mae: 0.0100 - val_loss: 4.3740e-04 - val_mae: 0.0133
# Epoch 97/200
# 236/236 [==============================] - 50s 212ms/step - loss: 2.0846e-04 - mae: 0.0100 - val_loss: 4.4159e-04 - val_mae: 0.0133
# Epoch 98/200
# 236/236 [==============================] - 50s 210ms/step - loss: 2.0035e-04 - mae: 0.0098 - val_loss: 4.3164e-04 - val_mae: 0.0131
# Epoch 99/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.9465e-04 - mae: 0.0097 - val_loss: 4.4224e-04 - val_mae: 0.0132
# Epoch 100/200
# 236/236 [==============================] - 50s 212ms/step - loss: 1.9296e-04 - mae: 0.0097 - val_loss: 4.3730e-04 - val_mae: 0.0132
# Epoch 101/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.9199e-04 - mae: 0.0096 - val_loss: 4.4195e-04 - val_mae: 0.0133
# Epoch 102/200
# 236/236 [==============================] - 50s 212ms/step - loss: 1.9056e-04 - mae: 0.0096 - val_loss: 4.4160e-04 - val_mae: 0.0132
# Epoch 103/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.8948e-04 - mae: 0.0096 - val_loss: 4.4233e-04 - val_mae: 0.0132
# Epoch 104/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.8777e-04 - mae: 0.0096 - val_loss: 4.4462e-04 - val_mae: 0.0134
# Epoch 105/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.8662e-04 - mae: 0.0095 - val_loss: 4.4408e-04 - val_mae: 0.0133
# Epoch 106/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.8594e-04 - mae: 0.0095 - val_loss: 4.4587e-04 - val_mae: 0.0133
# Epoch 107/200
# 236/236 [==============================] - 50s 212ms/step - loss: 1.8417e-04 - mae: 0.0095 - val_loss: 4.5873e-04 - val_mae: 0.0136
# Epoch 108/200
# 236/236 [==============================] - 50s 211ms/step - loss: 1.7839e-04 - mae: 0.0093 - val_loss: 4.4962e-04 - val_mae: 0.0132
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 400, 7)]     0
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 400, 16)      352         Input[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 400, 32)      1568        conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 400, 64)      6208        conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 400, 128)     24704       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 400, 256)     98560       conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 400, 256)     1024        conv1d_24[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 200, 256)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 200, 256), ( 525312      average_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 200, 16)      12304       lstm_4[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 200, 32)      1568        conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 200, 64)      6208        conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 200, 128)     24704       conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 200, 256)     98560       conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 256)     1024        conv1d_29[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 200, 256)     0           lstm_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 100, 256)     0           add_3[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 100, 256), ( 525312      average_pooling1d_1[0][0]
#                                                                  lstm_4[0][1]
#                                                                  lstm_4[0][2]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 100, 16)      12304       lstm_5[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 100, 32)      1568        conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 100, 64)      6208        conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 100, 128)     24704       conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 100, 256)     98560       conv1d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 100, 256)     1024        conv1d_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 100, 256)     0           lstm_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_2 (AveragePoo (None, 50, 256)      0           add_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 50, 256), (N 525312      average_pooling1d_2[0][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 50, 16)       12304       lstm_6[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 50, 32)       1568        conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 50, 64)       6208        conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 50, 128)      24704       conv1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 50, 256)      98560       conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 256)      1024        conv1d_39[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 50, 256)      0           lstm_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_3 (AveragePoo (None, 25, 256)      0           add_5[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, 256), (None, 525312      average_pooling1d_3[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           lstm_7[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 28)           7196        dropout[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 4, 7)         0           dense_2[0][0]
# ==================================================================================================
# Total params: 2,739,756
# Trainable params: 2,737,708
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# ******************
# Epoch 1/200
# 236/236 [==============================] - 60s 218ms/step - loss: 0.0158 - mae: 0.0907 - val_loss: 0.0387 - val_mae: 0.1619
# Epoch 2/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0054 - mae: 0.0569 - val_loss: 0.0247 - val_mae: 0.1249
# Epoch 3/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0041 - mae: 0.0496 - val_loss: 0.0031 - val_mae: 0.0420
# Epoch 4/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0035 - mae: 0.0456 - val_loss: 0.0020 - val_mae: 0.0329
# Epoch 5/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0030 - mae: 0.0422 - val_loss: 0.0026 - val_mae: 0.0384
# Epoch 6/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0028 - mae: 0.0401 - val_loss: 0.0024 - val_mae: 0.0366
# Epoch 7/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0025 - mae: 0.0378 - val_loss: 0.0021 - val_mae: 0.0342
# Epoch 8/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0023 - mae: 0.0366 - val_loss: 0.0026 - val_mae: 0.0391
# Epoch 9/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0021 - mae: 0.0350 - val_loss: 0.0021 - val_mae: 0.0347
# Epoch 10/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0020 - mae: 0.0335 - val_loss: 0.0018 - val_mae: 0.0317
# Epoch 11/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0018 - mae: 0.0323 - val_loss: 0.0014 - val_mae: 0.0262
# Epoch 12/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0017 - mae: 0.0314 - val_loss: 0.0020 - val_mae: 0.0335
# Epoch 13/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0013 - val_mae: 0.0268
# Epoch 14/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0016 - mae: 0.0294 - val_loss: 0.0020 - val_mae: 0.0327
# Epoch 15/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0020 - val_mae: 0.0333
# Epoch 16/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0014 - mae: 0.0281 - val_loss: 0.0013 - val_mae: 0.0262
# Epoch 17/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0016 - val_mae: 0.0291
# Epoch 18/200
# 236/236 [==============================] - 50s 211ms/step - loss: 0.0013 - mae: 0.0268 - val_loss: 0.0025 - val_mae: 0.0353
# Epoch 19/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0041 - val_mae: 0.0487
# Epoch 20/200
# 236/236 [==============================] - 49s 209ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 0.0013 - val_mae: 0.0249
# Epoch 21/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 0.0011 - val_mae: 0.0232
# Epoch 22/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 0.0018 - val_mae: 0.0311
# Epoch 23/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0011 - val_mae: 0.0237
# Epoch 24/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 0.0016 - val_mae: 0.0292
# Epoch 25/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0231
# Epoch 26/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0010 - mae: 0.0236 - val_loss: 0.0011 - val_mae: 0.0233
# Epoch 27/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0010 - mae: 0.0236 - val_loss: 0.0010 - val_mae: 0.0227
# Epoch 28/200
# 236/236 [==============================] - 50s 210ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0014 - val_mae: 0.0269
# Epoch 29/200
# 236/236 [==============================] - 50s 210ms/step - loss: 9.9230e-04 - mae: 0.0229 - val_loss: 0.0013 - val_mae: 0.0266
# Epoch 30/200
# 236/236 [==============================] - 50s 211ms/step - loss: 9.6360e-04 - mae: 0.0225 - val_loss: 0.0011 - val_mae: 0.0241
# Epoch 31/200
# 236/236 [==============================] - 50s 211ms/step - loss: 9.5316e-04 - mae: 0.0223 - val_loss: 0.0013 - val_mae: 0.0258
# Epoch 32/200
# 236/236 [==============================] - 50s 210ms/step - loss: 8.6109e-04 - mae: 0.0212 - val_loss: 7.4695e-04 - val_mae: 0.0192
# Epoch 33/200
# 236/236 [==============================] - 50s 211ms/step - loss: 8.3988e-04 - mae: 0.0209 - val_loss: 7.5798e-04 - val_mae: 0.0190
# Epoch 34/200
# 236/236 [==============================] - 50s 210ms/step - loss: 8.3032e-04 - mae: 0.0208 - val_loss: 9.3178e-04 - val_mae: 0.0217
# Epoch 35/200
# 236/236 [==============================] - 50s 211ms/step - loss: 8.3797e-04 - mae: 0.0209 - val_loss: 7.1478e-04 - val_mae: 0.0188
# Epoch 36/200
# 236/236 [==============================] - 50s 210ms/step - loss: 8.2509e-04 - mae: 0.0207 - val_loss: 6.9387e-04 - val_mae: 0.0181
# Epoch 37/200
# 236/236 [==============================] - 50s 211ms/step - loss: 8.1571e-04 - mae: 0.0205 - val_loss: 8.8413e-04 - val_mae: 0.0212
# Epoch 38/200
# 236/236 [==============================] - 50s 211ms/step - loss: 8.1374e-04 - mae: 0.0205 - val_loss: 9.5858e-04 - val_mae: 0.0224
# Epoch 39/200
# 236/236 [==============================] - 50s 210ms/step - loss: 8.1862e-04 - mae: 0.0205 - val_loss: 0.0028 - val_mae: 0.0355
# Epoch 40/200
# 236/236 [==============================] - 50s 211ms/step - loss: 8.2147e-04 - mae: 0.0206 - val_loss: 7.3148e-04 - val_mae: 0.0189
# Epoch 41/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.9782e-04 - mae: 0.0202 - val_loss: 0.0013 - val_mae: 0.0251
# Epoch 42/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.8874e-04 - mae: 0.0201 - val_loss: 9.0750e-04 - val_mae: 0.0206
# Epoch 43/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.4138e-04 - mae: 0.0195 - val_loss: 6.0538e-04 - val_mae: 0.0167
# Epoch 44/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.2385e-04 - mae: 0.0193 - val_loss: 6.0203e-04 - val_mae: 0.0168
# Epoch 45/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.1947e-04 - mae: 0.0192 - val_loss: 6.4473e-04 - val_mae: 0.0174
# Epoch 46/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.1791e-04 - mae: 0.0192 - val_loss: 6.1497e-04 - val_mae: 0.0168
# Epoch 47/200
# 236/236 [==============================] - 49s 210ms/step - loss: 7.1732e-04 - mae: 0.0192 - val_loss: 6.1395e-04 - val_mae: 0.0167
# Epoch 48/200
# 236/236 [==============================] - 49s 210ms/step - loss: 7.1279e-04 - mae: 0.0191 - val_loss: 6.6710e-04 - val_mae: 0.0176
# Epoch 49/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.1088e-04 - mae: 0.0191 - val_loss: 8.2372e-04 - val_mae: 0.0197
# Epoch 50/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.0818e-04 - mae: 0.0190 - val_loss: 6.0463e-04 - val_mae: 0.0169
# Epoch 51/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.0688e-04 - mae: 0.0190 - val_loss: 6.2306e-04 - val_mae: 0.0171
# Epoch 52/200
# 236/236 [==============================] - 50s 211ms/step - loss: 7.0916e-04 - mae: 0.0191 - val_loss: 8.7086e-04 - val_mae: 0.0209
# Epoch 53/200
# 236/236 [==============================] - 50s 210ms/step - loss: 7.0408e-04 - mae: 0.0190 - val_loss: 5.9583e-04 - val_mae: 0.0166
# Epoch 54/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.6042e-04 - mae: 0.0184 - val_loss: 5.4851e-04 - val_mae: 0.0158
# Epoch 55/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.4761e-04 - mae: 0.0182 - val_loss: 5.1838e-04 - val_mae: 0.0152
# Epoch 56/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.4851e-04 - mae: 0.0182 - val_loss: 5.5887e-04 - val_mae: 0.0161
# Epoch 57/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.4339e-04 - mae: 0.0182 - val_loss: 5.1181e-04 - val_mae: 0.0151
# Epoch 58/200
# 236/236 [==============================] - 49s 209ms/step - loss: 6.4348e-04 - mae: 0.0182 - val_loss: 5.2603e-04 - val_mae: 0.0154
# Epoch 59/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.4521e-04 - mae: 0.0182 - val_loss: 5.4425e-04 - val_mae: 0.0159
# Epoch 60/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.3654e-04 - mae: 0.0181 - val_loss: 5.3055e-04 - val_mae: 0.0156
# Epoch 61/200
# 236/236 [==============================] - 50s 211ms/step - loss: 6.3775e-04 - mae: 0.0181 - val_loss: 6.3113e-04 - val_mae: 0.0173
# Epoch 62/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.3478e-04 - mae: 0.0180 - val_loss: 5.5946e-04 - val_mae: 0.0160
# Epoch 63/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.3167e-04 - mae: 0.0180 - val_loss: 5.3090e-04 - val_mae: 0.0155
# Epoch 64/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.1259e-04 - mae: 0.0177 - val_loss: 5.3842e-04 - val_mae: 0.0157
# Epoch 65/200
# 236/236 [==============================] - 50s 211ms/step - loss: 6.0265e-04 - mae: 0.0176 - val_loss: 4.9083e-04 - val_mae: 0.0148
# Epoch 66/200
# 236/236 [==============================] - 50s 210ms/step - loss: 6.0223e-04 - mae: 0.0176 - val_loss: 4.8887e-04 - val_mae: 0.0147
# Epoch 67/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.9980e-04 - mae: 0.0175 - val_loss: 4.8622e-04 - val_mae: 0.0148
# Epoch 68/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.9844e-04 - mae: 0.0175 - val_loss: 4.8511e-04 - val_mae: 0.0147
# Epoch 69/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.9618e-04 - mae: 0.0175 - val_loss: 4.9300e-04 - val_mae: 0.0148
# Epoch 70/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.9546e-04 - mae: 0.0175 - val_loss: 4.8722e-04 - val_mae: 0.0147
# Epoch 71/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.9147e-04 - mae: 0.0174 - val_loss: 4.7481e-04 - val_mae: 0.0146
# Epoch 72/200
# 236/236 [==============================] - 49s 209ms/step - loss: 5.9380e-04 - mae: 0.0174 - val_loss: 5.1195e-04 - val_mae: 0.0152
# Epoch 73/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.8798e-04 - mae: 0.0174 - val_loss: 4.8353e-04 - val_mae: 0.0146
# Epoch 74/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.8880e-04 - mae: 0.0174 - val_loss: 5.0141e-04 - val_mae: 0.0150
# Epoch 75/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.8598e-04 - mae: 0.0173 - val_loss: 4.7369e-04 - val_mae: 0.0144
# Epoch 76/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.7158e-04 - mae: 0.0171 - val_loss: 4.4978e-04 - val_mae: 0.0140
# Epoch 77/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.6684e-04 - mae: 0.0171 - val_loss: 4.5469e-04 - val_mae: 0.0141
# Epoch 78/200
# ...
# Epoch 92/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.3932e-04 - mae: 0.0167 - val_loss: 4.3145e-04 - val_mae: 0.0137
# Epoch 93/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.3562e-04 - mae: 0.0166 - val_loss: 4.2647e-04 - val_mae: 0.0136
# Epoch 94/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.3672e-04 - mae: 0.0166 - val_loss: 4.2496e-04 - val_mae: 0.0136
# Epoch 95/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.3389e-04 - mae: 0.0166 - val_loss: 4.2316e-04 - val_mae: 0.0135
# Epoch 96/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.2918e-04 - mae: 0.0165 - val_loss: 4.2473e-04 - val_mae: 0.0135
# Epoch 97/200
# 236/236 [==============================] - 49s 210ms/step - loss: 5.2744e-04 - mae: 0.0165 - val_loss: 4.1852e-04 - val_mae: 0.0134
# Epoch 98/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.2721e-04 - mae: 0.0165 - val_loss: 4.1476e-04 - val_mae: 0.0133
# Epoch 99/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.2357e-04 - mae: 0.0164 - val_loss: 4.1049e-04 - val_mae: 0.0132
# Epoch 100/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.2369e-04 - mae: 0.0164 - val_loss: 4.1425e-04 - val_mae: 0.0133
# Epoch 101/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.2309e-04 - mae: 0.0164 - val_loss: 4.0780e-04 - val_mae: 0.0131
# Epoch 102/200
# 236/236 [==============================] - 49s 210ms/step - loss: 5.2211e-04 - mae: 0.0164 - val_loss: 4.1357e-04 - val_mae: 0.0133
# Epoch 103/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.2059e-04 - mae: 0.0164 - val_loss: 4.1308e-04 - val_mae: 0.0133
# Epoch 104/200
# 236/236 [==============================] - 49s 210ms/step - loss: 5.2057e-04 - mae: 0.0164 - val_loss: 4.2278e-04 - val_mae: 0.0135
# Epoch 105/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.2052e-04 - mae: 0.0164 - val_loss: 4.1439e-04 - val_mae: 0.0133
# Epoch 106/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.1445e-04 - mae: 0.0163 - val_loss: 4.0710e-04 - val_mae: 0.0131
# Epoch 107/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.1387e-04 - mae: 0.0163 - val_loss: 4.0626e-04 - val_mae: 0.0131
# Epoch 108/200
# 236/236 [==============================] - 49s 209ms/step - loss: 5.1304e-04 - mae: 0.0163 - val_loss: 4.0208e-04 - val_mae: 0.0130
# Epoch 109/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.1280e-04 - mae: 0.0163 - val_loss: 4.0542e-04 - val_mae: 0.0131
# Epoch 110/200
# 236/236 [==============================] - 49s 209ms/step - loss: 5.1458e-04 - mae: 0.0163 - val_loss: 4.0416e-04 - val_mae: 0.0130
# Epoch 111/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.1210e-04 - mae: 0.0163 - val_loss: 4.0410e-04 - val_mae: 0.0130
# Epoch 112/200
# 236/236 [==============================] - 49s 209ms/step - loss: 5.1044e-04 - mae: 0.0162 - val_loss: 4.0689e-04 - val_mae: 0.0131
# Epoch 113/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.1116e-04 - mae: 0.0162 - val_loss: 4.0471e-04 - val_mae: 0.0131
# Epoch 114/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.1031e-04 - mae: 0.0162 - val_loss: 4.0606e-04 - val_mae: 0.0131
# Epoch 115/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.0994e-04 - mae: 0.0162 - val_loss: 4.0799e-04 - val_mae: 0.0131
# Epoch 116/200
# 236/236 [==============================] - 49s 210ms/step - loss: 5.0576e-04 - mae: 0.0162 - val_loss: 4.0026e-04 - val_mae: 0.0130
# Epoch 117/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.0543e-04 - mae: 0.0162 - val_loss: 4.0029e-04 - val_mae: 0.0129
# Epoch 118/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.0664e-04 - mae: 0.0162 - val_loss: 3.9781e-04 - val_mae: 0.0129
# Epoch 119/200
# 236/236 [==============================] - 49s 210ms/step - loss: 5.0343e-04 - mae: 0.0161 - val_loss: 3.9645e-04 - val_mae: 0.0129
# Epoch 120/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.0429e-04 - mae: 0.0161 - val_loss: 4.0131e-04 - val_mae: 0.0130
# Epoch 121/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.0232e-04 - mae: 0.0161 - val_loss: 3.9934e-04 - val_mae: 0.0130
# Epoch 122/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.0623e-04 - mae: 0.0162 - val_loss: 3.9915e-04 - val_mae: 0.0129
# Epoch 123/200
# 236/236 [==============================] - 50s 211ms/step - loss: 5.0149e-04 - mae: 0.0161 - val_loss: 3.9503e-04 - val_mae: 0.0129
# Epoch 124/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.0331e-04 - mae: 0.0161 - val_loss: 3.9857e-04 - val_mae: 0.0130
# Epoch 125/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.0102e-04 - mae: 0.0161 - val_loss: 3.9584e-04 - val_mae: 0.0129
# Epoch 126/200
# 236/236 [==============================] - 50s 210ms/step - loss: 5.0147e-04 - mae: 0.0161 - val_loss: 3.9470e-04 - val_mae: 0.0128
# Epoch 127/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9812e-04 - mae: 0.0160 - val_loss: 3.9734e-04 - val_mae: 0.0129
# Epoch 128/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9980e-04 - mae: 0.0161 - val_loss: 3.9339e-04 - val_mae: 0.0128
# Epoch 129/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9776e-04 - mae: 0.0160 - val_loss: 3.9324e-04 - val_mae: 0.0128
# Epoch 130/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9984e-04 - mae: 0.0161 - val_loss: 3.9578e-04 - val_mae: 0.0129
# Epoch 131/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9617e-04 - mae: 0.0160 - val_loss: 3.9547e-04 - val_mae: 0.0128
# Epoch 132/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9762e-04 - mae: 0.0160 - val_loss: 3.9198e-04 - val_mae: 0.0128
# Epoch 133/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9771e-04 - mae: 0.0160 - val_loss: 3.9645e-04 - val_mae: 0.0129
# Epoch 134/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9940e-04 - mae: 0.0160 - val_loss: 3.9525e-04 - val_mae: 0.0129
# Epoch 135/200
# 236/236 [==============================] - 49s 209ms/step - loss: 4.9830e-04 - mae: 0.0160 - val_loss: 3.9284e-04 - val_mae: 0.0128
# Epoch 136/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9745e-04 - mae: 0.0160 - val_loss: 3.9212e-04 - val_mae: 0.0128
# Epoch 137/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9683e-04 - mae: 0.0160 - val_loss: 3.9242e-04 - val_mae: 0.0128
# Epoch 138/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9403e-04 - mae: 0.0160 - val_loss: 3.9184e-04 - val_mae: 0.0128
# Epoch 139/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9454e-04 - mae: 0.0160 - val_loss: 3.9155e-04 - val_mae: 0.0127
# Epoch 140/200
# 236/236 [==============================] - 50s 214ms/step - loss: 4.9341e-04 - mae: 0.0160 - val_loss: 3.9360e-04 - val_mae: 0.0128
# Epoch 141/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9419e-04 - mae: 0.0160 - val_loss: 3.9223e-04 - val_mae: 0.0128
# Epoch 142/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9332e-04 - mae: 0.0160 - val_loss: 3.9091e-04 - val_mae: 0.0128
# Epoch 143/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9471e-04 - mae: 0.0160 - val_loss: 3.8989e-04 - val_mae: 0.0127
# Epoch 144/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9630e-04 - mae: 0.0160 - val_loss: 3.9142e-04 - val_mae: 0.0128
# Epoch 145/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9413e-04 - mae: 0.0160 - val_loss: 3.9033e-04 - val_mae: 0.0127
# Epoch 146/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9342e-04 - mae: 0.0160 - val_loss: 3.9152e-04 - val_mae: 0.0127
# Epoch 147/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9363e-04 - mae: 0.0160 - val_loss: 3.9041e-04 - val_mae: 0.0127
# Epoch 148/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9444e-04 - mae: 0.0160 - val_loss: 3.9157e-04 - val_mae: 0.0128
# Epoch 149/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9236e-04 - mae: 0.0159 - val_loss: 3.9217e-04 - val_mae: 0.0128
# Epoch 150/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9218e-04 - mae: 0.0159 - val_loss: 3.9093e-04 - val_mae: 0.0128
# Epoch 151/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.9286e-04 - mae: 0.0160 - val_loss: 3.8925e-04 - val_mae: 0.0127
# Epoch 152/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9353e-04 - mae: 0.0160 - val_loss: 3.8991e-04 - val_mae: 0.0127
# Epoch 153/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9264e-04 - mae: 0.0160 - val_loss: 3.8976e-04 - val_mae: 0.0127
# Epoch 154/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9169e-04 - mae: 0.0159 - val_loss: 3.9042e-04 - val_mae: 0.0127
# Epoch 155/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9289e-04 - mae: 0.0160 - val_loss: 3.8933e-04 - val_mae: 0.0127
# Epoch 156/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.9241e-04 - mae: 0.0160 - val_loss: 3.8968e-04 - val_mae: 0.0127
# Epoch 157/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9205e-04 - mae: 0.0159 - val_loss: 3.8844e-04 - val_mae: 0.0127
# Epoch 158/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.9120e-04 - mae: 0.0159 - val_loss: 3.8798e-04 - val_mae: 0.0127
# Epoch 159/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9218e-04 - mae: 0.0159 - val_loss: 3.8936e-04 - val_mae: 0.0127
# Epoch 160/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9207e-04 - mae: 0.0159 - val_loss: 3.8895e-04 - val_mae: 0.0127
# Epoch 161/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8986e-04 - mae: 0.0159 - val_loss: 3.8751e-04 - val_mae: 0.0127
# Epoch 162/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9237e-04 - mae: 0.0159 - val_loss: 3.8922e-04 - val_mae: 0.0127
# Epoch 163/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.8902e-04 - mae: 0.0159 - val_loss: 3.8899e-04 - val_mae: 0.0127
# Epoch 164/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9008e-04 - mae: 0.0159 - val_loss: 3.8794e-04 - val_mae: 0.0127
# Epoch 165/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8996e-04 - mae: 0.0159 - val_loss: 3.8746e-04 - val_mae: 0.0127
# Epoch 166/200
# 236/236 [==============================] - 49s 209ms/step - loss: 4.8872e-04 - mae: 0.0159 - val_loss: 3.8821e-04 - val_mae: 0.0127
# Epoch 167/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9001e-04 - mae: 0.0159 - val_loss: 3.8827e-04 - val_mae: 0.0127
# Epoch 168/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8894e-04 - mae: 0.0159 - val_loss: 3.8649e-04 - val_mae: 0.0126
# Epoch 169/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9002e-04 - mae: 0.0159 - val_loss: 3.8795e-04 - val_mae: 0.0127
# Epoch 170/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.8775e-04 - mae: 0.0159 - val_loss: 3.8779e-04 - val_mae: 0.0127
# Epoch 171/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.9016e-04 - mae: 0.0159 - val_loss: 3.8743e-04 - val_mae: 0.0126
# Epoch 172/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9070e-04 - mae: 0.0159 - val_loss: 3.8713e-04 - val_mae: 0.0127
# Epoch 173/200
# 236/236 [==============================] - 51s 214ms/step - loss: 4.8960e-04 - mae: 0.0159 - val_loss: 3.8826e-04 - val_mae: 0.0127
# Epoch 174/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8986e-04 - mae: 0.0159 - val_loss: 3.8696e-04 - val_mae: 0.0127
# Epoch 175/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8794e-04 - mae: 0.0159 - val_loss: 3.8718e-04 - val_mae: 0.0127
# Epoch 176/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8923e-04 - mae: 0.0159 - val_loss: 3.8672e-04 - val_mae: 0.0126
# Epoch 177/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8943e-04 - mae: 0.0159 - val_loss: 3.8752e-04 - val_mae: 0.0127
# Epoch 178/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.8949e-04 - mae: 0.0159 - val_loss: 3.8680e-04 - val_mae: 0.0127
# Epoch 179/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.8721e-04 - mae: 0.0159 - val_loss: 3.8716e-04 - val_mae: 0.0127
# Epoch 180/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8947e-04 - mae: 0.0159 - val_loss: 3.8643e-04 - val_mae: 0.0126
# Epoch 181/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8717e-04 - mae: 0.0159 - val_loss: 3.8641e-04 - val_mae: 0.0126
# Epoch 182/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8634e-04 - mae: 0.0158 - val_loss: 3.8755e-04 - val_mae: 0.0127
# Epoch 183/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8650e-04 - mae: 0.0159 - val_loss: 3.8623e-04 - val_mae: 0.0126
# Epoch 184/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8662e-04 - mae: 0.0159 - val_loss: 3.8815e-04 - val_mae: 0.0127
# Epoch 185/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.8764e-04 - mae: 0.0159 - val_loss: 3.8713e-04 - val_mae: 0.0127
# Epoch 186/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8695e-04 - mae: 0.0159 - val_loss: 3.8671e-04 - val_mae: 0.0126
# Epoch 187/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.8896e-04 - mae: 0.0159 - val_loss: 3.8630e-04 - val_mae: 0.0126
# Epoch 188/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8723e-04 - mae: 0.0159 - val_loss: 3.8610e-04 - val_mae: 0.0126
# Epoch 189/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.8698e-04 - mae: 0.0159 - val_loss: 3.8694e-04 - val_mae: 0.0127
# Epoch 190/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.8798e-04 - mae: 0.0159 - val_loss: 3.8701e-04 - val_mae: 0.0126
# Epoch 191/200
# 236/236 [==============================] - 49s 209ms/step - loss: 4.8707e-04 - mae: 0.0159 - val_loss: 3.8678e-04 - val_mae: 0.0127
# Epoch 192/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.9009e-04 - mae: 0.0159 - val_loss: 3.8758e-04 - val_mae: 0.0127
# Epoch 193/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.8712e-04 - mae: 0.0159 - val_loss: 3.8561e-04 - val_mae: 0.0126
# Epoch 194/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.8535e-04 - mae: 0.0158 - val_loss: 3.8510e-04 - val_mae: 0.0126
# Epoch 195/200
# 236/236 [==============================] - 50s 211ms/step - loss: 4.8756e-04 - mae: 0.0159 - val_loss: 3.8545e-04 - val_mae: 0.0126
# Epoch 196/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8830e-04 - mae: 0.0159 - val_loss: 3.8596e-04 - val_mae: 0.0126
# Epoch 197/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8648e-04 - mae: 0.0159 - val_loss: 3.8629e-04 - val_mae: 0.0126
# Epoch 198/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8418e-04 - mae: 0.0158 - val_loss: 3.8620e-04 - val_mae: 0.0126
# Epoch 199/200
# 236/236 [==============================] - 49s 210ms/step - loss: 4.8691e-04 - mae: 0.0159 - val_loss: 3.8530e-04 - val_mae: 0.0126
# Epoch 200/200
# 236/236 [==============================] - 50s 210ms/step - loss: 4.8494e-04 - mae: 0.0158 - val_loss: 3.8592e-04 - val_mae: 0.0126

# %%
tfk.utils.plot_model(model, expand_nested=True)

# %%
future_window = 864

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled    


def autoregression_pred_multiout(model,window,future):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape
    pred = np.array([])
    X_temp = last_window
    for t in range(0,future_window,future):
        pred_temp = model.predict(X_temp)
        #pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,future:,:],pred_temp), axis=1)

    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred_multiout(model,sequence_length,future))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 6.040912710192005  MAE: 2.8080323962005407
# RMSE: 5.051595264778449  MAE: 2.3020621858886856
#
# Best model is CNN LSTM 3

# %%
colors = ['#DE6A3C','#9ceb00','#6500c9','#0040c9','#ff00bb','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.7
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
window = 100
future_window = 400

for i in range(7):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.3)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.7
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:future_window,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
for i,model in enumerate(models_array):
    save_model(model,models_lables[i])
#save_model(model_2,'model_2')
# Out:
# 2022-01-20 03:53:55.137440: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# CNN LSTM 2 saved!
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# CNN LSTM 3 saved!

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
