# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2data/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2data/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
for i in range(X.shape[-1]):
    plt.figure(figsize=(20,5))
    plt.plot(train_scaled[:,i])
    plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_lstm_stack(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7,bias_initializer=tfk.initializers.Constant(train_scaled.mean(axis=0)))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
models_array = []
history_array = []
epochs = 100
batch_size = 256

lstm_units = 128

sequence_length_array = [50,100,150,200,300,500]
stride = 1

for sequence_length in sequence_length_array:
    
    X_train, y_train = extract_sequences(train_scaled,sequence_length,stride)
    X_train.shape,y_train.shape
    
    input_shape = X_train.shape[1:]

    model = build_lstm_stack(input_shape,lstm_units)
    model.summary()

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 50, 7)]           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               69632
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 70,535
# Trainable params: 70,535
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 237/237 [==============================] - 3s 8ms/step - loss: 0.0032 - mae: 0.0367 - val_loss: 0.0013 - val_mae: 0.0244
# Epoch 2/100
# 237/237 [==============================] - 2s 6ms/step - loss: 0.0012 - mae: 0.0232 - val_loss: 9.8854e-04 - val_mae: 0.0211
# Epoch 3/100
# 237/237 [==============================] - 2s 7ms/step - loss: 0.0010 - mae: 0.0210 - val_loss: 9.1731e-04 - val_mae: 0.0204
# Epoch 4/100
# 237/237 [==============================] - 2s 7ms/step - loss: 9.4165e-04 - mae: 0.0202 - val_loss: 8.6790e-04 - val_mae: 0.0193
# Epoch 5/100
# 237/237 [==============================] - 2s 7ms/step - loss: 9.0152e-04 - mae: 0.0196 - val_loss: 8.6336e-04 - val_mae: 0.0195
# Epoch 6/100
# 237/237 [==============================] - 2s 6ms/step - loss: 8.7952e-04 - mae: 0.0192 - val_loss: 8.5931e-04 - val_mae: 0.0198
# Epoch 7/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.5918e-04 - mae: 0.0189 - val_loss: 8.0896e-04 - val_mae: 0.0185
# Epoch 8/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.5031e-04 - mae: 0.0187 - val_loss: 7.9321e-04 - val_mae: 0.0180
# Epoch 9/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.4045e-04 - mae: 0.0185 - val_loss: 7.7505e-04 - val_mae: 0.0176
# Epoch 10/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.2674e-04 - mae: 0.0182 - val_loss: 7.9214e-04 - val_mae: 0.0180
# Epoch 11/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.2813e-04 - mae: 0.0182 - val_loss: 7.9693e-04 - val_mae: 0.0182
# Epoch 12/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.2374e-04 - mae: 0.0181 - val_loss: 7.8077e-04 - val_mae: 0.0178
# Epoch 13/100
# 237/237 [==============================] - 2s 6ms/step - loss: 8.1613e-04 - mae: 0.0179 - val_loss: 7.6956e-04 - val_mae: 0.0174
# Epoch 14/100
# 237/237 [==============================] - 2s 7ms/step - loss: 8.1850e-04 - mae: 0.0180 - val_loss: 7.6807e-04 - val_mae: 0.0176
# Epoch 15/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.9706e-04 - mae: 0.0175 - val_loss: 7.6246e-04 - val_mae: 0.0174
# Epoch 16/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.9645e-04 - mae: 0.0175 - val_loss: 7.5650e-04 - val_mae: 0.0172
# Epoch 17/100
# 237/237 [==============================] - 2s 8ms/step - loss: 7.9829e-04 - mae: 0.0176 - val_loss: 7.5631e-04 - val_mae: 0.0172
# Epoch 18/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.9501e-04 - mae: 0.0175 - val_loss: 7.6428e-04 - val_mae: 0.0173
# Epoch 19/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.9308e-04 - mae: 0.0175 - val_loss: 7.6114e-04 - val_mae: 0.0174
# Epoch 20/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.9283e-04 - mae: 0.0175 - val_loss: 7.6275e-04 - val_mae: 0.0175
# Epoch 21/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.8811e-04 - mae: 0.0174 - val_loss: 7.5334e-04 - val_mae: 0.0171
# Epoch 22/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.8820e-04 - mae: 0.0174 - val_loss: 7.6565e-04 - val_mae: 0.0176
# Epoch 23/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.8773e-04 - mae: 0.0174 - val_loss: 7.4566e-04 - val_mae: 0.0169
# Epoch 24/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.8690e-04 - mae: 0.0174 - val_loss: 7.7825e-04 - val_mae: 0.0176
# Epoch 25/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.9059e-04 - mae: 0.0175 - val_loss: 7.4895e-04 - val_mae: 0.0171
# Epoch 26/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7531e-04 - mae: 0.0171 - val_loss: 7.4151e-04 - val_mae: 0.0170
# Epoch 27/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.7755e-04 - mae: 0.0172 - val_loss: 7.4070e-04 - val_mae: 0.0169
# Epoch 28/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7460e-04 - mae: 0.0171 - val_loss: 7.3793e-04 - val_mae: 0.0169
# Epoch 29/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7360e-04 - mae: 0.0171 - val_loss: 7.4534e-04 - val_mae: 0.0170
# Epoch 30/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7285e-04 - mae: 0.0171 - val_loss: 7.4383e-04 - val_mae: 0.0170
# Epoch 31/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7314e-04 - mae: 0.0171 - val_loss: 7.4508e-04 - val_mae: 0.0171
# Epoch 32/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7195e-04 - mae: 0.0171 - val_loss: 7.3627e-04 - val_mae: 0.0169
# Epoch 33/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7348e-04 - mae: 0.0171 - val_loss: 7.3635e-04 - val_mae: 0.0168
# Epoch 34/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7275e-04 - mae: 0.0171 - val_loss: 7.4133e-04 - val_mae: 0.0170
# Epoch 35/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.7124e-04 - mae: 0.0171 - val_loss: 7.4292e-04 - val_mae: 0.0172
# Epoch 36/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.6274e-04 - mae: 0.0169 - val_loss: 7.3285e-04 - val_mae: 0.0168
# Epoch 37/100
# 237/237 [==============================] - 2s 8ms/step - loss: 7.6239e-04 - mae: 0.0169 - val_loss: 7.3070e-04 - val_mae: 0.0168
# Epoch 38/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.6282e-04 - mae: 0.0169 - val_loss: 7.2841e-04 - val_mae: 0.0167
# Epoch 39/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.6296e-04 - mae: 0.0169 - val_loss: 7.3119e-04 - val_mae: 0.0168
# Epoch 40/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.6311e-04 - mae: 0.0169 - val_loss: 7.3080e-04 - val_mae: 0.0168
# Epoch 41/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.6024e-04 - mae: 0.0169 - val_loss: 7.3207e-04 - val_mae: 0.0168
# Epoch 42/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.6190e-04 - mae: 0.0169 - val_loss: 7.2976e-04 - val_mae: 0.0167
# Epoch 43/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5953e-04 - mae: 0.0169 - val_loss: 7.2677e-04 - val_mae: 0.0167
# Epoch 44/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5913e-04 - mae: 0.0168 - val_loss: 7.2585e-04 - val_mae: 0.0167
# Epoch 45/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5893e-04 - mae: 0.0169 - val_loss: 7.2592e-04 - val_mae: 0.0167
# Epoch 46/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5522e-04 - mae: 0.0168 - val_loss: 7.2419e-04 - val_mae: 0.0166
# Epoch 47/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.5429e-04 - mae: 0.0168 - val_loss: 7.2368e-04 - val_mae: 0.0166
# Epoch 48/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5395e-04 - mae: 0.0167 - val_loss: 7.2046e-04 - val_mae: 0.0166
# Epoch 49/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5378e-04 - mae: 0.0167 - val_loss: 7.2283e-04 - val_mae: 0.0167
# Epoch 50/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5386e-04 - mae: 0.0167 - val_loss: 7.2112e-04 - val_mae: 0.0166
# Epoch 51/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5291e-04 - mae: 0.0167 - val_loss: 7.2013e-04 - val_mae: 0.0166
# Epoch 52/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5403e-04 - mae: 0.0168 - val_loss: 7.2301e-04 - val_mae: 0.0166
# Epoch 53/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5297e-04 - mae: 0.0168 - val_loss: 7.2105e-04 - val_mae: 0.0166
# Epoch 54/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.5279e-04 - mae: 0.0168 - val_loss: 7.2099e-04 - val_mae: 0.0166
# Epoch 55/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.5233e-04 - mae: 0.0167 - val_loss: 7.2113e-04 - val_mae: 0.0166
# Epoch 56/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4912e-04 - mae: 0.0167 - val_loss: 7.1732e-04 - val_mae: 0.0165
# Epoch 57/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4859e-04 - mae: 0.0167 - val_loss: 7.1814e-04 - val_mae: 0.0166
# Epoch 58/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4900e-04 - mae: 0.0167 - val_loss: 7.1747e-04 - val_mae: 0.0165
# Epoch 59/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4877e-04 - mae: 0.0167 - val_loss: 7.1893e-04 - val_mae: 0.0166
# Epoch 60/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4852e-04 - mae: 0.0167 - val_loss: 7.1694e-04 - val_mae: 0.0165
# Epoch 61/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4815e-04 - mae: 0.0167 - val_loss: 7.1662e-04 - val_mae: 0.0165
# Epoch 62/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4793e-04 - mae: 0.0166 - val_loss: 7.1800e-04 - val_mae: 0.0165
# Epoch 63/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4742e-04 - mae: 0.0166 - val_loss: 7.1809e-04 - val_mae: 0.0166
# Epoch 64/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4754e-04 - mae: 0.0166 - val_loss: 7.1631e-04 - val_mae: 0.0165
# Epoch 65/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4715e-04 - mae: 0.0166 - val_loss: 7.1642e-04 - val_mae: 0.0165
# Epoch 66/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4582e-04 - mae: 0.0166 - val_loss: 7.1524e-04 - val_mae: 0.0165
# Epoch 67/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4596e-04 - mae: 0.0166 - val_loss: 7.1514e-04 - val_mae: 0.0165
# Epoch 68/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4544e-04 - mae: 0.0166 - val_loss: 7.1529e-04 - val_mae: 0.0165
# Epoch 69/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4558e-04 - mae: 0.0166 - val_loss: 7.1501e-04 - val_mae: 0.0165
# Epoch 70/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4560e-04 - mae: 0.0166 - val_loss: 7.1511e-04 - val_mae: 0.0165
# Epoch 71/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.4547e-04 - mae: 0.0166 - val_loss: 7.1447e-04 - val_mae: 0.0165
# Epoch 72/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4508e-04 - mae: 0.0166 - val_loss: 7.1559e-04 - val_mae: 0.0165
# Epoch 73/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4522e-04 - mae: 0.0166 - val_loss: 7.1555e-04 - val_mae: 0.0165
# Epoch 74/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.4503e-04 - mae: 0.0166 - val_loss: 7.1488e-04 - val_mae: 0.0165
# Epoch 75/100
# 237/237 [==============================] - 2s 6ms/step - loss: 7.4492e-04 - mae: 0.0166 - val_loss: 7.1486e-04 - val_mae: 0.0165
# Epoch 76/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4453e-04 - mae: 0.0166 - val_loss: 7.1449e-04 - val_mae: 0.0165
# Epoch 77/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4441e-04 - mae: 0.0166 - val_loss: 7.1423e-04 - val_mae: 0.0165
# Epoch 78/100
# 237/237 [==============================] - 2s 8ms/step - loss: 7.4408e-04 - mae: 0.0166 - val_loss: 7.1426e-04 - val_mae: 0.0165
# Epoch 79/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4409e-04 - mae: 0.0166 - val_loss: 7.1432e-04 - val_mae: 0.0165
# Epoch 80/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4404e-04 - mae: 0.0166 - val_loss: 7.1359e-04 - val_mae: 0.0165
# Epoch 81/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4395e-04 - mae: 0.0166 - val_loss: 7.1406e-04 - val_mae: 0.0165
# Epoch 82/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4397e-04 - mae: 0.0166 - val_loss: 7.1398e-04 - val_mae: 0.0165
# Epoch 83/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4381e-04 - mae: 0.0166 - val_loss: 7.1439e-04 - val_mae: 0.0165
# Epoch 84/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4363e-04 - mae: 0.0166 - val_loss: 7.1374e-04 - val_mae: 0.0165
# Epoch 85/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4367e-04 - mae: 0.0166 - val_loss: 7.1355e-04 - val_mae: 0.0165
# Epoch 86/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4363e-04 - mae: 0.0166 - val_loss: 7.1339e-04 - val_mae: 0.0165
# Epoch 87/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4354e-04 - mae: 0.0166 - val_loss: 7.1377e-04 - val_mae: 0.0165
# Epoch 88/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4340e-04 - mae: 0.0166 - val_loss: 7.1389e-04 - val_mae: 0.0165
# Epoch 89/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4354e-04 - mae: 0.0166 - val_loss: 7.1332e-04 - val_mae: 0.0165
# Epoch 90/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4353e-04 - mae: 0.0166 - val_loss: 7.1374e-04 - val_mae: 0.0165
# Epoch 91/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4338e-04 - mae: 0.0166 - val_loss: 7.1358e-04 - val_mae: 0.0165
# Epoch 92/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4325e-04 - mae: 0.0166 - val_loss: 7.1393e-04 - val_mae: 0.0165
# Epoch 93/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4338e-04 - mae: 0.0166 - val_loss: 7.1379e-04 - val_mae: 0.0165
# Epoch 94/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4318e-04 - mae: 0.0166 - val_loss: 7.1316e-04 - val_mae: 0.0165
# Epoch 95/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4289e-04 - mae: 0.0166 - val_loss: 7.1275e-04 - val_mae: 0.0165
# Epoch 96/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4295e-04 - mae: 0.0166 - val_loss: 7.1295e-04 - val_mae: 0.0165
# Epoch 97/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4287e-04 - mae: 0.0166 - val_loss: 7.1307e-04 - val_mae: 0.0165
# Epoch 98/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4282e-04 - mae: 0.0166 - val_loss: 7.1321e-04 - val_mae: 0.0165
# Epoch 99/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4267e-04 - mae: 0.0166 - val_loss: 7.1256e-04 - val_mae: 0.0165
# Epoch 100/100
# 237/237 [==============================] - 2s 7ms/step - loss: 7.4272e-04 - mae: 0.0166 - val_loss: 7.1331e-04 - val_mae: 0.0165
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 100, 7)]          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 128)               69632
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 70,535
# Trainable params: 70,535
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 237/237 [==============================] - 4s 12ms/step - loss: 0.0040 - mae: 0.0410 - val_loss: 0.0013 - val_mae: 0.0249
# Epoch 2/100
# 237/237 [==============================] - 3s 11ms/step - loss: 0.0012 - mae: 0.0239 - val_loss: 0.0011 - val_mae: 0.0215
# Epoch 3/100
# 237/237 [==============================] - 3s 11ms/step - loss: 0.0010 - mae: 0.0216 - val_loss: 9.7348e-04 - val_mae: 0.0210
# Epoch 4/100
# 237/237 [==============================] - 3s 11ms/step - loss: 9.5021e-04 - mae: 0.0203 - val_loss: 9.2544e-04 - val_mae: 0.0202
# Epoch 5/100
# 237/237 [==============================] - 3s 11ms/step - loss: 9.0195e-04 - mae: 0.0196 - val_loss: 8.6119e-04 - val_mae: 0.0191
# Epoch 6/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.6894e-04 - mae: 0.0190 - val_loss: 8.5110e-04 - val_mae: 0.0188
# Epoch 7/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.5320e-04 - mae: 0.0188 - val_loss: 8.5008e-04 - val_mae: 0.0185
# Epoch 8/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.4589e-04 - mae: 0.0187 - val_loss: 8.1852e-04 - val_mae: 0.0181
# Epoch 9/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.3730e-04 - mae: 0.0185 - val_loss: 7.9722e-04 - val_mae: 0.0178
# Epoch 10/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.3301e-04 - mae: 0.0184 - val_loss: 8.3170e-04 - val_mae: 0.0188
# Epoch 11/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.2245e-04 - mae: 0.0182 - val_loss: 8.0714e-04 - val_mae: 0.0180
# Epoch 12/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.1847e-04 - mae: 0.0181 - val_loss: 8.0895e-04 - val_mae: 0.0180
# Epoch 13/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.1924e-04 - mae: 0.0181 - val_loss: 7.9530e-04 - val_mae: 0.0177
# Epoch 14/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.1632e-04 - mae: 0.0180 - val_loss: 8.1074e-04 - val_mae: 0.0181
# Epoch 15/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.0808e-04 - mae: 0.0179 - val_loss: 8.3955e-04 - val_mae: 0.0192
# Epoch 16/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.0807e-04 - mae: 0.0179 - val_loss: 8.2024e-04 - val_mae: 0.0180
# Epoch 17/100
# 237/237 [==============================] - 3s 11ms/step - loss: 8.0317e-04 - mae: 0.0178 - val_loss: 7.9545e-04 - val_mae: 0.0182
# Epoch 18/100
# 237/237 [==============================] - 3s 12ms/step - loss: 8.0070e-04 - mae: 0.0178 - val_loss: 7.8578e-04 - val_mae: 0.0174
# Epoch 19/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.7964e-04 - mae: 0.0173 - val_loss: 7.6253e-04 - val_mae: 0.0171
# Epoch 20/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.8136e-04 - mae: 0.0173 - val_loss: 7.6523e-04 - val_mae: 0.0172
# Epoch 21/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.7699e-04 - mae: 0.0173 - val_loss: 7.5848e-04 - val_mae: 0.0170
# Epoch 22/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.7526e-04 - mae: 0.0172 - val_loss: 7.5199e-04 - val_mae: 0.0170
# Epoch 23/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.7528e-04 - mae: 0.0173 - val_loss: 7.6127e-04 - val_mae: 0.0173
# Epoch 24/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.7204e-04 - mae: 0.0172 - val_loss: 7.5397e-04 - val_mae: 0.0171
# Epoch 25/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.7101e-04 - mae: 0.0172 - val_loss: 7.4618e-04 - val_mae: 0.0169
# Epoch 26/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.6913e-04 - mae: 0.0172 - val_loss: 7.5251e-04 - val_mae: 0.0170
# Epoch 27/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.6994e-04 - mae: 0.0172 - val_loss: 7.4990e-04 - val_mae: 0.0170
# Epoch 28/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.6773e-04 - mae: 0.0172 - val_loss: 7.6351e-04 - val_mae: 0.0176
# Epoch 29/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.5224e-04 - mae: 0.0168 - val_loss: 7.6685e-04 - val_mae: 0.0175
# Epoch 30/100
# 237/237 [==============================] - 3s 12ms/step - loss: 7.5482e-04 - mae: 0.0169 - val_loss: 7.3280e-04 - val_mae: 0.0166
# Epoch 31/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.5160e-04 - mae: 0.0169 - val_loss: 7.3689e-04 - val_mae: 0.0168
# Epoch 32/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.5040e-04 - mae: 0.0169 - val_loss: 7.4009e-04 - val_mae: 0.0168
# Epoch 33/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.5183e-04 - mae: 0.0169 - val_loss: 7.3337e-04 - val_mae: 0.0168
# Epoch 34/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.4741e-04 - mae: 0.0168 - val_loss: 7.2910e-04 - val_mae: 0.0167
# Epoch 35/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.4842e-04 - mae: 0.0168 - val_loss: 7.3190e-04 - val_mae: 0.0166
# Epoch 36/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.4638e-04 - mae: 0.0168 - val_loss: 7.3038e-04 - val_mae: 0.0167
# Epoch 37/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.4831e-04 - mae: 0.0168 - val_loss: 7.4841e-04 - val_mae: 0.0171
# Epoch 38/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.4751e-04 - mae: 0.0168 - val_loss: 7.3126e-04 - val_mae: 0.0167
# Epoch 39/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3735e-04 - mae: 0.0166 - val_loss: 7.2188e-04 - val_mae: 0.0165
# Epoch 40/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3613e-04 - mae: 0.0166 - val_loss: 7.2360e-04 - val_mae: 0.0165
# Epoch 41/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3706e-04 - mae: 0.0166 - val_loss: 7.2054e-04 - val_mae: 0.0164
# Epoch 42/100
# 237/237 [==============================] - 3s 13ms/step - loss: 7.3574e-04 - mae: 0.0166 - val_loss: 7.2135e-04 - val_mae: 0.0165
# Epoch 43/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3586e-04 - mae: 0.0166 - val_loss: 7.1850e-04 - val_mae: 0.0164
# Epoch 44/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3560e-04 - mae: 0.0166 - val_loss: 7.2035e-04 - val_mae: 0.0165
# Epoch 45/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3505e-04 - mae: 0.0166 - val_loss: 7.1970e-04 - val_mae: 0.0164
# Epoch 46/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3437e-04 - mae: 0.0166 - val_loss: 7.1797e-04 - val_mae: 0.0164
# Epoch 47/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3399e-04 - mae: 0.0166 - val_loss: 7.1958e-04 - val_mae: 0.0164
# Epoch 48/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3245e-04 - mae: 0.0165 - val_loss: 7.1763e-04 - val_mae: 0.0164
# Epoch 49/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3430e-04 - mae: 0.0166 - val_loss: 7.1914e-04 - val_mae: 0.0164
# Epoch 50/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3258e-04 - mae: 0.0166 - val_loss: 7.2431e-04 - val_mae: 0.0166
# Epoch 51/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3287e-04 - mae: 0.0166 - val_loss: 7.1832e-04 - val_mae: 0.0165
# Epoch 52/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3206e-04 - mae: 0.0165 - val_loss: 7.3066e-04 - val_mae: 0.0166
# Epoch 53/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.3065e-04 - mae: 0.0165 - val_loss: 7.1609e-04 - val_mae: 0.0164
# Epoch 54/100
# 237/237 [==============================] - 3s 12ms/step - loss: 7.2593e-04 - mae: 0.0164 - val_loss: 7.1670e-04 - val_mae: 0.0164
# Epoch 55/100
# 237/237 [==============================] - 3s 12ms/step - loss: 7.2618e-04 - mae: 0.0164 - val_loss: 7.1423e-04 - val_mae: 0.0164
# Epoch 56/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2699e-04 - mae: 0.0165 - val_loss: 7.1359e-04 - val_mae: 0.0164
# Epoch 57/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2613e-04 - mae: 0.0164 - val_loss: 7.1492e-04 - val_mae: 0.0163
# Epoch 58/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2534e-04 - mae: 0.0164 - val_loss: 7.1470e-04 - val_mae: 0.0164
# Epoch 59/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2524e-04 - mae: 0.0164 - val_loss: 7.1301e-04 - val_mae: 0.0163
# Epoch 60/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2502e-04 - mae: 0.0164 - val_loss: 7.1387e-04 - val_mae: 0.0163
# Epoch 61/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2478e-04 - mae: 0.0164 - val_loss: 7.1525e-04 - val_mae: 0.0164
# Epoch 62/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2473e-04 - mae: 0.0164 - val_loss: 7.1239e-04 - val_mae: 0.0163
# Epoch 63/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2428e-04 - mae: 0.0164 - val_loss: 7.1512e-04 - val_mae: 0.0164
# Epoch 64/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2164e-04 - mae: 0.0164 - val_loss: 7.1144e-04 - val_mae: 0.0163
# Epoch 65/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2197e-04 - mae: 0.0164 - val_loss: 7.1050e-04 - val_mae: 0.0163
# Epoch 66/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2167e-04 - mae: 0.0164 - val_loss: 7.1259e-04 - val_mae: 0.0163
# Epoch 67/100
# 237/237 [==============================] - 3s 12ms/step - loss: 7.2191e-04 - mae: 0.0164 - val_loss: 7.1197e-04 - val_mae: 0.0163
# Epoch 68/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2161e-04 - mae: 0.0164 - val_loss: 7.1155e-04 - val_mae: 0.0163
# Epoch 69/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2130e-04 - mae: 0.0163 - val_loss: 7.1057e-04 - val_mae: 0.0163
# Epoch 70/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2143e-04 - mae: 0.0163 - val_loss: 7.1109e-04 - val_mae: 0.0163
# Epoch 71/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2121e-04 - mae: 0.0163 - val_loss: 7.1309e-04 - val_mae: 0.0164
# Epoch 72/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2081e-04 - mae: 0.0163 - val_loss: 7.1348e-04 - val_mae: 0.0164
# Epoch 73/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.2100e-04 - mae: 0.0163 - val_loss: 7.1145e-04 - val_mae: 0.0163
# Epoch 74/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1963e-04 - mae: 0.0163 - val_loss: 7.0953e-04 - val_mae: 0.0163
# Epoch 75/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1942e-04 - mae: 0.0163 - val_loss: 7.0955e-04 - val_mae: 0.0163
# Epoch 76/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1941e-04 - mae: 0.0163 - val_loss: 7.1068e-04 - val_mae: 0.0163
# Epoch 77/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1909e-04 - mae: 0.0163 - val_loss: 7.1035e-04 - val_mae: 0.0163
# Epoch 78/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1917e-04 - mae: 0.0163 - val_loss: 7.1005e-04 - val_mae: 0.0163
# Epoch 79/100
# 237/237 [==============================] - 3s 12ms/step - loss: 7.1950e-04 - mae: 0.0163 - val_loss: 7.1077e-04 - val_mae: 0.0163
# Epoch 80/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1917e-04 - mae: 0.0163 - val_loss: 7.0921e-04 - val_mae: 0.0163
# Epoch 81/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1908e-04 - mae: 0.0163 - val_loss: 7.0926e-04 - val_mae: 0.0163
# Epoch 82/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1925e-04 - mae: 0.0163 - val_loss: 7.0894e-04 - val_mae: 0.0163
# Epoch 83/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1907e-04 - mae: 0.0163 - val_loss: 7.1031e-04 - val_mae: 0.0163
# Epoch 84/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1864e-04 - mae: 0.0163 - val_loss: 7.0944e-04 - val_mae: 0.0162
# Epoch 85/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1842e-04 - mae: 0.0163 - val_loss: 7.0873e-04 - val_mae: 0.0162
# Epoch 86/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1842e-04 - mae: 0.0163 - val_loss: 7.0937e-04 - val_mae: 0.0163
# Epoch 87/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1835e-04 - mae: 0.0163 - val_loss: 7.0922e-04 - val_mae: 0.0162
# Epoch 88/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1848e-04 - mae: 0.0163 - val_loss: 7.0893e-04 - val_mae: 0.0163
# Epoch 89/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1839e-04 - mae: 0.0163 - val_loss: 7.0841e-04 - val_mae: 0.0163
# Epoch 90/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1821e-04 - mae: 0.0163 - val_loss: 7.0868e-04 - val_mae: 0.0162
# Epoch 91/100
# 237/237 [==============================] - 3s 12ms/step - loss: 7.1823e-04 - mae: 0.0163 - val_loss: 7.1043e-04 - val_mae: 0.0163
# Epoch 92/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1821e-04 - mae: 0.0163 - val_loss: 7.1099e-04 - val_mae: 0.0163
# Epoch 93/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1821e-04 - mae: 0.0163 - val_loss: 7.0883e-04 - val_mae: 0.0163
# Epoch 94/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1815e-04 - mae: 0.0163 - val_loss: 7.0908e-04 - val_mae: 0.0163
# Epoch 95/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1817e-04 - mae: 0.0163 - val_loss: 7.0860e-04 - val_mae: 0.0163
# Epoch 96/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1818e-04 - mae: 0.0163 - val_loss: 7.0870e-04 - val_mae: 0.0163
# Epoch 97/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1810e-04 - mae: 0.0163 - val_loss: 7.0907e-04 - val_mae: 0.0163
# Epoch 98/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1817e-04 - mae: 0.0163 - val_loss: 7.0913e-04 - val_mae: 0.0163
# Epoch 99/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1797e-04 - mae: 0.0163 - val_loss: 7.0855e-04 - val_mae: 0.0163
# Epoch 100/100
# 237/237 [==============================] - 3s 11ms/step - loss: 7.1795e-04 - mae: 0.0163 - val_loss: 7.0794e-04 - val_mae: 0.0162
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 150, 7)]          0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 128)               69632
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 70,535
# Trainable params: 70,535
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 237/237 [==============================] - 6s 19ms/step - loss: 0.0039 - mae: 0.0404 - val_loss: 0.0013 - val_mae: 0.0257
# Epoch 2/100
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0012 - mae: 0.0238 - val_loss: 0.0011 - val_mae: 0.0223
# Epoch 3/100
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0010 - mae: 0.0216 - val_loss: 0.0011 - val_mae: 0.0227
# Epoch 4/100
# 237/237 [==============================] - 4s 15ms/step - loss: 9.5609e-04 - mae: 0.0204 - val_loss: 8.6941e-04 - val_mae: 0.0190
# Epoch 5/100
# 237/237 [==============================] - 4s 16ms/step - loss: 9.1811e-04 - mae: 0.0199 - val_loss: 0.0011 - val_mae: 0.0231
# Epoch 6/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.7856e-04 - mae: 0.0192 - val_loss: 8.5350e-04 - val_mae: 0.0185
# Epoch 7/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.6399e-04 - mae: 0.0190 - val_loss: 8.6395e-04 - val_mae: 0.0195
# Epoch 8/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.5818e-04 - mae: 0.0189 - val_loss: 8.4409e-04 - val_mae: 0.0190
# Epoch 9/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.4290e-04 - mae: 0.0185 - val_loss: 8.2699e-04 - val_mae: 0.0187
# Epoch 10/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.3324e-04 - mae: 0.0184 - val_loss: 8.1263e-04 - val_mae: 0.0182
# Epoch 11/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.2607e-04 - mae: 0.0182 - val_loss: 8.4978e-04 - val_mae: 0.0188
# Epoch 12/100
# 237/237 [==============================] - 4s 16ms/step - loss: 8.2497e-04 - mae: 0.0182 - val_loss: 8.0150e-04 - val_mae: 0.0178
# Epoch 13/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.1837e-04 - mae: 0.0181 - val_loss: 8.5140e-04 - val_mae: 0.0185
# Epoch 14/100
# 237/237 [==============================] - 4s 15ms/step - loss: 8.1627e-04 - mae: 0.0180 - val_loss: 7.8892e-04 - val_mae: 0.0175
# Epoch 15/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.9600e-04 - mae: 0.0176 - val_loss: 7.7813e-04 - val_mae: 0.0172
# Epoch 16/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.9842e-04 - mae: 0.0177 - val_loss: 7.9135e-04 - val_mae: 0.0174
# Epoch 17/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.9176e-04 - mae: 0.0175 - val_loss: 7.8309e-04 - val_mae: 0.0173
# Epoch 18/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.9050e-04 - mae: 0.0176 - val_loss: 7.8055e-04 - val_mae: 0.0173
# Epoch 19/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.8933e-04 - mae: 0.0176 - val_loss: 7.6984e-04 - val_mae: 0.0173
# Epoch 20/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.8862e-04 - mae: 0.0175 - val_loss: 7.8487e-04 - val_mae: 0.0176
# Epoch 21/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.8513e-04 - mae: 0.0175 - val_loss: 7.7720e-04 - val_mae: 0.0174
# Epoch 22/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.8218e-04 - mae: 0.0175 - val_loss: 7.7903e-04 - val_mae: 0.0175
# Epoch 23/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.8148e-04 - mae: 0.0174 - val_loss: 7.8071e-04 - val_mae: 0.0177
# Epoch 24/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.8381e-04 - mae: 0.0175 - val_loss: 7.8748e-04 - val_mae: 0.0178
# Epoch 25/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.6705e-04 - mae: 0.0172 - val_loss: 7.6439e-04 - val_mae: 0.0169
# Epoch 26/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.6158e-04 - mae: 0.0171 - val_loss: 7.5635e-04 - val_mae: 0.0170
# Epoch 27/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.6022e-04 - mae: 0.0170 - val_loss: 7.4890e-04 - val_mae: 0.0167
# Epoch 28/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.5852e-04 - mae: 0.0170 - val_loss: 7.6798e-04 - val_mae: 0.0172
# Epoch 29/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.5959e-04 - mae: 0.0170 - val_loss: 7.7698e-04 - val_mae: 0.0172
# Epoch 30/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.5708e-04 - mae: 0.0170 - val_loss: 7.4762e-04 - val_mae: 0.0168
# Epoch 31/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.5681e-04 - mae: 0.0170 - val_loss: 7.4694e-04 - val_mae: 0.0168
# Epoch 32/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.5356e-04 - mae: 0.0169 - val_loss: 7.4195e-04 - val_mae: 0.0167
# Epoch 33/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.5381e-04 - mae: 0.0170 - val_loss: 7.6989e-04 - val_mae: 0.0175
# Epoch 34/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.5566e-04 - mae: 0.0170 - val_loss: 7.4268e-04 - val_mae: 0.0167
# Epoch 35/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.4951e-04 - mae: 0.0169 - val_loss: 7.4078e-04 - val_mae: 0.0167
# Epoch 36/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.4203e-04 - mae: 0.0167 - val_loss: 7.3570e-04 - val_mae: 0.0166
# Epoch 37/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.4111e-04 - mae: 0.0167 - val_loss: 7.4058e-04 - val_mae: 0.0166
# Epoch 38/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.4361e-04 - mae: 0.0168 - val_loss: 7.4228e-04 - val_mae: 0.0167
# Epoch 39/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.3950e-04 - mae: 0.0167 - val_loss: 7.3560e-04 - val_mae: 0.0165
# Epoch 40/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.4017e-04 - mae: 0.0167 - val_loss: 7.3209e-04 - val_mae: 0.0165
# Epoch 41/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.4047e-04 - mae: 0.0167 - val_loss: 7.3769e-04 - val_mae: 0.0165
# Epoch 42/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.4095e-04 - mae: 0.0167 - val_loss: 7.3844e-04 - val_mae: 0.0166
# Epoch 43/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3917e-04 - mae: 0.0167 - val_loss: 7.3398e-04 - val_mae: 0.0166
# Epoch 44/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3758e-04 - mae: 0.0166 - val_loss: 7.3260e-04 - val_mae: 0.0165
# Epoch 45/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3799e-04 - mae: 0.0167 - val_loss: 7.2734e-04 - val_mae: 0.0164
# Epoch 46/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3235e-04 - mae: 0.0165 - val_loss: 7.3482e-04 - val_mae: 0.0165
# Epoch 47/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3401e-04 - mae: 0.0166 - val_loss: 7.2556e-04 - val_mae: 0.0163
# Epoch 48/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.3144e-04 - mae: 0.0165 - val_loss: 7.2954e-04 - val_mae: 0.0164
# Epoch 49/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3243e-04 - mae: 0.0165 - val_loss: 7.2870e-04 - val_mae: 0.0163
# Epoch 50/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.3220e-04 - mae: 0.0165 - val_loss: 7.3197e-04 - val_mae: 0.0165
# Epoch 51/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3152e-04 - mae: 0.0165 - val_loss: 7.2588e-04 - val_mae: 0.0164
# Epoch 52/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3088e-04 - mae: 0.0165 - val_loss: 7.2959e-04 - val_mae: 0.0165
# Epoch 53/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3238e-04 - mae: 0.0165 - val_loss: 7.2574e-04 - val_mae: 0.0163
# Epoch 54/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3145e-04 - mae: 0.0165 - val_loss: 7.2857e-04 - val_mae: 0.0164
# Epoch 55/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.3088e-04 - mae: 0.0165 - val_loss: 7.2501e-04 - val_mae: 0.0163
# Epoch 56/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2842e-04 - mae: 0.0165 - val_loss: 7.2353e-04 - val_mae: 0.0163
# Epoch 57/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2766e-04 - mae: 0.0164 - val_loss: 7.2536e-04 - val_mae: 0.0164
# Epoch 58/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2788e-04 - mae: 0.0164 - val_loss: 7.2633e-04 - val_mae: 0.0163
# Epoch 59/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2765e-04 - mae: 0.0164 - val_loss: 7.2540e-04 - val_mae: 0.0163
# Epoch 60/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2820e-04 - mae: 0.0165 - val_loss: 7.2633e-04 - val_mae: 0.0163
# Epoch 61/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2710e-04 - mae: 0.0164 - val_loss: 7.2324e-04 - val_mae: 0.0163
# Epoch 62/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2741e-04 - mae: 0.0164 - val_loss: 7.2333e-04 - val_mae: 0.0164
# Epoch 63/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2723e-04 - mae: 0.0164 - val_loss: 7.2178e-04 - val_mae: 0.0163
# Epoch 64/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2750e-04 - mae: 0.0164 - val_loss: 7.2290e-04 - val_mae: 0.0163
# Epoch 65/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2729e-04 - mae: 0.0164 - val_loss: 7.2085e-04 - val_mae: 0.0163
# Epoch 66/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2557e-04 - mae: 0.0164 - val_loss: 7.2212e-04 - val_mae: 0.0162
# Epoch 67/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2530e-04 - mae: 0.0164 - val_loss: 7.2219e-04 - val_mae: 0.0163
# Epoch 68/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2524e-04 - mae: 0.0164 - val_loss: 7.2186e-04 - val_mae: 0.0163
# Epoch 69/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2535e-04 - mae: 0.0164 - val_loss: 7.2160e-04 - val_mae: 0.0163
# Epoch 70/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2539e-04 - mae: 0.0164 - val_loss: 7.2248e-04 - val_mae: 0.0163
# Epoch 71/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2484e-04 - mae: 0.0164 - val_loss: 7.2174e-04 - val_mae: 0.0163
# Epoch 72/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2483e-04 - mae: 0.0164 - val_loss: 7.2423e-04 - val_mae: 0.0163
# Epoch 73/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2512e-04 - mae: 0.0164 - val_loss: 7.2401e-04 - val_mae: 0.0163
# Epoch 74/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2481e-04 - mae: 0.0164 - val_loss: 7.2278e-04 - val_mae: 0.0163
# Epoch 75/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2494e-04 - mae: 0.0164 - val_loss: 7.2265e-04 - val_mae: 0.0163
# Epoch 76/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2413e-04 - mae: 0.0164 - val_loss: 7.2138e-04 - val_mae: 0.0163
# Epoch 77/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2411e-04 - mae: 0.0164 - val_loss: 7.2211e-04 - val_mae: 0.0162
# Epoch 78/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2416e-04 - mae: 0.0164 - val_loss: 7.2093e-04 - val_mae: 0.0163
# Epoch 79/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2421e-04 - mae: 0.0164 - val_loss: 7.2263e-04 - val_mae: 0.0162
# Epoch 80/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2427e-04 - mae: 0.0164 - val_loss: 7.2177e-04 - val_mae: 0.0162
# Epoch 81/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2380e-04 - mae: 0.0164 - val_loss: 7.2065e-04 - val_mae: 0.0162
# Epoch 82/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2426e-04 - mae: 0.0164 - val_loss: 7.2122e-04 - val_mae: 0.0162
# Epoch 83/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2386e-04 - mae: 0.0164 - val_loss: 7.2182e-04 - val_mae: 0.0162
# Epoch 84/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2400e-04 - mae: 0.0164 - val_loss: 7.2072e-04 - val_mae: 0.0162
# Epoch 85/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2385e-04 - mae: 0.0164 - val_loss: 7.2208e-04 - val_mae: 0.0163
# Epoch 86/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2371e-04 - mae: 0.0164 - val_loss: 7.2164e-04 - val_mae: 0.0162
# Epoch 87/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2389e-04 - mae: 0.0164 - val_loss: 7.2150e-04 - val_mae: 0.0162
# Epoch 88/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2373e-04 - mae: 0.0164 - val_loss: 7.2093e-04 - val_mae: 0.0162
# Epoch 89/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2379e-04 - mae: 0.0164 - val_loss: 7.2006e-04 - val_mae: 0.0162
# Epoch 90/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2364e-04 - mae: 0.0164 - val_loss: 7.2008e-04 - val_mae: 0.0163
# Epoch 91/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2375e-04 - mae: 0.0164 - val_loss: 7.2192e-04 - val_mae: 0.0163
# Epoch 92/100
# 237/237 [==============================] - 4s 16ms/step - loss: 7.2368e-04 - mae: 0.0164 - val_loss: 7.2073e-04 - val_mae: 0.0162
# Epoch 93/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2346e-04 - mae: 0.0164 - val_loss: 7.2092e-04 - val_mae: 0.0163
# Epoch 94/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2370e-04 - mae: 0.0164 - val_loss: 7.2151e-04 - val_mae: 0.0162
# Epoch 95/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2345e-04 - mae: 0.0164 - val_loss: 7.2203e-04 - val_mae: 0.0163
# Epoch 96/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2344e-04 - mae: 0.0164 - val_loss: 7.2044e-04 - val_mae: 0.0163
# Epoch 97/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2342e-04 - mae: 0.0164 - val_loss: 7.2060e-04 - val_mae: 0.0163
# Epoch 98/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2345e-04 - mae: 0.0164 - val_loss: 7.2094e-04 - val_mae: 0.0162
# Epoch 99/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2333e-04 - mae: 0.0164 - val_loss: 7.1991e-04 - val_mae: 0.0163
# Epoch 100/100
# 237/237 [==============================] - 4s 15ms/step - loss: 7.2334e-04 - mae: 0.0164 - val_loss: 7.2262e-04 - val_mae: 0.0163
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 200, 7)]          0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 128)               69632
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 70,535
# Trainable params: 70,535
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 237/237 [==============================] - 6s 22ms/step - loss: 0.0038 - mae: 0.0401 - val_loss: 0.0014 - val_mae: 0.0257
# Epoch 2/100
# 237/237 [==============================] - 5s 20ms/step - loss: 0.0012 - mae: 0.0240 - val_loss: 0.0010 - val_mae: 0.0219
# Epoch 3/100
# 237/237 [==============================] - 5s 20ms/step - loss: 0.0010 - mae: 0.0215 - val_loss: 9.5522e-04 - val_mae: 0.0208
# Epoch 4/100
# 237/237 [==============================] - 5s 21ms/step - loss: 9.6696e-04 - mae: 0.0206 - val_loss: 8.9101e-04 - val_mae: 0.0198
# Epoch 5/100
# 237/237 [==============================] - 5s 20ms/step - loss: 9.1473e-04 - mae: 0.0198 - val_loss: 0.0010 - val_mae: 0.0220
# Epoch 6/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.7845e-04 - mae: 0.0191 - val_loss: 8.5733e-04 - val_mae: 0.0190
# Epoch 7/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.7353e-04 - mae: 0.0192 - val_loss: 8.3569e-04 - val_mae: 0.0186
# Epoch 8/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.5143e-04 - mae: 0.0187 - val_loss: 8.4046e-04 - val_mae: 0.0192
# Epoch 9/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.4254e-04 - mae: 0.0185 - val_loss: 8.8345e-04 - val_mae: 0.0203
# Epoch 10/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.4078e-04 - mae: 0.0185 - val_loss: 8.1155e-04 - val_mae: 0.0184
# Epoch 11/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.2659e-04 - mae: 0.0182 - val_loss: 7.9235e-04 - val_mae: 0.0181
# Epoch 12/100
# 237/237 [==============================] - 5s 20ms/step - loss: 8.2143e-04 - mae: 0.0181 - val_loss: 7.8099e-04 - val_mae: 0.0178
# Epoch 13/100
# ...
# Epoch 96/100
# 236/236 [==============================] - 7s 29ms/step - loss: 7.1360e-04 - mae: 0.0162 - val_loss: 7.0496e-04 - val_mae: 0.0162
# Epoch 97/100
# 236/236 [==============================] - 7s 29ms/step - loss: 7.1356e-04 - mae: 0.0162 - val_loss: 7.0448e-04 - val_mae: 0.0162
# Epoch 98/100
# 236/236 [==============================] - 7s 29ms/step - loss: 7.1340e-04 - mae: 0.0162 - val_loss: 7.0565e-04 - val_mae: 0.0163
# Epoch 99/100
# 236/236 [==============================] - 7s 29ms/step - loss: 7.1339e-04 - mae: 0.0162 - val_loss: 7.0446e-04 - val_mae: 0.0162
# Epoch 100/100
# 236/236 [==============================] - 7s 29ms/step - loss: 7.1332e-04 - mae: 0.0162 - val_loss: 7.0416e-04 - val_mae: 0.0162
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 500, 7)]          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 128)               69632
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 70,535
# Trainable params: 70,535
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 236/236 [==============================] - 13s 49ms/step - loss: 0.0033 - mae: 0.0373 - val_loss: 0.0015 - val_mae: 0.0270
# Epoch 2/100
# 236/236 [==============================] - 11s 46ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0011 - val_mae: 0.0235
# Epoch 3/100
# 236/236 [==============================] - 11s 46ms/step - loss: 0.0010 - mae: 0.0214 - val_loss: 9.0592e-04 - val_mae: 0.0199
# Epoch 4/100
# 236/236 [==============================] - 11s 46ms/step - loss: 9.4494e-04 - mae: 0.0203 - val_loss: 9.2336e-04 - val_mae: 0.0205
# Epoch 5/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.9318e-04 - mae: 0.0194 - val_loss: 8.4979e-04 - val_mae: 0.0189
# Epoch 6/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.6630e-04 - mae: 0.0189 - val_loss: 8.2863e-04 - val_mae: 0.0187
# Epoch 7/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.5514e-04 - mae: 0.0188 - val_loss: 8.1623e-04 - val_mae: 0.0186
# Epoch 8/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.4188e-04 - mae: 0.0185 - val_loss: 7.9304e-04 - val_mae: 0.0182
# Epoch 9/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.4147e-04 - mae: 0.0185 - val_loss: 7.8982e-04 - val_mae: 0.0179
# Epoch 10/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.2955e-04 - mae: 0.0182 - val_loss: 8.5072e-04 - val_mae: 0.0189
# Epoch 11/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.2494e-04 - mae: 0.0181 - val_loss: 0.0011 - val_mae: 0.0242
# Epoch 12/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.3089e-04 - mae: 0.0183 - val_loss: 8.3688e-04 - val_mae: 0.0190
# Epoch 13/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.2253e-04 - mae: 0.0181 - val_loss: 8.1669e-04 - val_mae: 0.0190
# Epoch 14/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.2021e-04 - mae: 0.0181 - val_loss: 7.8838e-04 - val_mae: 0.0180
# Epoch 15/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.1475e-04 - mae: 0.0180 - val_loss: 7.6588e-04 - val_mae: 0.0174
# Epoch 16/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.0459e-04 - mae: 0.0178 - val_loss: 8.0398e-04 - val_mae: 0.0187
# Epoch 17/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.0428e-04 - mae: 0.0178 - val_loss: 8.1130e-04 - val_mae: 0.0188
# Epoch 18/100
# 236/236 [==============================] - 11s 46ms/step - loss: 8.0027e-04 - mae: 0.0177 - val_loss: 8.0132e-04 - val_mae: 0.0186
# Epoch 19/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.7824e-04 - mae: 0.0173 - val_loss: 7.6385e-04 - val_mae: 0.0178
# Epoch 20/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.8077e-04 - mae: 0.0174 - val_loss: 7.5477e-04 - val_mae: 0.0174
# Epoch 21/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.7508e-04 - mae: 0.0173 - val_loss: 7.3923e-04 - val_mae: 0.0170
# Epoch 22/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.7028e-04 - mae: 0.0172 - val_loss: 7.4838e-04 - val_mae: 0.0172
# Epoch 23/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.6786e-04 - mae: 0.0172 - val_loss: 7.6611e-04 - val_mae: 0.0178
# Epoch 24/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.7009e-04 - mae: 0.0172 - val_loss: 7.6258e-04 - val_mae: 0.0179
# Epoch 25/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.6756e-04 - mae: 0.0172 - val_loss: 7.4755e-04 - val_mae: 0.0173
# Epoch 26/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.6808e-04 - mae: 0.0172 - val_loss: 7.3366e-04 - val_mae: 0.0170
# Epoch 27/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.6618e-04 - mae: 0.0172 - val_loss: 7.5723e-04 - val_mae: 0.0175
# Epoch 28/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.6025e-04 - mae: 0.0171 - val_loss: 7.9649e-04 - val_mae: 0.0188
# Epoch 29/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4868e-04 - mae: 0.0168 - val_loss: 7.2311e-04 - val_mae: 0.0168
# Epoch 30/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4799e-04 - mae: 0.0168 - val_loss: 7.2055e-04 - val_mae: 0.0168
# Epoch 31/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4467e-04 - mae: 0.0168 - val_loss: 7.2039e-04 - val_mae: 0.0168
# Epoch 32/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4743e-04 - mae: 0.0168 - val_loss: 7.1551e-04 - val_mae: 0.0167
# Epoch 33/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4314e-04 - mae: 0.0167 - val_loss: 7.1996e-04 - val_mae: 0.0170
# Epoch 34/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4444e-04 - mae: 0.0168 - val_loss: 7.1357e-04 - val_mae: 0.0167
# Epoch 35/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4254e-04 - mae: 0.0167 - val_loss: 7.2059e-04 - val_mae: 0.0167
# Epoch 36/100
# 236/236 [==============================] - 11s 47ms/step - loss: 7.4662e-04 - mae: 0.0168 - val_loss: 7.2152e-04 - val_mae: 0.0168
# Epoch 37/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4248e-04 - mae: 0.0168 - val_loss: 7.1550e-04 - val_mae: 0.0168
# Epoch 38/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.4127e-04 - mae: 0.0167 - val_loss: 7.1258e-04 - val_mae: 0.0166
# Epoch 39/100
# 236/236 [==============================] - 11s 47ms/step - loss: 7.3216e-04 - mae: 0.0165 - val_loss: 7.0982e-04 - val_mae: 0.0165
# Epoch 40/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.3182e-04 - mae: 0.0165 - val_loss: 7.1578e-04 - val_mae: 0.0168
# Epoch 41/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.3193e-04 - mae: 0.0165 - val_loss: 7.0632e-04 - val_mae: 0.0165
# Epoch 42/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.3183e-04 - mae: 0.0165 - val_loss: 7.0150e-04 - val_mae: 0.0164
# Epoch 43/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.3059e-04 - mae: 0.0165 - val_loss: 7.0082e-04 - val_mae: 0.0164
# Epoch 44/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.3060e-04 - mae: 0.0165 - val_loss: 7.0521e-04 - val_mae: 0.0165
# Epoch 45/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2928e-04 - mae: 0.0165 - val_loss: 7.0405e-04 - val_mae: 0.0164
# Epoch 46/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2978e-04 - mae: 0.0165 - val_loss: 7.1849e-04 - val_mae: 0.0167
# Epoch 47/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.3106e-04 - mae: 0.0165 - val_loss: 7.1497e-04 - val_mae: 0.0167
# Epoch 48/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2857e-04 - mae: 0.0165 - val_loss: 7.0221e-04 - val_mae: 0.0164
# Epoch 49/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2405e-04 - mae: 0.0164 - val_loss: 6.9788e-04 - val_mae: 0.0164
# Epoch 50/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2377e-04 - mae: 0.0164 - val_loss: 6.9621e-04 - val_mae: 0.0163
# Epoch 51/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2331e-04 - mae: 0.0164 - val_loss: 6.9860e-04 - val_mae: 0.0164
# Epoch 52/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2406e-04 - mae: 0.0164 - val_loss: 7.0074e-04 - val_mae: 0.0164
# Epoch 53/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2306e-04 - mae: 0.0164 - val_loss: 7.0342e-04 - val_mae: 0.0164
# Epoch 54/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2391e-04 - mae: 0.0164 - val_loss: 6.9811e-04 - val_mae: 0.0164
# Epoch 55/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2323e-04 - mae: 0.0164 - val_loss: 6.9739e-04 - val_mae: 0.0164
# Epoch 56/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2265e-04 - mae: 0.0164 - val_loss: 6.9869e-04 - val_mae: 0.0163
# Epoch 57/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2257e-04 - mae: 0.0163 - val_loss: 6.9723e-04 - val_mae: 0.0163
# Epoch 58/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.2217e-04 - mae: 0.0163 - val_loss: 6.9612e-04 - val_mae: 0.0163
# Epoch 59/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1964e-04 - mae: 0.0163 - val_loss: 6.9606e-04 - val_mae: 0.0163
# Epoch 60/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1941e-04 - mae: 0.0163 - val_loss: 6.9398e-04 - val_mae: 0.0163
# Epoch 61/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1898e-04 - mae: 0.0163 - val_loss: 6.9652e-04 - val_mae: 0.0164
# Epoch 62/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1954e-04 - mae: 0.0163 - val_loss: 6.9333e-04 - val_mae: 0.0163
# Epoch 63/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1902e-04 - mae: 0.0163 - val_loss: 6.9391e-04 - val_mae: 0.0163
# Epoch 64/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1871e-04 - mae: 0.0163 - val_loss: 6.9526e-04 - val_mae: 0.0163
# Epoch 65/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1879e-04 - mae: 0.0163 - val_loss: 6.9629e-04 - val_mae: 0.0163
# Epoch 66/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1887e-04 - mae: 0.0163 - val_loss: 6.9407e-04 - val_mae: 0.0163
# Epoch 67/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1825e-04 - mae: 0.0163 - val_loss: 6.9467e-04 - val_mae: 0.0163
# Epoch 68/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1863e-04 - mae: 0.0163 - val_loss: 6.9508e-04 - val_mae: 0.0163
# Epoch 69/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1696e-04 - mae: 0.0162 - val_loss: 6.9236e-04 - val_mae: 0.0163
# Epoch 70/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1691e-04 - mae: 0.0162 - val_loss: 6.9327e-04 - val_mae: 0.0163
# Epoch 71/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1685e-04 - mae: 0.0162 - val_loss: 6.9275e-04 - val_mae: 0.0163
# Epoch 72/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1671e-04 - mae: 0.0162 - val_loss: 6.9289e-04 - val_mae: 0.0163
# Epoch 73/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1686e-04 - mae: 0.0162 - val_loss: 6.9443e-04 - val_mae: 0.0163
# Epoch 74/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1643e-04 - mae: 0.0162 - val_loss: 6.9348e-04 - val_mae: 0.0163
# Epoch 75/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1660e-04 - mae: 0.0162 - val_loss: 6.9291e-04 - val_mae: 0.0163
# Epoch 76/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1627e-04 - mae: 0.0162 - val_loss: 6.9203e-04 - val_mae: 0.0162
# Epoch 77/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1664e-04 - mae: 0.0162 - val_loss: 6.9578e-04 - val_mae: 0.0163
# Epoch 78/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1636e-04 - mae: 0.0162 - val_loss: 6.9344e-04 - val_mae: 0.0163
# Epoch 79/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1634e-04 - mae: 0.0162 - val_loss: 6.9409e-04 - val_mae: 0.0163
# Epoch 80/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1574e-04 - mae: 0.0162 - val_loss: 6.9154e-04 - val_mae: 0.0162
# Epoch 81/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1558e-04 - mae: 0.0162 - val_loss: 6.9201e-04 - val_mae: 0.0163
# Epoch 82/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1576e-04 - mae: 0.0162 - val_loss: 6.9170e-04 - val_mae: 0.0162
# Epoch 83/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1544e-04 - mae: 0.0162 - val_loss: 6.9157e-04 - val_mae: 0.0162
# Epoch 84/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1533e-04 - mae: 0.0162 - val_loss: 6.9225e-04 - val_mae: 0.0163
# Epoch 85/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1558e-04 - mae: 0.0162 - val_loss: 6.9380e-04 - val_mae: 0.0163
# Epoch 86/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1538e-04 - mae: 0.0162 - val_loss: 6.9161e-04 - val_mae: 0.0162
# Epoch 87/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1531e-04 - mae: 0.0162 - val_loss: 6.9371e-04 - val_mae: 0.0163
# Epoch 88/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1533e-04 - mae: 0.0162 - val_loss: 6.9159e-04 - val_mae: 0.0162
# Epoch 89/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1530e-04 - mae: 0.0162 - val_loss: 6.9198e-04 - val_mae: 0.0163
# Epoch 90/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1524e-04 - mae: 0.0162 - val_loss: 6.9145e-04 - val_mae: 0.0162
# Epoch 91/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1510e-04 - mae: 0.0162 - val_loss: 6.9248e-04 - val_mae: 0.0163
# Epoch 92/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1522e-04 - mae: 0.0162 - val_loss: 6.9167e-04 - val_mae: 0.0162
# Epoch 93/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1528e-04 - mae: 0.0162 - val_loss: 6.9213e-04 - val_mae: 0.0162
# Epoch 94/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1513e-04 - mae: 0.0162 - val_loss: 6.9155e-04 - val_mae: 0.0162
# Epoch 95/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1510e-04 - mae: 0.0162 - val_loss: 6.9158e-04 - val_mae: 0.0163
# Epoch 96/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1521e-04 - mae: 0.0162 - val_loss: 6.9183e-04 - val_mae: 0.0163
# Epoch 97/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1485e-04 - mae: 0.0162 - val_loss: 6.9181e-04 - val_mae: 0.0163
# Epoch 98/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1505e-04 - mae: 0.0162 - val_loss: 6.9137e-04 - val_mae: 0.0162
# Epoch 99/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1499e-04 - mae: 0.0162 - val_loss: 6.9138e-04 - val_mae: 0.0162
# Epoch 100/100
# 236/236 [==============================] - 11s 46ms/step - loss: 7.1513e-04 - mae: 0.0162 - val_loss: 6.9130e-04 - val_mae: 0.0162

# %%
future_window = 864

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred(model,sequence_length_array[i]))

# %%
best_rmse = 100000
best_model = 0
for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is #" + str(best_model) + " w/ sequence_length: " + str(sequence_length_array[best_model]))
# Out:
# RMSE: 36.14389293527128  MAE: 25.73782785866457
# RMSE: 6.327969431910832  MAE: 3.994561800995136
# RMSE: 4.051227900330658  MAE: 2.151938295629035
# RMSE: 5.2221831624837005  MAE: 2.6962163398778194
# RMSE: 4.658088102526953  MAE: 2.82616278860405
# RMSE: 5.308533454706722  MAE: 3.2408939750729857
#
# Best model is #2 w/ sequence_length: 150

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = max(sequence_length_array)
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label='Sequence length ' + str(sequence_length_array[j]),alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = max(sequence_length_array)
sequence_length_array_new = sequence_length_array[1:]
pred_array_new = pred_array[1:]
best_model_new = best_model-1
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.5)
    for j,pred in enumerate(pred_array_new):
        if(j!=best_model_new): 
            alpha_val = 0.2
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label='Sequence length ' + str(sequence_length_array_new[j]),alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)

model_lables = [str(j) for j in sequence_length_array];

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ model_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ model_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + model_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ model_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ model_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ model_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ model_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ model_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#import shutil
#from os import path
#def save_model(model,filename):
#    model.save(filename)
#    src = path.realpath(filename)
#    root_dir, tail = path.split(src)
#    shutil.make_archive(filename, 'zip', filename)
#    print(filename + ' saved!')

# %%
#save_model(model_1,'model_1')
#save_model(model_2,'model_2')

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
