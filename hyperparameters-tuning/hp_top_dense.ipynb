# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_lstm_1_dense(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_lstm_2_dense(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    x = tfkl.Dense(64)(x)
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
models_array = []
history_array = []

epochs = 150
batch_size = 256

stride = 1
sequence_length = 400
X_train, y_train = extract_sequences(train_scaled,sequence_length,stride)
X_train.shape,y_train.shape
    
input_shape = X_train.shape[1:]

lstm_units = 512

models = [build_lstm_1_dense, build_lstm_2_dense]
models_lables = ['lstm + 1 dense','lstm + 2 dense']

for m in models:

    model = m(input_shape,lstm_units)
    model.summary()

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# 2022-01-14 14:23:32.610262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:32.698140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:32.698882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:32.700020: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-14 14:23:32.700836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:32.701499: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:32.702127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:34.520346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:34.521175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:34.521839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-14 14:23:34.522431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 512)               1064960
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 3591
# =================================================================
# Total params: 1,068,551
# Trainable params: 1,068,551
# Non-trainable params: 0
# _________________________________________________________________
# 2022-01-14 14:23:36.673418: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 2022-01-14 14:23:39.262414: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 236/236 [==============================] - 42s 160ms/step - loss: 0.0050 - mae: 0.0410 - val_loss: 0.0015 - val_mae: 0.0271
# Epoch 2/150
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0013 - mae: 0.0246 - val_loss: 0.0012 - val_mae: 0.0230
# Epoch 3/150
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0011 - mae: 0.0225 - val_loss: 0.0012 - val_mae: 0.0237
# Epoch 4/150
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0010 - mae: 0.0210 - val_loss: 9.9718e-04 - val_mae: 0.0206
# Epoch 5/150
# 236/236 [==============================] - 37s 157ms/step - loss: 9.3412e-04 - mae: 0.0200 - val_loss: 9.3299e-04 - val_mae: 0.0196
# Epoch 6/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.8963e-04 - mae: 0.0193 - val_loss: 8.8782e-04 - val_mae: 0.0190
# Epoch 7/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.6729e-04 - mae: 0.0190 - val_loss: 9.3250e-04 - val_mae: 0.0201
# Epoch 8/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.5207e-04 - mae: 0.0188 - val_loss: 8.5556e-04 - val_mae: 0.0186
# Epoch 9/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.3638e-04 - mae: 0.0185 - val_loss: 8.8931e-04 - val_mae: 0.0197
# Epoch 10/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.2285e-04 - mae: 0.0183 - val_loss: 8.5157e-04 - val_mae: 0.0186
# Epoch 11/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.1464e-04 - mae: 0.0182 - val_loss: 8.4140e-04 - val_mae: 0.0182
# Epoch 12/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.1184e-04 - mae: 0.0181 - val_loss: 9.0173e-04 - val_mae: 0.0195
# Epoch 13/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.0406e-04 - mae: 0.0179 - val_loss: 8.2359e-04 - val_mae: 0.0180
# Epoch 14/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.9889e-04 - mae: 0.0178 - val_loss: 8.3556e-04 - val_mae: 0.0179
# Epoch 15/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.0128e-04 - mae: 0.0179 - val_loss: 8.7697e-04 - val_mae: 0.0193
# Epoch 16/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.9341e-04 - mae: 0.0177 - val_loss: 8.3496e-04 - val_mae: 0.0183
# Epoch 17/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.7025e-04 - mae: 0.0172 - val_loss: 7.9740e-04 - val_mae: 0.0175
# Epoch 18/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6973e-04 - mae: 0.0173 - val_loss: 8.0186e-04 - val_mae: 0.0178
# Epoch 19/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6769e-04 - mae: 0.0172 - val_loss: 8.0004e-04 - val_mae: 0.0176
# Epoch 20/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6449e-04 - mae: 0.0172 - val_loss: 8.0139e-04 - val_mae: 0.0177
# Epoch 21/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.7084e-04 - mae: 0.0173 - val_loss: 7.9257e-04 - val_mae: 0.0175
# Epoch 22/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6980e-04 - mae: 0.0173 - val_loss: 7.8795e-04 - val_mae: 0.0174
# Epoch 23/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6265e-04 - mae: 0.0171 - val_loss: 7.9495e-04 - val_mae: 0.0174
# Epoch 24/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6517e-04 - mae: 0.0172 - val_loss: 8.0472e-04 - val_mae: 0.0179
# Epoch 25/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6441e-04 - mae: 0.0172 - val_loss: 8.1655e-04 - val_mae: 0.0181
# Epoch 26/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6577e-04 - mae: 0.0172 - val_loss: 7.9787e-04 - val_mae: 0.0174
# Epoch 27/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4445e-04 - mae: 0.0168 - val_loss: 7.7346e-04 - val_mae: 0.0171
# Epoch 28/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4444e-04 - mae: 0.0168 - val_loss: 7.9728e-04 - val_mae: 0.0176
# Epoch 29/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.4355e-04 - mae: 0.0168 - val_loss: 7.6391e-04 - val_mae: 0.0169
# Epoch 30/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.4126e-04 - mae: 0.0168 - val_loss: 7.8989e-04 - val_mae: 0.0175
# Epoch 31/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.4282e-04 - mae: 0.0168 - val_loss: 7.8269e-04 - val_mae: 0.0176
# Epoch 32/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.4201e-04 - mae: 0.0168 - val_loss: 7.7346e-04 - val_mae: 0.0172
# Epoch 33/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.4209e-04 - mae: 0.0168 - val_loss: 7.8143e-04 - val_mae: 0.0173
# Epoch 34/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4344e-04 - mae: 0.0168 - val_loss: 7.6389e-04 - val_mae: 0.0170
# Epoch 35/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.3862e-04 - mae: 0.0167 - val_loss: 7.8150e-04 - val_mae: 0.0175
# Epoch 36/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.3920e-04 - mae: 0.0168 - val_loss: 7.7601e-04 - val_mae: 0.0172
# Epoch 37/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.4012e-04 - mae: 0.0168 - val_loss: 7.8654e-04 - val_mae: 0.0173
# Epoch 38/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2661e-04 - mae: 0.0165 - val_loss: 7.5665e-04 - val_mae: 0.0168
# Epoch 39/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2525e-04 - mae: 0.0165 - val_loss: 7.6075e-04 - val_mae: 0.0169
# Epoch 40/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2539e-04 - mae: 0.0165 - val_loss: 7.5834e-04 - val_mae: 0.0169
# Epoch 41/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2543e-04 - mae: 0.0165 - val_loss: 7.5808e-04 - val_mae: 0.0167
# Epoch 42/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2413e-04 - mae: 0.0165 - val_loss: 7.7565e-04 - val_mae: 0.0174
# Epoch 43/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2283e-04 - mae: 0.0165 - val_loss: 7.5329e-04 - val_mae: 0.0168
# Epoch 44/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2224e-04 - mae: 0.0165 - val_loss: 7.5414e-04 - val_mae: 0.0169
# Epoch 45/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2242e-04 - mae: 0.0165 - val_loss: 7.6761e-04 - val_mae: 0.0170
# Epoch 46/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2233e-04 - mae: 0.0165 - val_loss: 7.5590e-04 - val_mae: 0.0170
# Epoch 47/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2336e-04 - mae: 0.0165 - val_loss: 7.5580e-04 - val_mae: 0.0168
# Epoch 48/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1347e-04 - mae: 0.0163 - val_loss: 7.4714e-04 - val_mae: 0.0166
# Epoch 49/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1305e-04 - mae: 0.0163 - val_loss: 7.5321e-04 - val_mae: 0.0166
# Epoch 50/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1270e-04 - mae: 0.0163 - val_loss: 7.5287e-04 - val_mae: 0.0168
# Epoch 51/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1313e-04 - mae: 0.0163 - val_loss: 7.4819e-04 - val_mae: 0.0167
# Epoch 52/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1102e-04 - mae: 0.0163 - val_loss: 7.4474e-04 - val_mae: 0.0166
# Epoch 53/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1092e-04 - mae: 0.0162 - val_loss: 7.5701e-04 - val_mae: 0.0170
# Epoch 54/150
# 236/236 [==============================] - 38s 161ms/step - loss: 7.1031e-04 - mae: 0.0163 - val_loss: 7.4499e-04 - val_mae: 0.0166
# Epoch 55/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0972e-04 - mae: 0.0162 - val_loss: 7.5438e-04 - val_mae: 0.0167
# Epoch 56/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1110e-04 - mae: 0.0162 - val_loss: 7.4668e-04 - val_mae: 0.0167
# Epoch 57/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1037e-04 - mae: 0.0162 - val_loss: 7.4975e-04 - val_mae: 0.0168
# Epoch 58/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0583e-04 - mae: 0.0161 - val_loss: 7.4204e-04 - val_mae: 0.0165
# Epoch 59/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0528e-04 - mae: 0.0161 - val_loss: 7.4110e-04 - val_mae: 0.0166
# Epoch 60/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0387e-04 - mae: 0.0161 - val_loss: 7.3945e-04 - val_mae: 0.0166
# Epoch 61/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0342e-04 - mae: 0.0161 - val_loss: 7.4008e-04 - val_mae: 0.0165
# Epoch 62/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0454e-04 - mae: 0.0161 - val_loss: 7.3932e-04 - val_mae: 0.0165
# Epoch 63/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0387e-04 - mae: 0.0161 - val_loss: 7.4076e-04 - val_mae: 0.0165
# Epoch 64/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0339e-04 - mae: 0.0161 - val_loss: 7.4255e-04 - val_mae: 0.0166
# Epoch 65/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0343e-04 - mae: 0.0161 - val_loss: 7.4059e-04 - val_mae: 0.0165
# Epoch 66/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0262e-04 - mae: 0.0161 - val_loss: 7.4179e-04 - val_mae: 0.0165
# Epoch 67/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0309e-04 - mae: 0.0161 - val_loss: 7.3997e-04 - val_mae: 0.0165
# Epoch 68/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9974e-04 - mae: 0.0160 - val_loss: 7.3717e-04 - val_mae: 0.0164
# Epoch 69/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9957e-04 - mae: 0.0160 - val_loss: 7.3864e-04 - val_mae: 0.0165
# Epoch 70/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9968e-04 - mae: 0.0160 - val_loss: 7.3773e-04 - val_mae: 0.0165
# Epoch 71/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9978e-04 - mae: 0.0161 - val_loss: 7.3772e-04 - val_mae: 0.0165
# Epoch 72/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9945e-04 - mae: 0.0160 - val_loss: 7.3844e-04 - val_mae: 0.0165
# Epoch 73/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9958e-04 - mae: 0.0160 - val_loss: 7.3812e-04 - val_mae: 0.0164
# Epoch 74/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9911e-04 - mae: 0.0160 - val_loss: 7.3761e-04 - val_mae: 0.0165
# Epoch 75/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9901e-04 - mae: 0.0160 - val_loss: 7.3744e-04 - val_mae: 0.0165
# Epoch 76/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9919e-04 - mae: 0.0160 - val_loss: 7.3702e-04 - val_mae: 0.0165
# Epoch 77/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9875e-04 - mae: 0.0160 - val_loss: 7.4095e-04 - val_mae: 0.0165
# Epoch 78/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9771e-04 - mae: 0.0160 - val_loss: 7.3600e-04 - val_mae: 0.0164
# Epoch 79/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9757e-04 - mae: 0.0160 - val_loss: 7.3813e-04 - val_mae: 0.0165
# Epoch 80/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9747e-04 - mae: 0.0160 - val_loss: 7.3648e-04 - val_mae: 0.0165
# Epoch 81/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9742e-04 - mae: 0.0160 - val_loss: 7.3655e-04 - val_mae: 0.0164
# Epoch 82/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9724e-04 - mae: 0.0160 - val_loss: 7.3594e-04 - val_mae: 0.0164
# Epoch 83/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9729e-04 - mae: 0.0160 - val_loss: 7.3621e-04 - val_mae: 0.0165
# Epoch 84/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9735e-04 - mae: 0.0160 - val_loss: 7.3704e-04 - val_mae: 0.0164
# Epoch 85/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9708e-04 - mae: 0.0160 - val_loss: 7.3830e-04 - val_mae: 0.0164
# Epoch 86/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9704e-04 - mae: 0.0160 - val_loss: 7.3572e-04 - val_mae: 0.0164
# Epoch 87/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9673e-04 - mae: 0.0160 - val_loss: 7.3562e-04 - val_mae: 0.0164
# Epoch 88/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9679e-04 - mae: 0.0160 - val_loss: 7.3558e-04 - val_mae: 0.0164
# Epoch 89/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9653e-04 - mae: 0.0160 - val_loss: 7.3601e-04 - val_mae: 0.0165
# Epoch 90/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9673e-04 - mae: 0.0160 - val_loss: 7.3684e-04 - val_mae: 0.0164
# Epoch 91/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9696e-04 - mae: 0.0160 - val_loss: 7.3873e-04 - val_mae: 0.0164
# Epoch 92/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9715e-04 - mae: 0.0160 - val_loss: 7.3630e-04 - val_mae: 0.0164
# Epoch 93/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9643e-04 - mae: 0.0160 - val_loss: 7.3556e-04 - val_mae: 0.0165
# Epoch 94/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9641e-04 - mae: 0.0160 - val_loss: 7.3455e-04 - val_mae: 0.0164
# Epoch 95/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9630e-04 - mae: 0.0160 - val_loss: 7.3534e-04 - val_mae: 0.0164
# Epoch 96/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9627e-04 - mae: 0.0160 - val_loss: 7.3548e-04 - val_mae: 0.0164
# Epoch 97/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9604e-04 - mae: 0.0160 - val_loss: 7.3548e-04 - val_mae: 0.0164
# Epoch 98/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9618e-04 - mae: 0.0160 - val_loss: 7.3852e-04 - val_mae: 0.0165
# Epoch 99/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9631e-04 - mae: 0.0160 - val_loss: 7.3757e-04 - val_mae: 0.0164
# Epoch 100/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9598e-04 - mae: 0.0160 - val_loss: 7.3617e-04 - val_mae: 0.0164
# Epoch 101/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9602e-04 - mae: 0.0160 - val_loss: 7.3619e-04 - val_mae: 0.0165
# Epoch 102/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9581e-04 - mae: 0.0160 - val_loss: 7.3485e-04 - val_mae: 0.0165
# Epoch 103/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9570e-04 - mae: 0.0160 - val_loss: 7.3621e-04 - val_mae: 0.0164
# Epoch 104/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9554e-04 - mae: 0.0160 - val_loss: 7.3532e-04 - val_mae: 0.0164
# Epoch 105/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9580e-04 - mae: 0.0160 - val_loss: 7.3503e-04 - val_mae: 0.0164
# Epoch 106/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9583e-04 - mae: 0.0160 - val_loss: 7.3595e-04 - val_mae: 0.0165
# Epoch 107/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9572e-04 - mae: 0.0160 - val_loss: 7.3463e-04 - val_mae: 0.0164
# Epoch 108/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9544e-04 - mae: 0.0160 - val_loss: 7.3424e-04 - val_mae: 0.0164
# Epoch 109/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9515e-04 - mae: 0.0160 - val_loss: 7.3581e-04 - val_mae: 0.0164
# Epoch 110/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9523e-04 - mae: 0.0160 - val_loss: 7.3711e-04 - val_mae: 0.0164
# Epoch 111/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9531e-04 - mae: 0.0160 - val_loss: 7.3469e-04 - val_mae: 0.0164
# Epoch 112/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9519e-04 - mae: 0.0160 - val_loss: 7.3495e-04 - val_mae: 0.0164
# Epoch 113/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9522e-04 - mae: 0.0160 - val_loss: 7.3550e-04 - val_mae: 0.0164
# Epoch 114/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9500e-04 - mae: 0.0160 - val_loss: 7.3445e-04 - val_mae: 0.0164
# Epoch 115/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9486e-04 - mae: 0.0160 - val_loss: 7.3546e-04 - val_mae: 0.0164
# Epoch 116/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9493e-04 - mae: 0.0160 - val_loss: 7.3451e-04 - val_mae: 0.0164
# Epoch 117/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9487e-04 - mae: 0.0160 - val_loss: 7.3551e-04 - val_mae: 0.0164
# Epoch 118/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9499e-04 - mae: 0.0160 - val_loss: 7.3553e-04 - val_mae: 0.0165
# Epoch 119/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9485e-04 - mae: 0.0160 - val_loss: 7.3747e-04 - val_mae: 0.0164
# Epoch 120/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9496e-04 - mae: 0.0160 - val_loss: 7.3444e-04 - val_mae: 0.0164
# Epoch 121/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9469e-04 - mae: 0.0160 - val_loss: 7.3714e-04 - val_mae: 0.0164
# Epoch 122/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9431e-04 - mae: 0.0160 - val_loss: 7.3531e-04 - val_mae: 0.0165
# Epoch 123/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9451e-04 - mae: 0.0160 - val_loss: 7.3495e-04 - val_mae: 0.0164
# Epoch 124/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9459e-04 - mae: 0.0160 - val_loss: 7.3591e-04 - val_mae: 0.0164
# Epoch 125/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9407e-04 - mae: 0.0160 - val_loss: 7.3566e-04 - val_mae: 0.0164
# Epoch 126/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9413e-04 - mae: 0.0160 - val_loss: 7.3536e-04 - val_mae: 0.0164
# Epoch 127/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9481e-04 - mae: 0.0160 - val_loss: 7.3401e-04 - val_mae: 0.0164
# Epoch 128/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9425e-04 - mae: 0.0160 - val_loss: 7.3441e-04 - val_mae: 0.0164
# Epoch 129/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9396e-04 - mae: 0.0160 - val_loss: 7.3441e-04 - val_mae: 0.0164
# Epoch 130/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9375e-04 - mae: 0.0160 - val_loss: 7.3557e-04 - val_mae: 0.0164
# Epoch 131/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9415e-04 - mae: 0.0160 - val_loss: 7.3421e-04 - val_mae: 0.0164
# Epoch 132/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9380e-04 - mae: 0.0160 - val_loss: 7.3602e-04 - val_mae: 0.0165
# Epoch 133/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9395e-04 - mae: 0.0160 - val_loss: 7.3491e-04 - val_mae: 0.0165
# Epoch 134/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9372e-04 - mae: 0.0160 - val_loss: 7.3599e-04 - val_mae: 0.0165
# Epoch 135/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9389e-04 - mae: 0.0160 - val_loss: 7.3455e-04 - val_mae: 0.0164
# Epoch 136/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9357e-04 - mae: 0.0160 - val_loss: 7.3490e-04 - val_mae: 0.0163
# Epoch 137/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9373e-04 - mae: 0.0160 - val_loss: 7.3525e-04 - val_mae: 0.0165
# Epoch 138/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9359e-04 - mae: 0.0160 - val_loss: 7.3516e-04 - val_mae: 0.0164
# Epoch 139/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9376e-04 - mae: 0.0160 - val_loss: 7.3454e-04 - val_mae: 0.0164
# Epoch 140/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9389e-04 - mae: 0.0160 - val_loss: 7.3503e-04 - val_mae: 0.0165
# Epoch 141/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9369e-04 - mae: 0.0160 - val_loss: 7.3353e-04 - val_mae: 0.0164
# Epoch 142/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9335e-04 - mae: 0.0159 - val_loss: 7.3453e-04 - val_mae: 0.0164
# Epoch 143/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9330e-04 - mae: 0.0159 - val_loss: 7.3408e-04 - val_mae: 0.0165
# Epoch 144/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9318e-04 - mae: 0.0159 - val_loss: 7.3355e-04 - val_mae: 0.0164
# Epoch 145/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9289e-04 - mae: 0.0159 - val_loss: 7.3489e-04 - val_mae: 0.0164
# Epoch 146/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9300e-04 - mae: 0.0159 - val_loss: 7.3578e-04 - val_mae: 0.0165
# Epoch 147/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9304e-04 - mae: 0.0160 - val_loss: 7.3523e-04 - val_mae: 0.0164
# Epoch 148/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9283e-04 - mae: 0.0159 - val_loss: 7.3408e-04 - val_mae: 0.0164
# Epoch 149/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9297e-04 - mae: 0.0159 - val_loss: 7.3596e-04 - val_mae: 0.0164
# Epoch 150/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9299e-04 - mae: 0.0159 - val_loss: 7.3379e-04 - val_mae: 0.0164
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               1064960
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 1,098,247
# Trainable params: 1,098,247
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 236/236 [==============================] - 39s 161ms/step - loss: 0.0044 - mae: 0.0371 - val_loss: 0.0013 - val_mae: 0.0249
# Epoch 2/150
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0011 - mae: 0.0226 - val_loss: 0.0011 - val_mae: 0.0220
# Epoch 3/150
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0010 - mae: 0.0210 - val_loss: 0.0011 - val_mae: 0.0219
# Epoch 4/150
# 236/236 [==============================] - 37s 157ms/step - loss: 9.2491e-04 - mae: 0.0198 - val_loss: 9.2874e-04 - val_mae: 0.0194
# Epoch 5/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.8545e-04 - mae: 0.0192 - val_loss: 9.0446e-04 - val_mae: 0.0193
# Epoch 6/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.6506e-04 - mae: 0.0190 - val_loss: 8.9486e-04 - val_mae: 0.0190
# Epoch 7/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.4900e-04 - mae: 0.0186 - val_loss: 9.4798e-04 - val_mae: 0.0205
# Epoch 8/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.3826e-04 - mae: 0.0184 - val_loss: 8.5279e-04 - val_mae: 0.0184
# Epoch 9/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.3033e-04 - mae: 0.0183 - val_loss: 8.6908e-04 - val_mae: 0.0187
# Epoch 10/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.3071e-04 - mae: 0.0182 - val_loss: 8.6142e-04 - val_mae: 0.0184
# Epoch 11/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.2353e-04 - mae: 0.0181 - val_loss: 8.7415e-04 - val_mae: 0.0190
# Epoch 12/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.1571e-04 - mae: 0.0180 - val_loss: 8.9163e-04 - val_mae: 0.0190
# Epoch 13/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.1687e-04 - mae: 0.0181 - val_loss: 8.1753e-04 - val_mae: 0.0176
# Epoch 14/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.0498e-04 - mae: 0.0178 - val_loss: 8.8295e-04 - val_mae: 0.0186
# Epoch 15/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.1146e-04 - mae: 0.0180 - val_loss: 8.6264e-04 - val_mae: 0.0186
# Epoch 16/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.0484e-04 - mae: 0.0179 - val_loss: 8.6277e-04 - val_mae: 0.0187
# Epoch 17/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.0549e-04 - mae: 0.0179 - val_loss: 8.4657e-04 - val_mae: 0.0184
# Epoch 18/150
# 236/236 [==============================] - 37s 157ms/step - loss: 8.0695e-04 - mae: 0.0180 - val_loss: 8.4373e-04 - val_mae: 0.0188
# Epoch 19/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.9913e-04 - mae: 0.0178 - val_loss: 8.3953e-04 - val_mae: 0.0183
# Epoch 20/150
# 236/236 [==============================] - 37s 158ms/step - loss: 8.0083e-04 - mae: 0.0179 - val_loss: 8.8171e-04 - val_mae: 0.0194
# Epoch 21/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.9945e-04 - mae: 0.0178 - val_loss: 8.1588e-04 - val_mae: 0.0179
# Epoch 22/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.9671e-04 - mae: 0.0177 - val_loss: 8.1272e-04 - val_mae: 0.0178
# Epoch 23/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.9167e-04 - mae: 0.0177 - val_loss: 8.7578e-04 - val_mae: 0.0190
# Epoch 24/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6949e-04 - mae: 0.0172 - val_loss: 7.9087e-04 - val_mae: 0.0173
# Epoch 25/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6520e-04 - mae: 0.0171 - val_loss: 7.9765e-04 - val_mae: 0.0176
# Epoch 26/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6512e-04 - mae: 0.0171 - val_loss: 8.0478e-04 - val_mae: 0.0175
# Epoch 27/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6288e-04 - mae: 0.0171 - val_loss: 7.8724e-04 - val_mae: 0.0171
# Epoch 28/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6911e-04 - mae: 0.0173 - val_loss: 7.8386e-04 - val_mae: 0.0172
# Epoch 29/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6504e-04 - mae: 0.0172 - val_loss: 7.7742e-04 - val_mae: 0.0172
# Epoch 30/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.5991e-04 - mae: 0.0171 - val_loss: 8.1356e-04 - val_mae: 0.0178
# Epoch 31/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6153e-04 - mae: 0.0171 - val_loss: 7.8169e-04 - val_mae: 0.0173
# Epoch 32/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.6179e-04 - mae: 0.0171 - val_loss: 7.8095e-04 - val_mae: 0.0173
# Epoch 33/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5753e-04 - mae: 0.0171 - val_loss: 8.1354e-04 - val_mae: 0.0178
# Epoch 34/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4341e-04 - mae: 0.0168 - val_loss: 7.6657e-04 - val_mae: 0.0170
# Epoch 35/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.3985e-04 - mae: 0.0167 - val_loss: 7.7641e-04 - val_mae: 0.0172
# Epoch 36/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4031e-04 - mae: 0.0167 - val_loss: 7.7384e-04 - val_mae: 0.0170
# Epoch 37/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4153e-04 - mae: 0.0168 - val_loss: 7.7971e-04 - val_mae: 0.0172
# Epoch 38/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4300e-04 - mae: 0.0168 - val_loss: 7.7684e-04 - val_mae: 0.0171
# Epoch 39/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3850e-04 - mae: 0.0167 - val_loss: 7.9183e-04 - val_mae: 0.0174
# Epoch 40/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.4144e-04 - mae: 0.0168 - val_loss: 7.6460e-04 - val_mae: 0.0169
# Epoch 41/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.3935e-04 - mae: 0.0168 - val_loss: 7.6766e-04 - val_mae: 0.0170
# Epoch 42/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.3602e-04 - mae: 0.0167 - val_loss: 7.7610e-04 - val_mae: 0.0173
# Epoch 43/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.3689e-04 - mae: 0.0167 - val_loss: 7.6169e-04 - val_mae: 0.0169
# Epoch 44/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2467e-04 - mae: 0.0164 - val_loss: 7.5439e-04 - val_mae: 0.0168
# Epoch 45/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2516e-04 - mae: 0.0165 - val_loss: 7.5822e-04 - val_mae: 0.0168
# Epoch 46/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2511e-04 - mae: 0.0165 - val_loss: 7.6164e-04 - val_mae: 0.0170
# Epoch 47/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2707e-04 - mae: 0.0165 - val_loss: 7.5853e-04 - val_mae: 0.0168
# Epoch 48/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2351e-04 - mae: 0.0164 - val_loss: 7.5818e-04 - val_mae: 0.0168
# Epoch 49/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2432e-04 - mae: 0.0165 - val_loss: 7.6050e-04 - val_mae: 0.0168
# Epoch 50/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2363e-04 - mae: 0.0165 - val_loss: 7.5465e-04 - val_mae: 0.0168
# Epoch 51/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2380e-04 - mae: 0.0165 - val_loss: 7.6268e-04 - val_mae: 0.0170
# Epoch 52/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2313e-04 - mae: 0.0165 - val_loss: 7.5454e-04 - val_mae: 0.0168
# Epoch 53/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.2111e-04 - mae: 0.0164 - val_loss: 7.5602e-04 - val_mae: 0.0168
# Epoch 54/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1452e-04 - mae: 0.0163 - val_loss: 7.4714e-04 - val_mae: 0.0166
# Epoch 55/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1423e-04 - mae: 0.0163 - val_loss: 7.5285e-04 - val_mae: 0.0167
# Epoch 56/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1495e-04 - mae: 0.0163 - val_loss: 7.4944e-04 - val_mae: 0.0167
# Epoch 57/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1466e-04 - mae: 0.0163 - val_loss: 7.5024e-04 - val_mae: 0.0168
# Epoch 58/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1487e-04 - mae: 0.0163 - val_loss: 7.4587e-04 - val_mae: 0.0167
# Epoch 59/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1359e-04 - mae: 0.0163 - val_loss: 7.4825e-04 - val_mae: 0.0167
# Epoch 60/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1305e-04 - mae: 0.0163 - val_loss: 7.4724e-04 - val_mae: 0.0167
# Epoch 61/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.1200e-04 - mae: 0.0162 - val_loss: 7.4594e-04 - val_mae: 0.0167
# Epoch 62/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1339e-04 - mae: 0.0163 - val_loss: 7.4533e-04 - val_mae: 0.0166
# Epoch 63/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1302e-04 - mae: 0.0163 - val_loss: 7.4703e-04 - val_mae: 0.0166
# Epoch 64/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0832e-04 - mae: 0.0162 - val_loss: 7.4447e-04 - val_mae: 0.0167
# Epoch 65/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0796e-04 - mae: 0.0162 - val_loss: 7.4358e-04 - val_mae: 0.0166
# Epoch 66/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0723e-04 - mae: 0.0162 - val_loss: 7.4480e-04 - val_mae: 0.0166
# Epoch 67/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0748e-04 - mae: 0.0162 - val_loss: 7.4219e-04 - val_mae: 0.0166
# Epoch 68/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0712e-04 - mae: 0.0162 - val_loss: 7.4190e-04 - val_mae: 0.0165
# Epoch 69/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0668e-04 - mae: 0.0162 - val_loss: 7.4293e-04 - val_mae: 0.0166
# Epoch 70/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0697e-04 - mae: 0.0162 - val_loss: 7.4144e-04 - val_mae: 0.0166
# Epoch 71/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0720e-04 - mae: 0.0162 - val_loss: 7.4556e-04 - val_mae: 0.0167
# Epoch 72/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0681e-04 - mae: 0.0162 - val_loss: 7.4049e-04 - val_mae: 0.0165
# Epoch 73/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0679e-04 - mae: 0.0162 - val_loss: 7.4004e-04 - val_mae: 0.0164
# Epoch 74/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0369e-04 - mae: 0.0161 - val_loss: 7.3925e-04 - val_mae: 0.0165
# Epoch 75/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0382e-04 - mae: 0.0161 - val_loss: 7.3965e-04 - val_mae: 0.0166
# Epoch 76/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0377e-04 - mae: 0.0161 - val_loss: 7.3778e-04 - val_mae: 0.0165
# Epoch 77/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0324e-04 - mae: 0.0161 - val_loss: 7.4069e-04 - val_mae: 0.0165
# Epoch 78/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0322e-04 - mae: 0.0161 - val_loss: 7.3753e-04 - val_mae: 0.0165
# Epoch 79/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0327e-04 - mae: 0.0161 - val_loss: 7.3913e-04 - val_mae: 0.0165
# Epoch 80/150
# 236/236 [==============================] - 37s 159ms/step - loss: 7.0295e-04 - mae: 0.0161 - val_loss: 7.3808e-04 - val_mae: 0.0165
# Epoch 81/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0281e-04 - mae: 0.0161 - val_loss: 7.3837e-04 - val_mae: 0.0165
# Epoch 82/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0271e-04 - mae: 0.0161 - val_loss: 7.3841e-04 - val_mae: 0.0165
# Epoch 83/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0280e-04 - mae: 0.0161 - val_loss: 7.3815e-04 - val_mae: 0.0165
# Epoch 84/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0168e-04 - mae: 0.0161 - val_loss: 7.3801e-04 - val_mae: 0.0165
# Epoch 85/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0145e-04 - mae: 0.0161 - val_loss: 7.3902e-04 - val_mae: 0.0165
# Epoch 86/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0139e-04 - mae: 0.0161 - val_loss: 7.3698e-04 - val_mae: 0.0165
# Epoch 87/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0108e-04 - mae: 0.0161 - val_loss: 7.3675e-04 - val_mae: 0.0164
# Epoch 88/150
# 236/236 [==============================] - 37s 159ms/step - loss: 7.0116e-04 - mae: 0.0161 - val_loss: 7.3646e-04 - val_mae: 0.0165
# Epoch 89/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0106e-04 - mae: 0.0161 - val_loss: 7.3671e-04 - val_mae: 0.0165
# Epoch 90/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0119e-04 - mae: 0.0161 - val_loss: 7.3737e-04 - val_mae: 0.0164
# Epoch 91/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0125e-04 - mae: 0.0161 - val_loss: 7.3806e-04 - val_mae: 0.0164
# Epoch 92/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0156e-04 - mae: 0.0161 - val_loss: 7.3737e-04 - val_mae: 0.0165
# Epoch 93/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0086e-04 - mae: 0.0161 - val_loss: 7.3608e-04 - val_mae: 0.0165
# Epoch 94/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0065e-04 - mae: 0.0161 - val_loss: 7.3573e-04 - val_mae: 0.0165
# Epoch 95/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0057e-04 - mae: 0.0161 - val_loss: 7.3600e-04 - val_mae: 0.0164
# Epoch 96/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0052e-04 - mae: 0.0160 - val_loss: 7.3615e-04 - val_mae: 0.0165
# Epoch 97/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0045e-04 - mae: 0.0161 - val_loss: 7.3586e-04 - val_mae: 0.0164
# Epoch 98/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0046e-04 - mae: 0.0161 - val_loss: 7.3833e-04 - val_mae: 0.0165
# Epoch 99/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0058e-04 - mae: 0.0161 - val_loss: 7.3834e-04 - val_mae: 0.0165
# Epoch 100/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0036e-04 - mae: 0.0161 - val_loss: 7.3627e-04 - val_mae: 0.0164
# Epoch 101/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0030e-04 - mae: 0.0160 - val_loss: 7.3656e-04 - val_mae: 0.0165
# Epoch 102/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0027e-04 - mae: 0.0160 - val_loss: 7.3559e-04 - val_mae: 0.0165
# Epoch 103/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9993e-04 - mae: 0.0160 - val_loss: 7.3653e-04 - val_mae: 0.0165
# Epoch 104/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9988e-04 - mae: 0.0160 - val_loss: 7.3568e-04 - val_mae: 0.0165
# Epoch 105/150
# 236/236 [==============================] - 37s 157ms/step - loss: 7.0003e-04 - mae: 0.0160 - val_loss: 7.3574e-04 - val_mae: 0.0165
# Epoch 106/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0008e-04 - mae: 0.0160 - val_loss: 7.3638e-04 - val_mae: 0.0165
# Epoch 107/150
# 236/236 [==============================] - 37s 158ms/step - loss: 7.0022e-04 - mae: 0.0160 - val_loss: 7.3536e-04 - val_mae: 0.0164
# Epoch 108/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9988e-04 - mae: 0.0160 - val_loss: 7.3492e-04 - val_mae: 0.0165
# Epoch 109/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9947e-04 - mae: 0.0160 - val_loss: 7.3632e-04 - val_mae: 0.0164
# Epoch 110/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9961e-04 - mae: 0.0160 - val_loss: 7.3699e-04 - val_mae: 0.0164
# Epoch 111/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9961e-04 - mae: 0.0160 - val_loss: 7.3504e-04 - val_mae: 0.0164
# Epoch 112/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9952e-04 - mae: 0.0160 - val_loss: 7.3573e-04 - val_mae: 0.0164
# Epoch 113/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9946e-04 - mae: 0.0160 - val_loss: 7.3539e-04 - val_mae: 0.0164
# Epoch 114/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9929e-04 - mae: 0.0160 - val_loss: 7.3517e-04 - val_mae: 0.0165
# Epoch 115/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9924e-04 - mae: 0.0160 - val_loss: 7.3631e-04 - val_mae: 0.0164
# Epoch 116/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9930e-04 - mae: 0.0160 - val_loss: 7.3494e-04 - val_mae: 0.0165
# Epoch 117/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9920e-04 - mae: 0.0160 - val_loss: 7.3562e-04 - val_mae: 0.0164
# Epoch 118/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9926e-04 - mae: 0.0160 - val_loss: 7.3586e-04 - val_mae: 0.0165
# Epoch 119/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9913e-04 - mae: 0.0160 - val_loss: 7.3759e-04 - val_mae: 0.0164
# Epoch 120/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9932e-04 - mae: 0.0160 - val_loss: 7.3465e-04 - val_mae: 0.0164
# Epoch 121/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9905e-04 - mae: 0.0160 - val_loss: 7.3669e-04 - val_mae: 0.0165
# Epoch 122/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9874e-04 - mae: 0.0160 - val_loss: 7.3534e-04 - val_mae: 0.0165
# Epoch 123/150
# 236/236 [==============================] - 37s 159ms/step - loss: 6.9892e-04 - mae: 0.0160 - val_loss: 7.3430e-04 - val_mae: 0.0164
# Epoch 124/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9891e-04 - mae: 0.0160 - val_loss: 7.3551e-04 - val_mae: 0.0164
# Epoch 125/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9844e-04 - mae: 0.0160 - val_loss: 7.3658e-04 - val_mae: 0.0165
# Epoch 126/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9845e-04 - mae: 0.0160 - val_loss: 7.3618e-04 - val_mae: 0.0164
# Epoch 127/150
# 236/236 [==============================] - 37s 159ms/step - loss: 6.9895e-04 - mae: 0.0160 - val_loss: 7.3449e-04 - val_mae: 0.0165
# Epoch 128/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9837e-04 - mae: 0.0160 - val_loss: 7.3441e-04 - val_mae: 0.0164
# Epoch 129/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9848e-04 - mae: 0.0160 - val_loss: 7.3407e-04 - val_mae: 0.0164
# Epoch 130/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9809e-04 - mae: 0.0160 - val_loss: 7.3475e-04 - val_mae: 0.0165
# Epoch 131/150
# 236/236 [==============================] - 37s 159ms/step - loss: 6.9840e-04 - mae: 0.0160 - val_loss: 7.3420e-04 - val_mae: 0.0165
# Epoch 132/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9817e-04 - mae: 0.0160 - val_loss: 7.3651e-04 - val_mae: 0.0165
# Epoch 133/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9820e-04 - mae: 0.0160 - val_loss: 7.3420e-04 - val_mae: 0.0165
# Epoch 134/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9804e-04 - mae: 0.0160 - val_loss: 7.3529e-04 - val_mae: 0.0165
# Epoch 135/150
# 236/236 [==============================] - 37s 159ms/step - loss: 6.9816e-04 - mae: 0.0160 - val_loss: 7.3447e-04 - val_mae: 0.0165
# Epoch 136/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9790e-04 - mae: 0.0160 - val_loss: 7.3524e-04 - val_mae: 0.0164
# Epoch 137/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9807e-04 - mae: 0.0160 - val_loss: 7.3489e-04 - val_mae: 0.0165
# Epoch 138/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9780e-04 - mae: 0.0160 - val_loss: 7.3420e-04 - val_mae: 0.0164
# Epoch 139/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9803e-04 - mae: 0.0160 - val_loss: 7.3474e-04 - val_mae: 0.0165
# Epoch 140/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9831e-04 - mae: 0.0160 - val_loss: 7.3486e-04 - val_mae: 0.0165
# Epoch 141/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9805e-04 - mae: 0.0160 - val_loss: 7.3342e-04 - val_mae: 0.0164
# Epoch 142/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9786e-04 - mae: 0.0160 - val_loss: 7.3417e-04 - val_mae: 0.0165
# Epoch 143/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9771e-04 - mae: 0.0160 - val_loss: 7.3385e-04 - val_mae: 0.0165
# Epoch 144/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9751e-04 - mae: 0.0160 - val_loss: 7.3349e-04 - val_mae: 0.0165
# Epoch 145/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9732e-04 - mae: 0.0160 - val_loss: 7.3441e-04 - val_mae: 0.0165
# Epoch 146/150
# 236/236 [==============================] - 37s 157ms/step - loss: 6.9739e-04 - mae: 0.0160 - val_loss: 7.3484e-04 - val_mae: 0.0166
# Epoch 147/150
# 236/236 [==============================] - 37s 159ms/step - loss: 6.9732e-04 - mae: 0.0160 - val_loss: 7.3437e-04 - val_mae: 0.0165
# Epoch 148/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9722e-04 - mae: 0.0160 - val_loss: 7.3328e-04 - val_mae: 0.0164
# Epoch 149/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9734e-04 - mae: 0.0160 - val_loss: 7.3527e-04 - val_mae: 0.0164
# Epoch 150/150
# 236/236 [==============================] - 37s 158ms/step - loss: 6.9729e-04 - mae: 0.0160 - val_loss: 7.3344e-04 - val_mae: 0.0164

# %%
future_window = 1152

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred(model,sequence_length))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 4.198785556781365  MAE: 2.6793838632581006
# RMSE: 6.28243500089404  MAE: 4.134251479275568
#
# Best model is lstm + 1 dense

# %%
colors = ['#7d34fa','#ff8a0d','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#PAPER PLOTS

window = 100
future_window = 400
for i in range(7):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:future_window,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()
    plt.savefig('plot'+str(i))

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
save_model(models_array[best_model],'model')
#save_model(model_2,'model_2')
# Out:
# 2022-01-14 17:39:12.271356: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# model saved!

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
