# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Pre-processing

X_max = X.max(axis=0)
X_min = X.min(axis=0)

X_mean = X.mean(axis=0)
X_std = X.std(axis=0)

X_scaled = (X-X_min)/(X_max-X_min)

# %%
i = 0
plt.figure(figsize=(15,3))
plt.plot(X[:,i],color='steelblue')
plt.plot(X_scaled[:,i],color='limegreen',alpha=.5)
plt.axhline(y=X_mean[i],color='darkorange',linewidth=2)
plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)
plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
sequence_length = 400
stride = 1
X_train, y_train = extract_sequences(X_scaled,sequence_length,stride)
input_shape = X_train.shape[1:]

# %%
input_shape = X_train.shape[1:]
epochs = 200
batch_size = 256

# %%
def build_lstm(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.GRU(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
lstm_units=512
model = build_lstm(input_shape,lstm_units)
model.summary()
# Out:
# 2022-01-15 07:54:00.574861: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:00.663058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:00.663765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:00.664872: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-15 07:54:00.665675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:00.666376: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:00.667014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:02.411850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:02.412641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:02.413274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 07:54:02.413881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# gru (GRU)                    (None, 512)               800256
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 3591
# =================================================================
# Total params: 803,847
# Trainable params: 803,847
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

history = model.fit(
    X_train,
    y_train,
    validation_split=.1,
    epochs = epochs,
    batch_size = batch_size,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# 2022-01-15 07:54:04.847688: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-01-15 07:54:07.122033: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 240/240 [==============================] - 33s 123ms/step - loss: 0.0048 - mae: 0.0356 - val_loss: 0.0011 - val_mae: 0.0216
# Epoch 2/200
# 240/240 [==============================] - 29s 120ms/step - loss: 9.7527e-04 - mae: 0.0202 - val_loss: 9.4166e-04 - val_mae: 0.0198
# Epoch 3/200
# 240/240 [==============================] - 29s 120ms/step - loss: 9.0501e-04 - mae: 0.0192 - val_loss: 8.9797e-04 - val_mae: 0.0190
# Epoch 4/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.7854e-04 - mae: 0.0188 - val_loss: 8.7500e-04 - val_mae: 0.0189
# Epoch 5/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.5817e-04 - mae: 0.0185 - val_loss: 8.6781e-04 - val_mae: 0.0186
# Epoch 6/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.5095e-04 - mae: 0.0184 - val_loss: 8.3787e-04 - val_mae: 0.0180
# Epoch 7/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.4483e-04 - mae: 0.0184 - val_loss: 8.4046e-04 - val_mae: 0.0180
# Epoch 8/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.3327e-04 - mae: 0.0180 - val_loss: 8.2045e-04 - val_mae: 0.0178
# Epoch 9/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.3345e-04 - mae: 0.0181 - val_loss: 8.4960e-04 - val_mae: 0.0183
# Epoch 10/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.3221e-04 - mae: 0.0181 - val_loss: 8.3933e-04 - val_mae: 0.0185
# Epoch 11/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.3250e-04 - mae: 0.0181 - val_loss: 8.3030e-04 - val_mae: 0.0179
# Epoch 12/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.3500e-04 - mae: 0.0182 - val_loss: 8.4622e-04 - val_mae: 0.0186
# Epoch 13/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.2521e-04 - mae: 0.0180 - val_loss: 8.3773e-04 - val_mae: 0.0181
# Epoch 14/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.2349e-04 - mae: 0.0179 - val_loss: 8.2281e-04 - val_mae: 0.0180
# Epoch 15/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.2144e-04 - mae: 0.0180 - val_loss: 8.4560e-04 - val_mae: 0.0190
# Epoch 16/200
# 240/240 [==============================] - 29s 120ms/step - loss: 8.2840e-04 - mae: 0.0181 - val_loss: 8.0883e-04 - val_mae: 0.0176
# Epoch 17/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9579e-04 - mae: 0.0174 - val_loss: 8.0927e-04 - val_mae: 0.0176
# Epoch 18/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9769e-04 - mae: 0.0174 - val_loss: 8.0900e-04 - val_mae: 0.0176
# Epoch 19/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9597e-04 - mae: 0.0174 - val_loss: 7.9626e-04 - val_mae: 0.0177
# Epoch 20/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9907e-04 - mae: 0.0175 - val_loss: 8.3145e-04 - val_mae: 0.0183
# Epoch 21/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.9860e-04 - mae: 0.0175 - val_loss: 8.0937e-04 - val_mae: 0.0178
# Epoch 22/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9859e-04 - mae: 0.0175 - val_loss: 8.0609e-04 - val_mae: 0.0179
# Epoch 23/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9206e-04 - mae: 0.0174 - val_loss: 7.8989e-04 - val_mae: 0.0173
# Epoch 24/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9324e-04 - mae: 0.0175 - val_loss: 7.8840e-04 - val_mae: 0.0175
# Epoch 25/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9703e-04 - mae: 0.0176 - val_loss: 7.9357e-04 - val_mae: 0.0174
# Epoch 26/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.9018e-04 - mae: 0.0174 - val_loss: 7.9269e-04 - val_mae: 0.0174
# Epoch 27/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7898e-04 - mae: 0.0171 - val_loss: 7.7973e-04 - val_mae: 0.0172
# Epoch 28/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7978e-04 - mae: 0.0172 - val_loss: 7.7945e-04 - val_mae: 0.0172
# Epoch 29/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7975e-04 - mae: 0.0172 - val_loss: 7.8047e-04 - val_mae: 0.0172
# Epoch 30/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7638e-04 - mae: 0.0171 - val_loss: 7.8305e-04 - val_mae: 0.0173
# Epoch 31/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7900e-04 - mae: 0.0172 - val_loss: 7.9330e-04 - val_mae: 0.0177
# Epoch 32/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7976e-04 - mae: 0.0172 - val_loss: 7.9276e-04 - val_mae: 0.0177
# Epoch 33/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7822e-04 - mae: 0.0172 - val_loss: 7.8231e-04 - val_mae: 0.0174
# Epoch 34/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7539e-04 - mae: 0.0171 - val_loss: 7.8424e-04 - val_mae: 0.0174
# Epoch 35/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7898e-04 - mae: 0.0172 - val_loss: 7.7763e-04 - val_mae: 0.0172
# Epoch 36/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.7610e-04 - mae: 0.0172 - val_loss: 7.9117e-04 - val_mae: 0.0175
# Epoch 37/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6755e-04 - mae: 0.0170 - val_loss: 7.7671e-04 - val_mae: 0.0172
# Epoch 38/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6710e-04 - mae: 0.0169 - val_loss: 7.7276e-04 - val_mae: 0.0171
# Epoch 39/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6818e-04 - mae: 0.0170 - val_loss: 7.7353e-04 - val_mae: 0.0172
# Epoch 40/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6583e-04 - mae: 0.0170 - val_loss: 7.7121e-04 - val_mae: 0.0171
# Epoch 41/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6729e-04 - mae: 0.0170 - val_loss: 7.7546e-04 - val_mae: 0.0173
# Epoch 42/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6657e-04 - mae: 0.0170 - val_loss: 7.7627e-04 - val_mae: 0.0173
# Epoch 43/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6641e-04 - mae: 0.0170 - val_loss: 7.7160e-04 - val_mae: 0.0171
# Epoch 44/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6409e-04 - mae: 0.0169 - val_loss: 7.7038e-04 - val_mae: 0.0172
# Epoch 45/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6445e-04 - mae: 0.0169 - val_loss: 7.7884e-04 - val_mae: 0.0172
# Epoch 46/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6493e-04 - mae: 0.0170 - val_loss: 7.7797e-04 - val_mae: 0.0173
# Epoch 47/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.6033e-04 - mae: 0.0168 - val_loss: 7.6494e-04 - val_mae: 0.0170
# Epoch 48/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5921e-04 - mae: 0.0168 - val_loss: 7.6800e-04 - val_mae: 0.0172
# Epoch 49/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5868e-04 - mae: 0.0168 - val_loss: 7.6458e-04 - val_mae: 0.0170
# Epoch 50/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5937e-04 - mae: 0.0168 - val_loss: 7.6827e-04 - val_mae: 0.0171
# Epoch 51/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5807e-04 - mae: 0.0168 - val_loss: 7.6760e-04 - val_mae: 0.0171
# Epoch 52/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5778e-04 - mae: 0.0168 - val_loss: 7.6689e-04 - val_mae: 0.0171
# Epoch 53/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5812e-04 - mae: 0.0168 - val_loss: 7.6666e-04 - val_mae: 0.0170
# Epoch 54/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5809e-04 - mae: 0.0168 - val_loss: 7.6225e-04 - val_mae: 0.0169
# Epoch 55/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5785e-04 - mae: 0.0168 - val_loss: 7.6595e-04 - val_mae: 0.0170
# Epoch 56/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5777e-04 - mae: 0.0168 - val_loss: 7.7016e-04 - val_mae: 0.0171
# Epoch 57/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5425e-04 - mae: 0.0167 - val_loss: 7.6275e-04 - val_mae: 0.0170
# Epoch 58/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5361e-04 - mae: 0.0167 - val_loss: 7.6291e-04 - val_mae: 0.0170
# Epoch 59/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5352e-04 - mae: 0.0167 - val_loss: 7.6570e-04 - val_mae: 0.0170
# Epoch 60/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5329e-04 - mae: 0.0167 - val_loss: 7.6029e-04 - val_mae: 0.0169
# Epoch 61/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5303e-04 - mae: 0.0167 - val_loss: 7.6308e-04 - val_mae: 0.0170
# Epoch 62/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5361e-04 - mae: 0.0167 - val_loss: 7.6196e-04 - val_mae: 0.0170
# Epoch 63/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5307e-04 - mae: 0.0167 - val_loss: 7.6285e-04 - val_mae: 0.0169
# Epoch 64/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5281e-04 - mae: 0.0167 - val_loss: 7.6010e-04 - val_mae: 0.0169
# Epoch 65/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5243e-04 - mae: 0.0167 - val_loss: 7.6148e-04 - val_mae: 0.0170
# Epoch 66/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5245e-04 - mae: 0.0167 - val_loss: 7.6104e-04 - val_mae: 0.0170
# Epoch 67/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5049e-04 - mae: 0.0167 - val_loss: 7.5953e-04 - val_mae: 0.0169
# Epoch 68/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5078e-04 - mae: 0.0167 - val_loss: 7.6003e-04 - val_mae: 0.0169
# Epoch 69/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5032e-04 - mae: 0.0167 - val_loss: 7.6113e-04 - val_mae: 0.0170
# Epoch 70/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5007e-04 - mae: 0.0167 - val_loss: 7.5861e-04 - val_mae: 0.0169
# Epoch 71/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5025e-04 - mae: 0.0167 - val_loss: 7.5872e-04 - val_mae: 0.0169
# Epoch 72/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5041e-04 - mae: 0.0167 - val_loss: 7.5782e-04 - val_mae: 0.0169
# Epoch 73/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4998e-04 - mae: 0.0167 - val_loss: 7.5937e-04 - val_mae: 0.0169
# Epoch 74/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.5001e-04 - mae: 0.0167 - val_loss: 7.5785e-04 - val_mae: 0.0169
# Epoch 75/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4968e-04 - mae: 0.0167 - val_loss: 7.5735e-04 - val_mae: 0.0169
# Epoch 76/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4986e-04 - mae: 0.0167 - val_loss: 7.5746e-04 - val_mae: 0.0169
# Epoch 77/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4913e-04 - mae: 0.0167 - val_loss: 7.5771e-04 - val_mae: 0.0169
# Epoch 78/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4883e-04 - mae: 0.0167 - val_loss: 7.5778e-04 - val_mae: 0.0169
# Epoch 79/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4913e-04 - mae: 0.0167 - val_loss: 7.5721e-04 - val_mae: 0.0169
# Epoch 80/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4865e-04 - mae: 0.0167 - val_loss: 7.5872e-04 - val_mae: 0.0169
# Epoch 81/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4869e-04 - mae: 0.0167 - val_loss: 7.5695e-04 - val_mae: 0.0169
# Epoch 82/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4851e-04 - mae: 0.0167 - val_loss: 7.5745e-04 - val_mae: 0.0169
# Epoch 83/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4842e-04 - mae: 0.0167 - val_loss: 7.5687e-04 - val_mae: 0.0169
# Epoch 84/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4821e-04 - mae: 0.0167 - val_loss: 7.5649e-04 - val_mae: 0.0169
# Epoch 85/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4844e-04 - mae: 0.0167 - val_loss: 7.5646e-04 - val_mae: 0.0169
# Epoch 86/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4842e-04 - mae: 0.0167 - val_loss: 7.5615e-04 - val_mae: 0.0168
# Epoch 87/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4817e-04 - mae: 0.0166 - val_loss: 7.5799e-04 - val_mae: 0.0169
# Epoch 88/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4850e-04 - mae: 0.0167 - val_loss: 7.5652e-04 - val_mae: 0.0169
# Epoch 89/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4788e-04 - mae: 0.0166 - val_loss: 7.5683e-04 - val_mae: 0.0169
# Epoch 90/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4787e-04 - mae: 0.0166 - val_loss: 7.5562e-04 - val_mae: 0.0168
# Epoch 91/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4783e-04 - mae: 0.0167 - val_loss: 7.5611e-04 - val_mae: 0.0169
# Epoch 92/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4755e-04 - mae: 0.0166 - val_loss: 7.5627e-04 - val_mae: 0.0169
# Epoch 93/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4758e-04 - mae: 0.0166 - val_loss: 7.5580e-04 - val_mae: 0.0169
# Epoch 94/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4755e-04 - mae: 0.0166 - val_loss: 7.5633e-04 - val_mae: 0.0169
# Epoch 95/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4758e-04 - mae: 0.0166 - val_loss: 7.5677e-04 - val_mae: 0.0169
# Epoch 96/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4758e-04 - mae: 0.0166 - val_loss: 7.5757e-04 - val_mae: 0.0169
# Epoch 97/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4761e-04 - mae: 0.0166 - val_loss: 7.5531e-04 - val_mae: 0.0168
# Epoch 98/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4716e-04 - mae: 0.0166 - val_loss: 7.5479e-04 - val_mae: 0.0168
# Epoch 99/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4715e-04 - mae: 0.0166 - val_loss: 7.5476e-04 - val_mae: 0.0168
# Epoch 100/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4704e-04 - mae: 0.0166 - val_loss: 7.5593e-04 - val_mae: 0.0169
# Epoch 101/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4717e-04 - mae: 0.0166 - val_loss: 7.5582e-04 - val_mae: 0.0169
# Epoch 102/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4678e-04 - mae: 0.0166 - val_loss: 7.5512e-04 - val_mae: 0.0168
# Epoch 103/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4698e-04 - mae: 0.0166 - val_loss: 7.5610e-04 - val_mae: 0.0168
# Epoch 104/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4677e-04 - mae: 0.0166 - val_loss: 7.5496e-04 - val_mae: 0.0169
# Epoch 105/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4677e-04 - mae: 0.0166 - val_loss: 7.5473e-04 - val_mae: 0.0169
# Epoch 106/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4663e-04 - mae: 0.0166 - val_loss: 7.5828e-04 - val_mae: 0.0169
# Epoch 107/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4663e-04 - mae: 0.0166 - val_loss: 7.5486e-04 - val_mae: 0.0168
# Epoch 108/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4636e-04 - mae: 0.0166 - val_loss: 7.5415e-04 - val_mae: 0.0168
# Epoch 109/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4645e-04 - mae: 0.0166 - val_loss: 7.5499e-04 - val_mae: 0.0168
# Epoch 110/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4629e-04 - mae: 0.0166 - val_loss: 7.5521e-04 - val_mae: 0.0169
# Epoch 111/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4623e-04 - mae: 0.0166 - val_loss: 7.5428e-04 - val_mae: 0.0168
# Epoch 112/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4605e-04 - mae: 0.0166 - val_loss: 7.5545e-04 - val_mae: 0.0168
# Epoch 113/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4611e-04 - mae: 0.0166 - val_loss: 7.5434e-04 - val_mae: 0.0168
# Epoch 114/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4604e-04 - mae: 0.0166 - val_loss: 7.5403e-04 - val_mae: 0.0169
# Epoch 115/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4573e-04 - mae: 0.0166 - val_loss: 7.5354e-04 - val_mae: 0.0168
# Epoch 116/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4575e-04 - mae: 0.0166 - val_loss: 7.5349e-04 - val_mae: 0.0168
# Epoch 117/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4563e-04 - mae: 0.0166 - val_loss: 7.5393e-04 - val_mae: 0.0168
# Epoch 118/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4557e-04 - mae: 0.0166 - val_loss: 7.5390e-04 - val_mae: 0.0169
# Epoch 119/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4555e-04 - mae: 0.0166 - val_loss: 7.5264e-04 - val_mae: 0.0168
# Epoch 120/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4543e-04 - mae: 0.0166 - val_loss: 7.5407e-04 - val_mae: 0.0169
# Epoch 121/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4540e-04 - mae: 0.0166 - val_loss: 7.5333e-04 - val_mae: 0.0168
# Epoch 122/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4515e-04 - mae: 0.0166 - val_loss: 7.5299e-04 - val_mae: 0.0168
# Epoch 123/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4505e-04 - mae: 0.0166 - val_loss: 7.5371e-04 - val_mae: 0.0169
# Epoch 124/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4496e-04 - mae: 0.0166 - val_loss: 7.5504e-04 - val_mae: 0.0168
# Epoch 125/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4507e-04 - mae: 0.0166 - val_loss: 7.5349e-04 - val_mae: 0.0168
# Epoch 126/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4481e-04 - mae: 0.0166 - val_loss: 7.5291e-04 - val_mae: 0.0168
# Epoch 127/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4508e-04 - mae: 0.0166 - val_loss: 7.5393e-04 - val_mae: 0.0168
# Epoch 128/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4481e-04 - mae: 0.0166 - val_loss: 7.5247e-04 - val_mae: 0.0168
# Epoch 129/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4459e-04 - mae: 0.0166 - val_loss: 7.5218e-04 - val_mae: 0.0168
# Epoch 130/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4457e-04 - mae: 0.0166 - val_loss: 7.5241e-04 - val_mae: 0.0168
# Epoch 131/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4451e-04 - mae: 0.0166 - val_loss: 7.5276e-04 - val_mae: 0.0168
# Epoch 132/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4444e-04 - mae: 0.0166 - val_loss: 7.5401e-04 - val_mae: 0.0169
# Epoch 133/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4440e-04 - mae: 0.0166 - val_loss: 7.5275e-04 - val_mae: 0.0168
# Epoch 134/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4424e-04 - mae: 0.0166 - val_loss: 7.5326e-04 - val_mae: 0.0168
# Epoch 135/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4443e-04 - mae: 0.0166 - val_loss: 7.5211e-04 - val_mae: 0.0168
# Epoch 136/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4398e-04 - mae: 0.0166 - val_loss: 7.5346e-04 - val_mae: 0.0168
# Epoch 137/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4401e-04 - mae: 0.0166 - val_loss: 7.5138e-04 - val_mae: 0.0168
# Epoch 138/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4367e-04 - mae: 0.0166 - val_loss: 7.5152e-04 - val_mae: 0.0168
# Epoch 139/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4373e-04 - mae: 0.0166 - val_loss: 7.5144e-04 - val_mae: 0.0168
# Epoch 140/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4364e-04 - mae: 0.0166 - val_loss: 7.5104e-04 - val_mae: 0.0168
# Epoch 141/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4375e-04 - mae: 0.0166 - val_loss: 7.5071e-04 - val_mae: 0.0168
# Epoch 142/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4360e-04 - mae: 0.0166 - val_loss: 7.5084e-04 - val_mae: 0.0168
# Epoch 143/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4334e-04 - mae: 0.0166 - val_loss: 7.5213e-04 - val_mae: 0.0168
# Epoch 144/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4372e-04 - mae: 0.0166 - val_loss: 7.5145e-04 - val_mae: 0.0168
# Epoch 145/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4339e-04 - mae: 0.0166 - val_loss: 7.5019e-04 - val_mae: 0.0168
# Epoch 146/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4330e-04 - mae: 0.0166 - val_loss: 7.5137e-04 - val_mae: 0.0168
# Epoch 147/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4303e-04 - mae: 0.0166 - val_loss: 7.5025e-04 - val_mae: 0.0168
# Epoch 148/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4317e-04 - mae: 0.0166 - val_loss: 7.5124e-04 - val_mae: 0.0168
# Epoch 149/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4263e-04 - mae: 0.0166 - val_loss: 7.5065e-04 - val_mae: 0.0168
# Epoch 150/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4270e-04 - mae: 0.0166 - val_loss: 7.4977e-04 - val_mae: 0.0168
# Epoch 151/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4248e-04 - mae: 0.0166 - val_loss: 7.5092e-04 - val_mae: 0.0168
# Epoch 152/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4275e-04 - mae: 0.0166 - val_loss: 7.4970e-04 - val_mae: 0.0168
# Epoch 153/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4269e-04 - mae: 0.0166 - val_loss: 7.5263e-04 - val_mae: 0.0168
# Epoch 154/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4260e-04 - mae: 0.0166 - val_loss: 7.5164e-04 - val_mae: 0.0168
# Epoch 155/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4237e-04 - mae: 0.0166 - val_loss: 7.4945e-04 - val_mae: 0.0168
# Epoch 156/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4237e-04 - mae: 0.0166 - val_loss: 7.5034e-04 - val_mae: 0.0168
# Epoch 157/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4206e-04 - mae: 0.0166 - val_loss: 7.5090e-04 - val_mae: 0.0168
# Epoch 158/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4198e-04 - mae: 0.0166 - val_loss: 7.5147e-04 - val_mae: 0.0168
# Epoch 159/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4199e-04 - mae: 0.0166 - val_loss: 7.4929e-04 - val_mae: 0.0168
# Epoch 160/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4172e-04 - mae: 0.0166 - val_loss: 7.4907e-04 - val_mae: 0.0168
# Epoch 161/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4170e-04 - mae: 0.0166 - val_loss: 7.4954e-04 - val_mae: 0.0167
# Epoch 162/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4168e-04 - mae: 0.0166 - val_loss: 7.4885e-04 - val_mae: 0.0168
# Epoch 163/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4195e-04 - mae: 0.0166 - val_loss: 7.5026e-04 - val_mae: 0.0168
# Epoch 164/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4165e-04 - mae: 0.0166 - val_loss: 7.5003e-04 - val_mae: 0.0168
# Epoch 165/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4149e-04 - mae: 0.0166 - val_loss: 7.4897e-04 - val_mae: 0.0168
# Epoch 166/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4108e-04 - mae: 0.0166 - val_loss: 7.4886e-04 - val_mae: 0.0168
# Epoch 167/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4118e-04 - mae: 0.0166 - val_loss: 7.4986e-04 - val_mae: 0.0168
# Epoch 168/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4085e-04 - mae: 0.0166 - val_loss: 7.4874e-04 - val_mae: 0.0167
# Epoch 169/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4095e-04 - mae: 0.0166 - val_loss: 7.4801e-04 - val_mae: 0.0168
# Epoch 170/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4110e-04 - mae: 0.0166 - val_loss: 7.4777e-04 - val_mae: 0.0167
# Epoch 171/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4088e-04 - mae: 0.0166 - val_loss: 7.4862e-04 - val_mae: 0.0167
# Epoch 172/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4083e-04 - mae: 0.0166 - val_loss: 7.4825e-04 - val_mae: 0.0168
# Epoch 173/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4078e-04 - mae: 0.0166 - val_loss: 7.4905e-04 - val_mae: 0.0168
# Epoch 174/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4077e-04 - mae: 0.0166 - val_loss: 7.4804e-04 - val_mae: 0.0168
# Epoch 175/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.4041e-04 - mae: 0.0165 - val_loss: 7.4810e-04 - val_mae: 0.0167
# Epoch 176/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3997e-04 - mae: 0.0165 - val_loss: 7.4762e-04 - val_mae: 0.0167
# Epoch 177/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4040e-04 - mae: 0.0166 - val_loss: 7.4841e-04 - val_mae: 0.0168
# Epoch 178/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4001e-04 - mae: 0.0165 - val_loss: 7.4748e-04 - val_mae: 0.0167
# Epoch 179/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.4008e-04 - mae: 0.0166 - val_loss: 7.4793e-04 - val_mae: 0.0167
# Epoch 180/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.3971e-04 - mae: 0.0165 - val_loss: 7.4759e-04 - val_mae: 0.0167
# Epoch 181/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3972e-04 - mae: 0.0165 - val_loss: 7.4875e-04 - val_mae: 0.0167
# Epoch 182/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3994e-04 - mae: 0.0165 - val_loss: 7.4671e-04 - val_mae: 0.0167
# Epoch 183/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3957e-04 - mae: 0.0165 - val_loss: 7.4711e-04 - val_mae: 0.0167
# Epoch 184/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3930e-04 - mae: 0.0165 - val_loss: 7.4959e-04 - val_mae: 0.0167
# Epoch 185/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.3956e-04 - mae: 0.0165 - val_loss: 7.4717e-04 - val_mae: 0.0167
# Epoch 186/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3933e-04 - mae: 0.0165 - val_loss: 7.4851e-04 - val_mae: 0.0167
# Epoch 187/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3912e-04 - mae: 0.0165 - val_loss: 7.4625e-04 - val_mae: 0.0167
# Epoch 188/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3935e-04 - mae: 0.0165 - val_loss: 7.4723e-04 - val_mae: 0.0168
# Epoch 189/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3911e-04 - mae: 0.0165 - val_loss: 7.4787e-04 - val_mae: 0.0168
# Epoch 190/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.3887e-04 - mae: 0.0165 - val_loss: 7.4727e-04 - val_mae: 0.0167
# Epoch 191/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3856e-04 - mae: 0.0165 - val_loss: 7.4608e-04 - val_mae: 0.0167
# Epoch 192/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3846e-04 - mae: 0.0165 - val_loss: 7.4637e-04 - val_mae: 0.0167
# Epoch 193/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3858e-04 - mae: 0.0165 - val_loss: 7.4803e-04 - val_mae: 0.0168
# Epoch 194/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3892e-04 - mae: 0.0165 - val_loss: 7.4617e-04 - val_mae: 0.0168
# Epoch 195/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.3853e-04 - mae: 0.0165 - val_loss: 7.4562e-04 - val_mae: 0.0167
# Epoch 196/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3834e-04 - mae: 0.0165 - val_loss: 7.4668e-04 - val_mae: 0.0168
# Epoch 197/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3835e-04 - mae: 0.0165 - val_loss: 7.4554e-04 - val_mae: 0.0167
# Epoch 198/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3795e-04 - mae: 0.0165 - val_loss: 7.4730e-04 - val_mae: 0.0167
# Epoch 199/200
# 240/240 [==============================] - 29s 121ms/step - loss: 7.3797e-04 - mae: 0.0165 - val_loss: 7.4536e-04 - val_mae: 0.0167
# Epoch 200/200
# 240/240 [==============================] - 29s 120ms/step - loss: 7.3811e-04 - mae: 0.0165 - val_loss: 7.4696e-04 - val_mae: 0.0167

# %%
window = sequence_length
last_window = X_scaled[-window:]
last_window = np.expand_dims(last_window, axis=0)
pred = model.predict(last_window)
last_window.shape, pred.shape
# Out:
# ((1, 400, 7), (1, 7))

# %%
future_window = 1152

pred = np.array([])
X_temp = last_window
for t in range(future_window):
    pred_temp = model.predict(X_temp)
    pred_temp = np.expand_dims(pred_temp, axis=0)
    if(len(pred)==0):
        pred = pred_temp
    else:
        pred = np.concatenate((pred,pred_temp),axis=1)
    X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)

# %%
pred_scaled = pred[0]*(X_max-X_min)+X_min

# %%
window = 400
future_window = 1152
for i in range(pred.shape[-1]):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),X[-window:,i],color='steelblue',label='window')
    plt.plot(range(window,window+future_window),pred_scaled[:,i],color='red',label='prediction')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i))
    plt.legend()
    plt.savefig('bigplot'+str(i))

# %%
#PAPER PLOTS
window = 100
future_window = 400
for i in range(pred.shape[-1]):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),X[-window:,i],color='steelblue',label='window')
    plt.plot(range(window,window+future_window),pred_scaled[:future_window,i],color='red',label='prediction')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i))
    plt.legend()
    plt.savefig('tinyplot'+str(i))

# %%
#for i in range(pred_scaled.shape[-1]):
#    plt.figure(figsize=(20,5))
#    plt.plot(range(window),train_scaled[-window:,i])
#    plt.plot(range(window,window+future_window),val_scaled[:future_window,i])
#    plt.plot(range(window,window+future_window),pred[0,:,i])

# %%
best_epoch = np.argmin(history['val_loss'])
fig_size = (15,5)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#PAPER PLOTS
best_epoch = np.argmin(history['val_loss'])
fig_size = (7,3)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()
plt.savefig("mse.png")

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()
plt.savefig("mae.png")

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()
plt.savefig("lr.png")

# %%
model.save('model')
#model = tfk.models.load_model('model')
# !zip -r model.zip model
# Out:
# 2022-01-15 09:35:23.400259: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
#   adding: model/ (stored 0%)
#   adding: model/saved_model.pb (deflated 89%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.index (deflated 59%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 6%)
#   adding: model/assets/ (stored 0%)
#   adding: model/keras_metadata.pb (deflated 86%)
