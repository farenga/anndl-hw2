# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_lstm(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7,bias_initializer=tfk.initializers.Constant(train_scaled.mean(axis=0)))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_gru(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.GRU(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7,bias_initializer=tfk.initializers.Constant(train_scaled.mean(axis=0)))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
models_array = []
history_array = []

epochs = 200
batch_size = 256

stride = 1
sequence_length = 400
X_train, y_train = extract_sequences(train_scaled,sequence_length,stride)
X_train.shape,y_train.shape
    
input_shape = X_train.shape[1:]

units = 352

models = [build_lstm,build_gru]
models_lables = ['base lstm','base gru']

for m in models:

    model = m(input_shape,units)
    model.summary()

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# 2022-01-15 11:07:06.462126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:06.549500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:06.550209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:06.551269: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-15 11:07:06.552113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:06.552798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:06.553424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:08.304186: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:08.305000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:08.305681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-15 11:07:08.306250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 352)               506880
# _________________________________________________________________
# flatten (Flatten)            (None, 352)               0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 2471
# =================================================================
# Total params: 509,351
# Trainable params: 509,351
# Non-trainable params: 0
# _________________________________________________________________
# 2022-01-15 11:07:10.382440: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-01-15 11:07:12.781437: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 236/236 [==============================] - 25s 93ms/step - loss: 0.0033 - mae: 0.0386 - val_loss: 0.0014 - val_mae: 0.0253
# Epoch 2/200
# 236/236 [==============================] - 21s 90ms/step - loss: 0.0012 - mae: 0.0233 - val_loss: 0.0011 - val_mae: 0.0216
# Epoch 3/200
# 236/236 [==============================] - 21s 91ms/step - loss: 9.9346e-04 - mae: 0.0210 - val_loss: 0.0011 - val_mae: 0.0218
# Epoch 4/200
# 236/236 [==============================] - 21s 90ms/step - loss: 9.0748e-04 - mae: 0.0197 - val_loss: 9.3384e-04 - val_mae: 0.0200
# Epoch 5/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.7386e-04 - mae: 0.0192 - val_loss: 9.1063e-04 - val_mae: 0.0200
# Epoch 6/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.5536e-04 - mae: 0.0190 - val_loss: 8.5469e-04 - val_mae: 0.0185
# Epoch 7/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.3266e-04 - mae: 0.0185 - val_loss: 8.6653e-04 - val_mae: 0.0189
# Epoch 8/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.2266e-04 - mae: 0.0183 - val_loss: 8.4050e-04 - val_mae: 0.0184
# Epoch 9/200
# 236/236 [==============================] - 21s 91ms/step - loss: 8.2338e-04 - mae: 0.0183 - val_loss: 9.2123e-04 - val_mae: 0.0202
# Epoch 10/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.1173e-04 - mae: 0.0180 - val_loss: 8.5711e-04 - val_mae: 0.0187
# Epoch 11/200
# 236/236 [==============================] - 21s 91ms/step - loss: 8.0764e-04 - mae: 0.0179 - val_loss: 8.3221e-04 - val_mae: 0.0180
# Epoch 12/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.0515e-04 - mae: 0.0179 - val_loss: 8.1605e-04 - val_mae: 0.0177
# Epoch 13/200
# 236/236 [==============================] - 21s 90ms/step - loss: 8.0068e-04 - mae: 0.0178 - val_loss: 8.1231e-04 - val_mae: 0.0175
# Epoch 14/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.9156e-04 - mae: 0.0177 - val_loss: 8.2406e-04 - val_mae: 0.0177
# Epoch 15/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.9003e-04 - mae: 0.0176 - val_loss: 8.0853e-04 - val_mae: 0.0176
# Epoch 16/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.8407e-04 - mae: 0.0175 - val_loss: 8.5439e-04 - val_mae: 0.0187
# Epoch 17/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.8370e-04 - mae: 0.0176 - val_loss: 8.2071e-04 - val_mae: 0.0183
# Epoch 18/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.8219e-04 - mae: 0.0176 - val_loss: 8.0058e-04 - val_mae: 0.0176
# Epoch 19/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.7674e-04 - mae: 0.0174 - val_loss: 7.9876e-04 - val_mae: 0.0176
# Epoch 20/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.7074e-04 - mae: 0.0173 - val_loss: 8.1987e-04 - val_mae: 0.0181
# Epoch 21/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.7298e-04 - mae: 0.0174 - val_loss: 7.9434e-04 - val_mae: 0.0176
# Epoch 22/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.5086e-04 - mae: 0.0169 - val_loss: 7.7784e-04 - val_mae: 0.0173
# Epoch 23/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.4498e-04 - mae: 0.0168 - val_loss: 7.8433e-04 - val_mae: 0.0174
# Epoch 24/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.4968e-04 - mae: 0.0169 - val_loss: 7.9879e-04 - val_mae: 0.0179
# Epoch 25/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.4681e-04 - mae: 0.0169 - val_loss: 7.7933e-04 - val_mae: 0.0174
# Epoch 26/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.4655e-04 - mae: 0.0169 - val_loss: 7.6944e-04 - val_mae: 0.0170
# Epoch 27/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.4411e-04 - mae: 0.0169 - val_loss: 7.7175e-04 - val_mae: 0.0170
# Epoch 28/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.4745e-04 - mae: 0.0169 - val_loss: 7.8189e-04 - val_mae: 0.0175
# Epoch 29/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.4184e-04 - mae: 0.0168 - val_loss: 7.6061e-04 - val_mae: 0.0169
# Epoch 30/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.3798e-04 - mae: 0.0167 - val_loss: 7.9375e-04 - val_mae: 0.0176
# Epoch 31/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.4114e-04 - mae: 0.0168 - val_loss: 7.7187e-04 - val_mae: 0.0173
# Epoch 32/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2578e-04 - mae: 0.0165 - val_loss: 7.5892e-04 - val_mae: 0.0169
# Epoch 33/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.2334e-04 - mae: 0.0165 - val_loss: 7.6936e-04 - val_mae: 0.0170
# Epoch 34/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2461e-04 - mae: 0.0165 - val_loss: 7.5575e-04 - val_mae: 0.0169
# Epoch 35/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.2244e-04 - mae: 0.0165 - val_loss: 7.6067e-04 - val_mae: 0.0171
# Epoch 36/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2199e-04 - mae: 0.0165 - val_loss: 7.6589e-04 - val_mae: 0.0169
# Epoch 37/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2439e-04 - mae: 0.0165 - val_loss: 7.5766e-04 - val_mae: 0.0168
# Epoch 38/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2222e-04 - mae: 0.0164 - val_loss: 7.5848e-04 - val_mae: 0.0169
# Epoch 39/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2062e-04 - mae: 0.0165 - val_loss: 7.6378e-04 - val_mae: 0.0170
# Epoch 40/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2194e-04 - mae: 0.0165 - val_loss: 7.5289e-04 - val_mae: 0.0168
# Epoch 41/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.2007e-04 - mae: 0.0165 - val_loss: 7.5265e-04 - val_mae: 0.0167
# Epoch 42/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.1019e-04 - mae: 0.0162 - val_loss: 7.4497e-04 - val_mae: 0.0166
# Epoch 43/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.0868e-04 - mae: 0.0162 - val_loss: 7.4658e-04 - val_mae: 0.0167
# Epoch 44/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.0815e-04 - mae: 0.0162 - val_loss: 7.4521e-04 - val_mae: 0.0167
# Epoch 45/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.0808e-04 - mae: 0.0162 - val_loss: 7.4364e-04 - val_mae: 0.0167
# Epoch 46/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.0788e-04 - mae: 0.0162 - val_loss: 7.4753e-04 - val_mae: 0.0168
# Epoch 47/200
# 236/236 [==============================] - 21s 91ms/step - loss: 7.0864e-04 - mae: 0.0162 - val_loss: 7.4116e-04 - val_mae: 0.0166
# Epoch 48/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.0630e-04 - mae: 0.0162 - val_loss: 7.4270e-04 - val_mae: 0.0166
# Epoch 49/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.0702e-04 - mae: 0.0162 - val_loss: 7.4848e-04 - val_mae: 0.0166
# Epoch 50/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.0563e-04 - mae: 0.0162 - val_loss: 7.4511e-04 - val_mae: 0.0167
# Epoch 51/200
# 236/236 [==============================] - 21s 90ms/step - loss: 7.0680e-04 - mae: 0.0162 - val_loss: 7.5057e-04 - val_mae: 0.0167
# Epoch 52/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9990e-04 - mae: 0.0161 - val_loss: 7.3840e-04 - val_mae: 0.0165
# Epoch 53/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9860e-04 - mae: 0.0160 - val_loss: 7.4000e-04 - val_mae: 0.0166
# Epoch 54/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9845e-04 - mae: 0.0161 - val_loss: 7.3581e-04 - val_mae: 0.0164
# Epoch 55/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9812e-04 - mae: 0.0160 - val_loss: 7.4368e-04 - val_mae: 0.0166
# Epoch 56/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.9894e-04 - mae: 0.0161 - val_loss: 7.3700e-04 - val_mae: 0.0165
# Epoch 57/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9886e-04 - mae: 0.0161 - val_loss: 7.3689e-04 - val_mae: 0.0165
# Epoch 58/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9858e-04 - mae: 0.0161 - val_loss: 7.3544e-04 - val_mae: 0.0165
# Epoch 59/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9794e-04 - mae: 0.0161 - val_loss: 7.3498e-04 - val_mae: 0.0165
# Epoch 60/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9702e-04 - mae: 0.0160 - val_loss: 7.3339e-04 - val_mae: 0.0165
# Epoch 61/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.9646e-04 - mae: 0.0160 - val_loss: 7.3316e-04 - val_mae: 0.0164
# Epoch 62/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9415e-04 - mae: 0.0160 - val_loss: 7.3258e-04 - val_mae: 0.0164
# Epoch 63/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9335e-04 - mae: 0.0160 - val_loss: 7.3415e-04 - val_mae: 0.0164
# Epoch 64/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9308e-04 - mae: 0.0160 - val_loss: 7.3415e-04 - val_mae: 0.0164
# Epoch 65/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9303e-04 - mae: 0.0160 - val_loss: 7.3281e-04 - val_mae: 0.0164
# Epoch 66/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9228e-04 - mae: 0.0159 - val_loss: 7.3461e-04 - val_mae: 0.0164
# Epoch 67/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9243e-04 - mae: 0.0160 - val_loss: 7.3202e-04 - val_mae: 0.0164
# Epoch 68/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9220e-04 - mae: 0.0160 - val_loss: 7.3038e-04 - val_mae: 0.0163
# Epoch 69/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9202e-04 - mae: 0.0159 - val_loss: 7.3220e-04 - val_mae: 0.0164
# Epoch 70/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9202e-04 - mae: 0.0159 - val_loss: 7.3045e-04 - val_mae: 0.0164
# Epoch 71/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9216e-04 - mae: 0.0160 - val_loss: 7.3237e-04 - val_mae: 0.0165
# Epoch 72/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9187e-04 - mae: 0.0160 - val_loss: 7.3046e-04 - val_mae: 0.0164
# Epoch 73/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9177e-04 - mae: 0.0160 - val_loss: 7.3099e-04 - val_mae: 0.0163
# Epoch 74/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.9139e-04 - mae: 0.0159 - val_loss: 7.3057e-04 - val_mae: 0.0164
# Epoch 75/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9140e-04 - mae: 0.0160 - val_loss: 7.3058e-04 - val_mae: 0.0164
# Epoch 76/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9132e-04 - mae: 0.0159 - val_loss: 7.3015e-04 - val_mae: 0.0164
# Epoch 77/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.9101e-04 - mae: 0.0159 - val_loss: 7.3293e-04 - val_mae: 0.0164
# Epoch 78/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8910e-04 - mae: 0.0159 - val_loss: 7.2896e-04 - val_mae: 0.0163
# Epoch 79/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8893e-04 - mae: 0.0159 - val_loss: 7.3045e-04 - val_mae: 0.0164
# Epoch 80/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8904e-04 - mae: 0.0159 - val_loss: 7.2950e-04 - val_mae: 0.0164
# Epoch 81/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8877e-04 - mae: 0.0159 - val_loss: 7.2856e-04 - val_mae: 0.0163
# Epoch 82/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8846e-04 - mae: 0.0159 - val_loss: 7.2861e-04 - val_mae: 0.0163
# Epoch 83/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8850e-04 - mae: 0.0159 - val_loss: 7.2896e-04 - val_mae: 0.0163
# Epoch 84/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8858e-04 - mae: 0.0159 - val_loss: 7.2965e-04 - val_mae: 0.0163
# Epoch 85/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8833e-04 - mae: 0.0159 - val_loss: 7.3033e-04 - val_mae: 0.0163
# Epoch 86/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8837e-04 - mae: 0.0159 - val_loss: 7.2814e-04 - val_mae: 0.0163
# Epoch 87/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8818e-04 - mae: 0.0159 - val_loss: 7.2815e-04 - val_mae: 0.0163
# Epoch 88/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8726e-04 - mae: 0.0159 - val_loss: 7.2768e-04 - val_mae: 0.0163
# Epoch 89/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8717e-04 - mae: 0.0159 - val_loss: 7.2828e-04 - val_mae: 0.0164
# Epoch 90/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8721e-04 - mae: 0.0159 - val_loss: 7.2816e-04 - val_mae: 0.0163
# Epoch 91/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8729e-04 - mae: 0.0159 - val_loss: 7.2784e-04 - val_mae: 0.0163
# Epoch 92/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8760e-04 - mae: 0.0159 - val_loss: 7.2987e-04 - val_mae: 0.0163
# Epoch 93/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8693e-04 - mae: 0.0159 - val_loss: 7.2763e-04 - val_mae: 0.0164
# Epoch 94/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8704e-04 - mae: 0.0159 - val_loss: 7.2725e-04 - val_mae: 0.0163
# Epoch 95/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8696e-04 - mae: 0.0159 - val_loss: 7.2726e-04 - val_mae: 0.0163
# Epoch 96/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8672e-04 - mae: 0.0159 - val_loss: 7.2777e-04 - val_mae: 0.0163
# Epoch 97/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8681e-04 - mae: 0.0159 - val_loss: 7.2736e-04 - val_mae: 0.0163
# Epoch 98/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8680e-04 - mae: 0.0159 - val_loss: 7.2857e-04 - val_mae: 0.0163
# Epoch 99/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8673e-04 - mae: 0.0159 - val_loss: 7.2923e-04 - val_mae: 0.0163
# Epoch 100/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8669e-04 - mae: 0.0159 - val_loss: 7.2797e-04 - val_mae: 0.0163
# Epoch 101/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8663e-04 - mae: 0.0159 - val_loss: 7.2819e-04 - val_mae: 0.0163
# Epoch 102/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8651e-04 - mae: 0.0159 - val_loss: 7.2713e-04 - val_mae: 0.0163
# Epoch 103/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8641e-04 - mae: 0.0159 - val_loss: 7.2932e-04 - val_mae: 0.0164
# Epoch 104/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8654e-04 - mae: 0.0159 - val_loss: 7.2791e-04 - val_mae: 0.0163
# Epoch 105/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8643e-04 - mae: 0.0159 - val_loss: 7.2794e-04 - val_mae: 0.0163
# Epoch 106/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8642e-04 - mae: 0.0159 - val_loss: 7.2792e-04 - val_mae: 0.0163
# Epoch 107/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8657e-04 - mae: 0.0159 - val_loss: 7.2692e-04 - val_mae: 0.0163
# Epoch 108/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8635e-04 - mae: 0.0159 - val_loss: 7.2652e-04 - val_mae: 0.0163
# Epoch 109/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8608e-04 - mae: 0.0159 - val_loss: 7.2814e-04 - val_mae: 0.0163
# Epoch 110/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8614e-04 - mae: 0.0159 - val_loss: 7.2912e-04 - val_mae: 0.0163
# Epoch 111/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8614e-04 - mae: 0.0159 - val_loss: 7.2667e-04 - val_mae: 0.0163
# Epoch 112/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8604e-04 - mae: 0.0159 - val_loss: 7.2717e-04 - val_mae: 0.0163
# Epoch 113/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8605e-04 - mae: 0.0159 - val_loss: 7.2709e-04 - val_mae: 0.0163
# Epoch 114/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8600e-04 - mae: 0.0159 - val_loss: 7.2701e-04 - val_mae: 0.0163
# Epoch 115/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8587e-04 - mae: 0.0159 - val_loss: 7.2753e-04 - val_mae: 0.0163
# Epoch 116/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8586e-04 - mae: 0.0159 - val_loss: 7.2699e-04 - val_mae: 0.0163
# Epoch 117/200
# 236/236 [==============================] - 22s 91ms/step - loss: 6.8590e-04 - mae: 0.0159 - val_loss: 7.2766e-04 - val_mae: 0.0163
# Epoch 118/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8581e-04 - mae: 0.0159 - val_loss: 7.2752e-04 - val_mae: 0.0164
# Epoch 119/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8583e-04 - mae: 0.0159 - val_loss: 7.2829e-04 - val_mae: 0.0163
# Epoch 120/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8568e-04 - mae: 0.0159 - val_loss: 7.2698e-04 - val_mae: 0.0163
# Epoch 121/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8579e-04 - mae: 0.0159 - val_loss: 7.2700e-04 - val_mae: 0.0163
# Epoch 122/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8554e-04 - mae: 0.0159 - val_loss: 7.2798e-04 - val_mae: 0.0163
# Epoch 123/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8566e-04 - mae: 0.0159 - val_loss: 7.2613e-04 - val_mae: 0.0163
# Epoch 124/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8557e-04 - mae: 0.0159 - val_loss: 7.2650e-04 - val_mae: 0.0163
# Epoch 125/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8518e-04 - mae: 0.0159 - val_loss: 7.2767e-04 - val_mae: 0.0163
# Epoch 126/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8524e-04 - mae: 0.0159 - val_loss: 7.2786e-04 - val_mae: 0.0163
# Epoch 127/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8561e-04 - mae: 0.0159 - val_loss: 7.2671e-04 - val_mae: 0.0163
# Epoch 128/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8533e-04 - mae: 0.0159 - val_loss: 7.2668e-04 - val_mae: 0.0163
# Epoch 129/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8523e-04 - mae: 0.0158 - val_loss: 7.2603e-04 - val_mae: 0.0163
# Epoch 130/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8509e-04 - mae: 0.0158 - val_loss: 7.2706e-04 - val_mae: 0.0163
# Epoch 131/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8520e-04 - mae: 0.0159 - val_loss: 7.2694e-04 - val_mae: 0.0163
# Epoch 132/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8521e-04 - mae: 0.0159 - val_loss: 7.2820e-04 - val_mae: 0.0163
# Epoch 133/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8508e-04 - mae: 0.0159 - val_loss: 7.2603e-04 - val_mae: 0.0163
# Epoch 134/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8499e-04 - mae: 0.0158 - val_loss: 7.2689e-04 - val_mae: 0.0163
# Epoch 135/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8503e-04 - mae: 0.0159 - val_loss: 7.2612e-04 - val_mae: 0.0163
# Epoch 136/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8484e-04 - mae: 0.0159 - val_loss: 7.2599e-04 - val_mae: 0.0163
# Epoch 137/200
# 236/236 [==============================] - 22s 91ms/step - loss: 6.8483e-04 - mae: 0.0158 - val_loss: 7.2663e-04 - val_mae: 0.0163
# Epoch 138/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8491e-04 - mae: 0.0159 - val_loss: 7.2752e-04 - val_mae: 0.0163
# Epoch 139/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8489e-04 - mae: 0.0158 - val_loss: 7.2655e-04 - val_mae: 0.0163
# Epoch 140/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8499e-04 - mae: 0.0158 - val_loss: 7.2646e-04 - val_mae: 0.0163
# Epoch 141/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8482e-04 - mae: 0.0158 - val_loss: 7.2576e-04 - val_mae: 0.0163
# Epoch 142/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8464e-04 - mae: 0.0158 - val_loss: 7.2590e-04 - val_mae: 0.0163
# Epoch 143/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8464e-04 - mae: 0.0158 - val_loss: 7.2604e-04 - val_mae: 0.0163
# Epoch 144/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8453e-04 - mae: 0.0158 - val_loss: 7.2606e-04 - val_mae: 0.0163
# Epoch 145/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8437e-04 - mae: 0.0158 - val_loss: 7.2685e-04 - val_mae: 0.0163
# Epoch 146/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8434e-04 - mae: 0.0158 - val_loss: 7.2771e-04 - val_mae: 0.0164
# Epoch 147/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8439e-04 - mae: 0.0159 - val_loss: 7.2714e-04 - val_mae: 0.0163
# Epoch 148/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8444e-04 - mae: 0.0158 - val_loss: 7.2639e-04 - val_mae: 0.0163
# Epoch 149/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8427e-04 - mae: 0.0158 - val_loss: 7.2578e-04 - val_mae: 0.0163
# Epoch 150/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8440e-04 - mae: 0.0158 - val_loss: 7.2558e-04 - val_mae: 0.0163
# Epoch 151/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8451e-04 - mae: 0.0159 - val_loss: 7.2617e-04 - val_mae: 0.0163
# Epoch 152/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8412e-04 - mae: 0.0158 - val_loss: 7.2561e-04 - val_mae: 0.0163
# Epoch 153/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8400e-04 - mae: 0.0158 - val_loss: 7.2575e-04 - val_mae: 0.0163
# Epoch 154/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8431e-04 - mae: 0.0158 - val_loss: 7.2672e-04 - val_mae: 0.0163
# Epoch 155/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8415e-04 - mae: 0.0158 - val_loss: 7.2602e-04 - val_mae: 0.0163
# Epoch 156/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8389e-04 - mae: 0.0158 - val_loss: 7.2693e-04 - val_mae: 0.0163
# Epoch 157/200
# 236/236 [==============================] - 22s 91ms/step - loss: 6.8393e-04 - mae: 0.0158 - val_loss: 7.2569e-04 - val_mae: 0.0163
# Epoch 158/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8386e-04 - mae: 0.0158 - val_loss: 7.2621e-04 - val_mae: 0.0162
# Epoch 159/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8405e-04 - mae: 0.0158 - val_loss: 7.2566e-04 - val_mae: 0.0163
# Epoch 160/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8385e-04 - mae: 0.0158 - val_loss: 7.2528e-04 - val_mae: 0.0163
# Epoch 161/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8369e-04 - mae: 0.0158 - val_loss: 7.2571e-04 - val_mae: 0.0163
# Epoch 162/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8381e-04 - mae: 0.0158 - val_loss: 7.2498e-04 - val_mae: 0.0163
# Epoch 163/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8368e-04 - mae: 0.0158 - val_loss: 7.2555e-04 - val_mae: 0.0163
# Epoch 164/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8359e-04 - mae: 0.0158 - val_loss: 7.2647e-04 - val_mae: 0.0163
# Epoch 165/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8374e-04 - mae: 0.0158 - val_loss: 7.2639e-04 - val_mae: 0.0163
# Epoch 166/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8351e-04 - mae: 0.0158 - val_loss: 7.2493e-04 - val_mae: 0.0163
# Epoch 167/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8360e-04 - mae: 0.0158 - val_loss: 7.2508e-04 - val_mae: 0.0163
# Epoch 168/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8341e-04 - mae: 0.0158 - val_loss: 7.2497e-04 - val_mae: 0.0163
# Epoch 169/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8343e-04 - mae: 0.0158 - val_loss: 7.2578e-04 - val_mae: 0.0163
# Epoch 170/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8329e-04 - mae: 0.0158 - val_loss: 7.2489e-04 - val_mae: 0.0163
# Epoch 171/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8327e-04 - mae: 0.0158 - val_loss: 7.2435e-04 - val_mae: 0.0163
# Epoch 172/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8341e-04 - mae: 0.0158 - val_loss: 7.2524e-04 - val_mae: 0.0163
# Epoch 173/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8334e-04 - mae: 0.0158 - val_loss: 7.2478e-04 - val_mae: 0.0163
# Epoch 174/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8312e-04 - mae: 0.0158 - val_loss: 7.2636e-04 - val_mae: 0.0163
# Epoch 175/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8345e-04 - mae: 0.0158 - val_loss: 7.2463e-04 - val_mae: 0.0163
# Epoch 176/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8328e-04 - mae: 0.0158 - val_loss: 7.2552e-04 - val_mae: 0.0163
# Epoch 177/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8301e-04 - mae: 0.0158 - val_loss: 7.2501e-04 - val_mae: 0.0163
# Epoch 178/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8297e-04 - mae: 0.0158 - val_loss: 7.2507e-04 - val_mae: 0.0163
# Epoch 179/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8304e-04 - mae: 0.0158 - val_loss: 7.2687e-04 - val_mae: 0.0163
# Epoch 180/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8280e-04 - mae: 0.0158 - val_loss: 7.2453e-04 - val_mae: 0.0163
# Epoch 181/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8271e-04 - mae: 0.0158 - val_loss: 7.2424e-04 - val_mae: 0.0163
# Epoch 182/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8303e-04 - mae: 0.0158 - val_loss: 7.2550e-04 - val_mae: 0.0163
# Epoch 183/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8284e-04 - mae: 0.0158 - val_loss: 7.2427e-04 - val_mae: 0.0163
# Epoch 184/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8250e-04 - mae: 0.0158 - val_loss: 7.2491e-04 - val_mae: 0.0163
# Epoch 185/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8259e-04 - mae: 0.0158 - val_loss: 7.2616e-04 - val_mae: 0.0163
# Epoch 186/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8277e-04 - mae: 0.0158 - val_loss: 7.2519e-04 - val_mae: 0.0163
# Epoch 187/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8255e-04 - mae: 0.0158 - val_loss: 7.2369e-04 - val_mae: 0.0163
# Epoch 188/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8275e-04 - mae: 0.0158 - val_loss: 7.2468e-04 - val_mae: 0.0163
# Epoch 189/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8235e-04 - mae: 0.0158 - val_loss: 7.2486e-04 - val_mae: 0.0163
# Epoch 190/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8256e-04 - mae: 0.0158 - val_loss: 7.2517e-04 - val_mae: 0.0163
# Epoch 191/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8232e-04 - mae: 0.0158 - val_loss: 7.2476e-04 - val_mae: 0.0163
# Epoch 192/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8241e-04 - mae: 0.0158 - val_loss: 7.2455e-04 - val_mae: 0.0163
# Epoch 193/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8241e-04 - mae: 0.0158 - val_loss: 7.2423e-04 - val_mae: 0.0163
# Epoch 194/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8230e-04 - mae: 0.0158 - val_loss: 7.2445e-04 - val_mae: 0.0163
# Epoch 195/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8246e-04 - mae: 0.0158 - val_loss: 7.2482e-04 - val_mae: 0.0163
# Epoch 196/200
# 236/236 [==============================] - 21s 91ms/step - loss: 6.8209e-04 - mae: 0.0158 - val_loss: 7.2521e-04 - val_mae: 0.0163
# Epoch 197/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8263e-04 - mae: 0.0158 - val_loss: 7.2449e-04 - val_mae: 0.0163
# Epoch 198/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8202e-04 - mae: 0.0158 - val_loss: 7.2428e-04 - val_mae: 0.0163
# Epoch 199/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8212e-04 - mae: 0.0158 - val_loss: 7.2386e-04 - val_mae: 0.0163
# Epoch 200/200
# 236/236 [==============================] - 21s 90ms/step - loss: 6.8218e-04 - mae: 0.0158 - val_loss: 7.2405e-04 - val_mae: 0.0163
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# gru (GRU)                    (None, 352)               381216
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 352)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 2471
# =================================================================
# Total params: 383,687
# Trainable params: 383,687
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 236/236 [==============================] - 20s 80ms/step - loss: 0.0024 - mae: 0.0307 - val_loss: 0.0010 - val_mae: 0.0208
# Epoch 2/200
# 236/236 [==============================] - 19s 79ms/step - loss: 9.1734e-04 - mae: 0.0195 - val_loss: 9.1823e-04 - val_mae: 0.0194
# Epoch 3/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.7634e-04 - mae: 0.0190 - val_loss: 8.6756e-04 - val_mae: 0.0185
# Epoch 4/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.4178e-04 - mae: 0.0183 - val_loss: 8.7797e-04 - val_mae: 0.0189
# Epoch 5/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.3541e-04 - mae: 0.0182 - val_loss: 9.3576e-04 - val_mae: 0.0203
# Epoch 6/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.3203e-04 - mae: 0.0182 - val_loss: 8.5235e-04 - val_mae: 0.0183
# Epoch 7/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.1909e-04 - mae: 0.0179 - val_loss: 8.3649e-04 - val_mae: 0.0178
# Epoch 8/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.2301e-04 - mae: 0.0180 - val_loss: 8.3357e-04 - val_mae: 0.0177
# Epoch 9/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.1680e-04 - mae: 0.0179 - val_loss: 8.7471e-04 - val_mae: 0.0188
# Epoch 10/200
# 236/236 [==============================] - 19s 79ms/step - loss: 8.1195e-04 - mae: 0.0178 - val_loss: 8.4407e-04 - val_mae: 0.0180
# Epoch 11/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.1082e-04 - mae: 0.0178 - val_loss: 8.3892e-04 - val_mae: 0.0180
# Epoch 12/200
# 236/236 [==============================] - 18s 78ms/step - loss: 8.0499e-04 - mae: 0.0177 - val_loss: 8.2569e-04 - val_mae: 0.0176
# Epoch 13/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8709e-04 - mae: 0.0172 - val_loss: 8.1908e-04 - val_mae: 0.0177
# Epoch 14/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8675e-04 - mae: 0.0173 - val_loss: 8.1069e-04 - val_mae: 0.0174
# Epoch 15/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8997e-04 - mae: 0.0174 - val_loss: 8.1183e-04 - val_mae: 0.0176
# Epoch 16/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8567e-04 - mae: 0.0173 - val_loss: 8.1780e-04 - val_mae: 0.0177
# Epoch 17/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.8393e-04 - mae: 0.0172 - val_loss: 8.2352e-04 - val_mae: 0.0179
# Epoch 18/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8469e-04 - mae: 0.0173 - val_loss: 8.0800e-04 - val_mae: 0.0175
# Epoch 19/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8391e-04 - mae: 0.0173 - val_loss: 8.1885e-04 - val_mae: 0.0176
# Epoch 20/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8303e-04 - mae: 0.0173 - val_loss: 8.2155e-04 - val_mae: 0.0178
# Epoch 21/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.8451e-04 - mae: 0.0173 - val_loss: 8.0595e-04 - val_mae: 0.0176
# Epoch 22/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.7934e-04 - mae: 0.0172 - val_loss: 8.0347e-04 - val_mae: 0.0175
# Epoch 23/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.7837e-04 - mae: 0.0172 - val_loss: 8.1824e-04 - val_mae: 0.0177
# Epoch 24/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.7815e-04 - mae: 0.0172 - val_loss: 8.1796e-04 - val_mae: 0.0180
# Epoch 25/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.6571e-04 - mae: 0.0170 - val_loss: 7.9548e-04 - val_mae: 0.0174
# Epoch 26/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.6676e-04 - mae: 0.0170 - val_loss: 7.9346e-04 - val_mae: 0.0174
# Epoch 27/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6603e-04 - mae: 0.0170 - val_loss: 7.8838e-04 - val_mae: 0.0172
# Epoch 28/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6454e-04 - mae: 0.0170 - val_loss: 8.1561e-04 - val_mae: 0.0178
# Epoch 29/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6463e-04 - mae: 0.0170 - val_loss: 7.9540e-04 - val_mae: 0.0173
# Epoch 30/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6278e-04 - mae: 0.0170 - val_loss: 7.9972e-04 - val_mae: 0.0175
# Epoch 31/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6220e-04 - mae: 0.0170 - val_loss: 7.9561e-04 - val_mae: 0.0174
# Epoch 32/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6254e-04 - mae: 0.0170 - val_loss: 7.9254e-04 - val_mae: 0.0173
# Epoch 33/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.6238e-04 - mae: 0.0170 - val_loss: 7.9681e-04 - val_mae: 0.0175
# Epoch 34/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.6123e-04 - mae: 0.0170 - val_loss: 7.8490e-04 - val_mae: 0.0172
# Epoch 35/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.5256e-04 - mae: 0.0168 - val_loss: 7.8902e-04 - val_mae: 0.0174
# Epoch 36/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.5215e-04 - mae: 0.0168 - val_loss: 7.8324e-04 - val_mae: 0.0172
# Epoch 37/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.5189e-04 - mae: 0.0168 - val_loss: 7.8736e-04 - val_mae: 0.0171
# Epoch 38/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.5028e-04 - mae: 0.0168 - val_loss: 7.8639e-04 - val_mae: 0.0173
# Epoch 39/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.4980e-04 - mae: 0.0168 - val_loss: 7.8512e-04 - val_mae: 0.0172
# Epoch 40/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.4814e-04 - mae: 0.0167 - val_loss: 7.7777e-04 - val_mae: 0.0171
# Epoch 41/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.4700e-04 - mae: 0.0168 - val_loss: 7.7498e-04 - val_mae: 0.0170
# Epoch 42/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.4429e-04 - mae: 0.0167 - val_loss: 7.8108e-04 - val_mae: 0.0173
# Epoch 43/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.4274e-04 - mae: 0.0167 - val_loss: 7.7176e-04 - val_mae: 0.0171
# Epoch 44/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.4146e-04 - mae: 0.0167 - val_loss: 7.6897e-04 - val_mae: 0.0170
# Epoch 45/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3652e-04 - mae: 0.0166 - val_loss: 7.6617e-04 - val_mae: 0.0169
# Epoch 46/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3551e-04 - mae: 0.0165 - val_loss: 7.6431e-04 - val_mae: 0.0169
# Epoch 47/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3554e-04 - mae: 0.0165 - val_loss: 7.6562e-04 - val_mae: 0.0169
# Epoch 48/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.3498e-04 - mae: 0.0165 - val_loss: 7.6632e-04 - val_mae: 0.0169
# Epoch 49/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.3417e-04 - mae: 0.0165 - val_loss: 7.6468e-04 - val_mae: 0.0168
# Epoch 50/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3363e-04 - mae: 0.0165 - val_loss: 7.6914e-04 - val_mae: 0.0170
# Epoch 51/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3319e-04 - mae: 0.0165 - val_loss: 7.6464e-04 - val_mae: 0.0168
# Epoch 52/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3180e-04 - mae: 0.0165 - val_loss: 7.6190e-04 - val_mae: 0.0168
# Epoch 53/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3129e-04 - mae: 0.0165 - val_loss: 7.6926e-04 - val_mae: 0.0170
# Epoch 54/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.3108e-04 - mae: 0.0165 - val_loss: 7.6154e-04 - val_mae: 0.0167
# Epoch 55/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2800e-04 - mae: 0.0164 - val_loss: 7.5955e-04 - val_mae: 0.0168
# Epoch 56/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2784e-04 - mae: 0.0164 - val_loss: 7.5908e-04 - val_mae: 0.0167
# Epoch 57/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2768e-04 - mae: 0.0164 - val_loss: 7.5815e-04 - val_mae: 0.0167
# Epoch 58/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2726e-04 - mae: 0.0164 - val_loss: 7.5998e-04 - val_mae: 0.0168
# Epoch 59/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2701e-04 - mae: 0.0164 - val_loss: 7.5746e-04 - val_mae: 0.0168
# Epoch 60/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2662e-04 - mae: 0.0164 - val_loss: 7.5708e-04 - val_mae: 0.0168
# Epoch 61/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2585e-04 - mae: 0.0164 - val_loss: 7.5725e-04 - val_mae: 0.0167
# Epoch 62/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2675e-04 - mae: 0.0164 - val_loss: 7.5848e-04 - val_mae: 0.0167
# Epoch 63/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2587e-04 - mae: 0.0164 - val_loss: 7.5759e-04 - val_mae: 0.0168
# Epoch 64/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2558e-04 - mae: 0.0164 - val_loss: 7.5936e-04 - val_mae: 0.0168
# Epoch 65/200
# 236/236 [==============================] - 19s 78ms/step - loss: 7.2395e-04 - mae: 0.0163 - val_loss: 7.5587e-04 - val_mae: 0.0167
# Epoch 66/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2346e-04 - mae: 0.0163 - val_loss: 7.5603e-04 - val_mae: 0.0167
# Epoch 67/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2353e-04 - mae: 0.0164 - val_loss: 7.5521e-04 - val_mae: 0.0167
# Epoch 68/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2291e-04 - mae: 0.0163 - val_loss: 7.5492e-04 - val_mae: 0.0167
# Epoch 69/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2317e-04 - mae: 0.0163 - val_loss: 7.5521e-04 - val_mae: 0.0167
# Epoch 70/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2289e-04 - mae: 0.0163 - val_loss: 7.5502e-04 - val_mae: 0.0167
# Epoch 71/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2299e-04 - mae: 0.0163 - val_loss: 7.5454e-04 - val_mae: 0.0167
# Epoch 72/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2282e-04 - mae: 0.0163 - val_loss: 7.5512e-04 - val_mae: 0.0168
# Epoch 73/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2255e-04 - mae: 0.0163 - val_loss: 7.5470e-04 - val_mae: 0.0167
# Epoch 74/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2224e-04 - mae: 0.0163 - val_loss: 7.5488e-04 - val_mae: 0.0167
# Epoch 75/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2195e-04 - mae: 0.0163 - val_loss: 7.5347e-04 - val_mae: 0.0167
# Epoch 76/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2174e-04 - mae: 0.0163 - val_loss: 7.5351e-04 - val_mae: 0.0167
# Epoch 77/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2139e-04 - mae: 0.0163 - val_loss: 7.5412e-04 - val_mae: 0.0167
# Epoch 78/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2138e-04 - mae: 0.0163 - val_loss: 7.5349e-04 - val_mae: 0.0167
# Epoch 79/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2135e-04 - mae: 0.0163 - val_loss: 7.5458e-04 - val_mae: 0.0167
# Epoch 80/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2126e-04 - mae: 0.0163 - val_loss: 7.5368e-04 - val_mae: 0.0167
# Epoch 81/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2117e-04 - mae: 0.0163 - val_loss: 7.5313e-04 - val_mae: 0.0167
# Epoch 82/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2105e-04 - mae: 0.0163 - val_loss: 7.5315e-04 - val_mae: 0.0167
# Epoch 83/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2100e-04 - mae: 0.0163 - val_loss: 7.5372e-04 - val_mae: 0.0167
# Epoch 84/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2085e-04 - mae: 0.0163 - val_loss: 7.5376e-04 - val_mae: 0.0167
# Epoch 85/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2058e-04 - mae: 0.0163 - val_loss: 7.5447e-04 - val_mae: 0.0167
# Epoch 86/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2074e-04 - mae: 0.0163 - val_loss: 7.5321e-04 - val_mae: 0.0167
# Epoch 87/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2043e-04 - mae: 0.0163 - val_loss: 7.5283e-04 - val_mae: 0.0166
# Epoch 88/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.2043e-04 - mae: 0.0163 - val_loss: 7.5308e-04 - val_mae: 0.0167
# Epoch 89/200
# 236/236 [==============================] - 19s 80ms/step - loss: 7.2032e-04 - mae: 0.0163 - val_loss: 7.5316e-04 - val_mae: 0.0167
# Epoch 90/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2027e-04 - mae: 0.0163 - val_loss: 7.5388e-04 - val_mae: 0.0167
# Epoch 91/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2034e-04 - mae: 0.0163 - val_loss: 7.5276e-04 - val_mae: 0.0167
# Epoch 92/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.2064e-04 - mae: 0.0163 - val_loss: 7.5336e-04 - val_mae: 0.0167
# Epoch 93/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1995e-04 - mae: 0.0163 - val_loss: 7.5261e-04 - val_mae: 0.0167
# Epoch 94/200
# 236/236 [==============================] - 19s 78ms/step - loss: 7.1997e-04 - mae: 0.0163 - val_loss: 7.5232e-04 - val_mae: 0.0166
# Epoch 95/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1987e-04 - mae: 0.0163 - val_loss: 7.5264e-04 - val_mae: 0.0166
# Epoch 96/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1968e-04 - mae: 0.0163 - val_loss: 7.5205e-04 - val_mae: 0.0167
# Epoch 97/200
# 236/236 [==============================] - 19s 80ms/step - loss: 7.1968e-04 - mae: 0.0163 - val_loss: 7.5232e-04 - val_mae: 0.0166
# Epoch 98/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1959e-04 - mae: 0.0163 - val_loss: 7.5249e-04 - val_mae: 0.0167
# Epoch 99/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1968e-04 - mae: 0.0163 - val_loss: 7.5303e-04 - val_mae: 0.0167
# Epoch 100/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1950e-04 - mae: 0.0163 - val_loss: 7.5220e-04 - val_mae: 0.0167
# Epoch 101/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1942e-04 - mae: 0.0163 - val_loss: 7.5251e-04 - val_mae: 0.0167
# Epoch 102/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1952e-04 - mae: 0.0163 - val_loss: 7.5158e-04 - val_mae: 0.0167
# Epoch 103/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1915e-04 - mae: 0.0163 - val_loss: 7.5271e-04 - val_mae: 0.0167
# Epoch 104/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1907e-04 - mae: 0.0163 - val_loss: 7.5222e-04 - val_mae: 0.0166
# Epoch 105/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1907e-04 - mae: 0.0163 - val_loss: 7.5179e-04 - val_mae: 0.0167
# Epoch 106/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1893e-04 - mae: 0.0163 - val_loss: 7.5239e-04 - val_mae: 0.0167
# Epoch 107/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1911e-04 - mae: 0.0163 - val_loss: 7.5118e-04 - val_mae: 0.0166
# Epoch 108/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1893e-04 - mae: 0.0163 - val_loss: 7.5101e-04 - val_mae: 0.0166
# Epoch 109/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1867e-04 - mae: 0.0163 - val_loss: 7.5141e-04 - val_mae: 0.0166
# Epoch 110/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1860e-04 - mae: 0.0163 - val_loss: 7.5206e-04 - val_mae: 0.0167
# Epoch 111/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1859e-04 - mae: 0.0163 - val_loss: 7.5112e-04 - val_mae: 0.0166
# Epoch 112/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1847e-04 - mae: 0.0163 - val_loss: 7.5133e-04 - val_mae: 0.0167
# Epoch 113/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1832e-04 - mae: 0.0163 - val_loss: 7.5084e-04 - val_mae: 0.0166
# Epoch 114/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1825e-04 - mae: 0.0163 - val_loss: 7.5157e-04 - val_mae: 0.0166
# Epoch 115/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1814e-04 - mae: 0.0163 - val_loss: 7.5195e-04 - val_mae: 0.0166
# Epoch 116/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1813e-04 - mae: 0.0163 - val_loss: 7.5113e-04 - val_mae: 0.0166
# Epoch 117/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1808e-04 - mae: 0.0163 - val_loss: 7.5157e-04 - val_mae: 0.0166
# Epoch 118/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1811e-04 - mae: 0.0163 - val_loss: 7.5126e-04 - val_mae: 0.0167
# Epoch 119/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1797e-04 - mae: 0.0163 - val_loss: 7.5290e-04 - val_mae: 0.0166
# Epoch 120/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1798e-04 - mae: 0.0163 - val_loss: 7.5071e-04 - val_mae: 0.0166
# Epoch 121/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1786e-04 - mae: 0.0163 - val_loss: 7.5055e-04 - val_mae: 0.0166
# Epoch 122/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1764e-04 - mae: 0.0162 - val_loss: 7.5173e-04 - val_mae: 0.0167
# Epoch 123/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1775e-04 - mae: 0.0163 - val_loss: 7.5069e-04 - val_mae: 0.0167
# Epoch 124/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1768e-04 - mae: 0.0162 - val_loss: 7.5004e-04 - val_mae: 0.0166
# Epoch 125/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1719e-04 - mae: 0.0162 - val_loss: 7.5167e-04 - val_mae: 0.0166
# Epoch 126/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1729e-04 - mae: 0.0162 - val_loss: 7.5165e-04 - val_mae: 0.0166
# Epoch 127/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1740e-04 - mae: 0.0162 - val_loss: 7.5085e-04 - val_mae: 0.0167
# Epoch 128/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1730e-04 - mae: 0.0162 - val_loss: 7.4991e-04 - val_mae: 0.0166
# Epoch 129/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1705e-04 - mae: 0.0162 - val_loss: 7.4984e-04 - val_mae: 0.0166
# Epoch 130/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1709e-04 - mae: 0.0162 - val_loss: 7.5005e-04 - val_mae: 0.0166
# Epoch 131/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1697e-04 - mae: 0.0162 - val_loss: 7.5099e-04 - val_mae: 0.0167
# Epoch 132/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1704e-04 - mae: 0.0162 - val_loss: 7.5056e-04 - val_mae: 0.0166
# Epoch 133/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1684e-04 - mae: 0.0162 - val_loss: 7.5027e-04 - val_mae: 0.0167
# Epoch 134/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1669e-04 - mae: 0.0162 - val_loss: 7.5062e-04 - val_mae: 0.0167
# Epoch 135/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1670e-04 - mae: 0.0162 - val_loss: 7.5036e-04 - val_mae: 0.0167
# Epoch 136/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1679e-04 - mae: 0.0162 - val_loss: 7.5035e-04 - val_mae: 0.0166
# Epoch 137/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1649e-04 - mae: 0.0162 - val_loss: 7.5120e-04 - val_mae: 0.0167
# Epoch 138/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1654e-04 - mae: 0.0162 - val_loss: 7.5104e-04 - val_mae: 0.0166
# Epoch 139/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1649e-04 - mae: 0.0162 - val_loss: 7.5026e-04 - val_mae: 0.0166
# Epoch 140/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1657e-04 - mae: 0.0162 - val_loss: 7.4969e-04 - val_mae: 0.0166
# Epoch 141/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1631e-04 - mae: 0.0162 - val_loss: 7.4937e-04 - val_mae: 0.0166
# Epoch 142/200
# 236/236 [==============================] - 19s 78ms/step - loss: 7.1634e-04 - mae: 0.0162 - val_loss: 7.5015e-04 - val_mae: 0.0167
# Epoch 143/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1622e-04 - mae: 0.0162 - val_loss: 7.5025e-04 - val_mae: 0.0167
# Epoch 144/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1599e-04 - mae: 0.0162 - val_loss: 7.4939e-04 - val_mae: 0.0166
# Epoch 145/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1574e-04 - mae: 0.0162 - val_loss: 7.4948e-04 - val_mae: 0.0166
# Epoch 146/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1591e-04 - mae: 0.0162 - val_loss: 7.4930e-04 - val_mae: 0.0167
# Epoch 147/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1588e-04 - mae: 0.0162 - val_loss: 7.4964e-04 - val_mae: 0.0167
# Epoch 148/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1568e-04 - mae: 0.0162 - val_loss: 7.4971e-04 - val_mae: 0.0167
# Epoch 149/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1587e-04 - mae: 0.0162 - val_loss: 7.4922e-04 - val_mae: 0.0166
# Epoch 150/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1579e-04 - mae: 0.0162 - val_loss: 7.4897e-04 - val_mae: 0.0166
# Epoch 151/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1584e-04 - mae: 0.0162 - val_loss: 7.4869e-04 - val_mae: 0.0166
# Epoch 152/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1532e-04 - mae: 0.0162 - val_loss: 7.4900e-04 - val_mae: 0.0166
# Epoch 153/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1536e-04 - mae: 0.0162 - val_loss: 7.4852e-04 - val_mae: 0.0166
# Epoch 154/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1538e-04 - mae: 0.0162 - val_loss: 7.5030e-04 - val_mae: 0.0167
# Epoch 155/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1549e-04 - mae: 0.0162 - val_loss: 7.4938e-04 - val_mae: 0.0166
# Epoch 156/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1523e-04 - mae: 0.0162 - val_loss: 7.4988e-04 - val_mae: 0.0166
# Epoch 157/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1507e-04 - mae: 0.0162 - val_loss: 7.4907e-04 - val_mae: 0.0166
# Epoch 158/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1513e-04 - mae: 0.0162 - val_loss: 7.4890e-04 - val_mae: 0.0166
# Epoch 159/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1525e-04 - mae: 0.0162 - val_loss: 7.4882e-04 - val_mae: 0.0166
# Epoch 160/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1522e-04 - mae: 0.0162 - val_loss: 7.4859e-04 - val_mae: 0.0166
# Epoch 161/200
# 236/236 [==============================] - 18s 77ms/step - loss: 7.1483e-04 - mae: 0.0162 - val_loss: 7.4819e-04 - val_mae: 0.0166
# Epoch 162/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1491e-04 - mae: 0.0162 - val_loss: 7.4796e-04 - val_mae: 0.0166
# Epoch 163/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1466e-04 - mae: 0.0162 - val_loss: 7.4893e-04 - val_mae: 0.0167
# Epoch 164/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1444e-04 - mae: 0.0162 - val_loss: 7.4938e-04 - val_mae: 0.0166
# Epoch 165/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1469e-04 - mae: 0.0162 - val_loss: 7.4902e-04 - val_mae: 0.0166
# Epoch 166/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1460e-04 - mae: 0.0162 - val_loss: 7.4953e-04 - val_mae: 0.0166
# Epoch 167/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1467e-04 - mae: 0.0162 - val_loss: 7.4781e-04 - val_mae: 0.0166
# Epoch 168/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1449e-04 - mae: 0.0162 - val_loss: 7.4820e-04 - val_mae: 0.0166
# Epoch 169/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1456e-04 - mae: 0.0162 - val_loss: 7.4938e-04 - val_mae: 0.0166
# Epoch 170/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1434e-04 - mae: 0.0162 - val_loss: 7.4841e-04 - val_mae: 0.0166
# Epoch 171/200
# 236/236 [==============================] - 19s 80ms/step - loss: 7.1408e-04 - mae: 0.0162 - val_loss: 7.4787e-04 - val_mae: 0.0166
# Epoch 172/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1421e-04 - mae: 0.0162 - val_loss: 7.4793e-04 - val_mae: 0.0166
# Epoch 173/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1436e-04 - mae: 0.0162 - val_loss: 7.4784e-04 - val_mae: 0.0166
# Epoch 174/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1396e-04 - mae: 0.0162 - val_loss: 7.4830e-04 - val_mae: 0.0166
# Epoch 175/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1423e-04 - mae: 0.0162 - val_loss: 7.4783e-04 - val_mae: 0.0166
# Epoch 176/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1406e-04 - mae: 0.0162 - val_loss: 7.4797e-04 - val_mae: 0.0166
# Epoch 177/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1383e-04 - mae: 0.0162 - val_loss: 7.4756e-04 - val_mae: 0.0166
# Epoch 178/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1377e-04 - mae: 0.0162 - val_loss: 7.4786e-04 - val_mae: 0.0166
# Epoch 179/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1387e-04 - mae: 0.0162 - val_loss: 7.4882e-04 - val_mae: 0.0166
# Epoch 180/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1359e-04 - mae: 0.0162 - val_loss: 7.4738e-04 - val_mae: 0.0166
# Epoch 181/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1368e-04 - mae: 0.0162 - val_loss: 7.4704e-04 - val_mae: 0.0166
# Epoch 182/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1367e-04 - mae: 0.0162 - val_loss: 7.4773e-04 - val_mae: 0.0166
# Epoch 183/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1354e-04 - mae: 0.0162 - val_loss: 7.4823e-04 - val_mae: 0.0166
# Epoch 184/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1329e-04 - mae: 0.0162 - val_loss: 7.4810e-04 - val_mae: 0.0166
# Epoch 185/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1328e-04 - mae: 0.0162 - val_loss: 7.4906e-04 - val_mae: 0.0166
# Epoch 186/200
# 236/236 [==============================] - 19s 79ms/step - loss: 7.1348e-04 - mae: 0.0162 - val_loss: 7.4785e-04 - val_mae: 0.0166
# Epoch 187/200
# 236/236 [==============================] - 19s 80ms/step - loss: 7.1310e-04 - mae: 0.0162 - val_loss: 7.4714e-04 - val_mae: 0.0166
# Epoch 188/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1339e-04 - mae: 0.0162 - val_loss: 7.4697e-04 - val_mae: 0.0166
# Epoch 189/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1292e-04 - mae: 0.0162 - val_loss: 7.4736e-04 - val_mae: 0.0166
# Epoch 190/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1312e-04 - mae: 0.0162 - val_loss: 7.4719e-04 - val_mae: 0.0166
# Epoch 191/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1279e-04 - mae: 0.0162 - val_loss: 7.4751e-04 - val_mae: 0.0166
# Epoch 192/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1293e-04 - mae: 0.0162 - val_loss: 7.4714e-04 - val_mae: 0.0166
# Epoch 193/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1302e-04 - mae: 0.0162 - val_loss: 7.4696e-04 - val_mae: 0.0166
# Epoch 194/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1292e-04 - mae: 0.0162 - val_loss: 7.4741e-04 - val_mae: 0.0166
# Epoch 195/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1300e-04 - mae: 0.0162 - val_loss: 7.4720e-04 - val_mae: 0.0166
# Epoch 196/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1264e-04 - mae: 0.0162 - val_loss: 7.4718e-04 - val_mae: 0.0166
# Epoch 197/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1295e-04 - mae: 0.0162 - val_loss: 7.4689e-04 - val_mae: 0.0166
# Epoch 198/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1247e-04 - mae: 0.0162 - val_loss: 7.4756e-04 - val_mae: 0.0166
# Epoch 199/200
# 236/236 [==============================] - 18s 78ms/step - loss: 7.1255e-04 - mae: 0.0162 - val_loss: 7.4686e-04 - val_mae: 0.0166
# Epoch 200/200
# 236/236 [==============================] - 19s 78ms/step - loss: 7.1246e-04 - mae: 0.0162 - val_loss: 7.4672e-04 - val_mae: 0.0166

# %%
future_window = 1152

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred(model,sequence_length))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 5.2603725286642495  MAE: 3.761929086847687
# RMSE: 6.9692622845735  MAE: 4.720572183303563
#
# Best model is base lstm

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
for i,model in enumerate(models_array):
    save_model(model,models_lables[i])
#save_model(model_2,'model_2')
# Out:
# 2022-01-15 13:30:29.526396: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# base lstm saved!
# base gru saved!

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
