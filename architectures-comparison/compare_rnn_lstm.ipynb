# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_rnn(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.SimpleRNN(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_lstm(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_multi_lstm(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=True,return_state=True)(input_layer)
    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(x)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
models_array = []
history_array = []

epochs = 50
batch_size = 256

stride = 1
sequence_length = 400
X_train, y_train = extract_sequences(train_scaled,sequence_length,stride)
X_train.shape,y_train.shape
    
input_shape = X_train.shape[1:]

lstm_units = 512

models = [build_rnn, build_lstm, build_multi_lstm]
models_lables = ['base rnn','base lstm','multi lstm']

for m in models:

    model = m(input_shape,lstm_units)
    model.summary()

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# 2022-01-13 11:03:03.544515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:03.639507: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:03.640243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:03.642217: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-13 11:03:03.643135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:03.643862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:03.644494: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:05.395107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:05.395985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:05.396670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-13 11:03:05.397235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 512)               266240
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 3591
# =================================================================
# Total params: 269,831
# Trainable params: 269,831
# Non-trainable params: 0
# _________________________________________________________________
# 2022-01-13 11:03:07.320560: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 236/236 [==============================] - 71s 294ms/step - loss: 0.1378 - mae: 0.2796 - val_loss: 0.0216 - val_mae: 0.1128
# Epoch 2/50
# 236/236 [==============================] - 69s 293ms/step - loss: 0.0127 - mae: 0.0842 - val_loss: 0.0114 - val_mae: 0.0803
# Epoch 3/50
# 236/236 [==============================] - 69s 293ms/step - loss: 0.0106 - mae: 0.0773 - val_loss: 0.0098 - val_mae: 0.0757
# Epoch 4/50
# 236/236 [==============================] - 70s 297ms/step - loss: 0.0088 - mae: 0.0705 - val_loss: 0.0079 - val_mae: 0.0665
# Epoch 5/50
# 236/236 [==============================] - 68s 290ms/step - loss: 0.0069 - mae: 0.0619 - val_loss: 0.0059 - val_mae: 0.0571
# Epoch 6/50
# 236/236 [==============================] - 69s 294ms/step - loss: 0.0049 - mae: 0.0520 - val_loss: 0.0042 - val_mae: 0.0478
# Epoch 7/50
# 236/236 [==============================] - 71s 301ms/step - loss: 0.0034 - mae: 0.0427 - val_loss: 0.0028 - val_mae: 0.0388
# Epoch 8/50
# 236/236 [==============================] - 69s 294ms/step - loss: 0.0024 - mae: 0.0354 - val_loss: 0.0020 - val_mae: 0.0328
# Epoch 9/50
# 236/236 [==============================] - 69s 293ms/step - loss: 0.0017 - mae: 0.0297 - val_loss: 0.0015 - val_mae: 0.0277
# Epoch 10/50
# 236/236 [==============================] - 70s 296ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 0.0013 - val_mae: 0.0255
# Epoch 11/50
# 236/236 [==============================] - 70s 297ms/step - loss: 0.0012 - mae: 0.0239 - val_loss: 0.0012 - val_mae: 0.0245
# Epoch 12/50
# 236/236 [==============================] - 71s 301ms/step - loss: 0.0011 - mae: 0.0225 - val_loss: 0.0011 - val_mae: 0.0224
# Epoch 13/50
# 236/236 [==============================] - 69s 293ms/step - loss: 0.0010 - mae: 0.0218 - val_loss: 0.0010 - val_mae: 0.0211
# Epoch 14/50
# 236/236 [==============================] - 69s 294ms/step - loss: 0.0011 - mae: 0.0227 - val_loss: 0.0011 - val_mae: 0.0218
# Epoch 15/50
# 236/236 [==============================] - 70s 295ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0012 - val_mae: 0.0241
# Epoch 16/50
# 236/236 [==============================] - 70s 297ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0011 - val_mae: 0.0228
# Epoch 17/50
# 236/236 [==============================] - 70s 296ms/step - loss: 0.0014 - mae: 0.0270 - val_loss: 0.0019 - val_mae: 0.0329
# Epoch 18/50
# 236/236 [==============================] - 70s 295ms/step - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0012 - val_mae: 0.0236
# Epoch 19/50
# 236/236 [==============================] - 71s 302ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0015 - val_mae: 0.0281
# Epoch 20/50
# 236/236 [==============================] - 71s 301ms/step - loss: 0.0016 - mae: 0.0292 - val_loss: 0.0019 - val_mae: 0.0356
# Epoch 21/50
# 236/236 [==============================] - 73s 307ms/step - loss: 0.0016 - mae: 0.0297 - val_loss: 0.0010 - val_mae: 0.0211
# Epoch 22/50
# 236/236 [==============================] - 71s 301ms/step - loss: 0.0016 - mae: 0.0299 - val_loss: 0.0015 - val_mae: 0.0288
# Epoch 23/50
# 236/236 [==============================] - 71s 300ms/step - loss: 9.2940e-04 - mae: 0.0198 - val_loss: 0.0011 - val_mae: 0.0218
# Epoch 24/50
# 236/236 [==============================] - 71s 303ms/step - loss: 9.2925e-04 - mae: 0.0198 - val_loss: 9.9647e-04 - val_mae: 0.0210
# Epoch 25/50
# 236/236 [==============================] - 72s 304ms/step - loss: 9.3651e-04 - mae: 0.0200 - val_loss: 9.7217e-04 - val_mae: 0.0208
# Epoch 26/50
# 236/236 [==============================] - 72s 306ms/step - loss: 9.6496e-04 - mae: 0.0205 - val_loss: 0.0011 - val_mae: 0.0225
# Epoch 27/50
# 236/236 [==============================] - 72s 303ms/step - loss: 0.0011 - mae: 0.0221 - val_loss: 0.0015 - val_mae: 0.0283
# Epoch 28/50
# 236/236 [==============================] - 73s 309ms/step - loss: 0.0010 - mae: 0.0219 - val_loss: 0.0011 - val_mae: 0.0226
# Epoch 29/50
# 236/236 [==============================] - 72s 306ms/step - loss: 0.0011 - mae: 0.0231 - val_loss: 0.0014 - val_mae: 0.0273
# Epoch 30/50
# 236/236 [==============================] - 72s 307ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0011 - val_mae: 0.0227
# Epoch 31/50
# 236/236 [==============================] - 72s 305ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0014 - val_mae: 0.0279
# Epoch 32/50
# 236/236 [==============================] - 73s 310ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0012 - val_mae: 0.0247
# Epoch 33/50
# 236/236 [==============================] - 73s 310ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 34/50
# 236/236 [==============================] - 72s 306ms/step - loss: 0.0012 - mae: 0.0253 - val_loss: 0.0015 - val_mae: 0.0289
# Epoch 35/50
# 236/236 [==============================] - 73s 309ms/step - loss: 9.1912e-04 - mae: 0.0197 - val_loss: 9.5051e-04 - val_mae: 0.0203
# Epoch 36/50
# 236/236 [==============================] - 72s 307ms/step - loss: 8.9668e-04 - mae: 0.0193 - val_loss: 9.6024e-04 - val_mae: 0.0197
# Epoch 37/50
# 236/236 [==============================] - 74s 311ms/step - loss: 9.3202e-04 - mae: 0.0200 - val_loss: 0.0010 - val_mae: 0.0212
# Epoch 38/50
# 236/236 [==============================] - 73s 310ms/step - loss: 9.3353e-04 - mae: 0.0201 - val_loss: 9.2999e-04 - val_mae: 0.0194
# Epoch 39/50
# 236/236 [==============================] - 74s 312ms/step - loss: 9.3422e-04 - mae: 0.0200 - val_loss: 9.6814e-04 - val_mae: 0.0201
# Epoch 40/50
# 236/236 [==============================] - 72s 307ms/step - loss: 9.8902e-04 - mae: 0.0212 - val_loss: 0.0010 - val_mae: 0.0209
# Epoch 41/50
# 236/236 [==============================] - 74s 314ms/step - loss: 9.8769e-04 - mae: 0.0211 - val_loss: 9.7822e-04 - val_mae: 0.0207
# Epoch 42/50
# 236/236 [==============================] - 71s 303ms/step - loss: 0.0010 - mae: 0.0217 - val_loss: 0.0011 - val_mae: 0.0238
# Epoch 43/50
# 236/236 [==============================] - 73s 311ms/step - loss: 9.8330e-04 - mae: 0.0211 - val_loss: 9.9911e-04 - val_mae: 0.0208
# Epoch 44/50
# 236/236 [==============================] - 72s 303ms/step - loss: 9.9815e-04 - mae: 0.0215 - val_loss: 0.0011 - val_mae: 0.0223
# Epoch 45/50
# 236/236 [==============================] - 72s 302ms/step - loss: 8.8406e-04 - mae: 0.0191 - val_loss: 8.9414e-04 - val_mae: 0.0188
# Epoch 46/50
# 236/236 [==============================] - 71s 301ms/step - loss: 8.7754e-04 - mae: 0.0189 - val_loss: 0.0010 - val_mae: 0.0207
# Epoch 47/50
# 236/236 [==============================] - 72s 307ms/step - loss: 8.8812e-04 - mae: 0.0192 - val_loss: 9.6192e-04 - val_mae: 0.0207
# Epoch 48/50
# 236/236 [==============================] - 70s 298ms/step - loss: 8.9422e-04 - mae: 0.0194 - val_loss: 9.5044e-04 - val_mae: 0.0198
# Epoch 49/50
# 236/236 [==============================] - 72s 305ms/step - loss: 8.9985e-04 - mae: 0.0195 - val_loss: 8.9151e-04 - val_mae: 0.0189
# Epoch 50/50
# 236/236 [==============================] - 72s 306ms/step - loss: 9.1827e-04 - mae: 0.0198 - val_loss: 0.0011 - val_mae: 0.0218
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 400, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 512)               1064960
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 1,068,551
# Trainable params: 1,068,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2022-01-13 12:03:35.060808: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 236/236 [==============================] - 41s 160ms/step - loss: 0.0056 - mae: 0.0434 - val_loss: 0.0016 - val_mae: 0.0276
# Epoch 2/50
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0014 - mae: 0.0250 - val_loss: 0.0013 - val_mae: 0.0239
# Epoch 3/50
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0012 - val_mae: 0.0239
# Epoch 4/50
# 236/236 [==============================] - 37s 157ms/step - loss: 0.0010 - mae: 0.0213 - val_loss: 0.0011 - val_mae: 0.0219
# Epoch 5/50
# 236/236 [==============================] - 37s 157ms/step - loss: 9.5863e-04 - mae: 0.0203 - val_loss: 9.6834e-04 - val_mae: 0.0200
# Epoch 6/50
# 236/236 [==============================] - 37s 157ms/step - loss: 9.0856e-04 - mae: 0.0196 - val_loss: 9.0591e-04 - val_mae: 0.0191
# Epoch 7/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.8349e-04 - mae: 0.0192 - val_loss: 9.2166e-04 - val_mae: 0.0198
# Epoch 8/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.6305e-04 - mae: 0.0190 - val_loss: 9.0746e-04 - val_mae: 0.0196
# Epoch 9/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.4831e-04 - mae: 0.0187 - val_loss: 8.7292e-04 - val_mae: 0.0191
# Epoch 10/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.3185e-04 - mae: 0.0184 - val_loss: 8.6850e-04 - val_mae: 0.0190
# Epoch 11/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.2198e-04 - mae: 0.0183 - val_loss: 8.4779e-04 - val_mae: 0.0183
# Epoch 12/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.1314e-04 - mae: 0.0180 - val_loss: 8.4191e-04 - val_mae: 0.0183
# Epoch 13/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.0690e-04 - mae: 0.0180 - val_loss: 8.3453e-04 - val_mae: 0.0181
# Epoch 14/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.0195e-04 - mae: 0.0179 - val_loss: 8.5586e-04 - val_mae: 0.0183
# Epoch 15/50
# 236/236 [==============================] - 37s 157ms/step - loss: 8.0246e-04 - mae: 0.0179 - val_loss: 8.6180e-04 - val_mae: 0.0190
# Epoch 16/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.9535e-04 - mae: 0.0178 - val_loss: 8.5882e-04 - val_mae: 0.0190
# Epoch 17/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.9416e-04 - mae: 0.0177 - val_loss: 8.3542e-04 - val_mae: 0.0185
# Epoch 18/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.9785e-04 - mae: 0.0178 - val_loss: 8.4430e-04 - val_mae: 0.0186
# Epoch 19/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.8796e-04 - mae: 0.0176 - val_loss: 8.2186e-04 - val_mae: 0.0180
# Epoch 20/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.8540e-04 - mae: 0.0176 - val_loss: 8.5808e-04 - val_mae: 0.0188
# Epoch 21/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.8650e-04 - mae: 0.0176 - val_loss: 8.0879e-04 - val_mae: 0.0179
# Epoch 22/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6093e-04 - mae: 0.0171 - val_loss: 7.7879e-04 - val_mae: 0.0172
# Epoch 23/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5379e-04 - mae: 0.0170 - val_loss: 8.1753e-04 - val_mae: 0.0179
# Epoch 24/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6321e-04 - mae: 0.0171 - val_loss: 8.1313e-04 - val_mae: 0.0181
# Epoch 25/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5584e-04 - mae: 0.0170 - val_loss: 7.9717e-04 - val_mae: 0.0176
# Epoch 26/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5738e-04 - mae: 0.0171 - val_loss: 7.8703e-04 - val_mae: 0.0172
# Epoch 27/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5730e-04 - mae: 0.0171 - val_loss: 7.7747e-04 - val_mae: 0.0171
# Epoch 28/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.6211e-04 - mae: 0.0172 - val_loss: 7.7948e-04 - val_mae: 0.0173
# Epoch 29/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5535e-04 - mae: 0.0171 - val_loss: 7.7344e-04 - val_mae: 0.0173
# Epoch 30/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5171e-04 - mae: 0.0170 - val_loss: 7.9751e-04 - val_mae: 0.0175
# Epoch 31/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.5084e-04 - mae: 0.0170 - val_loss: 7.7435e-04 - val_mae: 0.0172
# Epoch 32/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3458e-04 - mae: 0.0167 - val_loss: 7.6655e-04 - val_mae: 0.0170
# Epoch 33/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3265e-04 - mae: 0.0166 - val_loss: 7.6791e-04 - val_mae: 0.0170
# Epoch 34/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3358e-04 - mae: 0.0166 - val_loss: 7.5908e-04 - val_mae: 0.0169
# Epoch 35/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3253e-04 - mae: 0.0166 - val_loss: 7.7016e-04 - val_mae: 0.0173
# Epoch 36/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3224e-04 - mae: 0.0166 - val_loss: 7.6507e-04 - val_mae: 0.0169
# Epoch 37/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3373e-04 - mae: 0.0167 - val_loss: 7.7676e-04 - val_mae: 0.0173
# Epoch 38/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3470e-04 - mae: 0.0167 - val_loss: 7.7598e-04 - val_mae: 0.0170
# Epoch 39/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.2989e-04 - mae: 0.0166 - val_loss: 7.8345e-04 - val_mae: 0.0174
# Epoch 40/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3103e-04 - mae: 0.0166 - val_loss: 7.6001e-04 - val_mae: 0.0168
# Epoch 41/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.3019e-04 - mae: 0.0166 - val_loss: 7.6090e-04 - val_mae: 0.0169
# Epoch 42/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1784e-04 - mae: 0.0163 - val_loss: 7.5977e-04 - val_mae: 0.0170
# Epoch 43/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1665e-04 - mae: 0.0163 - val_loss: 7.4923e-04 - val_mae: 0.0168
# Epoch 44/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1606e-04 - mae: 0.0163 - val_loss: 7.4943e-04 - val_mae: 0.0168
# Epoch 45/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1597e-04 - mae: 0.0163 - val_loss: 7.4768e-04 - val_mae: 0.0166
# Epoch 46/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1634e-04 - mae: 0.0163 - val_loss: 7.5248e-04 - val_mae: 0.0169
# Epoch 47/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1801e-04 - mae: 0.0164 - val_loss: 7.4834e-04 - val_mae: 0.0167
# Epoch 48/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1489e-04 - mae: 0.0163 - val_loss: 7.4865e-04 - val_mae: 0.0167
# Epoch 49/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1570e-04 - mae: 0.0163 - val_loss: 7.5757e-04 - val_mae: 0.0168
# Epoch 50/50
# 236/236 [==============================] - 37s 157ms/step - loss: 7.1459e-04 - mae: 0.0163 - val_loss: 7.4765e-04 - val_mae: 0.0167
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 400, 7)]     0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 400, 512), ( 1064960     Input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 512)          2099200     lstm_1[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 7)            3591        flatten_2[0][0]
# ==================================================================================================
# Total params: 3,167,751
# Trainable params: 3,167,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 236/236 [==============================] - 93s 387ms/step - loss: 0.0041 - mae: 0.0375 - val_loss: 0.0017 - val_mae: 0.0292
# Epoch 2/50
# 236/236 [==============================] - 90s 383ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 0.0012 - val_mae: 0.0232
# Epoch 3/50
# 236/236 [==============================] - 90s 383ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0011 - val_mae: 0.0218
# Epoch 4/50
# 236/236 [==============================] - 90s 383ms/step - loss: 9.3861e-04 - mae: 0.0203 - val_loss: 9.5142e-04 - val_mae: 0.0201
# Epoch 5/50
# 236/236 [==============================] - 90s 383ms/step - loss: 8.9379e-04 - mae: 0.0196 - val_loss: 8.9831e-04 - val_mae: 0.0197
# Epoch 6/50
# 236/236 [==============================] - 90s 383ms/step - loss: 8.7805e-04 - mae: 0.0193 - val_loss: 8.5762e-04 - val_mae: 0.0188
# Epoch 7/50
# 236/236 [==============================] - 90s 383ms/step - loss: 8.6441e-04 - mae: 0.0192 - val_loss: 9.1322e-04 - val_mae: 0.0204
# Epoch 8/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.5584e-04 - mae: 0.0191 - val_loss: 8.4153e-04 - val_mae: 0.0184
# Epoch 9/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.3949e-04 - mae: 0.0187 - val_loss: 9.0585e-04 - val_mae: 0.0197
# Epoch 10/50
# 236/236 [==============================] - 90s 384ms/step - loss: 8.4330e-04 - mae: 0.0188 - val_loss: 8.5451e-04 - val_mae: 0.0185
# Epoch 11/50
# 236/236 [==============================] - 90s 383ms/step - loss: 8.3579e-04 - mae: 0.0187 - val_loss: 9.1832e-04 - val_mae: 0.0201
# Epoch 12/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.2116e-04 - mae: 0.0183 - val_loss: 9.0801e-04 - val_mae: 0.0192
# Epoch 13/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.2192e-04 - mae: 0.0184 - val_loss: 8.6030e-04 - val_mae: 0.0191
# Epoch 14/50
# 236/236 [==============================] - 90s 383ms/step - loss: 8.2365e-04 - mae: 0.0185 - val_loss: 8.1574e-04 - val_mae: 0.0178
# Epoch 15/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.2360e-04 - mae: 0.0185 - val_loss: 9.0318e-04 - val_mae: 0.0195
# Epoch 16/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.1152e-04 - mae: 0.0182 - val_loss: 8.5579e-04 - val_mae: 0.0189
# Epoch 17/50
# 236/236 [==============================] - 91s 384ms/step - loss: 8.0647e-04 - mae: 0.0180 - val_loss: 8.1907e-04 - val_mae: 0.0183
# Epoch 18/50
# 236/236 [==============================] - 90s 383ms/step - loss: 8.0524e-04 - mae: 0.0181 - val_loss: 8.4718e-04 - val_mae: 0.0187
# Epoch 19/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.6397e-04 - mae: 0.0172 - val_loss: 7.9651e-04 - val_mae: 0.0177
# Epoch 20/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.6141e-04 - mae: 0.0172 - val_loss: 7.8352e-04 - val_mae: 0.0174
# Epoch 21/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.6371e-04 - mae: 0.0173 - val_loss: 7.9499e-04 - val_mae: 0.0176
# Epoch 22/50
# 236/236 [==============================] - 90s 384ms/step - loss: 7.6869e-04 - mae: 0.0173 - val_loss: 7.7241e-04 - val_mae: 0.0171
# Epoch 23/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.6165e-04 - mae: 0.0172 - val_loss: 7.9934e-04 - val_mae: 0.0175
# Epoch 24/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.6737e-04 - mae: 0.0173 - val_loss: 8.3178e-04 - val_mae: 0.0188
# Epoch 25/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.6327e-04 - mae: 0.0173 - val_loss: 8.4076e-04 - val_mae: 0.0186
# Epoch 26/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.7057e-04 - mae: 0.0175 - val_loss: 8.0944e-04 - val_mae: 0.0180
# Epoch 27/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.6479e-04 - mae: 0.0174 - val_loss: 8.0231e-04 - val_mae: 0.0176
# Epoch 28/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.6784e-04 - mae: 0.0174 - val_loss: 8.0130e-04 - val_mae: 0.0177
# Epoch 29/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.3868e-04 - mae: 0.0167 - val_loss: 7.6054e-04 - val_mae: 0.0170
# Epoch 30/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.3508e-04 - mae: 0.0167 - val_loss: 7.7933e-04 - val_mae: 0.0173
# Epoch 31/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.3873e-04 - mae: 0.0168 - val_loss: 7.7284e-04 - val_mae: 0.0174
# Epoch 32/50
# 236/236 [==============================] - 90s 384ms/step - loss: 7.3735e-04 - mae: 0.0167 - val_loss: 7.7004e-04 - val_mae: 0.0172
# Epoch 33/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.3986e-04 - mae: 0.0168 - val_loss: 7.8232e-04 - val_mae: 0.0174
# Epoch 34/50
# 236/236 [==============================] - 90s 384ms/step - loss: 7.3932e-04 - mae: 0.0168 - val_loss: 7.5843e-04 - val_mae: 0.0169
# Epoch 35/50
# 236/236 [==============================] - 90s 384ms/step - loss: 7.3620e-04 - mae: 0.0168 - val_loss: 7.8073e-04 - val_mae: 0.0176
# Epoch 36/50
# 236/236 [==============================] - 90s 383ms/step - loss: 7.3918e-04 - mae: 0.0169 - val_loss: 7.7232e-04 - val_mae: 0.0171
# Epoch 37/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.3745e-04 - mae: 0.0168 - val_loss: 7.7940e-04 - val_mae: 0.0174
# Epoch 38/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.3882e-04 - mae: 0.0168 - val_loss: 7.6667e-04 - val_mae: 0.0171
# Epoch 39/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.2112e-04 - mae: 0.0165 - val_loss: 7.6517e-04 - val_mae: 0.0170
# Epoch 40/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.2020e-04 - mae: 0.0164 - val_loss: 7.5396e-04 - val_mae: 0.0168
# Epoch 41/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1956e-04 - mae: 0.0164 - val_loss: 7.4973e-04 - val_mae: 0.0167
# Epoch 42/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1782e-04 - mae: 0.0164 - val_loss: 7.7172e-04 - val_mae: 0.0174
# Epoch 43/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1774e-04 - mae: 0.0164 - val_loss: 7.5190e-04 - val_mae: 0.0169
# Epoch 44/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1700e-04 - mae: 0.0164 - val_loss: 7.4973e-04 - val_mae: 0.0168
# Epoch 45/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1794e-04 - mae: 0.0164 - val_loss: 7.7692e-04 - val_mae: 0.0172
# Epoch 46/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1921e-04 - mae: 0.0164 - val_loss: 7.5255e-04 - val_mae: 0.0168
# Epoch 47/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1983e-04 - mae: 0.0165 - val_loss: 7.5330e-04 - val_mae: 0.0169
# Epoch 48/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.1686e-04 - mae: 0.0164 - val_loss: 7.5555e-04 - val_mae: 0.0170
# Epoch 49/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.0801e-04 - mae: 0.0162 - val_loss: 7.4853e-04 - val_mae: 0.0166
# Epoch 50/50
# 236/236 [==============================] - 91s 384ms/step - loss: 7.0693e-04 - mae: 0.0162 - val_loss: 7.4805e-04 - val_mae: 0.0167

# %%
future_window = 1152

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred(model,sequence_length))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 25.343800174611893  MAE: 14.028884621993331
# RMSE: 8.354513695892749  MAE: 5.039158645354869
# RMSE: 8.413618712747962  MAE: 3.985603559257979
#
# Best model is base lstm

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
#PAPER PLOTS

window = 100
future_window = 400
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
for i in range(7):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:future_window,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
save_model(models_array[best_model],'model')
#save_model(model_2,'model_2')
# Out:
# 2022-01-13 13:57:49.101054: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# model saved!

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
