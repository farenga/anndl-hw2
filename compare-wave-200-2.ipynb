# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,future=1,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length+future < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length:i+sequence_length+future])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_conv_0(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x1 = tfkl.MaxPooling1D()(x)

    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = False,return_state=True)(x1,initial_state=[h1,c1])
       
    x = tfkl.Flatten()(x1)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    x = tfkl.Dense(256,activation='relu')(x)
    x = tfkl.Dropout(.2)(x)
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_conv_1(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x1 = tfkl.AveragePooling1D()(x)

    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.AveragePooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.AveragePooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.AveragePooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = False,return_state=True)(x1,initial_state=[h1,c1])
       
    x = tfkl.Flatten()(x1)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    x = tfkl.Dense(256,activation='relu')(x)
    x = tfkl.Dropout(.2)(x)
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
stride = 1
sequence_length = 200
future = 2
X_train, y_train = extract_sequences(train_scaled,sequence_length, future, stride)
X_train.shape,y_train.shape
# Out:
# ((67174, 200, 7), (67174, 2, 7))

# %%
models_array = []
history_array = []

epochs = 200
batch_size = 256

    
input_shape = X_train.shape[1:]
print(input_shape)
models = [build_conv_0, build_conv_1]
models_lables = ['CNN LSTM 0','CNN LSTM 1']

for m in models:

    model = m(input_shape)
    model.summary()
    
    tfk.utils.plot_model(model)

    print("******************")
    
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.7, min_lr=1e-5)
        ]
    ).history
    
    models_array.append(model)
    history_array.append(history)
# Out:
# (200, 7)
# 2022-01-19 21:58:30.812971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:30.907200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:30.907930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:30.909041: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-19 21:58:30.910257: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:30.910927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:30.911592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:32.761066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:32.761936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:32.762631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-19 21:58:32.763220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 200, 7)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 200, 16)      352         Input[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 200, 32)      1568        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 200, 64)      6208        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 200, 128)     24704       conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 200, 256)     98560       conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 256)     1024        conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 100, 256)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 100, 256), ( 525312      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 100, 16)      12304       lstm[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 100, 32)      1568        conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 100, 64)      6208        conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 100, 128)     24704       conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 100, 256)     98560       conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 256)     1024        conv1d_9[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 100, 256)     0           lstm[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 50, 256)      0           add[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      max_pooling1d_1[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 50, 16)       12304       lstm_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 50, 32)       1568        conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 50, 64)       6208        conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 50, 128)      24704       conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 50, 256)      98560       conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 256)      1024        conv1d_14[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 50, 256)      0           lstm_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 25, 256)      0           add_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 25, 256), (N 525312      max_pooling1d_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 25, 16)       12304       lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 25, 32)       1568        conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 25, 64)       6208        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 25, 128)      24704       conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 25, 256)      98560       conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 256)      1024        conv1d_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 25, 256)      0           lstm_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 12, 256)      0           add_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, 256), (None, 525312      max_pooling1d_3[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          65792       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 14)           3598        dropout[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 2, 7)         0           dense_1[0][0]
# ==================================================================================================
# Total params: 2,736,158
# Trainable params: 2,734,110
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# ******************
# 2022-01-19 21:58:36.069108: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-01-19 21:58:43.207755: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 237/237 [==============================] - 46s 135ms/step - loss: 0.0132 - mae: 0.0819 - val_loss: 0.1379 - val_mae: 0.3443
# Epoch 2/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0045 - mae: 0.0520 - val_loss: 0.0160 - val_mae: 0.1060
# Epoch 3/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0034 - mae: 0.0449 - val_loss: 0.0031 - val_mae: 0.0449
# Epoch 4/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0029 - mae: 0.0416 - val_loss: 0.0023 - val_mae: 0.0373
# Epoch 5/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0026 - mae: 0.0388 - val_loss: 0.0020 - val_mae: 0.0341
# Epoch 6/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0023 - mae: 0.0365 - val_loss: 0.0016 - val_mae: 0.0302
# Epoch 7/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0022 - mae: 0.0352 - val_loss: 0.0016 - val_mae: 0.0298
# Epoch 8/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0020 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0280
# Epoch 9/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 0.0029 - val_mae: 0.0434
# Epoch 10/200
# 237/237 [==============================] - 30s 126ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 0.0019 - val_mae: 0.0327
# Epoch 11/200
# 237/237 [==============================] - 30s 126ms/step - loss: 0.0018 - mae: 0.0313 - val_loss: 0.0022 - val_mae: 0.0369
# Epoch 12/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0017 - mae: 0.0303 - val_loss: 0.0014 - val_mae: 0.0264
# Epoch 13/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0016 - mae: 0.0294 - val_loss: 0.0023 - val_mae: 0.0382
# Epoch 14/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0015 - mae: 0.0290 - val_loss: 0.0015 - val_mae: 0.0286
# Epoch 15/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0014 - mae: 0.0280 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 16/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0013 - val_mae: 0.0258
# Epoch 17/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0014 - mae: 0.0270 - val_loss: 0.0015 - val_mae: 0.0291
# Epoch 18/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 0.0016 - val_mae: 0.0300
# Epoch 19/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0013 - mae: 0.0266 - val_loss: 0.0015 - val_mae: 0.0287
# Epoch 20/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 21/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 22/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0014 - val_mae: 0.0266
# Epoch 23/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 0.0016 - val_mae: 0.0309
# Epoch 24/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 8.7949e-04 - val_mae: 0.0202
# Epoch 25/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0016 - val_mae: 0.0303
# Epoch 26/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0010 - mae: 0.0234 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 27/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0016 - val_mae: 0.0302
# Epoch 28/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0013 - val_mae: 0.0270
# Epoch 29/200
# 237/237 [==============================] - 30s 125ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0010 - val_mae: 0.0229
# Epoch 30/200
# 237/237 [==============================] - 30s 125ms/step - loss: 9.8232e-04 - mae: 0.0228 - val_loss: 0.0011 - val_mae: 0.0239
# Epoch 31/200
# 237/237 [==============================] - 29s 124ms/step - loss: 9.6021e-04 - mae: 0.0225 - val_loss: 0.0016 - val_mae: 0.0303
# Epoch 32/200
# 237/237 [==============================] - 30s 125ms/step - loss: 9.6047e-04 - mae: 0.0225 - val_loss: 0.0015 - val_mae: 0.0292
# Epoch 33/200
# 237/237 [==============================] - 29s 124ms/step - loss: 9.4474e-04 - mae: 0.0224 - val_loss: 0.0011 - val_mae: 0.0246
# Epoch 34/200
# 237/237 [==============================] - 29s 124ms/step - loss: 9.1814e-04 - mae: 0.0220 - val_loss: 8.6948e-04 - val_mae: 0.0203
# Epoch 35/200
# 237/237 [==============================] - 29s 124ms/step - loss: 8.4849e-04 - mae: 0.0211 - val_loss: 9.7579e-04 - val_mae: 0.0223
# Epoch 36/200
# 237/237 [==============================] - 30s 124ms/step - loss: 8.2837e-04 - mae: 0.0209 - val_loss: 8.5662e-04 - val_mae: 0.0208
# Epoch 37/200
# 237/237 [==============================] - 30s 125ms/step - loss: 8.1087e-04 - mae: 0.0207 - val_loss: 9.6585e-04 - val_mae: 0.0227
# Epoch 38/200
# 237/237 [==============================] - 30s 125ms/step - loss: 8.0408e-04 - mae: 0.0206 - val_loss: 9.4209e-04 - val_mae: 0.0224
# Epoch 39/200
# 237/237 [==============================] - 30s 125ms/step - loss: 8.1433e-04 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0288
# Epoch 40/200
# 237/237 [==============================] - 30s 125ms/step - loss: 7.9952e-04 - mae: 0.0205 - val_loss: 9.4784e-04 - val_mae: 0.0218
# Epoch 41/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.7915e-04 - mae: 0.0203 - val_loss: 8.0131e-04 - val_mae: 0.0198
# Epoch 42/200
# 237/237 [==============================] - 30s 125ms/step - loss: 7.8116e-04 - mae: 0.0203 - val_loss: 8.3780e-04 - val_mae: 0.0200
# Epoch 43/200
# 237/237 [==============================] - 30s 125ms/step - loss: 7.6343e-04 - mae: 0.0201 - val_loss: 8.8570e-04 - val_mae: 0.0214
# Epoch 44/200
# 237/237 [==============================] - 30s 125ms/step - loss: 7.5718e-04 - mae: 0.0200 - val_loss: 8.8850e-04 - val_mae: 0.0219
# Epoch 45/200
# 237/237 [==============================] - 30s 125ms/step - loss: 7.0767e-04 - mae: 0.0193 - val_loss: 6.5402e-04 - val_mae: 0.0173
# Epoch 46/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.8656e-04 - mae: 0.0190 - val_loss: 6.8340e-04 - val_mae: 0.0178
# Epoch 47/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.8474e-04 - mae: 0.0190 - val_loss: 7.9765e-04 - val_mae: 0.0201
# Epoch 48/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.7617e-04 - mae: 0.0189 - val_loss: 6.5248e-04 - val_mae: 0.0174
# Epoch 49/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.7400e-04 - mae: 0.0189 - val_loss: 7.0627e-04 - val_mae: 0.0184
# Epoch 50/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.8002e-04 - mae: 0.0190 - val_loss: 7.0945e-04 - val_mae: 0.0184
# Epoch 51/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.6589e-04 - mae: 0.0188 - val_loss: 7.8404e-04 - val_mae: 0.0201
# Epoch 52/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.5974e-04 - mae: 0.0187 - val_loss: 6.7887e-04 - val_mae: 0.0182
# Epoch 53/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.5297e-04 - mae: 0.0186 - val_loss: 6.2246e-04 - val_mae: 0.0170
# Epoch 54/200
# 237/237 [==============================] - 30s 124ms/step - loss: 6.4233e-04 - mae: 0.0184 - val_loss: 8.2036e-04 - val_mae: 0.0208
# Epoch 55/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.4593e-04 - mae: 0.0185 - val_loss: 9.9856e-04 - val_mae: 0.0232
# Epoch 56/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.0781e-04 - mae: 0.0179 - val_loss: 6.4880e-04 - val_mae: 0.0180
# Epoch 57/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.9726e-04 - mae: 0.0178 - val_loss: 6.0461e-04 - val_mae: 0.0166
# Epoch 58/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.8899e-04 - mae: 0.0177 - val_loss: 8.0387e-04 - val_mae: 0.0201
# Epoch 59/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.2465e-04 - mae: 0.0181 - val_loss: 6.2890e-04 - val_mae: 0.0172
# Epoch 60/200
# 237/237 [==============================] - 30s 126ms/step - loss: 5.8818e-04 - mae: 0.0177 - val_loss: 5.9086e-04 - val_mae: 0.0164
# Epoch 61/200
# 237/237 [==============================] - 30s 126ms/step - loss: 5.8294e-04 - mae: 0.0176 - val_loss: 5.9942e-04 - val_mae: 0.0168
# Epoch 62/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.7811e-04 - mae: 0.0175 - val_loss: 5.7851e-04 - val_mae: 0.0161
# Epoch 63/200
# 237/237 [==============================] - 30s 126ms/step - loss: 5.7414e-04 - mae: 0.0174 - val_loss: 6.0846e-04 - val_mae: 0.0169
# Epoch 64/200
# 237/237 [==============================] - 30s 126ms/step - loss: 5.7116e-04 - mae: 0.0174 - val_loss: 6.7045e-04 - val_mae: 0.0178
# Epoch 65/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.7373e-04 - mae: 0.0174 - val_loss: 6.1650e-04 - val_mae: 0.0172
# Epoch 66/200
# 237/237 [==============================] - 30s 126ms/step - loss: 5.5106e-04 - mae: 0.0171 - val_loss: 6.1304e-04 - val_mae: 0.0170
# Epoch 67/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.4034e-04 - mae: 0.0169 - val_loss: 5.6418e-04 - val_mae: 0.0159
# Epoch 68/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3592e-04 - mae: 0.0169 - val_loss: 5.5004e-04 - val_mae: 0.0157
# Epoch 69/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3880e-04 - mae: 0.0169 - val_loss: 5.6343e-04 - val_mae: 0.0162
# Epoch 70/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3527e-04 - mae: 0.0168 - val_loss: 5.5842e-04 - val_mae: 0.0160
# Epoch 71/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3777e-04 - mae: 0.0169 - val_loss: 5.7821e-04 - val_mae: 0.0163
# Epoch 72/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3430e-04 - mae: 0.0168 - val_loss: 7.6619e-04 - val_mae: 0.0199
# Epoch 73/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2727e-04 - mae: 0.0167 - val_loss: 5.8789e-04 - val_mae: 0.0162
# Epoch 74/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2516e-04 - mae: 0.0167 - val_loss: 5.4141e-04 - val_mae: 0.0154
# Epoch 75/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2483e-04 - mae: 0.0167 - val_loss: 6.0906e-04 - val_mae: 0.0171
# Epoch 76/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2593e-04 - mae: 0.0167 - val_loss: 5.6343e-04 - val_mae: 0.0160
# Epoch 77/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2241e-04 - mae: 0.0166 - val_loss: 5.3697e-04 - val_mae: 0.0153
# Epoch 78/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2028e-04 - mae: 0.0166 - val_loss: 5.2266e-04 - val_mae: 0.0151
# Epoch 79/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.0561e-04 - mae: 0.0164 - val_loss: 5.2715e-04 - val_mae: 0.0153
# Epoch 80/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.9741e-04 - mae: 0.0162 - val_loss: 5.7393e-04 - val_mae: 0.0166
# Epoch 81/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.9704e-04 - mae: 0.0163 - val_loss: 5.2056e-04 - val_mae: 0.0150
# Epoch 82/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.9992e-04 - mae: 0.0163 - val_loss: 5.3525e-04 - val_mae: 0.0156
# Epoch 83/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.9165e-04 - mae: 0.0162 - val_loss: 5.5569e-04 - val_mae: 0.0158
# Epoch 84/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.9363e-04 - mae: 0.0162 - val_loss: 5.1013e-04 - val_mae: 0.0146
# Epoch 85/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.9119e-04 - mae: 0.0162 - val_loss: 5.0398e-04 - val_mae: 0.0146
# Epoch 86/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.8700e-04 - mae: 0.0161 - val_loss: 5.0992e-04 - val_mae: 0.0145
# Epoch 87/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.8711e-04 - mae: 0.0161 - val_loss: 5.1442e-04 - val_mae: 0.0148
# Epoch 88/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.8671e-04 - mae: 0.0161 - val_loss: 5.4981e-04 - val_mae: 0.0157
# Epoch 89/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.7495e-04 - mae: 0.0159 - val_loss: 5.0083e-04 - val_mae: 0.0144
# Epoch 90/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.7214e-04 - mae: 0.0159 - val_loss: 4.9961e-04 - val_mae: 0.0143
# Epoch 91/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.7108e-04 - mae: 0.0158 - val_loss: 5.0426e-04 - val_mae: 0.0144
# Epoch 92/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6785e-04 - mae: 0.0158 - val_loss: 5.1668e-04 - val_mae: 0.0148
# Epoch 93/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6684e-04 - mae: 0.0158 - val_loss: 5.0508e-04 - val_mae: 0.0146
# Epoch 94/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6493e-04 - mae: 0.0158 - val_loss: 5.3382e-04 - val_mae: 0.0151
# Epoch 95/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6453e-04 - mae: 0.0158 - val_loss: 5.0918e-04 - val_mae: 0.0146
# Epoch 96/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6354e-04 - mae: 0.0157 - val_loss: 5.1014e-04 - val_mae: 0.0146
# Epoch 97/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6243e-04 - mae: 0.0157 - val_loss: 5.3971e-04 - val_mae: 0.0151
# Epoch 98/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.6093e-04 - mae: 0.0157 - val_loss: 5.0225e-04 - val_mae: 0.0144
# Epoch 99/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.5372e-04 - mae: 0.0156 - val_loss: 5.0456e-04 - val_mae: 0.0143
# Epoch 100/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.5198e-04 - mae: 0.0156 - val_loss: 5.0208e-04 - val_mae: 0.0142
# Epoch 101/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4814e-04 - mae: 0.0155 - val_loss: 5.1682e-04 - val_mae: 0.0146
# Epoch 102/200
# 237/237 [==============================] - 30s 126ms/step - loss: 4.5038e-04 - mae: 0.0156 - val_loss: 5.1809e-04 - val_mae: 0.0145
# Epoch 103/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4479e-04 - mae: 0.0155 - val_loss: 5.1783e-04 - val_mae: 0.0145
# Epoch 104/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4546e-04 - mae: 0.0155 - val_loss: 5.0784e-04 - val_mae: 0.0143
# Epoch 105/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4571e-04 - mae: 0.0155 - val_loss: 5.1779e-04 - val_mae: 0.0145
# Epoch 106/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4418e-04 - mae: 0.0155 - val_loss: 5.2739e-04 - val_mae: 0.0147
# Epoch 107/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4310e-04 - mae: 0.0155 - val_loss: 5.1233e-04 - val_mae: 0.0144
# Epoch 108/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4195e-04 - mae: 0.0154 - val_loss: 5.3081e-04 - val_mae: 0.0150
# Epoch 109/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.3609e-04 - mae: 0.0153 - val_loss: 5.0425e-04 - val_mae: 0.0141
# Epoch 110/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.3380e-04 - mae: 0.0153 - val_loss: 5.2357e-04 - val_mae: 0.0146
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 200, 7)]     0
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 200, 16)      352         Input[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 200, 32)      1568        conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 200, 64)      6208        conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 200, 128)     24704       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 200, 256)     98560       conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 256)     1024        conv1d_24[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 100, 256)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 100, 256), ( 525312      average_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 100, 16)      12304       lstm_4[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 100, 32)      1568        conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 100, 64)      6208        conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 100, 128)     24704       conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 100, 256)     98560       conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100, 256)     1024        conv1d_29[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 256)     0           lstm_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 50, 256)      0           add_3[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 50, 256), (N 525312      average_pooling1d_1[0][0]
#                                                                  lstm_4[0][1]
#                                                                  lstm_4[0][2]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 50, 16)       12304       lstm_5[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 50, 32)       1568        conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 50, 64)       6208        conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 50, 128)      24704       conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 50, 256)      98560       conv1d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 256)      1024        conv1d_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 256)      0           lstm_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_2 (AveragePoo (None, 25, 256)      0           add_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 25, 256), (N 525312      average_pooling1d_2[0][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 25, 16)       12304       lstm_6[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 25, 32)       1568        conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 25, 64)       6208        conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 25, 128)      24704       conv1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 25, 256)      98560       conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 256)      1024        conv1d_39[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 256)      0           lstm_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_3 (AveragePoo (None, 12, 256)      0           add_5[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, 256), (None, 525312      average_pooling1d_3[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           lstm_7[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          65792       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 14)           3598        dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 7)         0           dense_3[0][0]
# ==================================================================================================
# Total params: 2,736,158
# Trainable params: 2,734,110
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# ******************
# Epoch 1/200
# 237/237 [==============================] - 37s 129ms/step - loss: 0.0138 - mae: 0.0834 - val_loss: 0.1361 - val_mae: 0.3295
# Epoch 2/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0046 - mae: 0.0527 - val_loss: 0.0179 - val_mae: 0.1140
# Epoch 3/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0035 - mae: 0.0453 - val_loss: 0.0035 - val_mae: 0.0475
# Epoch 4/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0026 - val_mae: 0.0399
# Epoch 5/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0026 - mae: 0.0392 - val_loss: 0.0043 - val_mae: 0.0541
# Epoch 6/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0023 - mae: 0.0366 - val_loss: 0.0036 - val_mae: 0.0484
# Epoch 7/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0022 - mae: 0.0357 - val_loss: 0.0027 - val_mae: 0.0406
# Epoch 8/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0021 - mae: 0.0342 - val_loss: 0.0015 - val_mae: 0.0288
# Epoch 9/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 0.0016 - val_mae: 0.0301
# Epoch 10/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0018 - mae: 0.0319 - val_loss: 0.0018 - val_mae: 0.0322
# Epoch 11/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0017 - mae: 0.0310 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 12/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0017 - mae: 0.0303 - val_loss: 0.0022 - val_mae: 0.0350
# Epoch 13/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0016 - mae: 0.0292 - val_loss: 0.0039 - val_mae: 0.0511
# Epoch 14/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0014 - val_mae: 0.0282
# Epoch 15/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 16/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0014 - mae: 0.0278 - val_loss: 0.0014 - val_mae: 0.0281
# Epoch 17/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0014 - mae: 0.0270 - val_loss: 0.0016 - val_mae: 0.0305
# Epoch 18/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 19/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0012 - val_mae: 0.0251
# Epoch 20/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0013 - mae: 0.0258 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 21/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 0.0014 - val_mae: 0.0271
# Epoch 22/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 0.0012 - val_mae: 0.0241
# Epoch 23/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 0.0016 - val_mae: 0.0292
# Epoch 24/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0017 - val_mae: 0.0311
# Epoch 25/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0015 - val_mae: 0.0283
# Epoch 26/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 27/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 28/200
# 237/237 [==============================] - 29s 124ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 9.1172e-04 - val_mae: 0.0213
# Epoch 29/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0017 - val_mae: 0.0313
# Epoch 30/200
# 237/237 [==============================] - 29s 123ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0012 - val_mae: 0.0242
# Epoch 31/200
# 237/237 [==============================] - 29s 124ms/step - loss: 9.8629e-04 - mae: 0.0227 - val_loss: 0.0021 - val_mae: 0.0341
# Epoch 32/200
# 237/237 [==============================] - 29s 124ms/step - loss: 9.7127e-04 - mae: 0.0226 - val_loss: 0.0028 - val_mae: 0.0425
# Epoch 33/200
# 237/237 [==============================] - 29s 123ms/step - loss: 9.5297e-04 - mae: 0.0224 - val_loss: 0.0011 - val_mae: 0.0245
# Epoch 34/200
# 237/237 [==============================] - 29s 123ms/step - loss: 9.3741e-04 - mae: 0.0222 - val_loss: 0.0013 - val_mae: 0.0275
# Epoch 35/200
# 237/237 [==============================] - 29s 123ms/step - loss: 9.4253e-04 - mae: 0.0223 - val_loss: 0.0015 - val_mae: 0.0290
# Epoch 36/200
# 237/237 [==============================] - 29s 124ms/step - loss: 9.0701e-04 - mae: 0.0219 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 37/200
# 237/237 [==============================] - 29s 124ms/step - loss: 8.8190e-04 - mae: 0.0215 - val_loss: 0.0011 - val_mae: 0.0250
# Epoch 38/200
# 237/237 [==============================] - 29s 123ms/step - loss: 8.7301e-04 - mae: 0.0214 - val_loss: 0.0012 - val_mae: 0.0267
# Epoch 39/200
# 237/237 [==============================] - 29s 123ms/step - loss: 8.0319e-04 - mae: 0.0205 - val_loss: 0.0011 - val_mae: 0.0236
# Epoch 40/200
# 237/237 [==============================] - 29s 123ms/step - loss: 7.7442e-04 - mae: 0.0202 - val_loss: 7.9434e-04 - val_mae: 0.0198
# Epoch 41/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.6800e-04 - mae: 0.0200 - val_loss: 7.2010e-04 - val_mae: 0.0182
# Epoch 42/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.6705e-04 - mae: 0.0201 - val_loss: 0.0010 - val_mae: 0.0228
# Epoch 43/200
# 237/237 [==============================] - 29s 123ms/step - loss: 7.5078e-04 - mae: 0.0198 - val_loss: 0.0010 - val_mae: 0.0233
# Epoch 44/200
# 237/237 [==============================] - 29s 123ms/step - loss: 7.5501e-04 - mae: 0.0200 - val_loss: 0.0019 - val_mae: 0.0328
# Epoch 45/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.4649e-04 - mae: 0.0198 - val_loss: 9.5244e-04 - val_mae: 0.0223
# Epoch 46/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.3237e-04 - mae: 0.0196 - val_loss: 8.9141e-04 - val_mae: 0.0216
# Epoch 47/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.2918e-04 - mae: 0.0196 - val_loss: 0.0012 - val_mae: 0.0248
# Epoch 48/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.1611e-04 - mae: 0.0194 - val_loss: 8.5954e-04 - val_mae: 0.0210
# Epoch 49/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.1165e-04 - mae: 0.0194 - val_loss: 8.5446e-04 - val_mae: 0.0209
# Epoch 50/200
# 237/237 [==============================] - 29s 124ms/step - loss: 7.1420e-04 - mae: 0.0194 - val_loss: 7.2513e-04 - val_mae: 0.0187
# Epoch 51/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.5038e-04 - mae: 0.0185 - val_loss: 7.0577e-04 - val_mae: 0.0185
# Epoch 52/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.3723e-04 - mae: 0.0183 - val_loss: 7.1392e-04 - val_mae: 0.0187
# Epoch 53/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.2723e-04 - mae: 0.0182 - val_loss: 7.6227e-04 - val_mae: 0.0198
# Epoch 54/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.2517e-04 - mae: 0.0182 - val_loss: 8.3286e-04 - val_mae: 0.0212
# Epoch 55/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.2037e-04 - mae: 0.0181 - val_loss: 6.2613e-04 - val_mae: 0.0172
# Epoch 56/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.2099e-04 - mae: 0.0181 - val_loss: 6.9675e-04 - val_mae: 0.0184
# Epoch 57/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.1547e-04 - mae: 0.0180 - val_loss: 6.1700e-04 - val_mae: 0.0170
# Epoch 58/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.1047e-04 - mae: 0.0179 - val_loss: 7.4006e-04 - val_mae: 0.0186
# Epoch 59/200
# 237/237 [==============================] - 29s 124ms/step - loss: 6.1663e-04 - mae: 0.0180 - val_loss: 6.7737e-04 - val_mae: 0.0184
# Epoch 60/200
# 237/237 [==============================] - 30s 125ms/step - loss: 6.0470e-04 - mae: 0.0178 - val_loss: 7.5266e-04 - val_mae: 0.0193
# Epoch 61/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.9257e-04 - mae: 0.0177 - val_loss: 7.0292e-04 - val_mae: 0.0184
# Epoch 62/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.8366e-04 - mae: 0.0176 - val_loss: 6.2767e-04 - val_mae: 0.0171
# Epoch 63/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.8341e-04 - mae: 0.0175 - val_loss: 8.8692e-04 - val_mae: 0.0219
# Epoch 64/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.8377e-04 - mae: 0.0175 - val_loss: 6.2718e-04 - val_mae: 0.0173
# Epoch 65/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.8140e-04 - mae: 0.0175 - val_loss: 9.6235e-04 - val_mae: 0.0230
# Epoch 66/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.4988e-04 - mae: 0.0170 - val_loss: 5.9194e-04 - val_mae: 0.0166
# Epoch 67/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3637e-04 - mae: 0.0168 - val_loss: 5.3867e-04 - val_mae: 0.0155
# Epoch 68/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.3631e-04 - mae: 0.0168 - val_loss: 5.6868e-04 - val_mae: 0.0162
# Epoch 69/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.4106e-04 - mae: 0.0169 - val_loss: 5.5552e-04 - val_mae: 0.0158
# Epoch 70/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.3316e-04 - mae: 0.0167 - val_loss: 7.7703e-04 - val_mae: 0.0201
# Epoch 71/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2915e-04 - mae: 0.0167 - val_loss: 6.5712e-04 - val_mae: 0.0181
# Epoch 72/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.3119e-04 - mae: 0.0167 - val_loss: 7.3014e-04 - val_mae: 0.0197
# Epoch 73/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.2340e-04 - mae: 0.0166 - val_loss: 6.0723e-04 - val_mae: 0.0166
# Epoch 74/200
# 237/237 [==============================] - 30s 125ms/step - loss: 5.2420e-04 - mae: 0.0166 - val_loss: 6.3943e-04 - val_mae: 0.0174
# Epoch 75/200
# 237/237 [==============================] - 29s 124ms/step - loss: 5.2280e-04 - mae: 0.0166 - val_loss: 5.9480e-04 - val_mae: 0.0166
# Epoch 76/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.9951e-04 - mae: 0.0162 - val_loss: 5.2683e-04 - val_mae: 0.0151
# Epoch 77/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.9149e-04 - mae: 0.0161 - val_loss: 5.0501e-04 - val_mae: 0.0147
# Epoch 78/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.9047e-04 - mae: 0.0161 - val_loss: 5.0193e-04 - val_mae: 0.0147
# Epoch 79/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.8466e-04 - mae: 0.0160 - val_loss: 5.6631e-04 - val_mae: 0.0161
# Epoch 80/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.8661e-04 - mae: 0.0160 - val_loss: 6.2007e-04 - val_mae: 0.0173
# Epoch 81/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.8862e-04 - mae: 0.0161 - val_loss: 5.2105e-04 - val_mae: 0.0149
# Epoch 82/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.8370e-04 - mae: 0.0160 - val_loss: 5.4249e-04 - val_mae: 0.0157
# Epoch 83/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.7802e-04 - mae: 0.0159 - val_loss: 5.3826e-04 - val_mae: 0.0155
# Epoch 84/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.8104e-04 - mae: 0.0160 - val_loss: 7.5757e-04 - val_mae: 0.0197
# Epoch 85/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.8113e-04 - mae: 0.0160 - val_loss: 5.6728e-04 - val_mae: 0.0157
# Epoch 86/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.7306e-04 - mae: 0.0158 - val_loss: 5.3051e-04 - val_mae: 0.0150
# Epoch 87/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.7583e-04 - mae: 0.0159 - val_loss: 5.2635e-04 - val_mae: 0.0151
# Epoch 88/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.5955e-04 - mae: 0.0156 - val_loss: 5.1833e-04 - val_mae: 0.0148
# Epoch 89/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.5359e-04 - mae: 0.0155 - val_loss: 5.1380e-04 - val_mae: 0.0146
# Epoch 90/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.5091e-04 - mae: 0.0155 - val_loss: 5.2295e-04 - val_mae: 0.0148
# Epoch 91/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.4883e-04 - mae: 0.0155 - val_loss: 5.2952e-04 - val_mae: 0.0149
# Epoch 92/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.5071e-04 - mae: 0.0155 - val_loss: 5.2290e-04 - val_mae: 0.0151
# Epoch 93/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4561e-04 - mae: 0.0154 - val_loss: 4.9990e-04 - val_mae: 0.0143
# Epoch 94/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4606e-04 - mae: 0.0154 - val_loss: 5.2014e-04 - val_mae: 0.0149
# Epoch 95/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.4718e-04 - mae: 0.0154 - val_loss: 5.1084e-04 - val_mae: 0.0144
# Epoch 96/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.4183e-04 - mae: 0.0154 - val_loss: 4.9651e-04 - val_mae: 0.0142
# Epoch 97/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.4136e-04 - mae: 0.0154 - val_loss: 5.2200e-04 - val_mae: 0.0148
# Epoch 98/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.3379e-04 - mae: 0.0152 - val_loss: 5.0677e-04 - val_mae: 0.0143
# Epoch 99/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.2683e-04 - mae: 0.0151 - val_loss: 5.1333e-04 - val_mae: 0.0144
# Epoch 100/200
# 237/237 [==============================] - 30s 126ms/step - loss: 4.2876e-04 - mae: 0.0152 - val_loss: 5.0696e-04 - val_mae: 0.0143
# Epoch 101/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.2343e-04 - mae: 0.0151 - val_loss: 5.1192e-04 - val_mae: 0.0145
# Epoch 102/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.2547e-04 - mae: 0.0151 - val_loss: 5.0722e-04 - val_mae: 0.0143
# Epoch 103/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.2100e-04 - mae: 0.0151 - val_loss: 5.1436e-04 - val_mae: 0.0142
# Epoch 104/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.2377e-04 - mae: 0.0151 - val_loss: 5.1847e-04 - val_mae: 0.0145
# Epoch 105/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.2443e-04 - mae: 0.0151 - val_loss: 4.9615e-04 - val_mae: 0.0140
# Epoch 106/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.1916e-04 - mae: 0.0150 - val_loss: 5.0751e-04 - val_mae: 0.0143
# Epoch 107/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.2141e-04 - mae: 0.0150 - val_loss: 5.0670e-04 - val_mae: 0.0143
# Epoch 108/200
# 237/237 [==============================] - 30s 125ms/step - loss: 4.1171e-04 - mae: 0.0149 - val_loss: 5.1666e-04 - val_mae: 0.0144
# Epoch 109/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0976e-04 - mae: 0.0149 - val_loss: 4.9977e-04 - val_mae: 0.0140
# Epoch 110/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0899e-04 - mae: 0.0148 - val_loss: 4.9503e-04 - val_mae: 0.0138
# Epoch 111/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0890e-04 - mae: 0.0148 - val_loss: 5.2025e-04 - val_mae: 0.0144
# Epoch 112/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0960e-04 - mae: 0.0149 - val_loss: 4.9051e-04 - val_mae: 0.0137
# Epoch 113/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0621e-04 - mae: 0.0148 - val_loss: 5.0682e-04 - val_mae: 0.0140
# Epoch 114/200
# 237/237 [==============================] - 29s 123ms/step - loss: 4.0665e-04 - mae: 0.0148 - val_loss: 5.0834e-04 - val_mae: 0.0140
# Epoch 115/200
# 237/237 [==============================] - 29s 123ms/step - loss: 4.0476e-04 - mae: 0.0148 - val_loss: 5.0537e-04 - val_mae: 0.0140
# Epoch 116/200
# 237/237 [==============================] - 29s 123ms/step - loss: 4.0437e-04 - mae: 0.0148 - val_loss: 5.0105e-04 - val_mae: 0.0138
# Epoch 117/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0249e-04 - mae: 0.0148 - val_loss: 5.0877e-04 - val_mae: 0.0139
# Epoch 118/200
# 237/237 [==============================] - 29s 124ms/step - loss: 4.0027e-04 - mae: 0.0147 - val_loss: 5.0544e-04 - val_mae: 0.0138
# Epoch 119/200
# 237/237 [==============================] - 29s 123ms/step - loss: 4.0028e-04 - mae: 0.0147 - val_loss: 5.0360e-04 - val_mae: 0.0140
# Epoch 120/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.9702e-04 - mae: 0.0146 - val_loss: 5.0213e-04 - val_mae: 0.0139
# Epoch 121/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.9736e-04 - mae: 0.0147 - val_loss: 5.0209e-04 - val_mae: 0.0138
# Epoch 122/200
# 237/237 [==============================] - 29s 124ms/step - loss: 3.9796e-04 - mae: 0.0147 - val_loss: 4.9558e-04 - val_mae: 0.0137
# Epoch 123/200
# 237/237 [==============================] - 29s 124ms/step - loss: 3.9538e-04 - mae: 0.0146 - val_loss: 5.0091e-04 - val_mae: 0.0139
# Epoch 124/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.9548e-04 - mae: 0.0146 - val_loss: 5.0413e-04 - val_mae: 0.0140
# Epoch 125/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.9561e-04 - mae: 0.0146 - val_loss: 4.9902e-04 - val_mae: 0.0137
# Epoch 126/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.9476e-04 - mae: 0.0146 - val_loss: 5.0975e-04 - val_mae: 0.0142
# Epoch 127/200
# 237/237 [==============================] - 29s 124ms/step - loss: 3.9178e-04 - mae: 0.0146 - val_loss: 5.0792e-04 - val_mae: 0.0139
# Epoch 128/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.9141e-04 - mae: 0.0146 - val_loss: 5.0315e-04 - val_mae: 0.0137
# Epoch 129/200
# 237/237 [==============================] - 29s 124ms/step - loss: 3.8897e-04 - mae: 0.0145 - val_loss: 5.0424e-04 - val_mae: 0.0138
# Epoch 130/200
# 237/237 [==============================] - 29s 124ms/step - loss: 3.8653e-04 - mae: 0.0145 - val_loss: 5.0011e-04 - val_mae: 0.0137
# Epoch 131/200
# 237/237 [==============================] - 29s 123ms/step - loss: 3.8867e-04 - mae: 0.0145 - val_loss: 4.9156e-04 - val_mae: 0.0136
# Epoch 132/200
# 237/237 [==============================] - 29s 124ms/step - loss: 3.8835e-04 - mae: 0.0145 - val_loss: 4.9879e-04 - val_mae: 0.0138

# %%
tfk.utils.plot_model(model, expand_nested=True)

# %%
future_window = 864

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled    


def autoregression_pred_multiout(model,window,future):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape
    pred = np.array([])
    X_temp = last_window
    for t in range(0,future_window,future):
        pred_temp = model.predict(X_temp)
        #pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,future:,:],pred_temp), axis=1)

    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred_multiout(model,sequence_length,future))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 6.596245104500176  MAE: 3.2258283464402906
# RMSE: 6.3823403207186225  MAE: 3.013920537815137
#
# Best model is CNN LSTM 1

# %%
colors = ['#DE6A3C','#9ceb00','#6500c9','#0040c9','#ff00bb','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.7
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
window = 100
future_window = 400

for i in range(7):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.3)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.7
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:future_window,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
for i,model in enumerate(models_array):
    save_model(model,models_lables[i])
#save_model(model_2,'model_2')
# Out:
# 2022-01-20 00:04:43.874828: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# CNN LSTM 0 saved!
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# CNN LSTM 1 saved!

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
