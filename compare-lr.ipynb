# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2/Training.csv',delimiter=',',skip_header=True)

# %%
# Defining split sizes 

test_size = 1152
train_size = len(X) - test_size

train_raw = X[:train_size]
test_raw = X[train_size:]

train_raw.shape, test_raw.shape

plt.plot(figsize=(20,5))
plt.plot(range(10),train_raw[-10:,0])
plt.plot(range(10,20),test_raw[:10,0])
plt.plot(range(0,20),X[train_size-10:train_size+10,0],'+k')

# %%
# Pre-processing

train_max = train_raw.max(axis=0)
train_min = train_raw.min(axis=0)

X_mean = train_raw.mean(axis=0)
X_std = train_raw.std(axis=0)

train_scaled = (train_raw-train_min)/(train_max-train_min)
test_scaled = (test_raw-train_min)/(train_max-train_min)

# %%
i=0
plt.figure(figsize=(20,5))
plt.plot(train_scaled[:,i])
plt.plot(range(train_size, train_size+test_size),test_scaled[:,i])

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
def build_rnn(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.SimpleRNN(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_lstm(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(input_layer)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
def build_multi_lstm(input_shape,n_units):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.LSTM(units=n_units, return_sequences=True,return_state=True)(input_layer)
    x = tfkl.LSTM(units=n_units, return_sequences=False,return_state=False)(x)
    x = tfkl.Flatten()(x)
    
    output_layer = tfkl.Dense(7)(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
models_array = []
history_array = []

epochs = 100
batch_size = 256

stride = 1
sequence_length = 200
X_train, y_train = extract_sequences(train_scaled,sequence_length,stride)
X_train.shape,y_train.shape
    
input_shape = X_train.shape[1:]

lstm_units = 256

models = [build_lstm, build_lstm]
models_lables = ['w/o lr schedule','w/ lr schedule']

for i,m in enumerate(models):

    model = m(input_shape,lstm_units)
    
    model.summary()
    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

    if(i==1):
        history = model.fit(
            X_train,
            y_train,
            validation_split=.1,
            epochs = epochs,
            batch_size = batch_size,
            callbacks = [
                tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
                #tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
            ]
        ).history
    else:
        history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.5, min_lr=1e-5)
        ]
    ).history
    models_array.append(model)
    history_array.append(history)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 200, 7)]          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 256)               270336
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 272,135
# Trainable params: 272,135
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 237/237 [==============================] - 10s 35ms/step - loss: 0.0063 - mae: 0.0454 - val_loss: 0.0015 - val_mae: 0.0272
# Epoch 2/100
# 237/237 [==============================] - 8s 33ms/step - loss: 0.0014 - mae: 0.0253 - val_loss: 0.0012 - val_mae: 0.0239
# Epoch 3/100
# 237/237 [==============================] - 8s 33ms/step - loss: 0.0012 - mae: 0.0229 - val_loss: 0.0011 - val_mae: 0.0234
# Epoch 4/100
# 237/237 [==============================] - 8s 34ms/step - loss: 0.0010 - mae: 0.0216 - val_loss: 0.0010 - val_mae: 0.0222
# Epoch 5/100
# 237/237 [==============================] - 8s 33ms/step - loss: 9.6888e-04 - mae: 0.0205 - val_loss: 0.0011 - val_mae: 0.0224
# Epoch 6/100
# 237/237 [==============================] - 8s 33ms/step - loss: 9.2379e-04 - mae: 0.0198 - val_loss: 8.9055e-04 - val_mae: 0.0200
# Epoch 7/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.9185e-04 - mae: 0.0194 - val_loss: 8.2057e-04 - val_mae: 0.0185
# Epoch 8/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.6708e-04 - mae: 0.0190 - val_loss: 8.2851e-04 - val_mae: 0.0186
# Epoch 9/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.5638e-04 - mae: 0.0188 - val_loss: 8.4931e-04 - val_mae: 0.0196
# Epoch 10/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.4334e-04 - mae: 0.0186 - val_loss: 8.5434e-04 - val_mae: 0.0192
# Epoch 11/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.2782e-04 - mae: 0.0183 - val_loss: 7.9861e-04 - val_mae: 0.0184
# Epoch 12/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.2193e-04 - mae: 0.0182 - val_loss: 7.6620e-04 - val_mae: 0.0176
# Epoch 13/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.1327e-04 - mae: 0.0180 - val_loss: 7.5875e-04 - val_mae: 0.0175
# Epoch 14/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.1275e-04 - mae: 0.0181 - val_loss: 7.7972e-04 - val_mae: 0.0180
# Epoch 15/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.0566e-04 - mae: 0.0179 - val_loss: 7.7888e-04 - val_mae: 0.0180
# Epoch 16/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.0296e-04 - mae: 0.0179 - val_loss: 7.7837e-04 - val_mae: 0.0180
# Epoch 17/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.0313e-04 - mae: 0.0179 - val_loss: 7.5286e-04 - val_mae: 0.0174
# Epoch 18/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.0511e-04 - mae: 0.0180 - val_loss: 8.1184e-04 - val_mae: 0.0187
# Epoch 19/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.9653e-04 - mae: 0.0178 - val_loss: 8.0059e-04 - val_mae: 0.0182
# Epoch 20/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.9289e-04 - mae: 0.0177 - val_loss: 7.6497e-04 - val_mae: 0.0175
# Epoch 21/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.9217e-04 - mae: 0.0177 - val_loss: 8.6387e-04 - val_mae: 0.0193
# Epoch 22/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.9960e-04 - mae: 0.0178 - val_loss: 7.4125e-04 - val_mae: 0.0171
# Epoch 23/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6615e-04 - mae: 0.0172 - val_loss: 7.4965e-04 - val_mae: 0.0174
# Epoch 24/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6678e-04 - mae: 0.0172 - val_loss: 7.2658e-04 - val_mae: 0.0170
# Epoch 25/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6458e-04 - mae: 0.0172 - val_loss: 7.2873e-04 - val_mae: 0.0169
# Epoch 26/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6468e-04 - mae: 0.0172 - val_loss: 7.3434e-04 - val_mae: 0.0171
# Epoch 27/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6126e-04 - mae: 0.0171 - val_loss: 7.3140e-04 - val_mae: 0.0168
# Epoch 28/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6428e-04 - mae: 0.0171 - val_loss: 7.3185e-04 - val_mae: 0.0171
# Epoch 29/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.5931e-04 - mae: 0.0171 - val_loss: 7.2214e-04 - val_mae: 0.0167
# Epoch 30/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6000e-04 - mae: 0.0171 - val_loss: 7.1634e-04 - val_mae: 0.0167
# Epoch 31/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5882e-04 - mae: 0.0171 - val_loss: 7.1380e-04 - val_mae: 0.0166
# Epoch 32/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5768e-04 - mae: 0.0171 - val_loss: 7.3188e-04 - val_mae: 0.0172
# Epoch 33/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4509e-04 - mae: 0.0168 - val_loss: 7.0606e-04 - val_mae: 0.0164
# Epoch 34/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.4105e-04 - mae: 0.0167 - val_loss: 7.2102e-04 - val_mae: 0.0168
# Epoch 35/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4127e-04 - mae: 0.0167 - val_loss: 7.1175e-04 - val_mae: 0.0166
# Epoch 36/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4241e-04 - mae: 0.0168 - val_loss: 7.0291e-04 - val_mae: 0.0163
# Epoch 37/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4196e-04 - mae: 0.0167 - val_loss: 7.1055e-04 - val_mae: 0.0165
# Epoch 38/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.4082e-04 - mae: 0.0167 - val_loss: 6.9935e-04 - val_mae: 0.0164
# Epoch 39/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3976e-04 - mae: 0.0167 - val_loss: 7.0836e-04 - val_mae: 0.0164
# Epoch 40/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3965e-04 - mae: 0.0167 - val_loss: 7.1746e-04 - val_mae: 0.0168
# Epoch 41/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.3966e-04 - mae: 0.0167 - val_loss: 7.0552e-04 - val_mae: 0.0166
# Epoch 42/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4082e-04 - mae: 0.0168 - val_loss: 6.9999e-04 - val_mae: 0.0164
# Epoch 43/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2746e-04 - mae: 0.0165 - val_loss: 6.9379e-04 - val_mae: 0.0162
# Epoch 44/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2771e-04 - mae: 0.0165 - val_loss: 6.9460e-04 - val_mae: 0.0162
# Epoch 45/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2702e-04 - mae: 0.0165 - val_loss: 6.9232e-04 - val_mae: 0.0161
# Epoch 46/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2626e-04 - mae: 0.0165 - val_loss: 6.9497e-04 - val_mae: 0.0163
# Epoch 47/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2663e-04 - mae: 0.0165 - val_loss: 6.9380e-04 - val_mae: 0.0163
# Epoch 48/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2595e-04 - mae: 0.0164 - val_loss: 6.9330e-04 - val_mae: 0.0162
# Epoch 49/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2659e-04 - mae: 0.0165 - val_loss: 6.9328e-04 - val_mae: 0.0163
# Epoch 50/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2503e-04 - mae: 0.0165 - val_loss: 7.0601e-04 - val_mae: 0.0166
# Epoch 51/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2592e-04 - mae: 0.0165 - val_loss: 7.0606e-04 - val_mae: 0.0164
# Epoch 52/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2633e-04 - mae: 0.0165 - val_loss: 6.9176e-04 - val_mae: 0.0161
# Epoch 53/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1921e-04 - mae: 0.0163 - val_loss: 6.8781e-04 - val_mae: 0.0161
# Epoch 54/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1878e-04 - mae: 0.0163 - val_loss: 6.8824e-04 - val_mae: 0.0162
# Epoch 55/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1905e-04 - mae: 0.0163 - val_loss: 6.8626e-04 - val_mae: 0.0160
# Epoch 56/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1859e-04 - mae: 0.0163 - val_loss: 6.9275e-04 - val_mae: 0.0162
# Epoch 57/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1764e-04 - mae: 0.0163 - val_loss: 6.8709e-04 - val_mae: 0.0161
# Epoch 58/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1880e-04 - mae: 0.0163 - val_loss: 6.8755e-04 - val_mae: 0.0161
# Epoch 59/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1805e-04 - mae: 0.0163 - val_loss: 6.8958e-04 - val_mae: 0.0162
# Epoch 60/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1752e-04 - mae: 0.0163 - val_loss: 6.8826e-04 - val_mae: 0.0161
# Epoch 61/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1820e-04 - mae: 0.0163 - val_loss: 6.8469e-04 - val_mae: 0.0161
# Epoch 62/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1672e-04 - mae: 0.0163 - val_loss: 6.9116e-04 - val_mae: 0.0161
# Epoch 63/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1407e-04 - mae: 0.0162 - val_loss: 6.8441e-04 - val_mae: 0.0160
# Epoch 64/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1340e-04 - mae: 0.0162 - val_loss: 6.8587e-04 - val_mae: 0.0161
# Epoch 65/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1333e-04 - mae: 0.0162 - val_loss: 6.8803e-04 - val_mae: 0.0161
# Epoch 66/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1333e-04 - mae: 0.0162 - val_loss: 6.8472e-04 - val_mae: 0.0161
# Epoch 67/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1305e-04 - mae: 0.0162 - val_loss: 6.8513e-04 - val_mae: 0.0161
# Epoch 68/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1332e-04 - mae: 0.0162 - val_loss: 6.8554e-04 - val_mae: 0.0160
# Epoch 69/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1247e-04 - mae: 0.0162 - val_loss: 6.8236e-04 - val_mae: 0.0160
# Epoch 70/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1240e-04 - mae: 0.0162 - val_loss: 6.8420e-04 - val_mae: 0.0161
# Epoch 71/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1325e-04 - mae: 0.0162 - val_loss: 6.8355e-04 - val_mae: 0.0160
# Epoch 72/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1193e-04 - mae: 0.0162 - val_loss: 6.8477e-04 - val_mae: 0.0161
# Epoch 73/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1048e-04 - mae: 0.0162 - val_loss: 6.8118e-04 - val_mae: 0.0160
# Epoch 74/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1004e-04 - mae: 0.0162 - val_loss: 6.8257e-04 - val_mae: 0.0160
# Epoch 75/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1008e-04 - mae: 0.0162 - val_loss: 6.8260e-04 - val_mae: 0.0160
# Epoch 76/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1004e-04 - mae: 0.0162 - val_loss: 6.8262e-04 - val_mae: 0.0160
# Epoch 77/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0995e-04 - mae: 0.0162 - val_loss: 6.8242e-04 - val_mae: 0.0160
# Epoch 78/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1008e-04 - mae: 0.0162 - val_loss: 6.8278e-04 - val_mae: 0.0160
# Epoch 79/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1017e-04 - mae: 0.0162 - val_loss: 6.8201e-04 - val_mae: 0.0160
# Epoch 80/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0971e-04 - mae: 0.0162 - val_loss: 6.8082e-04 - val_mae: 0.0160
# Epoch 81/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0954e-04 - mae: 0.0162 - val_loss: 6.8283e-04 - val_mae: 0.0160
# Epoch 82/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0951e-04 - mae: 0.0162 - val_loss: 6.8361e-04 - val_mae: 0.0160
# Epoch 83/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0875e-04 - mae: 0.0162 - val_loss: 6.8144e-04 - val_mae: 0.0160
# Epoch 84/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0867e-04 - mae: 0.0161 - val_loss: 6.8142e-04 - val_mae: 0.0160
# Epoch 85/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0865e-04 - mae: 0.0162 - val_loss: 6.8132e-04 - val_mae: 0.0160
# Epoch 86/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0844e-04 - mae: 0.0161 - val_loss: 6.8115e-04 - val_mae: 0.0159
# Epoch 87/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0853e-04 - mae: 0.0162 - val_loss: 6.8179e-04 - val_mae: 0.0160
# Epoch 88/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0855e-04 - mae: 0.0161 - val_loss: 6.8134e-04 - val_mae: 0.0160
# Epoch 89/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0867e-04 - mae: 0.0161 - val_loss: 6.8141e-04 - val_mae: 0.0160
# Epoch 90/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0837e-04 - mae: 0.0161 - val_loss: 6.8132e-04 - val_mae: 0.0159
# Epoch 91/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0827e-04 - mae: 0.0161 - val_loss: 6.8256e-04 - val_mae: 0.0160
# Epoch 92/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0825e-04 - mae: 0.0161 - val_loss: 6.8155e-04 - val_mae: 0.0160
# Epoch 93/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0791e-04 - mae: 0.0161 - val_loss: 6.8293e-04 - val_mae: 0.0160
# Epoch 94/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0813e-04 - mae: 0.0161 - val_loss: 6.8125e-04 - val_mae: 0.0160
# Epoch 95/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0804e-04 - mae: 0.0161 - val_loss: 6.8164e-04 - val_mae: 0.0160
# Epoch 96/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0804e-04 - mae: 0.0161 - val_loss: 6.8101e-04 - val_mae: 0.0160
# Epoch 97/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0794e-04 - mae: 0.0161 - val_loss: 6.8118e-04 - val_mae: 0.0160
# Epoch 98/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0771e-04 - mae: 0.0161 - val_loss: 6.8188e-04 - val_mae: 0.0160
# Epoch 99/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0787e-04 - mae: 0.0161 - val_loss: 6.8058e-04 - val_mae: 0.0160
# Epoch 100/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0802e-04 - mae: 0.0161 - val_loss: 6.8207e-04 - val_mae: 0.0160
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 200, 7)]          0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 256)               270336
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 272,135
# Trainable params: 272,135
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 237/237 [==============================] - 9s 35ms/step - loss: 0.0057 - mae: 0.0439 - val_loss: 0.0015 - val_mae: 0.0272
# Epoch 2/100
# 237/237 [==============================] - 8s 33ms/step - loss: 0.0014 - mae: 0.0251 - val_loss: 0.0012 - val_mae: 0.0248
# Epoch 3/100
# 237/237 [==============================] - 8s 34ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 0.0011 - val_mae: 0.0227
# Epoch 4/100
# 237/237 [==============================] - 8s 33ms/step - loss: 0.0010 - mae: 0.0213 - val_loss: 0.0010 - val_mae: 0.0219
# Epoch 5/100
# 237/237 [==============================] - 8s 33ms/step - loss: 9.6385e-04 - mae: 0.0204 - val_loss: 0.0011 - val_mae: 0.0228
# Epoch 6/100
# 237/237 [==============================] - 8s 33ms/step - loss: 9.1564e-04 - mae: 0.0197 - val_loss: 9.3719e-04 - val_mae: 0.0211
# Epoch 7/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.9017e-04 - mae: 0.0193 - val_loss: 8.2226e-04 - val_mae: 0.0186
# Epoch 8/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.6190e-04 - mae: 0.0189 - val_loss: 8.2900e-04 - val_mae: 0.0186
# Epoch 9/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.4975e-04 - mae: 0.0187 - val_loss: 8.9438e-04 - val_mae: 0.0208
# Epoch 10/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.4506e-04 - mae: 0.0186 - val_loss: 8.4027e-04 - val_mae: 0.0188
# Epoch 11/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.2517e-04 - mae: 0.0182 - val_loss: 8.0117e-04 - val_mae: 0.0183
# Epoch 12/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.2740e-04 - mae: 0.0183 - val_loss: 7.6474e-04 - val_mae: 0.0177
# Epoch 13/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.1700e-04 - mae: 0.0181 - val_loss: 7.6662e-04 - val_mae: 0.0175
# Epoch 14/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.1743e-04 - mae: 0.0181 - val_loss: 7.9558e-04 - val_mae: 0.0183
# Epoch 15/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.1049e-04 - mae: 0.0179 - val_loss: 7.8629e-04 - val_mae: 0.0179
# Epoch 16/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.0751e-04 - mae: 0.0179 - val_loss: 7.7209e-04 - val_mae: 0.0177
# Epoch 17/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.0451e-04 - mae: 0.0178 - val_loss: 7.6447e-04 - val_mae: 0.0176
# Epoch 18/100
# 237/237 [==============================] - 8s 33ms/step - loss: 8.1047e-04 - mae: 0.0180 - val_loss: 8.0062e-04 - val_mae: 0.0184
# Epoch 19/100
# 237/237 [==============================] - 8s 34ms/step - loss: 8.0081e-04 - mae: 0.0178 - val_loss: 8.4480e-04 - val_mae: 0.0187
# Epoch 20/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.9689e-04 - mae: 0.0177 - val_loss: 7.7676e-04 - val_mae: 0.0176
# Epoch 21/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.9626e-04 - mae: 0.0177 - val_loss: 8.5408e-04 - val_mae: 0.0192
# Epoch 22/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.9982e-04 - mae: 0.0178 - val_loss: 7.4370e-04 - val_mae: 0.0171
# Epoch 23/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.9200e-04 - mae: 0.0176 - val_loss: 7.7319e-04 - val_mae: 0.0183
# Epoch 24/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.9187e-04 - mae: 0.0176 - val_loss: 7.2621e-04 - val_mae: 0.0169
# Epoch 25/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.8348e-04 - mae: 0.0175 - val_loss: 7.5925e-04 - val_mae: 0.0176
# Epoch 26/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.7934e-04 - mae: 0.0175 - val_loss: 7.3506e-04 - val_mae: 0.0171
# Epoch 27/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.7400e-04 - mae: 0.0174 - val_loss: 8.0062e-04 - val_mae: 0.0184
# Epoch 28/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.7618e-04 - mae: 0.0174 - val_loss: 7.5436e-04 - val_mae: 0.0177
# Epoch 29/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.7867e-04 - mae: 0.0175 - val_loss: 7.4623e-04 - val_mae: 0.0172
# Epoch 30/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.7451e-04 - mae: 0.0173 - val_loss: 7.6854e-04 - val_mae: 0.0180
# Epoch 31/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.7004e-04 - mae: 0.0173 - val_loss: 7.3972e-04 - val_mae: 0.0171
# Epoch 32/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.6536e-04 - mae: 0.0172 - val_loss: 7.2355e-04 - val_mae: 0.0168
# Epoch 33/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6494e-04 - mae: 0.0172 - val_loss: 7.4102e-04 - val_mae: 0.0170
# Epoch 34/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.7028e-04 - mae: 0.0173 - val_loss: 7.2931e-04 - val_mae: 0.0172
# Epoch 35/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5736e-04 - mae: 0.0171 - val_loss: 7.3014e-04 - val_mae: 0.0169
# Epoch 36/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.6293e-04 - mae: 0.0172 - val_loss: 7.4585e-04 - val_mae: 0.0172
# Epoch 37/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.6009e-04 - mae: 0.0171 - val_loss: 7.1714e-04 - val_mae: 0.0168
# Epoch 38/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5306e-04 - mae: 0.0170 - val_loss: 7.4601e-04 - val_mae: 0.0173
# Epoch 39/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5878e-04 - mae: 0.0171 - val_loss: 7.1826e-04 - val_mae: 0.0168
# Epoch 40/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.5077e-04 - mae: 0.0170 - val_loss: 7.2169e-04 - val_mae: 0.0172
# Epoch 41/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5270e-04 - mae: 0.0171 - val_loss: 7.0193e-04 - val_mae: 0.0164
# Epoch 42/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.5821e-04 - mae: 0.0172 - val_loss: 7.3798e-04 - val_mae: 0.0174
# Epoch 43/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4910e-04 - mae: 0.0170 - val_loss: 7.1741e-04 - val_mae: 0.0168
# Epoch 44/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.4995e-04 - mae: 0.0171 - val_loss: 7.1199e-04 - val_mae: 0.0166
# Epoch 45/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.4605e-04 - mae: 0.0169 - val_loss: 7.0860e-04 - val_mae: 0.0165
# Epoch 46/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4444e-04 - mae: 0.0169 - val_loss: 7.1640e-04 - val_mae: 0.0166
# Epoch 47/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4476e-04 - mae: 0.0169 - val_loss: 7.1875e-04 - val_mae: 0.0169
# Epoch 48/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4427e-04 - mae: 0.0169 - val_loss: 7.2384e-04 - val_mae: 0.0170
# Epoch 49/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.4505e-04 - mae: 0.0170 - val_loss: 7.0701e-04 - val_mae: 0.0166
# Epoch 50/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4003e-04 - mae: 0.0168 - val_loss: 7.1985e-04 - val_mae: 0.0169
# Epoch 51/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.4099e-04 - mae: 0.0169 - val_loss: 7.3270e-04 - val_mae: 0.0168
# Epoch 52/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3763e-04 - mae: 0.0168 - val_loss: 7.3784e-04 - val_mae: 0.0173
# Epoch 53/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3746e-04 - mae: 0.0168 - val_loss: 7.1231e-04 - val_mae: 0.0167
# Epoch 54/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3745e-04 - mae: 0.0168 - val_loss: 7.1184e-04 - val_mae: 0.0167
# Epoch 55/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3642e-04 - mae: 0.0168 - val_loss: 6.9792e-04 - val_mae: 0.0164
# Epoch 56/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.3484e-04 - mae: 0.0168 - val_loss: 7.1212e-04 - val_mae: 0.0166
# Epoch 57/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.3705e-04 - mae: 0.0168 - val_loss: 7.4537e-04 - val_mae: 0.0177
# Epoch 58/100
# 237/237 [==============================] - 8s 35ms/step - loss: 7.3511e-04 - mae: 0.0168 - val_loss: 7.0024e-04 - val_mae: 0.0164
# Epoch 59/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.3481e-04 - mae: 0.0168 - val_loss: 7.0733e-04 - val_mae: 0.0167
# Epoch 60/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.3032e-04 - mae: 0.0167 - val_loss: 7.0649e-04 - val_mae: 0.0164
# Epoch 61/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2841e-04 - mae: 0.0166 - val_loss: 7.0179e-04 - val_mae: 0.0165
# Epoch 62/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2593e-04 - mae: 0.0166 - val_loss: 7.0037e-04 - val_mae: 0.0163
# Epoch 63/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.3231e-04 - mae: 0.0168 - val_loss: 7.0772e-04 - val_mae: 0.0166
# Epoch 64/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2782e-04 - mae: 0.0167 - val_loss: 6.9807e-04 - val_mae: 0.0162
# Epoch 65/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2570e-04 - mae: 0.0166 - val_loss: 7.0873e-04 - val_mae: 0.0165
# Epoch 66/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2576e-04 - mae: 0.0166 - val_loss: 6.9432e-04 - val_mae: 0.0163
# Epoch 67/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2487e-04 - mae: 0.0166 - val_loss: 7.2788e-04 - val_mae: 0.0172
# Epoch 68/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2465e-04 - mae: 0.0166 - val_loss: 7.1431e-04 - val_mae: 0.0166
# Epoch 69/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2421e-04 - mae: 0.0167 - val_loss: 7.0229e-04 - val_mae: 0.0166
# Epoch 70/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2323e-04 - mae: 0.0166 - val_loss: 7.0594e-04 - val_mae: 0.0167
# Epoch 71/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.2281e-04 - mae: 0.0166 - val_loss: 6.9363e-04 - val_mae: 0.0162
# Epoch 72/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.2144e-04 - mae: 0.0166 - val_loss: 6.9373e-04 - val_mae: 0.0165
# Epoch 73/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1994e-04 - mae: 0.0166 - val_loss: 6.9074e-04 - val_mae: 0.0164
# Epoch 74/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1853e-04 - mae: 0.0165 - val_loss: 7.1862e-04 - val_mae: 0.0168
# Epoch 75/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1959e-04 - mae: 0.0166 - val_loss: 6.9815e-04 - val_mae: 0.0164
# Epoch 76/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1978e-04 - mae: 0.0166 - val_loss: 6.9890e-04 - val_mae: 0.0163
# Epoch 77/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1837e-04 - mae: 0.0166 - val_loss: 7.1695e-04 - val_mae: 0.0171
# Epoch 78/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1662e-04 - mae: 0.0165 - val_loss: 7.0120e-04 - val_mae: 0.0166
# Epoch 79/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1578e-04 - mae: 0.0165 - val_loss: 6.9399e-04 - val_mae: 0.0164
# Epoch 80/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1448e-04 - mae: 0.0165 - val_loss: 6.8677e-04 - val_mae: 0.0162
# Epoch 81/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1227e-04 - mae: 0.0165 - val_loss: 7.1951e-04 - val_mae: 0.0171
# Epoch 82/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1453e-04 - mae: 0.0165 - val_loss: 6.9631e-04 - val_mae: 0.0165
# Epoch 83/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1369e-04 - mae: 0.0165 - val_loss: 7.1286e-04 - val_mae: 0.0169
# Epoch 84/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.1333e-04 - mae: 0.0165 - val_loss: 7.2670e-04 - val_mae: 0.0171
# Epoch 85/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1345e-04 - mae: 0.0165 - val_loss: 7.0187e-04 - val_mae: 0.0166
# Epoch 86/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0992e-04 - mae: 0.0164 - val_loss: 6.9140e-04 - val_mae: 0.0164
# Epoch 87/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1018e-04 - mae: 0.0164 - val_loss: 6.8555e-04 - val_mae: 0.0162
# Epoch 88/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0912e-04 - mae: 0.0165 - val_loss: 7.0710e-04 - val_mae: 0.0168
# Epoch 89/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0686e-04 - mae: 0.0164 - val_loss: 6.9282e-04 - val_mae: 0.0161
# Epoch 90/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0685e-04 - mae: 0.0164 - val_loss: 7.0208e-04 - val_mae: 0.0166
# Epoch 91/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0727e-04 - mae: 0.0164 - val_loss: 7.0602e-04 - val_mae: 0.0170
# Epoch 92/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0765e-04 - mae: 0.0165 - val_loss: 6.8697e-04 - val_mae: 0.0163
# Epoch 93/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0321e-04 - mae: 0.0164 - val_loss: 7.3043e-04 - val_mae: 0.0170
# Epoch 94/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.1367e-04 - mae: 0.0165 - val_loss: 6.9870e-04 - val_mae: 0.0164
# Epoch 95/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0380e-04 - mae: 0.0164 - val_loss: 6.8682e-04 - val_mae: 0.0163
# Epoch 96/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0364e-04 - mae: 0.0164 - val_loss: 6.9649e-04 - val_mae: 0.0163
# Epoch 97/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0409e-04 - mae: 0.0164 - val_loss: 6.9987e-04 - val_mae: 0.0163
# Epoch 98/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0143e-04 - mae: 0.0164 - val_loss: 7.0227e-04 - val_mae: 0.0164
# Epoch 99/100
# 237/237 [==============================] - 8s 34ms/step - loss: 7.0278e-04 - mae: 0.0164 - val_loss: 6.8940e-04 - val_mae: 0.0163
# Epoch 100/100
# 237/237 [==============================] - 8s 33ms/step - loss: 7.0191e-04 - mae: 0.0164 - val_loss: 6.8311e-04 - val_mae: 0.0161

# %%
future_window = 500

# %%
def autoregression_pred(model,window):
    last_window = train_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape

    pred = np.array([])
    X_temp = last_window
    for t in range(future_window):
        pred_temp = model.predict(X_temp)
        pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,1:,:],pred_temp), axis=1)
        
    pred_scaled = pred[0]*(train_max-train_min)+train_min
    return pred_scaled

# %%
def compute_err(pred_scaled,return_values=True):
    rmse = np.sqrt(tfk.metrics.mse(test_raw[:future_window].flatten(),pred_scaled.flatten()))
    mae = (tfk.metrics.mae(test_raw[:future_window].flatten(),pred_scaled.flatten())).numpy()
    print("RMSE: " + str(rmse) + "  MAE: " + str(mae))
    if(return_values):
        return rmse,mae

# %%
pred_array = []
for i,model in enumerate(models_array):
    pred_array.append(autoregression_pred(model,sequence_length))

# %%
best_rmse = 1e7
best_model = 0

for i,pred in enumerate(pred_array):
    rmse,mae = compute_err(pred)
    if(rmse < best_rmse):
        best_rmse = rmse
        best_model = i
        
print("\nBest model is " + str(models_lables[best_model]))
# Out:
# RMSE: 3.5057690146710208  MAE: 2.1294862960908336
# RMSE: 17.890821197902095  MAE: 10.202458674770826
#
# Best model is w/o lr schedule

# %%
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
window = sequence_length
for i in range(7):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
fig_size = (15,5)
plt.figure(figsize=fig_size)


for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['loss'], label='Training loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_loss'], label='Validation loss '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch ' + models_lables[i], alpha=.5, ls='--',color=c)

plt.title('Mean Squared Error (Loss)')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)

for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['mae'], label='Training accuracy '+ models_lables[i],alpha=alpha_val,color=c)
    plt.plot(history['val_mae'], label='Validation accuracy '+ models_lables[i],alpha=alpha_val,ls='--',color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=.5, ls='--',color=c)
    
plt.title('Mean Absolute Error')
#plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
for i,history in enumerate(history_array):
    if(i!=best_model): 
        alpha_val = 0.35
        c = colors[i]
    else: 
        alpha_val = 1
        c = '#ff0000'
    best_epoch = np.argmin(history['val_loss'])
    plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
    plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)

plt.legend()
plt.grid(alpha=.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_34/1472302361.py in <module>
#      48         c = '#ff0000'
#      49     best_epoch = np.argmin(history['val_loss'])
# ---> 50     plt.plot(history['lr'], label='Learning Rate '+ models_lables[i],alpha=alpha_val,color=c)
#      51     plt.axvline(x=best_epoch, label='Best epoch '+ models_lables[i], alpha=alpha_val, ls='--',color=c)
#      52
#
# KeyError: 'lr'

# %%
#PAPER PLOTS

window = 100
future_window = 400
colors = ['#7d34fa','#fa34f3','#032cfc','#ff006f','#00ffd5','#62ff57']
for i in range(7):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),train_raw[-window:,i],color="steelblue")
    plt.plot(range(window,window+future_window),test_raw[:future_window,i],color="steelblue",alpha=.7)
    for j,pred in enumerate(pred_array):
        if(j!=best_model): 
            alpha_val = 0.35
            c = colors[j]
        else: 
            alpha_val = 1
            c = '#ff0000'
        plt.plot(range(window,window+future_window),pred[:future_window,i],label=models_lables[j],alpha=alpha_val,color=c)
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.title('Feature ' + str(i) + ' predictions')
    plt.legend()

# %%
import shutil
from os import path
def save_model(model,filename):
    model.save(filename)
    src = path.realpath(filename)
    root_dir, tail = path.split(src)
    shutil.make_archive(filename, 'zip', filename)
    print(filename + ' saved!')

# %%
save_model(models_array[best_model],'model')
#save_model(model_2,'model_2')

# %%
#!rm -r model model.zip model_1 model_1.zip model_2 model_2.zip
#!zip -r model.zip model
#model = tfk.models.load_model('model')
