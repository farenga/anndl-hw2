# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2data/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2data/Training.csv',delimiter=',',skip_header=True)

# %%
# Pre-processing

X_max = X.max(axis=0)
X_min = X.min(axis=0)

X_mean = X.mean(axis=0)
X_std = X.std(axis=0)

X_scaled = (X-X_min)/(X_max-X_min)

# %%
#for i in range(X.shape[-1]):
i=0
plt.figure(figsize=(20,3))
plt.plot(X[:,i],color='steelblue')
plt.plot(X_scaled[:,i],color='limegreen',alpha=.5)
plt.axhline(y=X_mean[i],color='darkorange',linewidth=2)
plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)
plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,future=1,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length+future < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length:i+sequence_length+future])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
stride = 1
sequence_length = 200
future = 2
X_train, y_train = extract_sequences(X_scaled,sequence_length, future, stride)
X_train.shape,y_train.shape
# Out:
# ((68326, 200, 7), (68326, 2, 7))

# %%
def build_conv(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x1 = tfkl.MaxPooling1D()(x)

    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = True,return_state=True)(x1,initial_state=[h1,c1])

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x1)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Add()([x1,x])
    x1 = tfkl.MaxPooling1D()(x)
    
    x1,h1,c1 = tfkl.LSTM(units=256,return_sequences = False,return_state=True)(x1,initial_state=[h1,c1])
       
    x = tfkl.Flatten()(x1)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    x = tfkl.Dense(256,activation='relu')(x)
    x = tfkl.Dropout(.2)(x)
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
input_shape = X_train.shape[1:]

model = build_conv(input_shape)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 200, 7)]     0
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 200, 16)      352         Input[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 200, 32)      1568        conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 200, 64)      6208        conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 200, 128)     24704       conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 200, 256)     98560       conv1d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 256)     1024        conv1d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 100, 256)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 100, 256), ( 525312      max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 100, 16)      12304       lstm_4[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 100, 32)      1568        conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 100, 64)      6208        conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 100, 128)     24704       conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 100, 256)     98560       conv1d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100, 256)     1024        conv1d_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 256)     0           lstm_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 50, 256)      0           add_3[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 50, 256), (N 525312      max_pooling1d_5[0][0]
#                                                                  lstm_4[0][1]
#                                                                  lstm_4[0][2]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 50, 16)       12304       lstm_5[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 50, 32)       1568        conv1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 50, 64)       6208        conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 50, 128)      24704       conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 50, 256)      98560       conv1d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 256)      1024        conv1d_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 256)      0           lstm_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 25, 256)      0           add_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 25, 256), (N 525312      max_pooling1d_6[0][0]
#                                                                  lstm_5[0][1]
#                                                                  lstm_5[0][2]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 25, 16)       12304       lstm_6[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 25, 32)       1568        conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 25, 64)       6208        conv1d_40[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 25, 128)      24704       conv1d_41[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 25, 256)      98560       conv1d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 256)      1024        conv1d_43[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 256)      0           lstm_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 12, 256)      0           add_5[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, 256), (None, 525312      max_pooling1d_7[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           lstm_7[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          65792       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 14)           3598        dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 7)         0           dense_3[0][0]
# ==================================================================================================
# Total params: 2,736,158
# Trainable params: 2,734,110
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %%
tfk.utils.plot_model(model, expand_nested=False)

# %%
epochs = 300
batch_size = 256

model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.7, min_lr=1e-5)
        ]
    ).history
# Out:
# Epoch 1/300
# 241/241 [==============================] - 39s 134ms/step - loss: 0.0134 - mae: 0.0829 - val_loss: 0.0983 - val_mae: 0.2828
# Epoch 2/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0046 - mae: 0.0525 - val_loss: 0.0103 - val_mae: 0.0841
# Epoch 3/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0034 - mae: 0.0451 - val_loss: 0.0037 - val_mae: 0.0499
# Epoch 4/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0030 - mae: 0.0417 - val_loss: 0.0042 - val_mae: 0.0495
# Epoch 5/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0027 - mae: 0.0394 - val_loss: 0.0022 - val_mae: 0.0361
# Epoch 6/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0024 - mae: 0.0369 - val_loss: 0.0020 - val_mae: 0.0330
# Epoch 7/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0022 - mae: 0.0355 - val_loss: 0.0021 - val_mae: 0.0356
# Epoch 8/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0020 - mae: 0.0340 - val_loss: 0.0022 - val_mae: 0.0355
# Epoch 9/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0019 - mae: 0.0330 - val_loss: 0.0017 - val_mae: 0.0307
# Epoch 10/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0018 - mae: 0.0317 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 11/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0017 - mae: 0.0311 - val_loss: 0.0017 - val_mae: 0.0302
# Epoch 12/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0026 - val_mae: 0.0415
# Epoch 13/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0016 - mae: 0.0296 - val_loss: 0.0018 - val_mae: 0.0314
# Epoch 14/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0015 - mae: 0.0287 - val_loss: 0.0017 - val_mae: 0.0301
# Epoch 15/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0015 - mae: 0.0282 - val_loss: 0.0012 - val_mae: 0.0254
# Epoch 16/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0018 - val_mae: 0.0318
# Epoch 17/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0013 - mae: 0.0269 - val_loss: 0.0012 - val_mae: 0.0246
# Epoch 18/300
# 241/241 [==============================] - 30s 125ms/step - loss: 0.0013 - mae: 0.0267 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 19/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0013 - val_mae: 0.0252
# Epoch 20/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0012 - mae: 0.0258 - val_loss: 0.0012 - val_mae: 0.0244
# Epoch 21/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 0.0015 - val_mae: 0.0289
# Epoch 22/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0012 - mae: 0.0255 - val_loss: 0.0014 - val_mae: 0.0275
# Epoch 23/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0012 - mae: 0.0247 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 24/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0012 - val_mae: 0.0250
# Epoch 25/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0014 - val_mae: 0.0271
# Epoch 26/300
# 241/241 [==============================] - 30s 124ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0026 - val_mae: 0.0386
# Epoch 27/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.9227e-04 - mae: 0.0228 - val_loss: 0.0015 - val_mae: 0.0291
# Epoch 28/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.8543e-04 - mae: 0.0228 - val_loss: 0.0020 - val_mae: 0.0342
# Epoch 29/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.6404e-04 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0262
# Epoch 30/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.5483e-04 - mae: 0.0224 - val_loss: 0.0016 - val_mae: 0.0312
# Epoch 31/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.4598e-04 - mae: 0.0223 - val_loss: 0.0013 - val_mae: 0.0278
# Epoch 32/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.3627e-04 - mae: 0.0222 - val_loss: 0.0015 - val_mae: 0.0289
# Epoch 33/300
# 241/241 [==============================] - 30s 124ms/step - loss: 9.3118e-04 - mae: 0.0221 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 34/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.9911e-04 - mae: 0.0218 - val_loss: 9.3770e-04 - val_mae: 0.0214
# Epoch 35/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.8601e-04 - mae: 0.0216 - val_loss: 0.0015 - val_mae: 0.0283
# Epoch 36/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.9902e-04 - mae: 0.0217 - val_loss: 0.0017 - val_mae: 0.0305
# Epoch 37/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.5146e-04 - mae: 0.0212 - val_loss: 9.0968e-04 - val_mae: 0.0211
# Epoch 38/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.5477e-04 - mae: 0.0213 - val_loss: 0.0012 - val_mae: 0.0258
# Epoch 39/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.4971e-04 - mae: 0.0212 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 40/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.2907e-04 - mae: 0.0209 - val_loss: 0.0011 - val_mae: 0.0240
# Epoch 41/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.1732e-04 - mae: 0.0208 - val_loss: 8.7423e-04 - val_mae: 0.0206
# Epoch 42/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.2117e-04 - mae: 0.0208 - val_loss: 0.0010 - val_mae: 0.0234
# Epoch 43/300
# 241/241 [==============================] - 30s 124ms/step - loss: 8.1204e-04 - mae: 0.0207 - val_loss: 8.7225e-04 - val_mae: 0.0208
# Epoch 44/300
# 241/241 [==============================] - 30s 124ms/step - loss: 7.9664e-04 - mae: 0.0204 - val_loss: 0.0011 - val_mae: 0.0243
# Epoch 45/300
# 241/241 [==============================] - 30s 125ms/step - loss: 7.2671e-04 - mae: 0.0196 - val_loss: 8.2666e-04 - val_mae: 0.0202
# Epoch 46/300
# 241/241 [==============================] - 30s 124ms/step - loss: 7.0777e-04 - mae: 0.0193 - val_loss: 7.6384e-04 - val_mae: 0.0195
# Epoch 47/300
# 241/241 [==============================] - 30s 124ms/step - loss: 7.0320e-04 - mae: 0.0193 - val_loss: 0.0010 - val_mae: 0.0235
# Epoch 48/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.9808e-04 - mae: 0.0192 - val_loss: 7.0276e-04 - val_mae: 0.0179
# Epoch 49/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.9073e-04 - mae: 0.0191 - val_loss: 8.8629e-04 - val_mae: 0.0212
# Epoch 50/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.8900e-04 - mae: 0.0191 - val_loss: 7.1414e-04 - val_mae: 0.0180
# Epoch 51/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.8443e-04 - mae: 0.0190 - val_loss: 0.0011 - val_mae: 0.0253
# Epoch 52/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.7361e-04 - mae: 0.0189 - val_loss: 6.8420e-04 - val_mae: 0.0177
# Epoch 53/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.6500e-04 - mae: 0.0187 - val_loss: 9.8065e-04 - val_mae: 0.0228
# Epoch 54/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.6102e-04 - mae: 0.0187 - val_loss: 8.5860e-04 - val_mae: 0.0210
# Epoch 55/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.5562e-04 - mae: 0.0186 - val_loss: 8.1559e-04 - val_mae: 0.0205
# Epoch 56/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.5578e-04 - mae: 0.0186 - val_loss: 7.8281e-04 - val_mae: 0.0198
# Epoch 57/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.5291e-04 - mae: 0.0185 - val_loss: 8.5102e-04 - val_mae: 0.0208
# Epoch 58/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.4437e-04 - mae: 0.0184 - val_loss: 7.2485e-04 - val_mae: 0.0185
# Epoch 59/300
# 241/241 [==============================] - 30s 124ms/step - loss: 6.0279e-04 - mae: 0.0178 - val_loss: 7.7210e-04 - val_mae: 0.0197
# Epoch 60/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.9471e-04 - mae: 0.0177 - val_loss: 9.6510e-04 - val_mae: 0.0222
# Epoch 61/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.8802e-04 - mae: 0.0176 - val_loss: 6.1208e-04 - val_mae: 0.0167
# Epoch 62/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.7931e-04 - mae: 0.0175 - val_loss: 5.9660e-04 - val_mae: 0.0165
# Epoch 63/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.7990e-04 - mae: 0.0175 - val_loss: 6.4673e-04 - val_mae: 0.0176
# Epoch 64/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.7822e-04 - mae: 0.0175 - val_loss: 9.3999e-04 - val_mae: 0.0225
# Epoch 65/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.7681e-04 - mae: 0.0175 - val_loss: 6.6491e-04 - val_mae: 0.0177
# Epoch 66/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.7159e-04 - mae: 0.0174 - val_loss: 8.7142e-04 - val_mae: 0.0213
# Epoch 67/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.6753e-04 - mae: 0.0173 - val_loss: 5.8705e-04 - val_mae: 0.0159
# Epoch 68/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.6845e-04 - mae: 0.0173 - val_loss: 7.0464e-04 - val_mae: 0.0183
# Epoch 69/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.6543e-04 - mae: 0.0173 - val_loss: 7.8402e-04 - val_mae: 0.0197
# Epoch 70/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.6017e-04 - mae: 0.0172 - val_loss: 6.5571e-04 - val_mae: 0.0178
# Epoch 71/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.5807e-04 - mae: 0.0172 - val_loss: 6.4157e-04 - val_mae: 0.0172
# Epoch 72/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.5306e-04 - mae: 0.0171 - val_loss: 5.9023e-04 - val_mae: 0.0163
# Epoch 73/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.3231e-04 - mae: 0.0168 - val_loss: 5.8594e-04 - val_mae: 0.0165
# Epoch 74/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.2493e-04 - mae: 0.0167 - val_loss: 5.5830e-04 - val_mae: 0.0156
# Epoch 75/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.2080e-04 - mae: 0.0166 - val_loss: 6.3382e-04 - val_mae: 0.0171
# Epoch 76/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.2321e-04 - mae: 0.0166 - val_loss: 5.7750e-04 - val_mae: 0.0160
# Epoch 77/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.1643e-04 - mae: 0.0165 - val_loss: 5.6362e-04 - val_mae: 0.0159
# Epoch 78/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.1049e-04 - mae: 0.0165 - val_loss: 5.7621e-04 - val_mae: 0.0158
# Epoch 79/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.1012e-04 - mae: 0.0165 - val_loss: 5.6943e-04 - val_mae: 0.0159
# Epoch 80/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.0573e-04 - mae: 0.0164 - val_loss: 5.6928e-04 - val_mae: 0.0155
# Epoch 81/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.0449e-04 - mae: 0.0164 - val_loss: 5.4537e-04 - val_mae: 0.0152
# Epoch 82/300
# 241/241 [==============================] - 30s 124ms/step - loss: 5.0651e-04 - mae: 0.0164 - val_loss: 6.2309e-04 - val_mae: 0.0169
# Epoch 83/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.8661e-04 - mae: 0.0161 - val_loss: 5.6686e-04 - val_mae: 0.0156
# Epoch 84/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.8109e-04 - mae: 0.0160 - val_loss: 5.6382e-04 - val_mae: 0.0157
# Epoch 85/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.8254e-04 - mae: 0.0160 - val_loss: 5.4255e-04 - val_mae: 0.0151
# Epoch 86/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.7724e-04 - mae: 0.0160 - val_loss: 5.6363e-04 - val_mae: 0.0154
# Epoch 87/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.7548e-04 - mae: 0.0160 - val_loss: 5.7997e-04 - val_mae: 0.0157
# Epoch 88/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.7715e-04 - mae: 0.0160 - val_loss: 5.4710e-04 - val_mae: 0.0150
# Epoch 89/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.7111e-04 - mae: 0.0159 - val_loss: 5.3445e-04 - val_mae: 0.0148
# Epoch 90/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.7154e-04 - mae: 0.0159 - val_loss: 5.8305e-04 - val_mae: 0.0161
# Epoch 91/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.7423e-04 - mae: 0.0159 - val_loss: 5.8722e-04 - val_mae: 0.0162
# Epoch 92/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.6796e-04 - mae: 0.0159 - val_loss: 5.3769e-04 - val_mae: 0.0149
# Epoch 93/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.5590e-04 - mae: 0.0156 - val_loss: 5.4769e-04 - val_mae: 0.0151
# Epoch 94/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.5214e-04 - mae: 0.0156 - val_loss: 5.7020e-04 - val_mae: 0.0154
# Epoch 95/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.5126e-04 - mae: 0.0156 - val_loss: 5.3598e-04 - val_mae: 0.0146
# Epoch 96/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.4843e-04 - mae: 0.0156 - val_loss: 5.2723e-04 - val_mae: 0.0145
# Epoch 97/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.4549e-04 - mae: 0.0155 - val_loss: 5.7928e-04 - val_mae: 0.0159
# Epoch 98/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.4659e-04 - mae: 0.0155 - val_loss: 5.4969e-04 - val_mae: 0.0149
# Epoch 99/300
# 241/241 [==============================] - 30s 125ms/step - loss: 4.4501e-04 - mae: 0.0155 - val_loss: 5.3948e-04 - val_mae: 0.0147
# Epoch 100/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.4507e-04 - mae: 0.0155 - val_loss: 5.5944e-04 - val_mae: 0.0151
# Epoch 101/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.4359e-04 - mae: 0.0155 - val_loss: 5.3765e-04 - val_mae: 0.0150
# Epoch 102/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.4381e-04 - mae: 0.0155 - val_loss: 5.4222e-04 - val_mae: 0.0146
# Epoch 103/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.3484e-04 - mae: 0.0153 - val_loss: 5.5498e-04 - val_mae: 0.0148
# Epoch 104/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2906e-04 - mae: 0.0152 - val_loss: 5.5148e-04 - val_mae: 0.0150
# Epoch 105/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2897e-04 - mae: 0.0152 - val_loss: 5.4168e-04 - val_mae: 0.0147
# Epoch 106/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2797e-04 - mae: 0.0152 - val_loss: 5.3886e-04 - val_mae: 0.0144
# Epoch 107/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2616e-04 - mae: 0.0152 - val_loss: 5.3865e-04 - val_mae: 0.0146
# Epoch 108/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2640e-04 - mae: 0.0152 - val_loss: 5.3618e-04 - val_mae: 0.0144
# Epoch 109/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2712e-04 - mae: 0.0152 - val_loss: 5.3306e-04 - val_mae: 0.0143
# Epoch 110/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2499e-04 - mae: 0.0152 - val_loss: 5.4461e-04 - val_mae: 0.0144
# Epoch 111/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2458e-04 - mae: 0.0152 - val_loss: 5.3549e-04 - val_mae: 0.0143
# Epoch 112/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.2340e-04 - mae: 0.0152 - val_loss: 5.5602e-04 - val_mae: 0.0148
# Epoch 113/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.1858e-04 - mae: 0.0151 - val_loss: 5.3886e-04 - val_mae: 0.0143
# Epoch 114/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.1614e-04 - mae: 0.0150 - val_loss: 5.3686e-04 - val_mae: 0.0143
# Epoch 115/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.1742e-04 - mae: 0.0151 - val_loss: 5.3438e-04 - val_mae: 0.0143
# Epoch 116/300
# 241/241 [==============================] - 30s 124ms/step - loss: 4.1478e-04 - mae: 0.0150 - val_loss: 5.3970e-04 - val_mae: 0.0145

# %%
future_window = 864

# %%
def autoregression_pred_multiout(model,window,future,future_window):
    last_window = X_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape
    pred = np.array([])
    X_temp = last_window
    for t in range(0,future_window,future):
        pred_temp = model.predict(X_temp)
        #pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,future:,:],pred_temp), axis=1)

    pred_scaled = pred[0]*(X_max-X_min)+X_min
    return pred_scaled

# %%
pred = autoregression_pred_multiout(model,sequence_length,future,future_window)

# %%
window = sequence_length
for i in range(pred.shape[-1]):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),X[-window:,i],color='steelblue')
    plt.plot(range(window,window+future_window),pred[:,i],color='lightblue')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)

# %%
future_window = 400
window = sequence_length
for i in range(pred.shape[-1]):
    plt.figure(figsize=(7,3))
    plt.plot(range(window),X[-window:,i],color='steelblue',label='past')
    plt.plot(range(window,window+future_window),pred[:future_window,i],color='lightblue',label='prediction')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-',label='mean')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5,label='std')
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.legend()

# %%
#for i in range(pred_scaled.shape[-1]):
#    plt.figure(figsize=(20,5))
#    plt.plot(range(window),train_scaled[-window:,i])
#    plt.plot(range(window,window+future_window),val_scaled[:future_window,i])
#    plt.plot(range(window,window+future_window),pred[0,:,i])

# %%
best_epoch = np.argmin(history['val_loss'])
fig_size = (15,5)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
best_epoch = np.argmin(history['val_loss'])
fig_size = (7,3)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# SCORE 3.9962544441

# %%
model.save('model')
#model = tfk.models.load_model('model')
# !zip -r model.zip model
# Out:
# 2022-01-19 11:55:44.694041: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
#   adding: model/ (stored 0%)
#   adding: model/saved_model.pb (deflated 90%)
#   adding: model/keras_metadata.pb (deflated 95%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.index (deflated 77%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: model/assets/ (stored 0%)
