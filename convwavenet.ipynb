# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.2

# %%
# Random seed for reproducibility
seed = 16

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_path = os.path.join('../input/anndlhw2data/Training.csv')

# %%
X = np.genfromtxt('../input/anndlhw2data/Training.csv',delimiter=',',skip_header=True)

# %%
# Pre-processing

X_max = X.max(axis=0)
X_min = X.min(axis=0)

X_mean = X.mean(axis=0)
X_std = X.std(axis=0)

X_scaled = (X-X_min)/(X_max-X_min)

# %%
#for i in range(X.shape[-1]):
i=0
plt.figure(figsize=(20,3))
plt.plot(X[:,i],color='steelblue')
plt.plot(X_scaled[:,i],color='limegreen',alpha=.5)
plt.axhline(y=X_mean[i],color='darkorange',linewidth=2)
plt.axhline(y=X_mean[i]+2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)
plt.axhline(y=X_mean[i]-2*X_std[i],color='magenta',alpha=.5,linestyle='--',linewidth=2)

# %%
# generate X, y
def extract_sequences(array,sequence_length = 200,future=1,stride=1,shuffle=True,seed=1):
   
    X = []
    y = []
    for i in range(0,len(array),stride):
        if i+sequence_length+future < len(array):
            X.append(array[i:i+sequence_length])
            y.append(array[i+sequence_length:i+sequence_length+future])
    X = np.array(X)
    y = np.array(y)
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(X)
        np.random.seed(seed)
        np.random.shuffle(y)
    return X, y

# %%
stride = 1
sequence_length = 200
future = 4
X_train, y_train = extract_sequences(X_scaled,sequence_length, future, stride)
X_train.shape,y_train.shape
# Out:
# ((68324, 200, 7), (68324, 4, 7))

# %%
def build_conv(input_shape):


    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(input_layer)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.MaxPool1D()(x)
    
    x = tfkl.Conv1D(filters=16,kernel_size=3,dilation_rate=1,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=32,kernel_size=3,dilation_rate=2,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=64,kernel_size=3,dilation_rate=4,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=128,kernel_size=3,dilation_rate=8,padding="causal",activation='relu')(x)
    x = tfkl.Conv1D(filters=256,kernel_size=3,dilation_rate=16,padding="causal",activation='relu')(x)
    x = tfkl.MaxPool1D()(x)

    x = tfkl.Flatten()(x)
    #x = tfkl.Concatenate()([tfkl.Flatten()(x), tfkl.Flatten()(x),tfkl.Flatten()(x2)])
    x = tfkl.Dense(7*future)(x)

    
    #x2 = tfkl.LSTM(units=256)(input_layer)
    
    output_layer = tfkl.Reshape((future,7))(x)
    
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    return model

# %%
input_shape = X_train.shape[1:]

model = build_conv(input_shape)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 200, 7)]          0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 200, 16)           352
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 200, 32)           1568
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 200, 64)           6208
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 200, 128)          24704
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 200, 256)          98560
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 100, 256)          0
# _________________________________________________________________
# conv1d_35 (Conv1D)           (None, 100, 16)           12304
# _________________________________________________________________
# conv1d_36 (Conv1D)           (None, 100, 32)           1568
# _________________________________________________________________
# conv1d_37 (Conv1D)           (None, 100, 64)           6208
# _________________________________________________________________
# conv1d_38 (Conv1D)           (None, 100, 128)          24704
# _________________________________________________________________
# conv1d_39 (Conv1D)           (None, 100, 256)          98560
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 50, 256)           0
# _________________________________________________________________
# conv1d_40 (Conv1D)           (None, 50, 16)            12304
# _________________________________________________________________
# conv1d_41 (Conv1D)           (None, 50, 32)            1568
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 50, 64)            6208
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 50, 128)           24704
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 28)                179228
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 4, 7)              0
# =================================================================
# Total params: 597,308
# Trainable params: 597,308
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
batch_size = 256

model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(1e-3), metrics=['mae'])

history = model.fit(
        X_train,
        y_train,
        validation_split=.1,
        epochs = epochs,
        batch_size = batch_size,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=10, factor=0.7, min_lr=1e-5)
        ]
    ).history
# Out:
# Epoch 1/100
# 241/241 [==============================] - 17s 65ms/step - loss: 0.0225 - mae: 0.1062 - val_loss: 0.0106 - val_mae: 0.0763
# Epoch 2/100
# 241/241 [==============================] - 15s 63ms/step - loss: 0.0081 - mae: 0.0656 - val_loss: 0.0062 - val_mae: 0.0567
# Epoch 3/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0060 - mae: 0.0561 - val_loss: 0.0054 - val_mae: 0.0526
# Epoch 4/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0052 - mae: 0.0519 - val_loss: 0.0048 - val_mae: 0.0494
# Epoch 5/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0047 - mae: 0.0493 - val_loss: 0.0043 - val_mae: 0.0468
# Epoch 6/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0049 - val_mae: 0.0520
# Epoch 7/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0040 - mae: 0.0456 - val_loss: 0.0041 - val_mae: 0.0469
# Epoch 8/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0036 - mae: 0.0437 - val_loss: 0.0035 - val_mae: 0.0429
# Epoch 9/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0033 - mae: 0.0419 - val_loss: 0.0030 - val_mae: 0.0404
# Epoch 10/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0029 - mae: 0.0396 - val_loss: 0.0027 - val_mae: 0.0383
# Epoch 11/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0027 - mae: 0.0381 - val_loss: 0.0028 - val_mae: 0.0397
# Epoch 12/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0024 - mae: 0.0356 - val_loss: 0.0023 - val_mae: 0.0350
# Epoch 13/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0022 - mae: 0.0343 - val_loss: 0.0021 - val_mae: 0.0339
# Epoch 14/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0020 - mae: 0.0330 - val_loss: 0.0020 - val_mae: 0.0328
# Epoch 15/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0019 - mae: 0.0317 - val_loss: 0.0018 - val_mae: 0.0310
# Epoch 16/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0017 - mae: 0.0305 - val_loss: 0.0022 - val_mae: 0.0355
# Epoch 17/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0016 - mae: 0.0298 - val_loss: 0.0016 - val_mae: 0.0291
# Epoch 18/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0015 - mae: 0.0284 - val_loss: 0.0015 - val_mae: 0.0289
# Epoch 19/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0015 - mae: 0.0284 - val_loss: 0.0015 - val_mae: 0.0285
# Epoch 20/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0014 - val_mae: 0.0279
# Epoch 21/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0014 - val_mae: 0.0275
# Epoch 22/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0013 - mae: 0.0261 - val_loss: 0.0014 - val_mae: 0.0274
# Epoch 23/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0012 - mae: 0.0256 - val_loss: 0.0013 - val_mae: 0.0268
# Epoch 24/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0011 - mae: 0.0247 - val_loss: 0.0012 - val_mae: 0.0256
# Epoch 25/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0012 - val_mae: 0.0250
# Epoch 26/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 27/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0011 - val_mae: 0.0243
# Epoch 28/100
# 241/241 [==============================] - 15s 62ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0011 - val_mae: 0.0245
# Epoch 29/100
# 241/241 [==============================] - 15s 62ms/step - loss: 9.7543e-04 - mae: 0.0227 - val_loss: 0.0011 - val_mae: 0.0250
# Epoch 30/100
# 241/241 [==============================] - 15s 62ms/step - loss: 9.8439e-04 - mae: 0.0228 - val_loss: 0.0011 - val_mae: 0.0238
# Epoch 31/100
# 241/241 [==============================] - 15s 62ms/step - loss: 9.4018e-04 - mae: 0.0223 - val_loss: 0.0011 - val_mae: 0.0238
# Epoch 32/100
# 241/241 [==============================] - 15s 62ms/step - loss: 9.6160e-04 - mae: 0.0226 - val_loss: 0.0010 - val_mae: 0.0232
# Epoch 33/100
# 241/241 [==============================] - 15s 62ms/step - loss: 9.3319e-04 - mae: 0.0222 - val_loss: 0.0011 - val_mae: 0.0238
# Epoch 34/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.7580e-04 - mae: 0.0214 - val_loss: 0.0011 - val_mae: 0.0247
# Epoch 35/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.7450e-04 - mae: 0.0214 - val_loss: 9.5666e-04 - val_mae: 0.0223
# Epoch 36/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.8073e-04 - mae: 0.0215 - val_loss: 0.0010 - val_mae: 0.0232
# Epoch 37/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.5976e-04 - mae: 0.0212 - val_loss: 9.0883e-04 - val_mae: 0.0218
# Epoch 38/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.4266e-04 - mae: 0.0210 - val_loss: 9.1537e-04 - val_mae: 0.0219
# Epoch 39/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.1611e-04 - mae: 0.0206 - val_loss: 9.1575e-04 - val_mae: 0.0217
# Epoch 40/100
# 241/241 [==============================] - 15s 62ms/step - loss: 8.0204e-04 - mae: 0.0204 - val_loss: 9.5314e-04 - val_mae: 0.0225
# Epoch 41/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.9359e-04 - mae: 0.0203 - val_loss: 9.4799e-04 - val_mae: 0.0222
# Epoch 42/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.9626e-04 - mae: 0.0203 - val_loss: 8.7470e-04 - val_mae: 0.0212
# Epoch 43/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.8168e-04 - mae: 0.0201 - val_loss: 9.4932e-04 - val_mae: 0.0225
# Epoch 44/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.7412e-04 - mae: 0.0200 - val_loss: 8.5828e-04 - val_mae: 0.0211
# Epoch 45/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.4066e-04 - mae: 0.0195 - val_loss: 8.5224e-04 - val_mae: 0.0210
# Epoch 46/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.5380e-04 - mae: 0.0197 - val_loss: 8.8320e-04 - val_mae: 0.0215
# Epoch 47/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.5025e-04 - mae: 0.0197 - val_loss: 9.6551e-04 - val_mae: 0.0230
# Epoch 48/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.5564e-04 - mae: 0.0198 - val_loss: 8.2033e-04 - val_mae: 0.0204
# Epoch 49/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.4036e-04 - mae: 0.0196 - val_loss: 9.5898e-04 - val_mae: 0.0225
# Epoch 50/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.2583e-04 - mae: 0.0193 - val_loss: 7.6436e-04 - val_mae: 0.0197
# Epoch 51/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.9033e-04 - mae: 0.0188 - val_loss: 8.3124e-04 - val_mae: 0.0206
# Epoch 52/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.1299e-04 - mae: 0.0192 - val_loss: 8.8237e-04 - val_mae: 0.0214
# Epoch 53/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.1364e-04 - mae: 0.0192 - val_loss: 8.8035e-04 - val_mae: 0.0215
# Epoch 54/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.0224e-04 - mae: 0.0190 - val_loss: 8.1099e-04 - val_mae: 0.0204
# Epoch 55/100
# 241/241 [==============================] - 15s 62ms/step - loss: 7.0201e-04 - mae: 0.0190 - val_loss: 7.3864e-04 - val_mae: 0.0193
# Epoch 56/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.6907e-04 - mae: 0.0184 - val_loss: 7.9415e-04 - val_mae: 0.0201
# Epoch 57/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.7776e-04 - mae: 0.0186 - val_loss: 8.0970e-04 - val_mae: 0.0204
# Epoch 58/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.6468e-04 - mae: 0.0184 - val_loss: 7.9122e-04 - val_mae: 0.0202
# Epoch 59/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.6795e-04 - mae: 0.0185 - val_loss: 7.9676e-04 - val_mae: 0.0202
# Epoch 60/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.6735e-04 - mae: 0.0185 - val_loss: 7.7961e-04 - val_mae: 0.0199
# Epoch 61/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.5879e-04 - mae: 0.0183 - val_loss: 7.5934e-04 - val_mae: 0.0196
# Epoch 62/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.3368e-04 - mae: 0.0179 - val_loss: 8.2134e-04 - val_mae: 0.0208
# Epoch 63/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.4736e-04 - mae: 0.0181 - val_loss: 8.2869e-04 - val_mae: 0.0208
# Epoch 64/100
# 241/241 [==============================] - 15s 63ms/step - loss: 6.5055e-04 - mae: 0.0182 - val_loss: 7.3481e-04 - val_mae: 0.0195
# Epoch 65/100
# 241/241 [==============================] - 15s 62ms/step - loss: 6.4082e-04 - mae: 0.0180 - val_loss: 7.2463e-04 - val_mae: 0.0191
# Epoch 66/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.3087e-04 - mae: 0.0160 - val_loss: 6.2299e-04 - val_mae: 0.0174
# Epoch 67/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.0800e-04 - mae: 0.0156 - val_loss: 6.1117e-04 - val_mae: 0.0171
# Epoch 68/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.0923e-04 - mae: 0.0157 - val_loss: 6.2633e-04 - val_mae: 0.0175
# Epoch 69/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.3088e-04 - mae: 0.0161 - val_loss: 6.4232e-04 - val_mae: 0.0179
# Epoch 70/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.3062e-04 - mae: 0.0161 - val_loss: 6.2847e-04 - val_mae: 0.0174
# Epoch 71/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.1153e-04 - mae: 0.0158 - val_loss: 6.0903e-04 - val_mae: 0.0170
# Epoch 72/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.1059e-04 - mae: 0.0158 - val_loss: 6.3705e-04 - val_mae: 0.0176
# Epoch 73/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.2171e-04 - mae: 0.0160 - val_loss: 6.3396e-04 - val_mae: 0.0175
# Epoch 74/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.2519e-04 - mae: 0.0161 - val_loss: 6.4006e-04 - val_mae: 0.0177
# Epoch 75/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.0761e-04 - mae: 0.0157 - val_loss: 6.7936e-04 - val_mae: 0.0183
# Epoch 76/100
# 241/241 [==============================] - 15s 62ms/step - loss: 5.1682e-04 - mae: 0.0159 - val_loss: 7.0237e-04 - val_mae: 0.0190
# Epoch 77/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.5724e-04 - mae: 0.0147 - val_loss: 5.7046e-04 - val_mae: 0.0163
# Epoch 78/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4651e-04 - mae: 0.0145 - val_loss: 5.8448e-04 - val_mae: 0.0166
# Epoch 79/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4890e-04 - mae: 0.0145 - val_loss: 5.6704e-04 - val_mae: 0.0163
# Epoch 80/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4633e-04 - mae: 0.0145 - val_loss: 5.8649e-04 - val_mae: 0.0167
# Epoch 81/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4564e-04 - mae: 0.0145 - val_loss: 5.9563e-04 - val_mae: 0.0170
# Epoch 82/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4621e-04 - mae: 0.0146 - val_loss: 5.7022e-04 - val_mae: 0.0164
# Epoch 83/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4671e-04 - mae: 0.0146 - val_loss: 5.8255e-04 - val_mae: 0.0166
# Epoch 84/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4989e-04 - mae: 0.0147 - val_loss: 5.8461e-04 - val_mae: 0.0167
# Epoch 85/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4596e-04 - mae: 0.0146 - val_loss: 5.8122e-04 - val_mae: 0.0167
# Epoch 86/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.4205e-04 - mae: 0.0145 - val_loss: 5.8087e-04 - val_mae: 0.0165
# Epoch 87/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.0727e-04 - mae: 0.0137 - val_loss: 5.3549e-04 - val_mae: 0.0156
# Epoch 88/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.0098e-04 - mae: 0.0136 - val_loss: 5.3561e-04 - val_mae: 0.0156
# Epoch 89/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.0106e-04 - mae: 0.0136 - val_loss: 5.4004e-04 - val_mae: 0.0158
# Epoch 90/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.9947e-04 - mae: 0.0136 - val_loss: 5.5712e-04 - val_mae: 0.0161
# Epoch 91/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.0286e-04 - mae: 0.0137 - val_loss: 5.4181e-04 - val_mae: 0.0158
# Epoch 92/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.0191e-04 - mae: 0.0137 - val_loss: 5.5063e-04 - val_mae: 0.0161
# Epoch 93/100
# 241/241 [==============================] - 15s 62ms/step - loss: 4.0086e-04 - mae: 0.0137 - val_loss: 5.4456e-04 - val_mae: 0.0158
# Epoch 94/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.9899e-04 - mae: 0.0136 - val_loss: 5.3569e-04 - val_mae: 0.0157
# Epoch 95/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.9792e-04 - mae: 0.0136 - val_loss: 5.4114e-04 - val_mae: 0.0158
# Epoch 96/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.9648e-04 - mae: 0.0136 - val_loss: 5.5426e-04 - val_mae: 0.0161
# Epoch 97/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.7433e-04 - mae: 0.0131 - val_loss: 5.1807e-04 - val_mae: 0.0152
# Epoch 98/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.7068e-04 - mae: 0.0130 - val_loss: 5.2382e-04 - val_mae: 0.0154
# Epoch 99/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.7108e-04 - mae: 0.0130 - val_loss: 5.1954e-04 - val_mae: 0.0153
# Epoch 100/100
# 241/241 [==============================] - 15s 62ms/step - loss: 3.7049e-04 - mae: 0.0130 - val_loss: 5.2738e-04 - val_mae: 0.0155

# %%
future_window = 864

# %%
def autoregression_pred_multiout(model,window,future,future_window):
    last_window = X_scaled[-window:]
    last_window = np.expand_dims(last_window, axis=0)
    pred = model.predict(last_window)
    last_window.shape, pred.shape
    pred = np.array([])
    X_temp = last_window
    for t in range(0,future_window,future):
        pred_temp = model.predict(X_temp)
        #pred_temp = np.expand_dims(pred_temp, axis=0)
        if(len(pred)==0):
            pred = pred_temp
        else:
            pred = np.concatenate((pred,pred_temp),axis=1)
        X_temp = np.concatenate((X_temp[:,future:,:],pred_temp), axis=1)

    pred_scaled = pred[0]*(X_max-X_min)+X_min
    return pred_scaled

# %%
pred = autoregression_pred_multiout(model,sequence_length,future,future_window)

# %%
window = sequence_length
for i in range(pred.shape[-1]):
    plt.figure(figsize=(20,5))
    plt.plot(range(window),X[-window:,i],color='steelblue')
    plt.plot(range(window,window+future_window),pred[:,i],color='lightblue')
    plt.axhline(y=X_mean[i],color='darkorange',linestyle='-')
    plt.axhline(y=X_mean[i]+X_std[i],color='magenta',linestyle='--',alpha=.5)
    plt.axhline(y=X_mean[i]-X_std[i],color='magenta',linestyle='--',alpha=.5)

# %%
#for i in range(pred_scaled.shape[-1]):
#    plt.figure(figsize=(20,5))
#    plt.plot(range(window),train_scaled[-window:,i])
#    plt.plot(range(window,window+future_window),val_scaled[:future_window,i])
#    plt.plot(range(window,window+future_window),pred[0,:,i])

# %%
best_epoch = np.argmin(history['val_loss'])
fig_size = (15,5)
plt.figure(figsize=fig_size)
plt.plot(history['loss'], label='Training loss', alpha=.8, color='darkorange')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.5, ls='--', color='green')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='darkorange')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=fig_size)
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='steelblue')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='green')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# SCORE 4.0981531143, same with no state and no layer norm

# %%
model.save('model')
#model = tfk.models.load_model('model')
# !zip -r model.zip model
# Out:
# 2022-01-18 21:02:31.538372: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
#   adding: model/ (stored 0%)
#   adding: model/saved_model.pb (deflated 90%)
#   adding: model/assets/ (stored 0%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.index (deflated 74%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 10%)
#   adding: model/keras_metadata.pb (deflated 95%)
